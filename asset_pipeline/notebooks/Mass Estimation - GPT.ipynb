# %%
import csv
with open("/scr/ig_pipeline/metadata/category_mapping.csv", "r") as f:
    category_list = list(csv.DictReader(f))
with open("/scr/bddl/bddl/generated_data/synsets.csv", "r") as f:
    synset_list = list(csv.DictReader(f))
synset_mapping = {s["synset"]: s for s in synset_list}

# %%
assert len(synset_mapping) == len(synset_list)

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package wordnet to /home/cgokmen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import string

raw_prompt = "Give me the estimated average mass of each of the below listed objects in JSON format, where the key is the object and the value is the mass in kilograms. Output only the JSON - no additional conversation.\n\n"

valid_chars = set(string.ascii_lowercase) | {" "}
def valid_name(s):
    return True
    return all(c in valid_chars for c in s)

# %%
from getpass import getpass
OPENAI_API_TOKEN = getpass()
# Out:
# ········

# %%
if False:
    from langchain.chat_models import ChatOpenAI
    from langchain.schema import HumanMessage
    import os
    os.environ["OPENAI_API_KEY"] = OPENAI_API_TOKEN
    llm = ChatOpenAI()

    from tqdm.notebook import tqdm
    messages = []
    for chunk_msg in tqdm(chunk_messages):
        messages.append(llm([HumanMessage(content=chunk_msg)]))

    import json
    gpt35_results = {}
    for message in messages:
        gpt35_results.update({json.loads(message.dict()["content"]))

# %%
GPT_MISSING = [c for c in category_list if c["category"].replace("_", " ") not in gpt4_responses]
MISSING_BATCH = GPT_MISSING[:75]
message = raw_prompt

for c in MISSING_BATCH:
    cat = c["category"]
    friendly_cat = cat.replace("_", " ")
    assert valid_name(friendly_cat), f"{cat} is not alphabetical."
    synset_name = c["synset"]

    try:
        s = synset_mapping[synset_name]
        friendly_synset_name = synset_name.split(".n.")[0].replace("_", " ")
        definition = wn.synset(synset_name).definition()
    except:
        # Get the parent's definition
        parent = s["hypernyms"].split(",")[0]
        friendly_synset_name = parent.split(".n.")[0].replace("_", " ")
        definition = wn.synset(parent).definition()

    assert valid_name(friendly_synset_name), f"{friendly_synset_name} is not alphabetical."
    message += f'"{friendly_cat}": a kind of "{friendly_synset_name}", {definition}\n'
    
print(len(GPT_MISSING) / 75)
print(message)
# Out:
# 0.38666666666666666
# Give me the estimated average mass of each of the below listed objects in JSON format, where the key is the object and the value is the mass in kilograms. Output only the JSON - no additional conversation.
#
# "packing box": a kind of "packing box", a large crate in which goods are packed for shipment or storage
# "plant pot stand": a kind of "rack", a support for displaying various articles
# "slingback": a kind of "slingback", a shoe that has a strap that wraps around the heel
# "walking shoe": a kind of "walking shoe", a light comfortable shoe designed for vigorous walking
# "set triangle": a kind of "square", a hand tool consisting of two straight arms at right angles; used to construct or test right angles
# "box of shampoo": a kind of "grocery", (usually plural) consumer goods sold by a grocer
# "bottle of alcohol": a kind of "grocery", (usually plural) consumer goods sold by a grocer
# ...

# %%
gpt4_responses = {
    "ceilings": "varies",
    "walls": "varies",
    "floors": "varies",
    "armchair": 20,
    "basket": 1,
    "bathtub": 110,
    "bed": 50,
    "bench": 25,
    "bottom cabinet": 50,
    "bottom cabinet no top": 40,
    "breakfast table": 10,
    "burner": 0.5,
    "carpet": "varies",
    "chaise longue": 30,
    "chest": 20,
    "coffee maker": 2.5,
    "coffee table": 15,
    "console table": 15,
    "countertop": "varies",
    "crib": 30,
    "desk": 40,
    "dishwasher": 45,
    "door": 35,
    "floor lamp": 5,
    "folding chair": 4.5,
    "fridge": 75,
    "gaming table": 50,
    "grandfather clock": 50,
    "guitar": 2,
    "heater": 8,
    "highchair": 8,
    "laptop": 2,
    "loudspeaker": 15,
    "microwave": 15,
    "mirror": "varies",
    "monitor": 5,
    "oven": 65,
    "pedestal table": 15,
    "piano": 200,
    "picture": "varies",
    "pillow": 1.5,
    "pool table": 250,
    "pot plant": "varies",
    "rail fence": "varies",
    "range hood": 15,
    "rocking chair": 15,
    "shelf": "varies",
    "shower": "varies",
    "sink": 25,
    "sofa": 45,
    "speaker system": 20,
    "stand": 7,
    "standing tv": 20,
    "stool": 4,
    "stove": 75,
    "straight chair": 7,
    "swivel chair": 15,
    "table lamp": 2.5,
    "toilet": 35,
    "top cabinet": 40,
    "towel rack": 1.5,
    "trash can": 2,
    "treadmill": 80,
    "wall clock": 1,
    "wall mounted tv": 20,
    "washer": 75,
    "window": "varies",
    "apple": 0.15,
    "apricot": 0.04,
    "artichoke": 0.2,
    "banana": 0.12,
    "beet": 0.175,
    "bell pepper": 0.15,
    "bowl": 0.4,
    "broccoli": 0.3,
    "bucket": 1,
    "bulldog clip": 0.01,
    "bulletin board": "varies",
    "egg": 0.05,
    "eggplant": 0.15,
    "frying pan": 1.0,
    "glass": 0.4,
    "gooseberry": 0.01,
    "grape": 0.005,
    "grater": 0.3,
    "griddle": 2.0,
    "half apple": 0.1,
    "half chestnut": 0.01,
    "half coconut fruit": 0.3,
    "half lemon": 0.06,
    "half mushroom": 0.01,
    "half orange": 0.075,
    "half pineapple": 1.0,
    "half plum": 0.03,
    "half pomegranate": 0.2,
    "half pomelo": 0.5,
    "half beefsteak tomato": 0.125,
    "head cabbage": 1.0,
    "honing steel": 0.3,
    "jar": 0.5,
    "kettle": 1.0,
    "kitchen analog scale": 1.0,
    "kiwi": 0.075,
    "lemon": 0.12,
    "lettuce": 0.5,
    "lid": 0.2,
    "mat": 1.0,
    "mug": 0.4,
    "mushroom": 0.02,
    "olive": 0.005,
    "bottle of olive oil": 1.0,
    "orange": 0.15,
    "paper clip": 0.001,
    "paper towel": 0.01,
    "paper towel holder": 0.5,
    "parsley": 0.02,
    "pea": 0.002,
    "peach": 0.15,
    "pear": 0.18,
    "pen": 0.01,
    "pencil": 0.01,
    "pencil box": 0.2,
    "pepper grinder": 0.5,
    "pineapple": 2.0,
    "pistachio": 0.001,
    "plum": 0.07,
    "pomegranate": 0.4,
    "pomelo": 1.0,
    "pop case": 5.0,
    "potato": 0.2,
    "pumpkin": 4.0,
    "radish": 0.02,
    "raspberry": 0.003,
    "rosehip": 0.005,
    "saucepan": 1.5,
    "soup ladle": 0.15,
    "spatula": 0.1,
    "spinach": 0.03,
    "spoon": 0.05,
    "sticky note": 0.005,
    "straight pin": 0.001,
    "strawberry": 0.015,
    "sweet corn": 0.25,
    "table knife": 0.08,
    "tablefork": 0.07,
    "teapot": 1.0,
    "thumbtack": 0.001,
    "toasting fork": 0.1,
    "tongs": 0.2,
    "vidalia onion": 0.15,
    "candy cane": 0.028,
    "shampoo": 0.4,
    "candle": 0.2,
    "folderal": 0.5,
    "light bulb": 0.03,
    "wall socket": 0.15,
    "bell": 1,
    "baseboard": 2,
    "plywood": 25,
    "tile": 1.8,
    "clout nail": 0.01,
    "hinge": 0.075,
    "screwdriver": 0.15,
    "pocketknife": 0.15,
    "hardback": 1,
    "notebook": 0.5,
    "hairbrush": 0.1,
    "chili": 0.045,
    "hamburger": 0.2,
    "tray": 0.5,
    "toothpick": 0.0004,
    "plate": 0.6,
    "dart": 0.02,
    "dartboard": 3.5,
    "blender": 1.5,
    "straw": 0.0012,
    "folder": 0.25,
    "calculator": 0.1,
    "necklace": 0.05,
    "bracelet": 0.03,
    "ring": 0.015,
    "cup": 0.3,
    "platter": 1.5,
    "cauldron": 5,
    "coffee cup": 0.35,
    "bow": 0.05,
    "wreath": 1,
    "chopstick": 0.02,
    "sushi": 0.075,
    "sheet": 0.5,
    "broom": 1,
    "carpet sweeper": 2.5,
    "coat": 1,
    "jeans": 0.7,
    "paintbrush": 0.05,
    "pajamas": 0.3,
    "pegboard": 10,
    "scrub brush": 0.35,
    "sock": 0.065,
    "trowel": 0.4,
    "vacuum": 5,
    "umbrella": 0.5,
    "toaster": 1.5,
    "iron": 1.3,
    "hook": 0.02,
    "car": 1500,
    "drill": 1.5,
    "dustpan": 0.25,
    "lawn mower": 30,
    "painting": 3,
    "bottle of powder": 1.2,
    "rake": 1.5,
    "scraper": 0.5,
    "ladder": 10,
    "toothbrush": 0.02,
    "chicken": 1.5,
    "dress": 0.5,
    "hanger": 0.1,
    "pork": 1,
    "rib": 0.3,
    "steak": 0.35,
    "jar of sugar": 1.5,
    "crab": 0.6,
    "fillet": 0.2,
    "magazine": 0.25,
    "newspaper": 0.1,
    "muffin": 0.1,
    "ice cube": 0.03,
    "cinnamon": 0.2,
    "lime": 0.13,
    "almond": 0.002,
    "grill": 15,
    "bagel": 0.085,
    "baguette": 0.25,
    "basil": 0.005,
    "celery": 0.4,
    "cupcake": 0.1,
    "green onion": 0.015,
    "lasagna": 0.85,
    "duffel bag": 7.5,
    "facsimile": 8.0,
    "gingerbread": 0.045,
    "lipstick": 0.03,
    "lollipop": 0.028,
    "modem": 0.4,
    "printer": 7.2,
    "scanner": 5.5,
    "stocking": 0.05,
    "watch": 0.08,
    "carton": 0.3,
    "briefcase": 2.5,
    "tea bag": 0.002,
    "shoulder bag": 1.0,
    "paper bag": 0.02,
    "backpack": 1.0,
    "eames chair": 8.0,
    "shower stall": 90.0,
    "soap dispenser": 0.4,
    "toilet paper": 0.227,
    "room light": 2.5,
    "architectural plan": 0.05,
    "urinal": 25.0,
    "bicycle": 15.0,
    "square light": 2.5,
    "downlight": 1.0,
    "toilet paper dispenser": 1.5,
    "vending machine": 400.0,
    "desktop computer": 7.0,
    "magazine rack": 5.0,
    "motorcycle": 180.0,
    "locker": 25.0,
    "photocopier": 100.0,
    "shredder": 8.0,
    "sign": 4.5,
    "conference table": 70.0,
    "cart": 15.0,
    "electric mixer": 2.0,
    "paper towel dispenser": 3.0,
    "wall mounted shelf": 4.0,
    "jug": 1.0,
    "commercial kitchen sink": 50.0,
    "commercial kitchen table": 60.0,
    "room ventilator": 7.0,
    "deep fryer": 15.0,
    "metal bottom cabinet": 30.0,
    "gravy boat": 0.5,
    "croissant": 0.065,
    "flower": 0.1,
    "electric switch": 0.2,
    "pillar": 1000.0,
    "chess set": 2.5,
    "cloche": 1.0,
    "wall mounted soap dispenser": 1.0,
    "cleaver": 1.0,
    "can of corn": 0.425,
    "booth": 100.0,
    "boiler": 10.0,
    "food slicer": 7.0,
    "fire extinguisher": 9.0,
    "jukebox": 100.0,
    "pay phone": 27.0,
    "menu": 0.05,
    "pepper shaker": 0.15,
    "salt shaker": 0.15,
    "bar": 1000.0,
    "chandelier": 15.0,
    "popcorn machine": 20.0,
    "beer tap": 2.5,
    "ceiling air conditioner": 20.0,
    "phonograph record": 0.38,
    "hanging plant": 2.0,
    "room divider": 20.0,
    "lantern": 1.0,
    "cake stand": 1.5,
    "skeletal frame": 50.0,
    "ottoman": 15.0,
    "counter": 50.0,
    "key chain": 0.05,
    "arched window": 40.0,
    "curtain": 2.0,
    "handle": 0.2,
    "l shaped handle": 0.25,
    "wall mounted light": 2.0,
    "pasta server": 0.1,
    "handset": 0.3,
    "potato masher": 0.2,
    "skimmer": 0.1,
    "whisk": 0.1,
    "bunch of bananas": 1.25,
    "wok": 2.0,
    "ceiling rack": 10.0,
    "arbor": 80.0,
    "binder": 1.0,
    "freezer": 70.0,
    "canister": 1.0,
    "shopping basket": 0.5,
    "kebab": 0.2,
    "bag of cocoa": 0.5,
    "paper cup": 0.01,
    "box of granola bars": 0.5,
    "box of rice": 1.0,
    "tissue dispenser": 0.3,
    "bottle of water": 1.0,
    "security camera": 1.5,
    "open air cooler": 35.0,
    "umbrella rack": 10.0,
    "snack rack": 10.0,
    "oden cooker": 3.0,
    "crock pot": 3.0,
    "greenery": 0.1,
    "box of beer": 7.0,
    "coaster": 0.05,
    "wineglass": 0.2,
    "credit card terminal": 1.0,
    "cash register": 10.0,
    "bedding": 5.0,
    "showerhead": 0.5,
    "bush": 15.0,
    "hand dryer": 2.5,
    "vase": 1.0,
    "window blind": 1.5,
    "flat bench": 15.0,
    "free weight": 10.0,
    "free weight rack": 20.0,
    "ceiling fan": 7.0,
    "weight bar": 10.0,
    "soda cup": 0.02,
    "exercise bike": 35.0,
    "elliptical machine": 80.0,
    "spotlight": 1.0,
    "hot tub": 200.0,
    "fence": 50.0,
    "water glass": 0.2,
    "dessert stand": 1.5,
    "turnstile": 100.0,
    "checkout counter": 50.0,
    "box of candy": 0.5,
    "candle holder": 1.0,
    "bottle of whiskey": 1.5,
    "bouquet": 0.75,
    "fragrance decanter": 1.0,
    "massage bed": 100.0,
    "wine fridge": 50.0,
    "sauna heater": 10.0,
    "beer glass": 0.4,
    "jam dispenser": 2.0,
    "soap dish": 0.2,
    "grocery shelf": 30.0,
    "grocery cupboard": 20.0,
    "sauna bench": 30.0,
    "statue": 100.0,
    "hammam bench": 30.0,
    "bag of rice": 1.0,
    "carton of eggs": 0.6,
    "mango": 0.2,
    "microscope": 6.0,
    "test tube rack": 0.5,
    "test tube": 0.05,
    "gate": 30.0,
    "plant stem": 0.05,
    "garden light": 2.0,
    "fire sprinkler": 1.0,
    "blackboard": 10.0,
    "blackboard eraser": 0.05,
    "round bottom flask": 0.5,
    "buret": 0.1,
    "candy dispenser shelf": 15.0,
    "dry food dispenser shelf": 15.0,
    "drinking fountain": 50.0,
    "bottle of pop": 1.0,
    "can of soda": 0.355,
    "projector": 3.0,
    "ceiling mounted projector": 3.0,
    "table runner": 0.2,
    "durian": 2.0,
    "alarm clock": 0.5,
    "place mat": 0.1,
    "bidet": 25.0,
    "wafer": 0.01,
    "chocolate bar": 0.1,
    "graduated cylinder": 0.2,
    "box of oatmeal": 0.5,
    "display case": 40.0,
    "pack of cigarettes": 0.02,
    "desk organizer": 1.0,
    "cubicle": 200.0,
    "desk phone": 1.0,
    "erlenmeyer flask": 0.2,
    "bed screen": 10.0,
    "first aid kit": 1.0,
    "hospital bed": 100.0,
    "gym mat": 10.0,
    "globe": 1.0,
    "pedestal": 20.0,
    "tree": 500.0,
    "ceiling mounted basketball hoop": 15.0,
    "pommel horse": 30.0,
    "parallel bars": 75.0,
    "scoreboard": 50.0,
    "butter": 0.227,
    "caliper": 0.3,
    "canned food": 0.4,
    "cantaloup": 1.1,
    "carafe": 0.5,
    "carrot": 0.06,
    "carving knife": 0.2,
    "casserole": 1.3,
    "cherry": 0.01,
    "chestnut": 0.01,
    "chip": 0.005,
    "chives": 0.005,
    "chopping board": 0.7,
    "clove": 0.003,
    "coatrack": 5,
    "colander": 0.4,
    "cruet": 0.3,
    "cucumber": 0.3,
    "digital scale": 1,
    "dinner napkin": 0.02,
    "dipper": 0.1,
    "dish rack": 1,
    "walnut": 0.015,
    "watermelon": 9,
    "whiteboard": 7,
    "bottle of wine": 1.2,
    "zucchini": 0.2,
    "gym shoe": 0.4,
    "video game": 0.1,
    "board game": 1.2,
    "walker": 2.5,
    "sandal": 0.3,
    "hat": 0.1,
    "bottle of protein powder": 1.1,
    "keyboard": 0.9,
    "headset": 0.3,
    "mouse": 0.1,
    "hard drive": 0.6,
    "hammer": 1.5,
    "glove": 0.1,
    "bath towel": 0.6,
    "dishtowel": 0.1,
    "hand towel": 0.1,
    "toy": 0.2,
    "envelope": 0.01,
    "box of chocolates": 0.5,
    "soap": 0.15,
    "box of crackers": 0.25,
    "ball": 0.43,
    "t shirt": 0.2,
    "mousetrap": 0.1,
    "pretzel": 0.03,
    "prosciutto": 0.05,
    "razor": 0.05,
    "tinsel": 0.02,
    "christmas tree": 30,
    "christmas tree decorated": 32,
    "fire alarm": 0.2,
    "comb": 0.02,
    "dental floss": 0.01,
    "document": 0.02,
    "volleyball net": 11.3,
    "lab table": 45,
    "display fridge": 130,
    "bookcase": 30.8,
    "funnel": 0.05,
    "gooseneck microphone": 1,
    "magnetic stirrer": 2.5,
    "classroom mock up": 100,
    "elevator door": 90,
    "information bulletin": 0.05,
    "saucepot": 1.5,
    "stockpot": 2.5,
    "specimen bottle": 0.2,
    "pencil holder": 0.1,
    "periodic table": 2.3,
    "petri dish": 0.025,
    "clipboard": 0.4,
    "test tube holder": 0.15,
    "paperback book": 0.28,
    "paper sheet": 0.005,
    "saucer": 0.1,
    "webcam": 0.1,
    "spirit lamp": 0.3,
    "buret clamp": 0.3,
    "flask clamp": 0.3,
    "test tube clamp": 0.15,
    "playground": 50000,
    "sandbox": 1000,
    "toy box": 2,
    "toilet paper holder": 0.5,
    "electric fan": 2,
    "terrarium": 5,
    "trophy": 2,
    "lab exhaust hood": 50,
    "water cooler": 20,
    "map": 0.1,
    "garden plant": 1,
    "bottle of champagne": 1.4,
    "pill bottle": 0.05,
    "sculpture": 20,
    "picture frame": 1,
    "bench press machine": 80,
    "pine cone": 0.05,
    "sound system": 10,
    "camera": 0.5,
    "drink dispenser": 3,
    "bun": 0.05,
    "eyeglasses": 0.03,
    "seashell": 0.02,
    "structural element": 500,
    "swing": 25,
    "shopping cart": 20,
    "box of sake": 1.5,
    "bottle of sake": 1.2,
    "motion sensor": 0.2,
    "hair dryer": 0.5,
    "fireplace": 800,
    "rock": 10,
    "tiramisu": 0.5,
    "storage box": 1,
    "chalice": 0.5,
    "reagent bottle": 1,
    "marker": 0.02,
    "wall mounted loudspeaker": 3,
    "projection screen": 10,
    "stadium stand": 10000,
    "notepad": 0.2,
    "stairs": 200,
    "lawn": 5000,
    "blanket": 1.5,
    "background": 5,
    "soccer ball": 0.43,
    "hammock": 3,
    "fairy light": 0.5,
    "railing": 10,
    "cigar": 0.02,
    "stapler": 0.25,
    "ivy": 2,
    "bamboo": 2,
    "garden umbrella": 8,
    "weed": 0.2,
    "hall tree": 20,
    "pergola": 100,
    "candy": 0.02,
    "rose": 1,
    "garage door": 80,
    "knife block": 2,
    "garden chair": 5,
    "postcard": 0.006,
    "coffee bean": 0.001,
    "paper coffee filter": 0.003,
    "colored pencil": 0.006,
    "comic book": 0.2,
    "joystick": 0.4,
    "cookie cutter": 0.05,
    "bottle of orange juice": 1.2,
    "hair spray": 0.4,
    "corkscrew": 0.075,
    "mannequin": 15,
    "ceremonial robe": 1.5,
    "shoe": 0.4,
    "cotton ball": 0.0015,
    "cranberry": 0.002,
    "lobster": 0.6,
    "crayon": 0.01,
    "crouton": 0.002,
    "sliced cucumber": 0.025,
    "chopped lettuce": 0.025,
    "crystal": 1,
    "bottle": 0.5,
    "garden coffee table": 10,
    "garden statue": 50,
    "driveway": 5000,
    "hanging banners": 1,
    "decoration": 0.3,
    "nightstand": 10,
    "suitcase": 4.5,
    "teaspoon": 0.02,
    "wardrobe": 50,
    "pestle": 0.5,
    "skirt": 0.2,
    "hourglass": 0.3,
    "pants": 0.5,
    "drawer unit": 30,
    "ashtray": 0.4,
    "tennis racket": 0.3,
    "poster": 0.05,
    "fennel": 0.2,
    "curtain rod": 2,
    "bottle of coke": 1.5,
    "mint leaf": 0.001,
    "cymbal": 1,
    "dahlia flower": 0.03,
    "flower petal": 0.001,
    "spray bottle": 0.4,
    "decanter": 1,
    "dehumidifier": 10,
    "denture": 0.025,
    "diamond": 0.003,
    "diaper": 0.1,
    "dice": 0.006,
    "dowel": 0.02,
    "dried apricot": 0.005,
    "bay leaf": 0.002,
    "drumstick": 0.2,
    "drumset": 20,
    "duct tape": 0.3,
    "dumpling": 0.025,
    "zhenglong": 3,
    "dutch oven": 5,
    "mattress": 35,
    "easter egg": 0.05,
    "electric hand mixer": 1.5,
    "electric kettle": 1.2,
    "feather": 0.001,
    "sliced chocolate cake": 0.075,
    "firewood": 4,
    "fishing rod": 0.5,
    "flag pole": 10,
    "flashlight": 0.2,
    "fountain": 2000,
    "frame": 1.5,
    "french fry holder": 0.05,
    "french fries": 0.075,
    "french toast": 0.1,
    "garlic": 0.045,
    "beer keg": 72,
    "coffee grinder": 1.2,
    "geode": 2,
    "gift box": 0.5,
    "bottle of gin": 1.3,
    "granola bar": 0.045,
    "dreidel": 0.015,
    "dried cranberry": 0.001,
    "goggles": 0.2,
    "french press": 0.97,
    "heap of granola": 0.5,
    "heap of raisins": 0.43,
    "heap of oatmeal": 0.45,
    "grapefruit": 0.35,
    "heap of gravel": 1500,
    "green bean": 0.01,
    "portafilter": 0.8,
    "hamster wheel": 0.5,
    "haystack": 200,
    "hazelnut": 0.002,
    "heatgun": 1,
    "basil leaf": 0.001,
    "hockey puck": 0.17,
    "hiking boot": 1.2,
    "hockey stick": 0.6,
    "hoe": 2,
    "hoodie": 0.7,
    "hotdog frank": 0.075,
    "hotdog bun": 0.05,
    "ice bucket": 1,
    "ironing board": 6,
    "jade roller": 0.15,
    "jelly bean": 0.002,
    "quilt": 2.5,
    "jersey": 0.3,
    "jigger": 0.15,
    "kale": 0.5,
    "juicer": 2,
    "keys": 0.022,
    "meringue": 0.03,
    "kayak": 20,
    "paddle": 1,
    "holly decoration": 0.5,
    "jade": 2,
    "work helmet": 1.4,
    "air conditioner": 25,
    "allen wrench": 0.1,
    "antlers": 3,
    "apple pie": 1,
    "apron": 0.2,
    "arugula": 0.01,
    "asparagus": 0.1,
    "avocado": 0.2,
    "axe": 2.5,
    "baby bottle": 0.1,
    "bacon": 1,
    "bait": 0.02,
    "baking sheet": 1.5,
    "balloon": 0.002,
    "bandage": 0.02,
    "bandana": 0.1,
    "baseball": 0.145,
    "baseball bat": 1,
    "baseball cap": 0.1,
    "baseball glove": 0.7,
    "bath rug": 1.4,
    "battery": 0.2,
    "batting gloves": 0.15,
    "bedsheet": 1.5,
    "beeswax candle": 0.2,
    "bikini": 0.1,
    "birdcage": 1.5,
    "birdseed": 0.025,
    "biscuit": 0.05,
    "blouse": 0.2,
    "blueberry": 0.002,
    "blueberry mousse": 0.2,
    "bobby pin": 0.002,
    "book case": 30.0,
    "bookend": 0.5,
    "bowling ball": 6.35,
    "box": 0.42,
    "boxing gloves": 0.45,
    "bra": 0.1,
    "branch": 1.0,
    "bratwurst": 0.15,
    "bread": 1.0,
    "breadcrumb": 0.0005,
    "brisket": 5.0,
    "brownie": 0.05,
    "brussels sprouts": 0.015,
    "bottle of bug repellent": 0.35,
    "bulb": 0.03,
    "burrito": 0.5,
    "butternut squash": 1.5,
    "candied yam": 0.2,
    "can of coffee": 1.0,
    "can of sardines": 0.2,
    "can of tomatoes": 0.4,
    "canvas": 1.0,
    "cardigan": 0.4,
    "cardstock": 0.02,
    "cauliflower": 1.2,
    "ceramic tile": 2.0,
    "chalk": 0.05,
    "charcoal": 0.5,
    "charcoal grill": 10.0,
    "chard": 0.5,
    "cheese danish": 0.075,
    "cherry tomato": 0.02,
    "chicken breast": 0.2,
    "chicken coop": 50.0,
    "chicken leg": 0.15,
    "chicken thigh": 0.15,
    "chicken wing": 0.03,
    "chili pepper": 0.01,
    "china": 1.0,
    "chisel": 0.5,
    "chocolate chip": 0.002,
    "chorizo": 0.15,
    "cigarette": 0.001,
    "cinnamon stick": 0.01,
    "clamp": 0.5,
    "clothesline": 0.5,
    "compost bin": 10.0,
    "cooler": 2.0,
    "crawfish": 0.05,
    "credit card": 0.005,
    "cutting board": 1.5,
    "bottle of dish soap": 0.8,
    "dog food": 15.0,
    "donut": 0.05,
    "drying rack": 3.0,
    "duck": 1.0,
    "easel": 5.0,
    "firewood grate": 15.0,
    "food processor": 4.0,
    "fuel can": 1.0,
    "goalkeeper gloves": 0.1,
    "goblet": 0.3,
    "golf club": 1.0,
    "green tea": 0.002,
    "gunpowder": 0.7,
    "hanging basket": 2.0,
    "headstone": 113.4,
    "inhaler": 0.05,
    "instant pot": 5,
    "jacket": 0.8,
    "letter": 0.028,
    "life jacket": 0.7,
    "lighter": 0.02,
    "lighter fluid": 0.2,
    "lingerie": 0.1,
    "lint roller": 0.07,
    "lip balm": 0.015,
    "litter box": 1.5,
    "log": 30,
    "longboard": 3.5,
    "loofah": 0.02,
    "magnifying glass": 0.1,
    "mailbox": 6,
    "marshmallow": 0.007,
    "face mask": 0.03,
    "match": 0.001,
    "match box": 0.02,
    "measuring cup": 0.2,
    "measuring tape": 0.15,
    "meat thermometer": 0.05,
    "microfiber cloth": 0.08,
    "microphone": 0.4,
    "mint": 0.002,
    "mixing bowl": 0.8,
    "mortar": 1.3,
    "moth ball": 0.005,
    "mulch": 1000,
    "mussel": 0.05,
    "name tag": 0.01,
    "nativity figurine": 0.3,
    "necktie": 0.15,
    "nectarine": 0.15,
    "nickel": 0.005,
    "noodle": 0.005,
    "okra": 0.03,
    "omelet": 0.2,
    "onesie": 0.2,
    "outlet": 0.1,
    "oyster": 0.1,
    "pallet": 25,
    "papaya": 1,
    "paper liners": 0.005,
    "paraffin wax": 0.5,
    "feta": 0.2,
    "parsnip": 0.15,
    "pastry cutter": 0.1,
    "paver": 5,
    "pea pod": 0.02,
    "peanut": 0.001,
    "pearl": 0.0005,
    "pencil case": 0.1,
    "pennant": 0.1,
    "penny": 0.0025,
    "pet bed": 1.5,
    "cell phone": 0.174,
    "pickle": 0.03,
    "pickup truck": 1800,
    "pill": 0.001,
    "pillowcase": 0.2,
    "pipe cleaner": 0.01,
    "pitcher": 0.6,
    "pizza": 0.8,
    "pizza box": 0.2,
    "plant pot": 0.7,
    "plastic bag": 0.015,
    "plier": 0.25,
    "plug": 0.05,
    "poker": 0.5,
    "pole": 4,
    "polo shirt": 0.2,
    "pork chop": 0.2,
    "pork rib": 0.45,
    "power drill": 1.5,
    "power strip": 0.7,
    "pressure cooker": 2.2,
    "pump": 15,
    "punching bag": 25,
    "putty knife": 0.1,
    "jigsaw puzzle": 0.7,
    "jigsaw puzzle piece": 0.005,
    "quail breast": 0.06,
    "quail breast raw": 0.06,
    "quail leg": 0.02,
    "quarter": 0.00567,
    "quartz": 2.65,
    "radio": 1.2,
    "raincoat": 0.7,
    "raspberries": 0.002,
    "retainer": 0.01,
    "rhubarb": 0.6,
    "rice cooker": 2.7,
    "risotto": 0.4,
    "sliced roast beef": 0.2,
    "roasting pan": 1.2,
    "rolling pin": 1.5,
    "rope": 1.4,
    "rosemary": 0.001,
    "ruler": 0.02,
    "rutabaga": 0.8,
    "salmon": 1,
    "sandals": 0.3,
    "sauna suit": 0.7,
    "scone": 0.07,
    "scrambled eggs": 0.1,
    "screw": 0.01,
    "shaker": 0.2,
    "shoe box": 0.3,
    "shortening": 0.5,
    "shorts": 0.3,
    "shovel": 1.8,
    "shrimp": 0.04,
    "shutter": 5,
    "silver coins": 0.025,
    "skates": 1.8,
    "ski": 2.5,
    "smoker": 45,
    "sneakers": 0.7,
    "snow globe": 1,
    "socks": 0.1,
    "sod": 15,
    "softball": 0.2,
    "spaghetti": 0.1,
    "sparkler": 0.02,
    "sponge": 0.015,
    "squid": 0.4,
    "star anise": 0.01,
    "steamer basket": 0.5,
    "steel wool": 0.017,
    "sticker": 0.001,
    "strawberries": 0.012,
    "stroller": 9,
    "sunflower": 1,
    "sunglasses": 0.03,
    "sweatshirt": 0.3,
    "syringe": 0.02,
    "tablet": 0.5,
    "tackle box": 1.5,
    "taco": 0.1,
    "tag": 0.001,
    "tank top": 0.15,
    "tarp": 1.8,
    "tassel": 0.005,
    "teacup": 0.2,
    "teddy bear": 0.5,
    "tennis ball": 0.057,
    "tent": 4,
    "textbook": 1.5,
    "thermostat": 0.125,
    "ticket": 0.002,
    "tights": 0.1,
    "toolbox": 4.0,
    "tortilla": 0.025,
    "tortilla chips": 0.002,
    "tote": 0.7,
    "toy train": 1.2,
    "trailer": 2000.0,
    "trombone": 3.6,
    "trumpet": 1.3,
    "tulip": 0.03,
    "tuna": 30.0,
    "tupperware": 0.2,
    "twine": 0.05,
    "utility knife": 0.2,
    "valentine wreath": 1.0,
    "vest": 0.5,
    "violin": 0.6,
    "violin case": 2.5,
    "bottle of vodka": 1.5,
    "waffle": 0.075,
    "waffle maker": 1.8,
    "wallet": 0.2,
    "wallpaper": 1.0,
    "water dispenser": 2.5,
    "water filter": 0.5,
    "watering can": 0.3,
    "white chocolate": 0.1,
    "whitewall tire": 10.0,
    "wire cutter": 0.3,
    "wrapping paper": 0.5,
    "zipper": 0.01,
    "bottle of lemon juice": 1.0,
    "bar soap": 0.15,
    "bottle of liquid soap": 1.2,
    "cocktail glass": 0.2,
    "drip pot": 1.0,
    "pool stick": 0.5,
    "pool ball": 0.17,
    "date": 0.02,
    "cap": 0.1,
    "shelf back panel": 5.0,
    "shelf shelf": 10.0,
    "shelf top": 8.0,
    "shelf baseboard": 3.0,
    "shelf side": 4.0,
    "bottle of beer": 0.9,
    "box of cereal": 0.5,
    "bag of chips": 0.2,
    "coconut fruit": 1.4,
    "bottle of cologne": 0.5,
    "boxed cpu board": 0.7,
    "bottle of detergent": 2.5,
    "ginger root": 0.12,
    "boxed ink cartridge": 0.2,
    "jar of jam": 0.7,
    "tube of lotion": 0.2,
    "jar of mayonnaise": 0.9,
    "bottle of medicine": 0.2,
    "jug of milk": 2.3,
    "bucket of paint": 6.0,
    "pack of pasta": 1.0,
    "bottle of perfume": 0.3,
    "wading pool": 7.0,
    "pack of protein powder": 1.0,
    "jar of puree": 0.7,
    "boxed router": 0.5,
    "jar of spaghetti sauce": 1.0,
    "bottle of sunscreen": 0.2,
    "tube of toothpaste": 0.2,
    "cup of yogurt": 0.25,
    "bag of cookies": 0.5,
    "diced green onion": 0.05,
    "hose cart": 30,
    "jar of grains": 1.5,
    "paint roller": 0.5,
    "salad bowl": 0.7,
    "half watermelon": 4.5,
    "box of flour": 2.3,
    "bottle of apple juice": 1.5,
    "bag of auricularia": 0.5,
    "bag of shiitake": 0.5,
    "bottle of barbecue sauce": 0.8,
    "box of brown sugar": 0.5,
    "box of cane sugar": 0.5,
    "box of corn flakes": 0.5,
    "box of lasagna": 0.5,
    "box of milk": 1,
    "box of sanitary napkins": 0.2,
    "box of tissues": 0.2,
    "box of yogurt": 1,
    "bottle of carrot juice": 1.5,
    "bottle of catsup": 1,
    "bottle of garlic sauce": 1,
    "bottle of hot sauce": 0.3,
    "bottle of lime juice": 1.5,
    "bottle of pesto": 0.3,
    "box of tomato juice": 1.5,
    "bottle of tomato paste": 0.4,
    "pack of bread": 0.5,
    "bottle of coffee": 1,
    "bottle of milk": 1,
    "bottle of soup": 1,
    "box of fruit": 2,
    "box of lemons": 2,
    "box of raspberries": 0.5,
    "bag of flour": 2.3,
    "bottle of ginger beer": 1.5,
    "bottle of lemon sauce": 1,
    "can of baking mix": 0.5,
    "box of baking mix": 0.5,
    "bottle of mushroom sauce": 1,
    "can of oatmeal": 0.5,
    "jar of orange sauce": 1,
    "box of apple juice": 1.5,
    "bag of cream cheese": 0.5,
    "bag of ice cream": 1,
    "bottle of lemonade": 1.5,
    "bottle of papaya juice": 1.5,
    "bottle of soy milk": 1,
    "bottle of tonic": 1.5,
    "box of ice cream": 1,
    "box of salt": 1.3,
    "can of icetea": 0.35,
    "carton of milk": 1,
    "carton of orange juice": 1,
    "carton of pineapple juice": 1,
    "pack of chocolate bar": 0.1,
    "bottle of coconut water": 1,
    "box of cream": 0.3,
    "bottle of fruit punch": 1.5,
    "bottle of lotion": 0.2,
    "bag of popcorn": 0.3,
    "boxed cake": 0.5,
    "box of champagne": 1.5,
    "box of rum": 1,
    "box of whiskey": 1,
    "box of wine": 1.5,
    "box of butter": 0.5,
    "carton of soy milk": 1,
    "carton of chocolate milk": 1.0,
    "box of coffee": 0.454,
    "pack of ramen": 0.085,
    "bottle of rum": 1.4,
    "bottle of soda": 1.0,
    "bottle of tea": 1.0,
    "box of vegetable juice": 1.0,
    "shampoo dispenser": 1.2,
    "conditioner dispenser": 1.2,
    "bag of tea": 0.1,
    "wrapped hamburger": 0.15,
    "bottle of mustard": 0.454,
    "isopropanol dispenser": 1.0,
    "bottle of cooking oil": 0.946,
    "can of tomato paste": 0.156,
    "roof": 10000.0,
    "bottle of shampoo": 0.5,
    "bottle of acetone": 1.0,
    "bottle of acid": 1.0,
    "bottle of vinegar": 1.0,
    "glue stick": 0.02,
    "bottle of glue": 0.15,
    "spray can": 0.25,
    "hamper": 1.0,
    "volleyball": 0.27,
    "loin": 2.0,
    "air filter": 0.5,
    "air freshener atomizer": 0.25,
    "bottle of alfredo sauce": 0.7,
    "algae": 0.01,
    "bottle of allspice": 0.15,
    "box of almond milk": 1.0,
    "bottle of antihistamines": 0.15,
    "bottle of apple cider": 1.0,
    "bottle of applesauce": 0.454,
    "arepa": 0.1,
    "ash": 1.0,
    "bottle of aspirin": 0.15,
    "bottle of baby oil": 0.2,
    "box of baking powder": 0.23,
    "box of baking soda": 0.454,
    "box of barley": 0.454,
    "can of bay leaves": 0.05,
    "bird feeder": 1.5,
    "bottle of bleach agent": 3.78,
    "bottle of brandy": 1.4,
    "bag of breadcrumbs": 0.23,
    "broccolini": 0.2,
    "bag of brown rice": 1.0,
    "bottle of buttermilk": 1.0,
    "cactus": 5.0,
    "calendar": 0.3,
    "cashew": 0.01,
    "catalog": 0.6,
    "bottle of caulk": 0.4,
    "cd": 0.015,
    "centerpiece": 2.0,
    "charger": 0.2,
    "cheesecake": 2.5,
    "bouillon cube": 0.01,
    "chicken tender": 0.05,
    "chicken wire": 3.0,
    "chickpea": 0.01,
    "bottle of chocolate sauce": 0.5,
    "cilantro": 0.05,
    "sliced lemon": 0.06,
    "bottle of cleaner": 1.5,
    "bottle of cocoa": 0.6,
    "box of coconut milk": 1.0,
    "bottle of coconut milk": 1.2,
    "bottle of coconut oil": 0.92,
    "copper wire": 0.015,
    "bottle of cranberry juice": 1.4,
    "bottle of skin cream": 0.2,
    "bottle of chili pepper": 0.15,
    "jar of cumin": 0.18,
    "jar of curry powder": 0.2,
    "bottle of degreaser": 0.95,
    "jar of dill seed": 0.05,
    "doll": 0.5,
    "bottle of essential oil": 0.15,
    "bottle of fabric softener": 1.8,
    "bottle of face cream": 0.25,
    "bottle of fennel": 0.15,
    "bag of fertilizer": 25.0,
    "bottle of food coloring": 0.05,
    "bottle of frosting": 0.5,
    "bottle of ginger": 0.2,
    "bottle of glass cleaner": 1.2,
    "bottle of ground cloves": 0.15,
    "bottle of ground mace": 0.15,
    "bottle of ground nutmeg": 0.15,
    "bottle of conditioner": 0.9,
    "icicle lights": 0.5,
    "jar of ink": 0.3,
    "kabob": 0.2,
    "skiff": 50.0,
    "farm stand": 60.0,
    "sourdough": 1.0,
    "toast": 0.05,
    "banana bread": 1.0,
    "hamburger bun": 0.075,
    "fruitcake": 2.0,
    "digital camera": 0.5,
    "pillar candle": 0.75,
    "cedar chest": 25.0,
    "key": 0.02,
    "bottle of lacquer": 0.6,
    "bottle of lavender oil": 0.15,
    "leaf": 0.002,
    "leaf blower": 3.6,
    "leek": 0.1,
    "legging": 0.2,
    "leotard": 0.2,
    "chocolate chip cookie": 0.025,
    "chocolate biscuit": 0.02,
    "butter cookie": 0.02,
    "bottle of sour cream": 0.5,
    "legal document": 0.05,
    "cookie dough": 1.5,
    "chocolate cake": 2.5,
    "cinnamon roll": 0.075,
    "clothes dryer": 50.0,
    "rubber eraser": 0.02,
    "license plate": 0.3,
    "sliced lime": 0.03,
    "lock": 0.3,
    "water faucet": 1.5,
    "skyrocket": 0.2,
    "national flag": 1.0,
    "canteen": 0.35,
    "bottle of lubricant": 0.5,
    "lunch box": 0.3,
    "mac and cheese": 0.5,
    "lily": 0.2,
    "macaron": 0.02,
    "mail": 0.1,
    "mallet": 1.0,
    "bottle of maple syrup": 1.36,
    "marigold": 0.1,
    "mashed potatoes": 0.2,
    "bottle of mayonnaise": 0.91,
    "rubber glove": 0.04,
    "bunchgrass": 0.5,
    "sliced melon": 0.5,
    "bottle of milkshake": 0.6,
    "bottle of cold cream": 0.5,
    "bottle of molasses": 1.43,
    "money": 0.01,
    "mop": 2.0,
    "mop bucket": 1.0,
    "mousepad": 0.1,
    "bottle of mustard seeds": 0.75,
    "bottle of oil": 0.91,
    "sliced onion": 0.15,
    "bottle of onion powder": 0.5,
    "storage organizer": 10.0,
    "bottle of paint remover": 1.0,
    "virginia ham": 5.0,
    "serving cart": 15.0,
    "jar of pepper": 0.2,
    "ruby": 0.001,
    "parer": 0.1,
    "buttermilk pancake": 0.08,
    "penne": 0.01,
    "conchiglie": 0.01,
    "ravioli": 0.03,
    "bottle of black pepper": 0.5,
    "sliced papaya": 0.3,
    "bottle of paprika": 0.5,
    "bottle of parsley": 0.5,
    "bottle of peanut butter": 0.5,
    "pecan": 0.005,
    "peppermint candy": 0.01,
    "bottle of pesticide": 1.0,
    "poop": 0.2,
    "pine nut": 0.001,
    "pipe": 2.0,
    "toy figure": 0.05,
    "swimming pool": 20000.0,
    "shoe rack": 5.0,
    "whiskey stone": 0.03,
    "boulder": 1000.0,
    "bottle of pizza sauce": 0.5,
    "jar of bath salt": 1.0,
    "club sandwich": 0.2,
    "pack of kielbasa": 1.0,
    "ripsaw": 1.0,
    "chainsaw": 7.0,
    "shears": 0.2,
    "dress shirt": 0.3,
    "bottle of poppy seeds": 0.5,
    "postage stamp": 0.0001,
    "bottle of seasoning": 0.5,
    "power washer": 7.5,
    "pruner": 1.0,
    "bottle of pumpkin pie spice": 0.5,
    "pumpkin seed": 0.001,
    "quiche": 0.5,
    "raisin": 0.001,
    "receipt": 0.001,
    "bottle of rosemary": 0.2,
    "bottle of sage": 0.2,
    "bottle of salsa": 0.68,
    "bottle of sangria": 1.25,
    "bottle of disinfectant": 1.1,
    "bottle of spice": 0.2,
    "saxophone": 2.5,
    "scoop": 0.15,
    "octopus": 0.3,
    "bottle of sealant": 1,
    "bottle of sesame oil": 0.9,
    "bottle of sesame seeds": 0.35,
    "shiitake": 0.025,
    "sieve": 0.2,
    "bottle of soy sauce": 1,
    "soybean": 0.0002,
    "bottle of paint": 2.5,
    "sprinkler": 0.5,
    "squeegee": 0.15,
    "bottle of sriracha": 0.68,
    "stake": 2,
    "staple": 0.0001,
    "bag of starch": 1,
    "bottle of solvent": 1,
    "sugar cube": 0.003,
    "sunflower seed": 0.0001,
    "bottle of supplements": 0.5,
    "bottle of almond oil": 0.9,
    "tablecloth": 1,
    "box of takeout": 1,
    "tank": 30000,
    "bottle of tea leaves": 0.2,
    "bottle of tequila": 1.4,
    "sliced tomato": 0.1,
    "bag of snacks": 0.5,
    "turkey": 7,
    "tweezers": 0.03,
    "van": 3000,
    "vegetable peeler": 0.08,
    "wheelbarrow": 20,
    "whetstone": 0.5,
    "whistle": 0.02,
    "wind chime": 1,
    "wood chip": 0.002,
    "bag of yeast": 0.5,
    "yoga mat": 1.5,
    "wooden spoon": 0.08,
    "tablespoon": 0.02,
    "taboret": 2,
    "echeveria elegans": 0.5,
    "crewneck sweater": 0.5,
    "maillot": 0.2,
    "cellulose tape": 0.2,
    "masking tape": 0.2,
    "cheese tart": 0.1,
    "tartlet": 0.05,
    "digital thermometer": 0.1,
    "cotton thread": 0.02,
    "car tire": 10,
    "beefsteak tomato": 0.2,
    "camera tripod": 1.5,
    "lorry": 8000,
    "tobacco pipe": 0.05,
    "white turnip": 0.2,
    "boxers": 0.1,
    "dip candle": 0.02,
    "open end wrench": 0.5,
    "black bean": 0.0002,
    "rubber boot": 1.5,
    "packing box": 5.0,
    "plant pot stand": 3.5,
    "slingback": 0.3,
    "walking shoe": 0.8,
    "set triangle": 0.1,
    "box of shampoo": 1.5,
    "bottle of alcohol": 1.0,
    "bottle of ammonia": 1.2,
    "radiator": 10.0,
    "box of cookies": 0.5,
    "can of beans": 0.4,
    "jar of jelly": 0.6,
    "blackberry": 0.002,
    "deodorant stick": 0.15,
    "bottle of deicer": 0.5,
    "dvd": 0.02,
    "ice tray": 0.2,
    "bag of oranges": 2.5,
    "vanilla flower": 0.0001,
    "jar of honey": 1.3,
    "clothesline pole": 3.0,
    "burlap bag": 0.2,
    "trout": 1.5,
    "case of eyeshadow": 0.05,
    "swiss cheese": 1.0,
    "peanut nut": 0.0001,
    "balsamic vinegar bottle": 0.75,
    "box of aluminium foil": 0.5,
}

# %%
for c in category_list:
    cat = c["category"]
    friendly_cat = cat.replace("_", " ")
    gpt3_result = gpt35_results.get(friendly_cat, "")
    try:
        gpt3_result = "%.3f" % float(gpt3_result)
    except Exception as e:
        gpt3_result = ""
    gpt4_result = gpt4_responses.get(friendly_cat, "")
    try:
        gpt4_result = "%.3f" % float(gpt4_result)
    except:
        gpt4_result = ""
    print(gpt3_result + "," + gpt4_result)
# Out:
# ,
# ,
# ,
# 25.000,20.000
# 5.000,1.000
# 150.000,110.000
# 50.000,50.000
# 30.000,25.000
# 50.000,50.000
# 30.000,40.000
# 40.000,10.000
# ,0.500
# ,
# 50.000,30.000
# 20.000,20.000
# 5.000,2.500
# 20.000,15.000
# 15.000,15.000
# ,
# 20.000,30.000
# 50.000,40.000
# 60.000,45.000
# ,35.000
# 5.000,5.000
# 5.000,4.500
# 100.000,75.000
# 60.000,50.000
# 100.000,50.000
# 5.000,2.000
# ,8.000
# 10.000,8.000
# 2.000,2.000
# 5.000,15.000
# 15.000,15.000
# 10.000,
# 5.000,5.000
# 50.000,65.000
# 40.000,15.000
# 200.000,200.000
# ,
# 1.000,1.500
# 250.000,250.000
# ,
# ,
# 20.000,15.000
# 25.000,15.000
# 10.000,
# 50.000,
# 30.000,25.000
# 100.000,45.000
# 20.000,20.000
# 5.000,7.000
# 25.000,20.000
# 3.000,4.000
# 50.000,75.000
# 5.000,7.000
# 8.000,15.000
# 2.000,2.500
# 30.000,35.000
# 40.000,40.000
# 2.000,1.500
# 5.000,2.000
# 100.000,80.000
# 2.000,1.000
# 20.000,20.000
# 70.000,75.000
# 20.000,
# 0.200,0.150
# 0.050,0.040
# 0.500,0.200
# 0.100,0.120
# 0.300,0.175
# 0.200,0.150
# ...

# %%
# print({x["category"].replace("_", " ") for x in category_list} - set(gpt35_results.keys()))
# gpt35_results["box of aluminium foil"] = gpt35_results["box  of  aluminium foil"]
# del gpt35_results["box  of  aluminium foil"]
# Out:
# {'pack of chocolate bar', 'pack of bread', 'agent'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 2
#       1 print({x["category"].replace("_", " ") for x in category_list} - set(gpt35_results.keys()))
# ----> 2 gpt35_results["box of aluminium foil"] = gpt35_results["box  of  aluminium foil"]
#       3 del gpt35_results["box  of  aluminium foil"]
#
# KeyError: 'box  of  aluminium foil'
