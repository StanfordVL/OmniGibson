# %%
from bddl.knowledge_base import *
# Out:
# Loading BDDL knowledge base... This may take a few seconds.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Cem\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Complained object qwoqqr does not exist in the database. Skipping.
# Complained object dnypbe does not exist in the database. Skipping.
# Complained object upmkjr does not exist in the database. Skipping.
# Complained object wmchsj does not exist in the database. Skipping.
# Complained object uqusgj does not exist in the database. Skipping.
# Complained object urmqxk does not exist in the database. Skipping.
# Complained object aginyz does not exist in the database. Skipping.
# Complained object pcpvvu does not exist in the database. Skipping.
# Complained object fveyao does not exist in the database. Skipping.
# Complained object knunaz does not exist in the database. Skipping.
# Complained object didlbp does not exist in the database. Skipping.
# ...

# %%
for ps in ParticleSystem.all_objects():
  for particle in ps.particles:
    if "substance" not in particle.provider:
      print(f"Particle {particle.name} in ParticleSystem {ps.name} has no substance provider.")
    if "scenes/" in particle.provider:
      print(f"Particle {particle.name} in ParticleSystem {ps.name} has a provider that is a scene, which is not allowed.")
# Out:
# Particle acjxoq in ParticleSystem alga has no substance provider.
# Particle voawxd in ParticleSystem almond has no substance provider.
# Particle kjjkii in ParticleSystem almond has no substance provider.
# Particle kkckpq in ParticleSystem almond has no substance provider.
# Particle mqxqgs in ParticleSystem almond has no substance provider.
# Particle ptcdjs in ParticleSystem almond has no substance provider.
# Particle pxsxoj in ParticleSystem almond has no substance provider.
# Particle vjruxb in ParticleSystem almond has no substance provider.
# Particle vmnhqj in ParticleSystem almond has no substance provider.
# Particle wywdvp in ParticleSystem almond has no substance provider.
# Particle acooui in ParticleSystem almond has no substance provider.
# Particle ozvqdx in ParticleSystem bird_feed has no substance provider.
# Particle ncvtfs in ParticleSystem black_bean has no substance provider.
# Particle mfkwzi in ParticleSystem black_bean has no substance provider.
# ...
