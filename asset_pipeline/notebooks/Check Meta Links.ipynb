# %%
import glob
import json

# %%
meta_links_by_obj = {}
for fn in glob.glob("/scr/BEHAVIOR-1K/asset_pipeline/cad/*/*/artifacts/object_list.json"):
    with open(fn) as f:
        meta_links_by_obj.update(json.load(f)["meta_links"])

# %%
meta_links_by_obj
# Out:
# {'ceilings-bpheuv': ['collision'],
#  'ceilings-bwcjal': ['collision'],
#  'ceilings-cmtgio': ['collision'],
#  'ceilings-hkpbtx': ['collision'],
#  'ceilings-holqmb': ['collision'],
#  'ceilings-jkgiww': ['collision'],
#  'ceilings-msnxsu': ['collision'],
#  'ceilings-odcayc': ['collision'],
#  'ceilings-pueokn': ['collision'],
#  'ceilings-qsqnsq': ['collision'],
#  'ceilings-sxfdbk': ['collision'],
#  'ceilings-unxwzc': ['collision'],
#  'ceilings-xcvxqs': ['collision'],
#  'ceilings-xqhgay': ['collision'],
#  'ceilings-yeqcqn': ['collision'],
#  'ceilings-ytbprd': ['collision'],
#  'floors-esoefs': ['collision'],
#  'floors-igemfx': ['collision'],
#  'floors-jciltq': ['collision'],
#  'floors-jmlrre': ['collision'],
#  'floors-nbzcbu': ['collision'],
#  'floors-nzidpe': ['collision'],
#  'floors-oskvfp': ['collision'],
#  'floors-owamxh': ['collision'],
#  'floors-qhmout': ['collision'],
#  'floors-qqdoab': ['collision'],
#  'floors-qzdhdl': ['collision'],
# ...
