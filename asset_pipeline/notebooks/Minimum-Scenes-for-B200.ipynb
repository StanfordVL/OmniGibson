# %%
import glob
from bddl.activity import Conditions
import pathlib
import re

# %%
# Load the combined list
import json
with open(r"C:\Users\cgokmen\Downloads\combined_room_object_list.json", "r") as f:
    scene_room_object_list = json.load(f)["scenes"]

# %%
import json, csv
from nltk.corpus import wordnet as wn
import networkx as nx
legit_synsets = {x.name() for x in wn.all_synsets()}

# Build the legit-synset graph
G = nx.DiGraph()
G.add_nodes_from(x.name() for x in wn.all_synsets())
for parent in wn.all_synsets():
    for child in parent.hyponyms():
        G.add_edge(parent.name(), child.name())
        
# Add the illegit-synset graph
with open(r"C:\Users\cgokmen\research\bddl\utils\custom_synsets.csv") as f:
    reader = csv.DictReader(f)
    for row in reader:
        child = row["custom_synset"].strip()
        parent = wn.synset(row["hypernyms"].strip()).name()
        assert parent in G.nodes, "Could not find " + parent
        G.add_edge(parent, child)

# %%
# Get the activity filename map
act_to_fn = {}

from_b1k = glob.glob(r"C:\Users\cgokmen\research\ObjectPropertyAnnotation\init_goal_cond_annotations\problem_files_verified_b1k\*")
from_b100 = glob.glob(r"C:\Users\cgokmen\research\bddl\bddl\activity_definitions\*")
for x in from_b1k + from_b100:
    p = pathlib.Path(x)
    if not p.is_dir():
        continue
    act_name = p.name.replace(" ", "_").replace("-", "_").replace("'", "_")
    if act_name in act_to_fn:
        print(f"Found duplicate for {act_name}")
    act_to_fn[act_name] = p
# Out:
# Found duplicate for packing_car_for_trip

# %%
starting_scenes = {"Rs_int", "Beechwood_0_int", "Wainscott_0_int", "Ihlen_0_int", "Merom_1_int", "house_single_floor"}

# %%
# The BEHAVIOR 200 activity list
activities = set("""throwing away leftovers
putting away toys
putting away Halloween decorations
fill a bucket in a small sink
pour a glass of wine
folding piece of cloth
cleaning bathtub
mowing the lawn
spraying for bugs
make a steak
make a strawberry slushie
freeze pies
chop an onion
bringing in kindling
bringing in mail
bringing newspaper in
bringing paper to recycling
bringing water
clean a wood pipe
collecting children's toys
dispose of a pizza box
dispose of batteries
dispose of glass
dispose of medication
dispose of paper
heating food up
heating soup
hiding Easter eggs
loading the car
opening doors
opening windows
organizing art supplies
organizing office documents
outfit a basic toolbox
pack a beach bag
pack a pencil case
pack your gym bag
packing books into car
packing cleaning suppies into car
packing documents into car
packing grocery bags into car
packing hiking equipment into car
packing hobby equipment
packing meal for delivery
packing moving van
packing picnic food into car
packing picnic into car
packing sports equipment into car
passing out drinks
picking up litter
picking up toys
picking vegetables in garden
place houseplants around your home
praeparing lunch box
prepare a breakfast bar
prepare a slow dinner party
prepare an emergency school kit
prepare and cook prawns
prepare and cook scallops
prepare grapefruit for serving
preparing food for a fundraiser
put together a scrapping tool kit
put togethera basic pruning kit
putting away games
putting away tools
putting backpack in car for school
putting bike in garage
putting meal in fridge at work
putting out cat food
putting out dog food
putting shoes on rack
recycling glass bottles
recycling newspapers
recycling office papers
setting up room for games
setup a baby crib
sorting art supplies
sorting household items
sorting potatoes
stacking wood
stock a bar
store batteries
store beer
store bobby pins
store brownies
store daffodil bulbs
store dahlia bulbs
store eggs
store firewood outdoors
store firewood
store honey
store nuts
store produce
store vodka
taking trash outside
throwing out used napkins
turn off a normal school calculator
turning on radio
turning sprinkler off
turning sprinkler on
unloading the car
unloading shopping from car
boxing food after dinner
can beans
carrying out garden furniture
carrying water
changing dog's water
cleaning restaurant table
unloading shopping items
toast-buns
toast coconut
toast sunflower seeds
thaw frozen fish
assembling gift baskets
bottling fruit
boxing books up for storage
bringing in wood
brushing lint off clothing
chopping vegetables
cleaning a car
cleaning barbecue grill
cleaning bathrooms
cleaning bedroom
cleaning carpets
cleaning closet
cleaning cupboards
cleaning floors
cleaning freezer
cleaning garage
cleaning high chair
cleaning kitchen cupboard
cleaning microwave oven
cleaning out drawers
cleaning oven
cleaning up refrigerator
cleaning shoes
cleaning sneakers
cleaning stove
cleaning table after clearing
cleaning the hot tub
cleaning the pool
cleaning toilet
cleaning up after a meal
cleaning up the kitchen only
cleaning windows
clearing the table after dinner
collect misplaced items
collecting aluminum cans
defrosting freezer
installing a fax machine
installing a modem
installing a printer
installing a scanner
installing alarms
laying tile floors
laying wood floors
loading the dishwasher
locking every door
locking every window
making tea
mopping floors
moving boxes to storage
organizing boxes in garage
organizing file cabinet
organizing school stuff
packing adult's bags
packing bags or suitcase
packing boxes for household move or trip
packing child's bag
packing food for work
packing lunches
picking up take-out food
picking up trash
polishing furniture
polishing shoes
polishing silver
preserving food
putting away Christmas decorations
putting dishes away after cleaning
putting leftovers away
putting up Christmas decorations inside
re-shelving library books
rearranging furniture
serving a meal
serving hors d'oeuvres
setting mousetraps
sorting groceries
sorting mail
storing food
storing the groceries
thawing frozen food
unpacking suitcase
vacuuming floors
washing cars or other vehicles
washing dishes
washing floor
washing pots and pans
watering houseplants
waxing cars or other vehicles
can_syrup
can_vegetables
canning_food
clean_a_lobster
cleaning_parks
cleaning_the_yard
cleaning_up_plates_and_food
clearing_table_after_breakfast
clearing_table_after_coffee
clearing_table_after_dinner
clearing_table_after_snacks
clearing_table_after_supper
collecting_mail_from_the_letterbox
delivering_groceries_to_doorstep
emptying_trash_cans
gathering_nuts
make_bento
make_gift_bags_for_baby_showers
packing_car_for_trip
packing_recreational_vehicle_for_trip
pouring_water_in_a_glass
prepare_a_raised_bed_garden
putting_away_yard_equipment
set_up_a_coffee_station_in_your_kitchen
setting_up_for_an_event
setting_up_room_for_a_movie
setup_a_fish_tank
sorting_bottles,_cans,_and_paper
store_an_uncooked_turkey
store_silver_coins
store_tulip_bulbs
unloading_groceries""".replace(" ", "_").replace("-", "_").replace("'", "_").split("\n"))
# activities = set(act_to_fn.keys())

missing_acts = set(activities) - set(act_to_fn.keys())
print("Total acts", len(activities))
print("Missing acts", len(missing_acts))
assert not missing_acts, "Missing acts: " + str(missing_acts)
# Out:
# Total acts 231
# Missing acts 0

# %%
scene_mapping = {}
with open(r"D:\ig_pipeline\metadata\b1k_activity_to_preselected_scenes.csv", newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        name = row["activity_name"].strip().replace(" ", "_").replace("-", "_").replace("'", "_")
        task_scenes = []
        for i in range(3):
            scene = row[f"scene{i}"].strip()
            if scene:
                task_scenes.append(scene)
        assert name and task_scenes, f"Failed for {name}"
        scene_mapping[name] = task_scenes
with open(r"D:\ig_pipeline\metadata\b100_activity_to_preselected_scenes.json") as f:
    mapping = json.load(f)
    for task, scenes in mapping.items():
        name = task.strip().replace(" ", "_").replace("-", "_").replace("'", "_")
        scene_mapping[name] = scenes
    
activities_found_in_mapping = set(scene_mapping.keys())
missing_mappings = activities - activities_found_in_mapping
# assert not missing_mappings, f"Missing mappings: {missing_mappings}"

# %%
import collections
from nltk.corpus import wordnet as wn

def counts_for(child, parent):  
    try:
        if nx.has_path(G, parent, child):
            return True
        else:
            c = wn.synset(child).name()
            p = wn.synset(parent).name()
            return nx.has_path(G, p, c)
    except Exception as e:
        # print(e)
        return False

def room_has_requirements(room_contents, room_reqs, verbose=False):
    success = True
    for req_name, req_number in room_reqs.items():
        found_stuff_for_req = 0
        for content_name, content_cnt in room_contents.items():
            if counts_for(content_name, req_name):
                found_stuff_for_req += content_cnt
                
        if found_stuff_for_req < req_number:
            if verbose:
                print(f"            Scene contains {found_stuff_for_req} {req_name} while {req_number} is required.")
            success = False
    return success

def any_room_has_requirements(s, required_rm, required_stuff, verbose=False):
    scene_contents = scene_room_object_list[s]
    matching_scene_rooms = [x for x in scene_contents.keys() if re.fullmatch("^" + required_rm + "_[0-9]+$", x)]
    for msr in matching_scene_rooms:
        if room_has_requirements(scene_contents[msr], required_stuff, verbose=verbose):
            return True
        else:
            if verbose:
                print(f"        {s}'s {msr} is not a match for {required_rm}")

    return False
            
def scene_compatible_with_task(s, task_requirements, verbose=False):
    requirements_by_rm = collections.defaultdict(collections.Counter)
    for obj, rm in task_requirements:
        assert not rm.endswith("_0")
        requirements_by_rm[rm.replace("_0", "")][obj] += 1
    
    for required_rm, required_stuff in requirements_by_rm.items():
        if not any_room_has_requirements(s, required_rm, required_stuff, verbose=verbose):
            if verbose:
                print(f"    Failed in {s} bc we couldn't find a suitable {required_rm}\n")
            return False
        
    return True

def evaluate_task(task_name, believe_assignments=False):
    task_file = act_to_fn[task_name] / "problem0.bddl"
    assert task_file.exists(), f"{task_name} file missing"
    with open(task_file, "r") as f:
        predefined_problem = "".join(f.readlines())
    # for m in re.findall("\(([A-Za-z_]+?) ", predefined_problem):
    #     if m not in pred_wl:
    #         return set()
    # init_states = predefined_problem.split(":init")[1].split(":goal")[0]
    # requirements = list(re.findall(r"\(inroom ([A-Za-z0-9_\.]+)_[0-9]+ ([A-Za-z0-9_\.]+)\)", init_states))
    dom = "omnigibson" if "ObjectPropertyAnnotation" in str(task_file) else "igibson"
    conds = Conditions(task_name, "potato", dom, predefined_problem=predefined_problem)
    objects = set(conds.parsed_objects.keys())
    raw_requirements = [cond[1:] for cond in conds.parsed_initial_conditions if cond[0] == "inroom"]
    assert all(len(req) == 2 for req in raw_requirements), task_name + ":" + str(raw_requirements)
    requirements = [(req.rsplit("_", 1)[0], rm) for req, rm in raw_requirements]
    good_scenes = {
        s for s in scene_room_object_list.keys() if scene_compatible_with_task(s, requirements)
    }
    if False:  # task_name in scene_mapping:
        assigned_scenes = set(scene_mapping[task_name]) & starting_scenes
        
        # Temporary forgiveness for things that do match something
        if good_scenes & starting_scenes or not assigned_scenes:
            return objects, good_scenes
        
        missing_assigned_scenes = assigned_scenes - set(good_scenes)
        error_type = "Complete" if missing_assigned_scenes == assigned_scenes else "Partial"
        unexpected_matches = set(good_scenes) - assigned_scenes
        unexpected_match_str = f"Unexpected matches: {unexpected_matches}" if unexpected_matches and missing_assigned_scenes == assigned_scenes else ""
        if missing_assigned_scenes:
            print(f"\n{error_type} mismatch: {task_name} is assigned {assigned_scenes} but {missing_assigned_scenes} do not match init criteria. {unexpected_match_str}")
            for s in missing_assigned_scenes:
                scene_compatible_with_task(s, requirements, verbose=True)
        
        if believe_assignments:
            return objects, good_scenes | assigned_scenes
    return objects, good_scenes

# %%
improved_scene_mapping = {x: evaluate_task(x, believe_assignments=False) for x in activities}
unmatched_acts = [act for act, (_, scenes) in improved_scene_mapping.items() if not scenes]
print(len(unmatched_acts))
print(unmatched_acts)
# Out:
# 15
# ['picking_up_toys', 'turn_off_a_normal_school_calculator', 'setup_a_baby_crib', 'turning_sprinkler_off', 'putting_backpack_in_car_for_school', 'turning_sprinkler_on', 'putting_meal_in_fridge_at_work', 'dispose_of_batteries', 'store_bobby_pins', 'organizing_office_documents', 'putting_away_games', 'stacking_wood', 'store_firewood_outdoors', 'unloading_shopping_items', 'toast_sunflower_seeds']

# %%
def get_tasks_possible_with_scenes(scene_set):
    b200_scene_mapping = {x: (improved_scene_mapping[x][0], set(improved_scene_mapping[x][1]) & scene_set) for x in activities if x in improved_scene_mapping}
    return {x: (objects, sorted(scenes)) for x, (objects, scenes) in b200_scene_mapping.items() if scenes}

# %%
print(len(get_tasks_possible_with_scenes({"house_single_floor"})))
print(len(get_tasks_possible_with_scenes({"house_single_floor", "Rs_int"})))
print(len(get_tasks_possible_with_scenes({"house_single_floor", "Wainscott_0_int"})))
print(len(get_tasks_possible_with_scenes({"house_single_floor", "Wainscott_0_int", "Rs_int"})))
print(len(get_tasks_possible_with_scenes({"Rs_int", "house_single_floor", "Wainscott_0_int", "Ihlen_0_int"})))
print(len(get_tasks_possible_with_scenes({"Rs_int", "Beechwood_0_int", "Wainscott_0_int", "Ihlen_0_int", "Merom_1_int", "house_single_floor"})))
# Out:
# 116
# 165
# 173
# 179
# 188
# 202

# %%
print("\n".join(str(x) for x in sorted(scene_mapping_repro.items())))
# Out:
# ('assembling_gift_baskets', ({'basket.n.01', 'cheese.n.01', 'agent.n.01', 'cookie.n.01', 'bow.n.08', 'floor.n.01', 'candle.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('bottling_fruit', ({'jar.n.01', 'strawberry.n.01', 'electric_refrigerator.n.01', 'peach.n.03', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'carving_knife.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('boxing_books_up_for_storage', ({'book.n.02', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'shelf.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Rs_int']))
# ('boxing_food_after_dinner', ({'electric_refrigerator.n.01', 'agent.n.01', 'leftovers.n.01', 'floor.n.01', 'breakfast_table.n.01', 'box.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('bringing_in_kindling', ({'lawn.n.01', 'bag.n.01', 'disinfectant.n.01', 'coffee_table.n.01', 'agent.n.01', 'floor.n.01', 'firewood.n.01', 'fireplace.n.01'}, ['house_single_floor']))
# ('bringing_in_mail', ({'lawn.n.01', 'coffee_table.n.01', 'agent.n.01', 'mail.n.04', 'floor.n.01', 'mailbox.n.01'}, ['house_single_floor']))
# ('bringing_in_wood', ({'plywood.n.01', 'agent.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('bringing_newspaper_in', ({'lawn.n.01', 'coffee_table.n.01', 'agent.n.01', 'floor.n.01', 'newspaper.n.03'}, ['house_single_floor']))
# ('bringing_paper_to_recycling', ({'bin.n.01', 'paper.n.01', 'agent.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('brushing_lint_off_clothing', ({'scrub_brush.n.01', 'sweater.n.01', 'agent.n.01', 'floor.n.01', 'bed.n.01'}, ['Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('can_beans', ({'can.n.01', 'cabinet.n.01', 'pot.n.01', 'agent.n.01', 'black_bean.n.01', 'floor.n.01', 'countertop.n.01', 'shelf.n.01'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('can_syrup', ({'stove.n.01', 'jar.n.01', 'cabinet.n.01', 'pot.n.01', 'maple_syrup.n.01', 'agent.n.01', 'lid.n.02', 'floor.n.01'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('can_vegetables', ({'stove.n.01', 'jar.n.01', 'vegetable.n.01', 'cooker.n.01', 'chopping_board.n.01', 'cabinet.n.01', 'pot.n.01', 'knife.n.01', 'agent.n.01', 'lid.n.02', 'floor.n.01', 'countertop.n.01'}, ['Wainscott_0_int']))
# ('canning_food', ({'jar.n.01', 'water.n.06', 'food.n.02', 'electric_refrigerator.n.01', 'cabinet.n.01', 'chopping_board.n.01', 'pot.n.01', 'knife.n.01', 'agent.n.01', 'sink.n.01', 'lid.n.02', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('carrying_out_garden_furniture', ({'lawn.n.01', 'barrow.n.03', 'lawn_chair.n.01', 'driveway.n.01', 'agent.n.01', 'floor.n.01'}, ['house_single_floor']))
# ('carrying_water', ({'water.n.06', 'backpack.n.01', 'agent.n.01', 'sink.n.01', 'bottle.n.01', 'floor.n.01', 'shelf.n.01'}, ['house_single_floor']))
# ('chop_an_onion', ({'water.n.06', 'onion.n.03', 'chopping_board.n.01', 'agent.n.01', 'knife.n.01', 'sink.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('chopping_vegetables', ({'tomato.n.01', 'electric_refrigerator.n.01', 'dish.n.01', 'cabinet.n.01', 'agent.n.01', 'chestnut.n.03', 'knife.n.01', 'sink.n.01', 'floor.n.01', 'countertop.n.01', 'vidalia_onion.n.01', 'mushroom.n.05'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('clean_a_lobster', ({'agent.n.01', 'knife.n.01', 'floor.n.01', 'bowl.n.01', 'lobster.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('clean_a_wood_pipe', ({'cleansing_agent.n.01', 'water.n.06', 'stain.n.01', 'towel.n.01', 'agent.n.01', 'sink.n.01', 'bottle.n.01', 'floor.n.01', 'pipe.n.02', 'countertop.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_a_car', ({'rag.n.01', 'car.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'bucket.n.01', 'shelf.n.01'}, ['Ihlen_0_int']))
# ('cleaning_barbecue_grill', ({'rag.n.01', 'grill.n.02', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'bucket.n.01', 'table.n.02'}, ['Ihlen_0_int']))
# ('cleaning_bathrooms', ({'rag.n.01', 'toilet.n.02', 'bathtub.n.01', 'agent.n.01', 'sink.n.01', 'brush.n.02', 'floor.n.01', 'soap.n.01', 'bucket.n.01'}, ['Merom_1_int', 'house_single_floor']))
# ('cleaning_bathtub', ({'bathtub.n.01', 'scrub_brush.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'bucket.n.01'}, ['Merom_1_int', 'house_single_floor']))
# ('cleaning_bedroom', ({'hand_towel.n.01', 'jewelry.n.01', 'painting.n.01', 'apparel.n.01', 'sheet.n.03', 'cabinet.n.01', 'agent.n.01', 'vacuum.n.04', 'floor.n.01', 'bed.n.01', 'perfume.n.02'}, ['Merom_1_int']))
# ('cleaning_carpets', ({'hand_towel.n.01', 'cabinet.n.01', 'agent.n.01', 'dryer.n.01', 'sink.n.01', 'washer.n.03', 'floor.n.01', 'door.n.01', 'shampoo.n.01'}, ['Beechwood_0_int', 'house_single_floor']))
# ('cleaning_cupboards', ({'book.n.02', 'bin.n.01', 'rag.n.01', 'cleansing_agent.n.01', 'scrub_brush.n.01', 'cabinet.n.01', 'agent.n.01', 'pen.n.01', 'floor.n.01', 'screwdriver.n.01', 'bed.n.01', 'marker.n.03', 'bucket.n.01'}, ['Merom_1_int']))
# ('cleaning_floors', ({'cleansing_agent.n.01', 'scrub_brush.n.01', 'agent.n.01', 'broom.n.01', 'sink.n.01', 'floor.n.01', 'dustpan.n.02', 'door.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_freezer', ({'stove.n.01', 'food.n.01', 'cleansing_agent.n.01', 'electric_refrigerator.n.01', 'towel.n.01', 'chair.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'door.n.01', 'countertop.n.01', 'table.n.02'}, ['Wainscott_0_int']))
# ('cleaning_garage', ({'box.n.01', 'bin.n.01', 'rag.n.01', 'shelf.n.01', 'cabinet.n.01', 'agent.n.01', 'broom.n.01', 'bottle.n.01', 'table.n.02', 'sink.n.01', 'floor.n.01', 'newspaper.n.03'}, ['Ihlen_0_int']))
# ('cleaning_high_chair', ({'piece_of_cloth.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'highchair.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_kitchen_cupboard', ({'cleansing_agent.n.01', 'piece_of_cloth.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'countertop.n.01', 'cup.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('cleaning_microwave_oven', ({'microwave.n.02', 'rag.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'ashcan.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('cleaning_out_drawers', ({'piece_of_cloth.n.01', 'cabinet.n.01', 'agent.n.01', 'spoon.n.01', 'sink.n.01', 'floor.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_oven', ({'rag.n.01', 'oven.n.01', 'scrub_brush.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'receptacle.n.01', 'soap.n.01', 'newspaper.n.03'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_parks', ({'lawn.n.01', 'agent.n.01', 'recycling_bin.n.01', 'bottle.n.01', 'floor.n.01'}, ['house_single_floor']))
# ('cleaning_shoes', ({'rag.n.01', 'towel.n.01', 'agent.n.01', 'shoe.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'bed.n.01'}, ['Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_sneakers', ({'gym_shoe.n.01', 'towel.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'brush.n.02', 'floor.n.01', 'soap.n.01', 'countertop.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('cleaning_stove', ({'stove.n.01', 'rag.n.01', 'dishtowel.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_table_after_clearing', ({'dishtowel.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_the_hot_tub', ({'pool.n.01', 'scrub_brush.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01'}, ['Ihlen_0_int', 'house_single_floor']))
# ('cleaning_the_pool', ({'pool.n.01', 'scrub_brush.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'detergent.n.02', 'shelf.n.01'}, ['Ihlen_0_int']))
# ('cleaning_the_yard', ({'fence.n.01', 'shrub.n.01', 'compost__container.n.01', 'weed.n.01', 'agent.n.01', 'recycling_bin.n.01', 'leaf.n.01', 'floor.n.01', 'yard.n.02'}, ['house_single_floor']))
# ('cleaning_toilet', ({'toilet.n.02', 'scrub_brush.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'detergent.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_up_after_a_meal', ({'dishwasher.n.01', 'detergent.n.02', 'plate.n.04', 'chair.n.01', 'agent.n.01', 'sink.n.01', 'sack.n.01', 'floor.n.01', 'hamburger.n.01', 'cup.n.01', 'bowl.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int']))
# ('cleaning_up_plates_and_food', ({'bin.n.01', 'rice.n.01', 'plate.n.04', 'agent.n.01', 'pizza.n.01', 'container.n.01', 'floor.n.01', 'aluminum_foil.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('cleaning_up_refrigerator', ({'rag.n.01', 'electric_refrigerator.n.01', 'tray.n.01', 'cabinet.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'countertop.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('cleaning_up_the_kitchen_only', ({'bin.n.01', 'rag.n.01', 'vegetable_oil.n.01', 'electric_refrigerator.n.01', 'plate.n.04', 'blender.n.01', 'cabinet.n.01', 'dustpan.n.02', 'apple.n.01', 'window.n.01', 'agent.n.01', 'broom.n.01', 'sink.n.01', 'floor.n.01', 'casserole.n.02', 'soap.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('cleaning_windows', ({'rag.n.01', 'cleansing_agent.n.01', 'cabinet.n.01', 'window.n.01', 'towel.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('clearing_table_after_breakfast', ({'water.n.06', 'electric_refrigerator.n.01', 'plate.n.04', 'agent.n.01', 'sink.n.01', 'leftovers.n.01', 'floor.n.01', 'shelf.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('clearing_table_after_coffee', ({'agent.n.01', 'floor.n.01', 'coffee_maker.n.01', 'dishwasher.n.01', 'countertop.n.01', 'mug.n.04'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('clearing_table_after_dinner', ({'electric_refrigerator.n.01', 'plate.n.04', 'agent.n.01', 'spinach.n.02', 'floor.n.01', 'chicken.n.01', 'breakfast_table.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('clearing_table_after_snacks', ({'electric_refrigerator.n.01', 'plate.n.04', 'agent.n.01', 'apple.n.01', 'chocolate.n.02', 'floor.n.01', 'breakfast_table.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('clearing_table_after_supper', ({'electric_refrigerator.n.01', 'tablefork.n.01', 'plate.n.04', 'agent.n.01', 'leftovers.n.01', 'floor.n.01', 'breakfast_table.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('clearing_the_table_after_dinner', ({'catsup.n.01', 'chair.n.01', 'agent.n.01', 'bowl.n.01', 'floor.n.01', 'beverage.n.01', 'cup.n.01', 'bucket.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('collect_misplaced_items', ({'sofa.n.01', 'necklace.n.01', 'gym_shoe.n.01', 'cabinet.n.01', 'agent.n.01', 'sock.n.01', 'floor.n.01', 'notebook.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int']))
# ('collecting_aluminum_cans', ({'pop.n.02', 'agent.n.01', 'floor.n.01', 'bed.n.01', 'bucket.n.01'}, ['Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('collecting_children_s_toys', ({'game.n.09', 'coffee_table.n.01', 'agent.n.01', 'plaything.n.01', 'floor.n.01', 'block.n.01', 'shelf.n.01'}, ['house_single_floor']))
# ('collecting_mail_from_the_letterbox', ({'coffee_table.n.01', 'agent.n.01', 'driveway.n.01', 'floor.n.01', 'package.n.02', 'mailbox.n.01'}, ['house_single_floor']))
# ('defrosting_freezer', ({'rag.n.01', 'food.n.02', 'electric_refrigerator.n.01', 'towel.n.01', 'agent.n.01', 'sink.n.01', 'scraper.n.01', 'floor.n.01', 'receptacle.n.01', 'countertop.n.01', 'bucket.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('delivering_groceries_to_doorstep', ({'bag.n.01', 'agent.n.01', 'floor.n.01', 'chicken.n.01', 'milk.n.01', 'door.n.01', 'bread.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('dispose_of_a_pizza_box', ({'bin.n.01', 'electric_refrigerator.n.01', 'pizza_box.n.01', 'agent.n.01', 'pizza.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('dispose_of_medication', ({'bin.n.01', 'pill.n.02', 'water.n.06', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'aspirin.n.01', 'pill_bottle.n.01', 'shelf.n.01'}, ['Ihlen_0_int', 'house_single_floor']))
# ('dispose_of_paper', ({'wrapping_paper.n.01', 'bin.n.01', 'coffee_table.n.01', 'agent.n.01', 'paper.n.01', 'floor.n.01', 'newspaper.n.03'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('emptying_trash_cans', ({'bag.n.01', 'rag.n.01', 'agent.n.01', 'bottle.n.01', 'floor.n.01', 'countertop.n.01', 'bucket.n.01', 'newspaper.n.03'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('fill_a_bucket_in_a_small_sink', ({'water.n.06', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'bucket.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('folding_piece_of_cloth', ({'dryer.n.01', 'piece_of_cloth.n.01', 'agent.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'house_single_floor']))
# ('gathering_nuts', ({'fence.n.01', 'tree.n.01', 'agent.n.01', 'walnut.n.01', 'floor.n.01', 'glove.n.02', 'bucket.n.01'}, ['house_single_floor']))
# ('heating_food_up', ({'microwave.n.02', 'electric_refrigerator.n.01', 'plate.n.04', 'agent.n.01', 'meal.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('heating_soup', ({'microwave.n.02', 'agent.n.01', 'soup.n.01', 'floor.n.01', 'countertop.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('installing_a_fax_machine', ({'facsimile.n.02', 'agent.n.01', 'floor.n.01', 'table.n.02'}, ['Beechwood_0_int']))
# ('installing_a_modem', ({'modem.n.01', 'agent.n.01', 'floor.n.01', 'table.n.02'}, ['Beechwood_0_int']))
# ('installing_a_printer', ({'printer.n.03', 'agent.n.01', 'floor.n.01', 'table.n.02'}, ['Beechwood_0_int']))
# ('installing_a_scanner', ({'table.n.02', 'agent.n.01', 'floor.n.01', 'scanner.n.02'}, ['Beechwood_0_int']))
# ('installing_alarms', ({'alarm.n.02', 'agent.n.01', 'floor.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('laying_tile_floors', ({'tile.n.01', 'agent.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('laying_wood_floors', ({'saw.n.02', 'agent.n.01', 'hammer.n.02', 'floor.n.01', 'plywood.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('loading_the_car', ({'car.n.01', 'agent.n.01', 'laptop.n.01', 'driveway.n.01', 'floor.n.01', 'bag.n.06', 'grocery_bag.n.01'}, ['house_single_floor']))
# ('loading_the_dishwasher', ({'plate.n.04', 'agent.n.01', 'floor.n.01', 'dishwasher.n.01', 'countertop.n.01', 'mug.n.04', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('locking_every_door', ({'bed.n.01', 'door.n.01', 'agent.n.01', 'floor.n.01'}, ['Merom_1_int', 'Rs_int', 'house_single_floor']))
# ('locking_every_window', ({'sofa.n.01', 'agent.n.01', 'window.n.01', 'floor.n.01', 'bed.n.01'}, ['Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('make_a_steak', ({'stove.n.01', 'olive_oil.n.01', 'chopping_board.n.01', 'agent.n.01', 'garlic.n.02', 'salt.n.02', 'steak.n.01', 'black_pepper.n.02', 'container.n.01', 'bottle.n.01', 'floor.n.01', 'pan.n.01', 'countertop.n.01'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('make_a_strawberry_slushie', ({'smoothie.n.02', 'strawberry.n.01', 'glass.n.02', 'blender.n.01', 'chopping_board.n.01', 'lemon_juice__container.n.01', 'lemon_juice.n.01', 'agave.n.01', 'countertop.n.01', 'ice.n.01', 'cup.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('make_bento', ({'electric_refrigerator.n.01', 'agent.n.01', 'apple.n.01', 'sandwich.n.01', 'cookie.n.01', 'floor.n.01', 'countertop.n.01', 'box.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('make_gift_bags_for_baby_showers', ({'wafer.n.02', 'bag.n.01', 'tissue.n.02', 'cabinet.n.01', 'agent.n.01', 'rug.n.01', 'floor.n.01', 'doll.n.01', 'shelf.n.01'}, ['Beechwood_0_int', 'Rs_int']))
# ('making_tea', ({'stove.n.01', 'tea_bag.n.01', 'lemon.n.01', 'electric_refrigerator.n.01', 'cabinet.n.01', 'agent.n.01', 'teapot.n.01', 'knife.n.01', 'floor.n.01'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('mopping_floors', ({'piece_of_cloth.n.01', 'agent.n.01', 'broom.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'bucket.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('moving_boxes_to_storage', ({'shelf.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02'}, ['Ihlen_0_int']))
# ('mowing_the_lawn', ({'grass.n.01', 'agent.n.01', 'floor.n.01', 'yard.n.02', 'lawn_mower.n.01'}, ['house_single_floor']))
# ('opening_doors', ({'door.n.01', 'agent.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('opening_windows', ({'agent.n.01', 'window.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('organizing_art_supplies', ({'sofa.n.01', 'agent.n.01', 'floor.n.01', 'paintbrush.n.01', 'pencil.n.01', 'pen.n.01', 'duffel_bag.n.01', 'marker.n.03'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('organizing_boxes_in_garage', ({'plate.n.04', 'shelf.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'saucepan.n.01', 'ball.n.01'}, ['Ihlen_0_int']))
# ('organizing_file_cabinet', ({'document.n.01', 'chair.n.01', 'cabinet.n.01', 'agent.n.01', 'folder.n.02', 'floor.n.01', 'marker.n.03', 'table.n.02'}, ['Beechwood_0_int']))
# ('organizing_school_stuff', ({'book.n.02', 'calculator.n.02', 'backpack.n.01', 'agent.n.01', 'folder.n.02', 'table.n.02', 'floor.n.01', 'pen.n.01', 'pencil.n.01', 'bed.n.01', 'highlighter.n.02'}, ['Wainscott_0_int', 'house_single_floor']))
# ('outfit_a_basic_toolbox', ({'agent.n.01', 'drill.n.01', 'pliers.n.01', 'floor.n.01', 'flashlight.n.01', 'allen_wrench.n.01', 'toolbox.n.01', 'screwdriver.n.01'}, ['Merom_1_int', 'house_single_floor']))
# ('pack_a_beach_bag', ({'fruit.n.01', 'towel.n.01', 'agent.n.01', 'sandwich.n.01', 'carryall.n.01', 'floor.n.01', 'sunscreen__bottle.n.01', 'door.n.01'}, ['Merom_1_int', 'house_single_floor']))
# ('pack_a_pencil_case', ({'pencil_box.n.01', 'agent.n.01', 'desk.n.01', 'pencil.n.01', 'pen.n.01', 'floor.n.01', 'scissors.n.01', 'eraser.n.01'}, ['house_single_floor']))
# ('pack_your_gym_bag', ({'gym_shoe.n.01', 'coffee_table.n.01', 'muffin.n.01', 'agent.n.01', 'tank_top.n.01', 'sock.n.01', 'floor.n.01', 'duffel_bag.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('packing_adult_s_bags', ({'toothbrush.n.01', 'jewelry.n.01', 'backpack.n.01', 'mouse.n.04', 'agent.n.01', 'makeup.n.01', 'hanger.n.02', 'floor.n.01', 'door.n.01', 'bed.n.01'}, ['Merom_1_int', 'house_single_floor']))
# ('packing_bags_or_suitcase', ({'toothpaste.n.01', 'toothbrush.n.01', 'hardback.n.01', 'backpack.n.01', 'window.n.01', 'agent.n.01', 'underwear.n.01', 'floor.n.01', 'door.n.01', 'bed.n.01', 'shampoo.n.01'}, ['Merom_1_int', 'Rs_int', 'house_single_floor']))
# ('packing_books_into_car', ({'car.n.01', 'agent.n.01', 'driveway.n.01', 'book.n.01', 'floor.n.01', 'bag.n.06'}, ['house_single_floor']))
# ('packing_boxes_for_household_move_or_trip', ({'book.n.02', 'dishtowel.n.01', 'plate.n.04', 'sweater.n.01', 'shirt.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('packing_car_for_trip', ({'briefcase.n.01', 'car.n.01', 'pencil_box.n.01', 'agent.n.01', 'headset.n.01', 'floor.n.01', 'duffel_bag.n.01', 'table.n.02'}, ['Ihlen_0_int']))
# ('packing_child_s_bag', ({'earphone.n.01', 'backpack.n.01', 'agent.n.01', 'apple.n.01', 'bracelet.n.02', 'floor.n.01', 'bed.n.01', 'notebook.n.01', 'sunglass.n.01'}, ['Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('packing_cleaning_suppies_into_car', ({'rag.n.01', 'car.n.01', 'backpack.n.01', 'scrub_brush.n.01', 'agent.n.01', 'driveway.n.01', 'mask.n.02', 'floor.n.01'}, ['house_single_floor']))
# ('packing_documents_into_car', ({'document.n.01', 'car.n.01', 'agent.n.01', 'driveway.n.01', 'book.n.01', 'floor.n.01', 'carton.n.02'}, ['house_single_floor']))
# ('packing_food_for_work', ({'electric_refrigerator.n.01', 'cabinet.n.01', 'apple.n.01', 'sandwich.n.01', 'juice.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'snack_food.n.01', 'countertop.n.01', 'door.n.01'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('packing_grocery_bags_into_car', ({'lawn.n.01', 'toilet_tissue.n.01', 'car.n.01', 'baked_goods.n.01', 'salt.n.01', 'agent.n.01', 'driveway.n.01', 'toiletry.n.01', 'floor.n.01', 'grocery_bag.n.01'}, ['house_single_floor']))
# ('packing_hiking_equipment_into_car', ({'water_bottle.n.01', 'lawn.n.01', 'food.n.02', 'car.n.01', 'backpack.n.01', 'shelter.n.01', 'agent.n.01', 'driveway.n.01', 'floor.n.01', 'sleeping_bag.n.01'}, ['house_single_floor']))
# ('packing_hobby_equipment', ({'puzzle.n.02', 'sofa.n.01', 'baseball.n.02', 'window.n.01', 'soccer_ball.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'shelf.n.01'}, ['Beechwood_0_int', 'Rs_int']))
# ('packing_lunches', ({'salad.n.01', 'electric_refrigerator.n.01', 'banana.n.02', 'pop.n.02', 'cabinet.n.01', 'juice.n.01', 'sandwich.n.01', 'apple.n.01', 'cookie.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'countertop.n.01', 'chip.n.04', 'table.n.02'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('packing_moving_van', ({'truck.n.01', 'mattress.n.01', 'chair.n.01', 'agent.n.01', 'blanket.n.01', 'floor.n.01', 'carton.n.02'}, ['house_single_floor']))
# ('packing_picnic_food_into_car', ({'water_bottle.n.01', 'lawn.n.01', 'car.n.01', 'agent.n.01', 'driveway.n.01', 'sandwich.n.01', 'meal.n.01', 'floor.n.01', 'bag.n.06', 'snack_food.n.01', 'bread.n.01', 'table.n.02'}, ['house_single_floor']))
# ('packing_picnic_into_car', ({'water_bottle.n.01', 'basket.n.01', 'car.n.01', 'paper_towel.n.01', 'agent.n.01', 'driveway.n.01', 'cupcake.n.01', 'knife.n.01', 'blanket.n.01', 'beverage.n.01', 'floor.n.01', 'sunscreen__bottle.n.01'}, ['house_single_floor']))
# ('packing_recreational_vehicle_for_trip', ({'lawn.n.01', 'basket.n.01', 'hose.n.03', 'wheel.n.01', 'chair.n.01', 'driveway.n.01', 'recreational_vehicle.n.01', 'knife.n.01', 'cord.n.01', 'agent.n.01', 'foodstuff.n.02', 'floor.n.01', 'charger.n.02'}, ['house_single_floor']))
# ('packing_sports_equipment_into_car', ({'lawn.n.01', 'car.n.01', 'tree.n.01', 'agent.n.01', 'driveway.n.01', 'helmet.n.01', 'sports_equipment.n.01', 'sock.n.01', 'floor.n.01'}, ['house_single_floor']))
# ('picking_up_litter', ({'plastic_bag.n.01', 'tissue.n.02', 'agent.n.01', 'recycling_bin.n.01', 'bottle.n.01', 'floor.n.01'}, ['house_single_floor']))
# ('picking_up_take_out_food', ({'sushi.n.01', 'agent.n.01', 'floor.n.01', 'carton.n.02', 'hamburger.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('picking_up_trash', ({'pad.n.01', 'pop.n.02', 'agent.n.01', 'ashcan.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('picking_vegetables_in_garden', ({'lawn.n.01', 'artichoke.n.01', 'basket.n.01', 'fence.n.01', 'agent.n.01', 'vegetable.n.02', 'floor.n.01', 'beet.n.01', 'chard.n.01'}, ['house_single_floor']))
# ('place_houseplants_around_your_home', ({'basket.n.01', 'vascular_plant.n.01', 'agent.n.01', 'cactus.n.01', 'floor.n.01', 'table.n.02'}, ['house_single_floor']))
# ('polishing_furniture', ({'rag.n.01', 'shelf.n.01', 'agent.n.01', 'floor.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Rs_int']))
# ('polishing_shoes', ({'rag.n.01', 'agent.n.01', 'shoe.n.01', 'sink.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('polishing_silver', ({'rag.n.01', 'cabinet.n.01', 'agent.n.01', 'spoon.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('pouring_water_in_a_glass', ({'water.n.06', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'pitcher.n.02', 'countertop.n.01', 'water_glass.n.02'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('praeparing_lunch_box', ({'water_bottle.n.01', 'chopping_board.n.01', 'apple.n.01', 'sandwich.n.01', 'cabinet.n.01', 'cookie.n.01', 'agent.n.01', 'floor.n.01', 'countertop.n.01', 'box.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('prepare_a_breakfast_bar', ({'danish.n.02', 'electric_refrigerator.n.01', 'orange_juice__carton.n.01', 'tray.n.01', 'waffle.n.01', 'pancake.n.01', 'muffin.n.01', 'cabinet.n.01', 'agent.n.01', 'toast.n.01', 'floor.n.01', 'scone.n.01', 'countertop.n.01', 'breakfast_table.n.01', 'platter.n.01', 'box.n.01'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('prepare_a_raised_bed_garden', ({'planter.n.03', 'agent.n.01', 'marigold.n.01', 'floor.n.01', 'trowel.n.01'}, ['house_single_floor']))
# ('prepare_a_slow_dinner_party', ({'salad.n.01', 'turkey.n.04', 'microwave.n.02', 'wine_bottle.n.01', 'electric_refrigerator.n.01', 'chalice.n.01', 'cabinet.n.01', 'dinner_plate.n.01', 'agent.n.01', 'floor.n.01', 'carving_knife.n.01', 'countertop.n.01', 'platter.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('prepare_an_emergency_school_kit', ({'perfume__bottle.n.01', 'backpack.n.01', 'wallset.n.01', 'tissue.n.02', 'agent.n.01', 'floor.n.01', 'pen.n.01', 'granola_bar.n.01', 'notebook.n.01', 'gum__box.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('prepare_and_cook_prawns', ({'stove.n.01', 'frying_pan.n.01', 'electric_refrigerator.n.01', 'chopping_board.n.01', 'dinner_plate.n.01', 'agent.n.01', 'knife.n.01', 'butter.n.01', 'garlic.n.02', 'salt.n.02', 'floor.n.01', 'shrimp.n.03', 'countertop.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('prepare_and_cook_scallops', ({'stove.n.01', 'water.n.06', 'vegetable_oil.n.01', 'frying_pan.n.01', 'counter.n.01', 'paper_towel.n.01', 'vegetable_oil__bottle.n.01', 'agent.n.01', 'garlic.n.02', 'floor.n.01', 'scallop.n.02'}, ['house_single_floor']))
# ('prepare_grapefruit_for_serving', ({'water.n.06', 'plate.n.04', 'agent.n.01', 'floor.n.01', 'grapefruit.n.02', 'countertop.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('preserving_food', ({'jar.n.01', 'strawberry.n.01', 'electric_refrigerator.n.01', 'carving_knife.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'beef.n.02', 'pan.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('put_together_a_scrapping_tool_kit', ({'agent.n.01', 'pliers.n.01', 'hammer.n.02', 'floor.n.01', 'wrench.n.03', 'toolbox.n.01', 'screwdriver.n.01'}, ['Ihlen_0_int', 'house_single_floor']))
# ('put_togethera_basic_pruning_kit', ({'shears.n.01', 'agent.n.01', 'floor.n.01', 'toolbox.n.01', 'pruner.n.02', 'pruning_saw.n.01'}, ['Ihlen_0_int', 'house_single_floor']))
# ('putting_away_Christmas_decorations', ({'ribbon.n.01', 'wreath.n.01', 'cabinet.n.01', 'agent.n.01', 'bow.n.08', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int']))
# ('putting_away_Halloween_decorations', ({'sofa.n.01', 'sheet.n.03', 'caldron.n.01', 'pumpkin.n.02', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'candle.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int']))
# ('putting_away_tools', ({'edge_tool.n.01', 'wrench.n.03', 'agent.n.01', 'floor.n.01', 'screwdriver.n.01', 'box.n.01'}, ['Ihlen_0_int', 'house_single_floor']))
# ('putting_away_toys', ({'agent.n.01', 'plaything.n.01', 'floor.n.01', 'carton.n.02', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('putting_away_yard_equipment', ({'flower.n.02', 'chest.n.02', 'shears.n.01', 'agent.n.01', 'hoe.n.01', 'rake.n.03', 'floor.n.01', 'shovel.n.01', 'trowel.n.01'}, ['house_single_floor']))
# ('putting_bike_in_garage', ({'car.n.01', 'bicycle.n.01', 'agent.n.01', 'helmet.n.01', 'floor.n.01', 'door.n.01'}, ['house_single_floor']))
# ('putting_dishes_away_after_cleaning', ({'plate.n.04', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('putting_leftovers_away', ({'electric_refrigerator.n.01', 'agent.n.01', 'sauce.n.01', 'floor.n.01', 'countertop.n.01', 'pasta.n.02'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('putting_out_cat_food', ({'agent.n.01', 'cat_food__tin.n.01', 'rug.n.01', 'floor.n.01', 'cat_food.n.01', 'bowl.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('putting_out_dog_food', ({'bowl.n.03', 'agent.n.01', 'rug.n.01', 'floor.n.01', 'dog_food__bag.n.01', 'dog_food.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('putting_shoes_on_rack', ({'gym_shoe.n.01', 'agent.n.01', 'rack.n.01', 'floor.n.01', 'sandal.n.01'}, ['Merom_1_int']))
# ('putting_up_Christmas_decorations_inside', ({'sofa.n.01', 'wrapping.n.01', 'wreath.n.01', 'agent.n.01', 'bow.n.08', 'floor.n.01', 'christmas_tree.n.05', 'carton.n.02', 'candle.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('re_shelving_library_books', ({'book.n.02', 'agent.n.01', 'table.n.02', 'floor.n.01', 'shelf.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Rs_int']))
# ('rearranging_furniture', ({'window.n.01', 'agent.n.01', 'floor.n.01', 'door.n.01', 'bed.n.01', 'seat.n.03', 'lamp.n.02'}, ['Merom_1_int', 'Rs_int', 'house_single_floor']))
# ('recycling_glass_bottles', ({'bin.n.01', 'agent.n.01', 'cabinet.n.01', 'bottle.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('recycling_newspapers', ({'bin.n.01', 'cabinet.n.01', 'agent.n.01', 'magazine.n.02', 'paper.n.01', 'floor.n.01', 'swivel_chair.n.01', 'newspaper.n.03'}, ['Beechwood_0_int']))
# ('recycling_office_papers', ({'bin.n.01', 'document.n.01', 'agent.n.01', 'floor.n.01', 'breakfast_table.n.01'}, ['Beechwood_0_int']))
# ('serving_a_meal', ({'stove.n.01', 'salad.n.01', 'water.n.06', 'fork.n.01', 'electric_refrigerator.n.01', 'plate.n.04', 'cabinet.n.01', 'agent.n.01', 'knife.n.01', 'spoon.n.01', 'soup.n.01', 'cake.n.03', 'floor.n.01', 'chicken.n.01', 'bread.n.01', 'table.n.02'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('serving_hors_d_oeuvres', ({'salad.n.01', 'cracker.n.01', 'electric_refrigerator.n.01', 'cheese.n.01', 'tray.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'parsley.n.02', 'table.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('set_up_a_coffee_station_in_your_kitchen', ({'water_bottle.n.01', 'instant_coffee__container.n.01', 'cabinet.n.01', 'coffee_filter.n.01', 'teacup.n.02', 'agent.n.01', 'saucer.n.02', 'floor.n.01', 'coffee_maker.n.01', 'dishwasher.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('setting_mousetraps', ({'mousetrap.n.01', 'toilet.n.02', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'bed.n.01'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('setting_up_for_an_event', ({'agent.n.01', 'floor.n.01', 'beverage.n.01', 'hamburger.n.01', 'tablecloth.n.01', 'gift.n.01'}, ['house_single_floor']))
# ('setting_up_room_for_a_movie', ({'television_receiver.n.01', 'sofa.n.01', 'agent.n.01', 'popcorn.n.02', 'coca_cola.n.01', 'table.n.02', 'floor.n.01', 'throw.n.04', 'bowl.n.01', 'shelf.n.01'}, ['Beechwood_0_int', 'Rs_int']))
# ('setting_up_room_for_games', ({'puzzle.n.02', 'cabinet.n.01', 'agent.n.01', 'board_game.n.01', 'floor.n.01', 'die.n.01', 'table.n.02'}, ['Merom_1_int']))
# ('setup_a_fish_tank', ({'water.n.06', 'rock.n.01', 'agent.n.01', 'tank.n.02', 'filter.n.01', 'floor.n.01', 'bucket.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('sorting_art_supplies', ({'pencil_box.n.01', 'coffee_table.n.01', 'cabinet.n.01', 'agent.n.01', 'paper.n.01', 'paintbrush.n.01', 'glue__bottle.n.01', 'carton.n.02', 'floor.n.01', 'marker.n.03'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int']))
# ('sorting_bottles,_cans,_and_paper', ({'can.n.01', 'agent.n.01', 'magazine.n.02', 'bottle.n.01', 'floor.n.01', 'countertop.n.01', 'bucket.n.01', 'newspaper.n.03'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('sorting_groceries', ({'electric_refrigerator.n.01', 'carrot.n.03', 'cheese.n.01', 'chair.n.01', 'apple.n.01', 'cabinet.n.01', 'broccoli.n.02', 'agent.n.01', 'soup.n.01', 'yogurt.n.01', 'flour.n.01', 'floor.n.01', 'milk.n.01', 'countertop.n.01', 'bread.n.01', 'orange.n.01', 'meat.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('sorting_household_items', ({'basket.n.01', 'toothbrush.n.01', 'deodorant__atomizer.n.01', 'detergent__bottle.n.01', 'cabinet.n.01', 'makeup.n.01', 'agent.n.01', 'floor.n.01', 'soap_dish.n.01', 'sanitary_napkin.n.01'}, ['Merom_1_int']))
# ('sorting_mail', ({'sofa.n.01', 'agent.n.01', 'floor.n.01', 'envelope.n.01', 'newspaper.n.03'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('spraying_for_bugs', ({'lawn.n.01', 'insectifuge.n.01', 'agent.n.01', 'atomizer.n.01', 'floor.n.01'}, ['house_single_floor']))
# ('store_an_uncooked_turkey', ({'bag.n.01', 'turkey.n.04', 'electric_refrigerator.n.01', 'agent.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_batteries', ({'agent.n.01', 'battery.n.01', 'chest_of_drawers.n.01', 'floor.n.01', 'shelf.n.01'}, ['house_single_floor']))
# ('store_beer', ({'electric_refrigerator.n.01', 'agent.n.01', 'beer_bottle.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_brownies', ({'electric_refrigerator.n.01', 'tray.n.01', 'agent.n.01', 'brownie.n.03', 'floor.n.01', 'countertop.n.01', 'box.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_daffodil_bulbs', ({'daffodil.n.01', 'bowl.n.03', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_dahlia_bulbs', ({'box.n.01', 'agent.n.01', 'floor.n.01', 'wall.n.01'}, ['Ihlen_0_int', 'Wainscott_0_int']))
# ('store_eggs', ({'egg.n.02', 'electric_refrigerator.n.01', 'agent.n.01', 'floor.n.01', 'countertop.n.01', 'box.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_firewood', ({'firewood.n.01', 'rack.n.01', 'agent.n.01', 'floor.n.01'}, ['Merom_1_int']))
# ('store_honey', ({'agent.n.01', 'cabinet.n.01', 'honey__jar.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_nuts', ({'mason_jar.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'edible_nut.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_produce', ({'electric_refrigerator.n.01', 'plastic_bag.n.01', 'agent.n.01', 'floor.n.01', 'produce.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('store_silver_coins', ({'tarnish__container.n.01', 'silver.n.02', 'towel.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'breakfast_table.n.01', 'cup.n.01'}, ['Beechwood_0_int']))
# ('store_tulip_bulbs', ({'bin.n.01', 'scissors.n.01', 'electric_refrigerator.n.01', 'paper_towel.n.01', 'agent.n.01', 'tulip.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('store_vodka', ({'floor.n.01', 'agent.n.01', 'cabinet.n.01', 'vodka__bottle.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('storing_food', ({'oatmeal.n.01', 'vegetable_oil.n.01', 'sugar.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'countertop.n.01', 'chip.n.04'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('storing_the_groceries', ({'cereal.n.03', 'electric_refrigerator.n.01', 'cabinet.n.01', 'agent.n.01', 'broccoli.n.02', 'pork.n.01', 'floor.n.01', 'lettuce.n.03', 'raspberry.n.02', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('taking_trash_outside', ({'bin.n.01', 'rubbish.n.01', 'agent.n.01', 'floor.n.01'}, ['house_single_floor']))
# ('thaw_frozen_fish', ({'microwave.n.02', 'electric_refrigerator.n.01', 'plate.n.04', 'agent.n.01', 'floor.n.01', 'fish.n.02', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('thawing_frozen_food', ({'electric_refrigerator.n.01', 'agent.n.01', 'sink.n.01', 'date.n.08', 'olive.n.04', 'floor.n.01', 'fish.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('throwing_away_leftovers', ({'plate.n.04', 'agent.n.01', 'ashcan.n.01', 'floor.n.01', 'hamburger.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('throwing_out_used_napkins', ({'bin.n.01', 'vegetable_oil.n.01', 'stain.n.01', 'agent.n.01', 'napkin.n.01', 'floor.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('toast_buns', ({'bun.n.01', 'toaster.n.02', 'oven.n.01', 'agent.n.01', 'floor.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('toast_coconut', ({'stove.n.01', 'frying_pan.n.01', 'agent.n.01', 'coconut.n.01', 'floor.n.01'}, ['Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('turning_on_radio', ({'floor.n.01', 'agent.n.01', 'radio.n.01'}, ['Beechwood_0_int', 'Ihlen_0_int', 'Merom_1_int', 'Wainscott_0_int', 'house_single_floor']))
# ('unloading_groceries', ({'cereal.n.03', 'bag.n.01', 'egg.n.02', 'yogurt__container.n.01', 'electric_refrigerator.n.01', 'cabinet.n.01', 'agent.n.01', 'floor.n.01', 'bread.n.01'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('unloading_the_car', ({'bag.n.06', 'agent.n.01', 'car.n.01', 'floor.n.01'}, ['Ihlen_0_int', 'house_single_floor']))
# ('unpacking_suitcase', ({'toothbrush.n.01', 'sofa.n.01', 'agent.n.01', 'sock.n.01', 'floor.n.01', 'carton.n.02', 'notebook.n.01', 'perfume.n.02'}, ['Beechwood_0_int', 'Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('vacuuming_floors', ({'vacuum.n.04', 'ashcan.n.01', 'floor.n.01', 'agent.n.01'}, ['Merom_1_int', 'Rs_int', 'Wainscott_0_int', 'house_single_floor']))
# ('washing_cars_or_other_vehicles', ({'rag.n.01', 'car.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'bucket.n.01'}, ['Ihlen_0_int']))
# ('washing_dishes', ({'plate.n.04', 'scrub_brush.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'countertop.n.01', 'cup.n.01', 'bowl.n.01'}, ['Beechwood_0_int', 'Rs_int', 'Wainscott_0_int']))
# ('washing_floor', ({'toilet.n.02', 'shower.n.01', 'towel.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'bed.n.01', 'bucket.n.01'}, ['Rs_int', 'Wainscott_0_int']))
# ('washing_pots_and_pans', ({'scrub_brush.n.01', 'pan.n.01', 'cabinet.n.01', 'teapot.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'soap.n.01', 'kettle.n.01', 'countertop.n.01'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('watering_houseplants', ({'pot_plant.n.01', 'agent.n.01', 'sink.n.01', 'floor.n.01', 'countertop.n.01', 'table.n.02'}, ['Beechwood_0_int', 'Wainscott_0_int']))
# ('waxing_cars_or_other_vehicles', ({'rag.n.01', 'vehicle.n.01', 'vessel.n.03', 'agent.n.01', 'floor.n.01', 'shelf.n.01'}, ['Ihlen_0_int']))

# %%
scene_mapping_repro = {x: scenes for x, (objects, scenes) in get_tasks_possible_with_scenes(starting_scenes).items()}
preselection_fn = r"D:\ig_pipeline\metadata\b200_compatible_scenes.json"
with open(preselection_fn, "w") as preselection_f:
    json.dump(scene_mapping_repro, preselection_f, indent=4)
object_mapping = {x: sorted(objects) for x, (objects, scenes) in get_tasks_possible_with_scenes(starting_scenes).items()}
objects_fn = r"D:\ig_pipeline\metadata\b200_objects.json"
with open(objects_fn, "w") as objects_f:
    json.dump(object_mapping, objects_f, indent=4)
