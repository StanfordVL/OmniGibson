# %%
import re
syn_exp = re.compile(r'(.*)__(bottle|box|carton|bag|jar|dispenser|container|can)\..*')
for cat, syn in rows:
    match = syn_exp.fullmatch(syn)
    if match:
        syn = f"{match.group(2)}__of__{match.group(1)}.n.01"
    print(syn)
# Out:
# bottle__of__apple_juice.n.01
# bag__of__auricularia.n.01
# bag__of__shiitake.n.01
# bottle__of__barbecue_sauce.n.01
# box__of__brown_sugar.n.01
# box__of__cane_sugar.n.01
# box__of__corn_flake.n.01
# box__of__lasagna.n.01
# box__of__milk.n.01
# box__of__oatmeal.n.01
# box__of__sanitary_napkin.n.01
# box__of__tissue.n.01
# box__of__yogurt.n.01
# bottle__of__carrot_juice.n.01
# bottle__of__catsup.n.01
# bottle__of__garlic_sauce.n.01
# bottle__of__hot_sauce.n.01
# bottle__of__lime_juice.n.01
# bottle__of__pesto.n.01
# box__of__tomato_juice.n.01
# bottle__of__tomato_paste.n.01
# packaged_bread.n.01
# packaged_oranges.n.01
# bottle__of__coffee.n.01
# bottle__of__milk.n.01
# bottle__of__soup.n.01
# box__of__fruit.n.01
# box__of__granola_bar.n.01
# packaged_lemons.n.01
# boxed_raspberries.n.01
# bagged_chip.n.01
# bag__of__flour.n.01
# bottle__of__ginger_beer.n.01
# bottle__of__lemon_sauce.n.01
# container__of__mix.n.01
# box__of__mix.n.01
# bottle__of__mushroom_sauce.n.01
# container__of__oatmeal.n.01
# jar__of__orange_sauce.n.01
# box__of__apple_juice.n.01
# bag__of__cream_cheese.n.01
# bagged_ice_cream.n.01
# bottle__of__lemonade.n.01
# bottle__of__papaya_juice.n.01
# bottle__of__soy_milk.n.01
# bottle__of__tonic.n.01
# box__of__ice_cream.n.01
# box__of__salt.n.01
# can__of__icetea.n.01
# carton__of__milk.n.01
# carton__of__orange_juice.n.01
# carton__of__pineapple_juice.n.01
# bagged_chocolate_bar.n.01
# bottle__of__coconut_water.n.01
# box__of__cream.n.01
# bottle__of__fruit_punch.n.01
# bottle__of__lotion.n.01
# bagged_cookie.n.01
# bagged_popcorn.n.01
# boxed_cake.n.01
# champagne_box.n.01
# boxed_cookie.n.01
# rum_box.n.01
# whiskey_box.n.01
# wine_box.n.01
# boxed_butter.n.01
# carton__of__soy_milk.n.01
# boxed_chocolate.n.01
# carton__of__chocolate_milk.n.01
# boxed__coffee.n.01
# packed_ramen.n.01
# bottle__of__rum.n.01
# bottle__of__soda.n.01
# bottle__of__tea.n.01
# box__of__vegetable_juice.n.01
# dispenser__of__shampoo.n.01
# dispenser__of__conditioner.n.01
# bagged_tea.n.01
# wrapped_hamburger.n.01
# bottle__of__mustard.n.01
# dispenser__of__isopropanol.n.01
# bottle__of__cooking_oil.n.01
# can__of__tomato_paste.n.01
# roof.n.01
# bottle__of__shampoo.n.01
# bottle__of__acetone.n.01
# bottle__of__acid.n.01
# bottle__of__vinegar.n.01
# glue_stick.n.01
# bottle__of__glue.n.01
# aerosol.n.02
# hamper.n.02
# volleyball.n.02
# loin.n.01
# air_filter.n.01
# air_freshner.n.01
# bottle__of__alfredo_sauce.n.01
# algae.n.01
# bottle__of__allspice.n.01
# boxed__almond_milk.n.01
# aluminium_foil.n.01
# bottle__of__antihistamines.n.01
# bottle__of__apple_cider.n.01
# bottle__of__applesauce.n.01
# arepa.n.01
# ash.n.01
# bottle__of__aspirin.n.01
# bottle__of__baby_oil.n.01
# boxed__baking_powder.n.01
# boxed__baking_soda.n.01
# bottle__of__balsamic_vinegar.n.01
# boxed__barley.n.01
# bottle__of__bay_leaf.n.01
# bottle__of__beans.n.01
# bird_feeder.n.01
# bottle__of__bleach.n.01
# bottle__of__brandy.n.01
# bagged__breadcrumbs.n.01
# broccolini.n.01
# bagged__brown_rice.n.01
# bottle__of__buttermilk.n.01
# cactus.n.01
# calendar.n.01
# cashew.n.02
# catalog.n.01
# bottle__of__caulk.n.01
# cd.n.04
# centerpiece.n.02
# charger.n.02
# cheesecake.n.01
# bouillon_cube.n.01
# chicken_tender.n.01
# chicken_wire.n.01
# chickpea.n.03
# bottle__of__chocolate_sauce.n.01
# packed__cigarette.n.01
# coriander.n.03
# sliced_lemon.n.01
# bottle__of__cleaner.n.01
# bottle__of__cocoa.n.01
# boxed__coconut_milk.n.01
# bottle__of__coconut_milk.n.01
# bottle__of__coconut_oil.n.01
# copper_wire.n.01
# bottle__of__cranberry_juice.n.01
# bottle__of__skin_cream.n.01
# bottle__of__chili_pepper.n.01
# bottle__of__cumin.n.01
# bottle__of__curry_powder.n.01
# bottle__of__degreaser.n.01
# bottle__of__dill_seed.n.01
# doll.n.01
# bottle__of__essential_oil.n.01
# bottle__of__fabric_softener.n.01
# bottle__of__face_cream.n.01
# bottle__of__fennel.n.01
# bagged__fertilizer.n.01
# bottle__of__food_coloring.n.01
# bottle__of__frosting.n.01
# bottle__of__ginger.n.01
# bottle__of__glass_cleaner.n.01
# bottle__of__ground_clove.n.01
# bottle__of__ground_mace.n.01
# bottle__of__ground_nutmeg.n.01
# bottle__of__hair_conditioner.n.01
# icicle_lights.n.01
# jarred__ink.n.01
# kabob.n.01
# bottle__of__ketchup.n.01
# skiff.n.01
# farm_stand.n.01
# sour_bread.n.01
# toast.n.01
# banana_bread.n.01
# hamburger_bun.n.01
# fruitcake.n.02
# digital_camera.n.01
# pillar_candle.n.01
# cheddar.n.02
# cedar_chest.n.01
# key.n.01
# bottle__of__lacquer.n.01
# bottle__of__lavender_oil.n.01
# entire_leaf.n.01
# leaf_blower.n.01
# leek.n.01
# legging.n.01
# leotard.n.01
# chocolate_chip_cookie.n.01
# chocolate_biscuit.n.01
# butter_cookie.n.01
# bottle__of__sour_cream.n.01
# legal_document.n.01
# cookie_dough.n.01
# chocolate_cake.n.01
# cinnamon_roll.n.01
# clothes_dryer.n.01
# rubber_eraser.n.01
# license_plate.n.01
# sliced__lime.n.01
# lock.n.01
# water_faucet.n.01
# skyrocket.n.02
# national_flag.n.01
# canteen.n.01
# bottle__of__lubricant.n.01
# lunch_box.n.01
# lunch_box_lid.n.01
# mac_and_cheese.n.01
# lily.n.01
# macaron.n.01
# mail.n.04
# mallet.n.01
# bottle__of__maple_syrup.n.01
# marigold.n.01
# mashed_potatoes.n.02
# bottle__of__mayonnaise.n.01
# rubber_glove.n.01
# bunchgrass.n.01
# sliced__melon.n.01
# bottle__of__milkshake.n.01
# bottle__of__cold_cream.n.01
# bottle__of__molasses.n.01
# money.n.01
# mop.n.01
# mop_bucket.n.01
# mousepad.n.01
# bottle__of__mustard.n.01
# bottle__of__mustard_seed.n.01
# bottle__of__oil.n.01
# sliced__onion.n.01
# bottle__of__onion_powder.n.01
# storage_organizer.n.01
# bottle__of__paint_remover.n.01
# virginia_ham.n.01
# serving_cart.n.01
# jar__of__pepper.n.01
# jar__of__bean.n.01
# ruby.n.01
# parer.n.02
# buttermilk_pancake.n.01
# penne.n.01
# conchiglie.n.01
# ravioli.n.01
# bottle__of__black_pepper.n.01
# sliced__papaya.n.01
# bottle__of__paprika.n.01
# bottle__of__parsley.n.01
# bottle__of__peanut_butter.n.01
# pecan.n.01
# peppermint.n.01
# bottle__of__pesticide.n.01
# pet_poop.n.01
# pine_nut.n.01
# pipe.n.02
# toy_figure.n.01
# swimming_pool.n.01
# shoe_rack.n.01
# whiskey_stone.n.01
# boulder.n.01
# bottle__of__pizza_sauce.n.01
# bottle__of__bath_salt.n.01
# club_sandwich.n.01
# frank.n.02
# packed__kielbasa.n.01
# ripsaw.n.01
# chain_saw.n.01
# shears.n.01
# dress_shirt.n.01
# bottle__of__poppy_seed.n.01
# postage_stamp.n.01
# bottle__of__seasoning.n.01
# power_washer.n.01
# pruner.n.01
# bottle__of__pumpkin_pie_spice.n.01
# pumpkin_seed.n.01
# quiche.n.02
# raisin.n.01
# receipt.n.02
# bottle__of__red_wine.n.01
# bagged__rice.n.01
# bottle__of__rosemary.n.01
# bottle__of__rum.n.01
# bottle__of__sage.n.01
# bottle__of__salsa.n.01
# bottle__of__sangria.n.01
# bottle__of__disinfectant.n.01
# bottle__of__spice.n.01
# saxophone.n.01
# scoop.n.06
# octupus.n.01
# bottle__of__sealant.n.01
# bottle__of__sesame_oil.n.01
# bottle__of__sesame_seeds.n.01
# bottle__of__shampoo.n.01
# shiitake.n.01
# sieve.n.01
# canned__soda.n.01
# bottle__of__soy_milk.n.01
# bottle__of__soy_sauce.n.01
# soybean.n.01
# bottle__of__paint.n.01
# sprinkler.n.01
# squeegee.n.01
# bottle__of__sriracha.n.01
# stake.n.05
# staple.n.05
# bagged__starch.n.01
# bottle__of__solvent.n.01
# sugar_cube.n.01
# sunflower_seed.n.01
# bottle__of__supplements.n.01
# bottle__of__almond_oil.n.01
# tablecloth.n.01
# take_out_box.n.01
# tank.n.02
# bottle__of__tea_leaf.n.01
# bottle__of__tequila.n.01
# sliced__tomato.n.01
# bagged__snack.n.01
# turkey.n.01
# tweezers.n.01
# van.n.05
# vegetable_peeler.n.01
# wallnut.n.01
# wheelbarrow.n.01
# whetstone.n.01
# whistle.n.01
# wind_chime.n.01
# wood_chip.n.01
# bagged__yeast.n.01
# yoga_mat.n.01
# wooden_spoon.n.02
# tablespoon.n.02
# taboret.n.01
# echeveria_elegans.n.01
# crewneck_sweater.n.01
# maillot.n.01
# cellulose_tape.n.01
# masking_tape.n.01
# cheese_tart.n.01
# tartlet.n.01
# self-registering_thermometer.n.01
# cotton.n.04
# car_tire.n.01
# beefsteak_tomato.n.01
# camera_tripod.n.01
# lorry.n.02
# pipe.n.01
# white_turnip.n.02
# drawers.n.01
# dip.n.07
# open-end_wrench.n.01
# black_bean.n.01
# rubber_boot.n.01
# packing_box.n.02
# plant_pot_stand.n.01
# slingback.n.01
# walking_shoe.n.01
# blackberry.n.01

# %%
cat_exp = re.compile(r'(.*)_(bottle|box|carton|bag|jar|dispenser|container|can)$')
for cat, syn in rows:
    match = cat_exp.fullmatch(cat)
    if match:
        cat = f"{match.group(2)}_of_{match.group(1)}"
    print(cat)
# Out:
# bottle_of_apple_juice
# bag_of_auricularia
# bag_of_shiitake
# bottle_of_barbecue_sauce
# box_of_brown_sugar
# box_of_cane_sugar
# box_of_corn_flake
# box_of_lasagna
# box_of_milk
# box_of_oatmeal
# box_of_sanitary_napkin
# box_of_tissue
# box_of_yogurt
# bottle_of_carrot_juice
# bottle_of_catsup
# bottle_of_garlic_sauce
# bottle_of_hot_sauce
# bottle_of_lime_juice
# bottle_of_pesto
# box_of_tomato_juice
# bottle_of_tomato_paste
# packaged_bread
# packaged_oranges
# bottle_of_coffee
# bottle_of_milk
# bottle_of_soup
# box_of_fruit
# box_of_granola_bar
# boxed_lemons
# boxed_raspberries
# bagged_chip
# bag_of_flour
# bottle_of_ginger_beer
# bottle_of_lemon_sauce
# container_of_mix
# box_of_mix
# bottle_of_mushroom_sauce
# container_of_oatmeal
# jar_of_orange_sauce
# box_of_apple_juice
# bag_of_cream_cheese
# bagged_ice_cream
# bottle_of_lemonade
# bottle_of_papaya_juice
# bottle_of_soy_milk
# bottle_of_tonic
# box_of_ice_cream
# box_of_salt
# can_of_icetea
# carton_of_milk
# carton_of_orange_juice
# carton_of_pineapple_juice
# bagged_chocolate_bar
# bottle_of_coconut_water
# box_of_cream
# bottle_of_fruit_punch
# bottle_of_lotion
# bagged_cookie
# bagged_popcorn
# boxed_cake
# box_of_champagne
# boxed_cookie
# box_of_rum
# box_of_whiskey
# box_of_wine
# boxed_butter
# carton_of_soy_milk
# boxed_chocolate
# carton_of_chocolate_milk
# boxed_coffee
# packed_ramen
# bottle_of_rum
# bottle_of_soda
# bottle_of_tea
# box_of_vegetable_juice
# dispenser_of_shampoo
# dispenser_of_conditioner
# bagged_tea
# wrapped_hamburger
# bottle_of_mustard
# dispenser_of_isopropanol
# bottle_of_cooking_oil
# can_of_tomato_paste
# roof
# bottle_of_shampoo
# bottle_of_acetone
# bottle_of_acid
# bottle_of_vinegar
# glue_stick
# bottle_of_glue
# can_of_spray
# hamper
# volleyball
# loin
# air_filter
# air_freshner
# bottle_of_alfredo_sauce
# algae
# bottle_of_allspice
# boxed_almond_milk
# aluminium_foil
# bottle_of_antihistamines
# bottle_of_apple_cider
# bottle_of_applesauce
# arepa
# ash
# bottle_of_aspirin
# bottle_of_baby_oil
# boxed_baking_powder
# boxed_baking_soda
# bottle_of_balsamic_vinegar
# boxed_barley
# bottle_of_bay_leaf
# bottle_of_beans
# bird_feeder
# bottle_of_bleach
# bottle_of_brandy
# bagged_breadcrumbs
# broccolini
# bagged_brown_rice
# bottle_of_buttermilk
# cactus
# calendar
# cashew
# catalog
# bottle_of_caulk
# cd
# centerpiece
# charger
# cheesecake
# bouillon_cube
# chicken_tender
# chicken_wire
# chickpea
# bottle_of_chocolate_sauce
# packed_cigarette
# cilantro
# sliced_lemon
# bottle_of_cleaner
# bottle_of_cocoa
# boxed_coconut_milk
# bottle_of_coconut_milk
# bottle_of_coconut_oil
# copper_wire
# bottle_of_cranberry_juice
# bottle_of_skin_cream
# bottle_of_chili_pepper
# bottle_of_cumin
# bottle_of_curry_powder
# bottle_of_degreaser
# bottle_of_dill_seed
# doll
# bottle_of_essential_oil
# bottle_of_fabric_softener
# bottle_of_face_cream
# bottle_of_fennel
# bagged_fertilizer
# bottle_of_food_coloring
# bottle_of_frosting
# bottle_of_ginger
# bottle_of_glass_cleaner
# bottle_of_ground_clove
# bottle_of_ground_mace
# bottle_of_ground_nutmeg
# bottle_of_hair_conditioner
# icicle_lights
# jarred_ink
# kabob
# bottle_of_ketchup
# skiff
# farm_stand
# sourdough
# toast
# banana_bread
# hamburger_bun
# fruitcake
# digital_camera
# pillar_candle
# cheddar
# cedar_chest
# key
# bottle_of_lacquer
# bottle_of_lavender_oil
# leaf
# leaf_blower
# leek
# legging
# leotard
# chocolate_chip_cookie
# chocolate_biscuit
# butter_cookie
# bottle_of_sour_cream
# legal_document
# cookie_dough
# chocolate_cake
# cinnamon_roll
# clothes_dryer
# rubber_eraser
# license_plate
# sliced_lime
# lock
# water_faucet
# skyrocket
# national_flag
# canteen
# bottle_of_lubricant
# box_of_lunch
# lunch_box_lid
# mac_and_cheese
# lily
# macaron
# mail
# mallet
# bottle_of_maple_syrup
# marigold
# mashed_potatoes
# bottle_of_mayonnaise
# rubber_glove
# bunchgrass
# sliced_melon
# bottle_of_milkshake
# bottle_of_cold_cream
# bottle_of_molasses
# money
# mop
# mop_bucket
# mousepad
# bottle_of_mustard
# bottle_of_mustard_seed
# bottle_of_oil
# sliced_onion
# bottle_of_onion_powder
# storage_organizer
# bottle_of_paint_remover
# virginia_ham
# serving_cart
# jar_of_pepper
# jar_of_bean
# ruby
# parer
# buttermilk_pancake
# penne
# conchiglie
# ravioli
# bottle_of_black_pepper
# sliced_papaya
# bottle_of_paprika
# bottle_of_parsley
# bottle_of_peanut_butter
# pecan
# peppermint
# bottle_of_pesticide
# pet_poop
# pine_nut
# pipe
# toy_figure
# swimming_pool
# shoe_rack
# whiskey_stone
# boulder
# bottle_of_pizza_sauce
# bottle_of_bath_salt
# club_sandwich
# hogdog_sausage
# packed_kielbasa
# ripsaw
# chainsaw
# shears
# dress_shirt
# bottle_of_poppy_seed
# postage_stamp
# bottle_of_seasoning
# power_washer
# pruner
# bottle_of_pumpkin_pie_spice
# pumpkin_seed
# quiche
# raisin
# receipt
# bottle_of_red_wine
# bagged_rice
# bottle_of_rosemary
# bottle_of_rum
# bottle_of_sage
# bottle_of_salsa
# bottle_of_sangria
# bottle_of_disinfectant
# bottle_of_spice
# saxophone
# scoop
# octupus
# bottle_of_sealant
# bottle_of_sesame_oil
# bottle_of_sesame_seeds
# bottle_of_shampoo
# shiitake
# sieve
# canned_soda
# bottle_of_soy_milk
# bottle_of_soy_sauce
# soybean
# bottle_of_paint
# sprinkler
# squeegee
# bottle_of_sriracha
# stake
# staple
# bagged_starch
# bottle_of_solvent
# sugar_cube
# sunflower_seed
# bottle_of_supplements
# bottle_of_almond_oil
# tablecloth
# box_of_take_out
# tank
# bottle_of_tea_leaf
# bottle_of_tequila
# sliced_tomato
# bagged_snack
# turkey
# tweezers
# van
# vegetable_peeler
# wallnut
# wheelbarrow
# whetstone
# whistle
# wind_chime
# wood_chip
# bagged_yeast
# yoga_mat
# wooden_spoon
# tablespoon
# taboret
# echeveria_elegans
# crewneck_sweater
# maillot
# cellulose_tape
# masking_tape
# cheese_tart
# tartlet
# digital_thermometer
# cotton_thread
# car_tire
# beefsteak_tomato
# camera_tripod
# lorry
# tobacco_pipe
# white_turnip
# boxers
# dip_candle
# open_end_wrench
# black_bean
# rubber_boot
# box_of_packing
# plant_pot_stand
# slingback
# walking_shoe
# blackberry

# %%
import csv
with open("D:\BEHAVIOR-1K\asset_pipeline\metadata\custom_synsets.csv", "r") as f:
    data = list(csv.DictReader(f))

# %%
import collections
ctr = collections.Counter(x["synset"] for x in data)
ctr.most_common()
# Out:
# [('acetone__bottle.n.01', 1),
#  ('acetone.n.01', 1),
#  ('acid.n.01', 1),
#  ('acorn.n.01', 1),
#  ('action.n.07', 1),
#  ('adapter.n.02', 1),
#  ('address.n.05', 1),
#  ('adhesive_material.n.01', 1),
#  ('aerosol.n.02', 1),
#  ('agave.n.01', 1),
#  ('agent.n.01', 1),
#  ('aioli.n.01', 1),
#  ('air_conditioner.n.01', 1),
#  ('air_filter.n.01', 1),
#  ('air_freshener__atomizer.n.01', 1),
#  ('alarm_clock.n.01', 1),
#  ('alarm.n.02', 1),
#  ('alcohol.n.01', 1),
#  ('alga.n.01', 1),
#  ('allen_wrench.n.01', 1),
#  ('allspice__shaker.n.01', 1),
#  ('allspice.n.03', 1),
#  ('almond_oil.n.01', 1),
#  ('almond.n.02', 1),
#  ('aluminum_foil.n.01', 1),
#  ('aluminum.n.01', 1),
#  ('ammonia_water__atomizer.n.01', 1),
#  ('ammonia_water__bottle.n.01', 1),
#  ('ammonia_water.n.01', 1),
#  ('analgesic.n.01', 1),
#  ('anchor.n.01', 1),
#  ('anchor.n.02', 1),
#  ('antenna.n.01', 1),
#  ('antifreeze.n.01', 1),
#  ('antifungal.n.01', 1),
#  ('antihistamine.n.01', 1),
#  ('antipasto.n.01', 1),
#  ('antique.n.02', 1),
#  ('antler.n.01', 1),
#  ('apparel.n.01', 1),
#  ('appetizer.n.01', 1),
#  ('apple_juice__bottle.n.01', 1),
#  ('apple_juice.n.01', 1),
#  ('apple_pie.n.01', 1),
#  ('apple.n.01', 1),
#  ('applesauce.n.01', 1),
#  ('appliance.n.02', 1),
#  ('apricot.n.02', 1),
#  ('apron.n.01', 1),
#  ('arbor.n.03', 1),
#  ('arborio_rice.n.01', 1),
#  ('arepa.n.01', 1),
#  ('armchair.n.01', 1),
#  ('aroma.n.02', 1),
#  ('art.n.01', 1),
#  ('artichoke.n.01', 1),
#  ('artichoke.n.02', 1),
#  ('artwork.n.01', 1),
#  ('arugula.n.02', 1),
#  ('ash.n.01', 1),
#  ('ashcan.n.01', 1),
#  ('ashtray.n.01', 1),
#  ('asparagus.n.02', 1),
#  ('asphalt.n.01', 1),
#  ('aspirin.n.01', 1),
#  ('atomizer.n.01', 1),
#  ('audio_system.n.01', 1),
#  ('auricularia.n.01', 1),
#  ('avocado.n.01', 1),
#  ('ax.n.01', 1),
#  ('axle.n.01', 1),
#  ('baby_buggy.n.01', 1),
#  ('baby_corn.n.01', 1),
#  ('baby_oil.n.01', 1),
#  ('baby_shoe.n.01', 1),
#  ('background.n.02', 1),
#  ('backpack.n.01', 1),
#  ('bacon.n.01', 1),
#  ('bag__of__auricularia.n.01', 1),
#  ('bag__of__breadcrumbs.n.01', 1),
#  ('bag__of__brown_rice.n.01', 1),
#  ('bag__of__chips.n.01', 1),
#  ('bag__of__cocoa.n.01', 1),
#  ('bag__of__cookies.n.01', 1),
#  ('bag__of__cream_cheese.n.01', 1),
#  ('bag__of__fertilizer.n.01', 1),
#  ('bag__of__flour.n.01', 1),
#  ('bag__of__ice_cream.n.01', 1),
#  ('bag__of__oranges.n.01', 1),
#  ('bag__of__popcorn.n.01', 1),
#  ('bag__of__rice.n.01', 1),
#  ('bag__of__shiitake.n.01', 1),
#  ('bag__of__snacks.n.01', 1),
#  ('bag__of__starch.n.01', 1),
#  ('bag__of__tea.n.01', 1),
#  ('bag__of__yeast.n.01', 1),
#  ('bag.n.01', 1),
#  ('bag.n.04', 1),
#  ('bag.n.06', 1),
#  ('bagel_dough.n.01', 1),
#  ('bagel.n.01', 1),
#  ('baggage.n.01', 1),
#  ('bagged__rubbish.n.01', 1),
#  ('bagged_chip.n.01', 1),
#  ('bagged_chocolate_bar.n.01', 1),
#  ('bagged_cookie.n.01', 1),
#  ('bagged_ice_cream.n.01', 1),
#  ('bagged_popcorn.n.01', 1),
#  ('baguet.n.01', 1),
#  ('bait.n.01', 1),
#  ('baked_goods.n.01', 1),
#  ('baking_powder__jar.n.01', 1),
#  ('baking_powder.n.01', 1),
#  ('ball.n.01', 1),
#  ('balloon.n.01', 1),
#  ('bamboo.n.01', 1),
#  ('banana_bread.n.01', 1),
#  ('banana.n.02', 1),
#  ('band.n.07', 1),
#  ('bandage.n.01', 1),
#  ('bandanna.n.01', 1),
#  ('banner.n.01', 1),
#  ('bap.n.01', 1),
#  ('bar_soap.n.01', 1),
#  ('bar.n.02', 1),
#  ('bar.n.03', 1),
#  ('bar.n.13', 1),
#  ('barbecue_sauce__bottle.n.01', 1),
#  ('barbecue_sauce.n.01', 1),
#  ('bark.n.01', 1),
#  ('barley.n.02', 1),
#  ('barrel.n.03', 1),
#  ('barrow.n.03', 1),
#  ('base.n.08', 1),
#  ('baseball_cap.n.01', 1),
#  ('baseball_glove.n.01', 1),
#  ('baseball.n.02', 1),
#  ('baseboard.n.01', 1),
#  ('basil__jar.n.01', 1),
#  ('basil.n.03', 1),
#  ('basket.n.01', 1),
#  ('basket.n.03', 1),
#  ('bat.n.05', 1),
#  ('bath_mat.n.01', 1),
#  ('bath_towel.n.01', 1),
#  ('bathtub.n.01', 1),
#  ('batter.n.02', 1),
#  ('battery.n.01', 1),
#  ('batting_glove.n.01', 1),
#  ('bay_leaf.n.01', 1),
#  ('bean_curd.n.01', 1),
#  ('bean.n.01', 1),
#  ('bearing.n.06', 1),
#  ('bed_linen.n.01', 1),
#  ('bed.n.01', 1),
#  ('bedclothes.n.01', 1),
#  ('beef_broth__carton.n.01', 1),
#  ('beef_broth.n.01', 1),
#  ('beef_roast.n.01', 1),
#  ('beef_stew.n.01', 1),
#  ('beef.n.02', 1),
#  ('beefsteak_tomato.n.01', 1),
#  ('beer_barrel.n.01', 1),
#  ('beer_bottle.n.01', 1),
#  ('beer_box.n.01', 1),
#  ('beer_glass.n.01', 1),
#  ('beer_mug.n.01', 1),
#  ('beer_tap.n.01', 1),
#  ('beer.n.01', 1),
#  ('beeswax.n.01', 1),
#  ('beet.n.02', 1),
#  ('beetroot.n.01', 1),
#  ('bell_pepper.n.02', 1),
#  ('bell.n.01', 1),
#  ('belt.n.01', 1),
#  ('belt.n.02', 1),
#  ('bench_press.n.01', 1),
#  ('bench.n.01', 1),
#  ('berry.n.01', 1),
#  ('beverage.n.01', 1),
#  ('bicycle_chain.n.01', 1),
#  ('bicycle_rack.n.01', 1),
#  ('bicycle.n.01', 1),
#  ('bidet.n.01', 1),
#  ('bikini.n.02', 1),
#  ('bin.n.01', 1),
#  ('binder.n.01', 1),
#  ('binder.n.03', 1),
#  ('bird_feed__bag.n.01', 1),
#  ('bird_feed.n.01', 1),
#  ('bird_feeder.n.01', 1),
#  ('birdcage.n.01', 1),
#  ('biscuit_dough.n.01', 1),
#  ('biscuit.n.01', 1),
#  ('bite.n.04', 1),
#  ('black_bean.n.01', 1),
#  ('black_pepper.n.02', 1),
#  ('blackberry.n.01', 1),
#  ('blackboard_eraser.n.01', 1),
#  ('blackboard.n.01', 1),
#  ('blade.n.09', 1),
#  ('blanket.n.01', 1),
#  ('blazer.n.01', 1),
#  ('bleaching_agent__bottle.n.01', 1),
#  ('bleaching_agent.n.01', 1),
#  ('blender.n.01', 1),
#  ('bleu.n.01', 1),
#  ('blind.n.03', 1),
#  ('block.n.01', 1),
#  ('blouse.n.01', 1),
#  ('blower.n.01', 1),
#  ('blueberry_compote.n.01', 1),
#  ('blueberry_mousse.n.01', 1),
#  ('blueberry.n.02', 1),
#  ('board_game.n.01', 1),
#  ('board.n.02', 1),
#  ('boat.n.01', 1),
#  ('bobby_pin.n.01', 1),
#  ('bok_choy.n.01', 1),
#  ('bolt.n.06', 1),
#  ('bone.n.01', 1),
#  ('bonfire.n.01', 1),
#  ('book.n.01', 1),
#  ('book.n.02', 1),
#  ('bookcase.n.01', 1),
#  ('bookend.n.01', 1),
#  ('boot.n.01', 1),
#  ('booth.n.01', 1),
#  ('booth.n.02', 1),
#  ('borax.n.01', 1),
#  ('bottle__of__acetone.n.01', 1),
#  ('bottle__of__acid.n.01', 1),
#  ('bottle__of__alcohol.n.01', 1),
#  ('bottle__of__alfredo_sauce.n.01', 1),
#  ('bottle__of__allspice.n.01', 1),
#  ('bottle__of__almond_oil.n.01', 1),
#  ('bottle__of__ammonia.n.01', 1),
#  ('bottle__of__antihistamines.n.01', 1),
#  ('bottle__of__apple_cider.n.01', 1),
#  ('bottle__of__apple_juice.n.01', 1),
#  ('bottle__of__applesauce.n.01', 1),
#  ('bottle__of__aspirin.n.01', 1),
#  ('bottle__of__baby_oil.n.01', 1),
#  ('bottle__of__balsamic_vinegar.n.01', 1),
#  ('bottle__of__barbecue_sauce.n.01', 1),
#  ('bottle__of__beer.n.01', 1),
#  ('bottle__of__black_pepper.n.01', 1),
#  ('bottle__of__bleach.n.01', 1),
#  ('bottle__of__brandy.n.01', 1),
#  ('bottle__of__bug_repellent.n.01', 1),
#  ('bottle__of__buttermilk.n.01', 1),
#  ('bottle__of__carrot_juice.n.01', 1),
#  ('bottle__of__catsup.n.01', 1),
#  ('bottle__of__caulk.n.01', 1),
#  ('bottle__of__champagne.n.01', 1),
#  ('bottle__of__chili_pepper.n.01', 1),
#  ('bottle__of__chocolate_sauce.n.01', 1),
#  ('bottle__of__cleaner.n.01', 1),
#  ('bottle__of__cocoa.n.01', 1),
#  ('bottle__of__coconut_milk.n.01', 1),
#  ('bottle__of__coconut_oil.n.01', 1),
#  ('bottle__of__coconut_water.n.01', 1),
#  ('bottle__of__coffee.n.01', 1),
#  ('bottle__of__coke.n.01', 1),
#  ('bottle__of__cold_cream.n.01', 1),
#  ('bottle__of__cologne.n.01', 1),
#  ('bottle__of__conditioner.n.01', 1),
#  ('bottle__of__cooking_oil.n.01', 1),
#  ('bottle__of__cranberry_juice.n.01', 1),
#  ('bottle__of__degreaser.n.01', 1),
#  ('bottle__of__deicer.n.01', 1),
#  ('bottle__of__detergent.n.01', 1),
#  ('bottle__of__dish_soap.n.01', 1),
#  ('bottle__of__disinfectant.n.01', 1),
#  ('bottle__of__essential_oil.n.01', 1),
#  ('bottle__of__fabric_softener.n.01', 1),
#  ('bottle__of__face_cream.n.01', 1),
#  ('bottle__of__fennel.n.01', 1),
#  ('bottle__of__food_coloring.n.01', 1),
#  ('bottle__of__frosting.n.01', 1),
#  ('bottle__of__fruit_punch.n.01', 1),
#  ('bottle__of__garlic_sauce.n.01', 1),
#  ('bottle__of__gin.n.01', 1),
#  ('bottle__of__ginger_beer.n.01', 1),
#  ('bottle__of__ginger.n.01', 1),
#  ('bottle__of__glass_cleaner.n.01', 1),
#  ('bottle__of__glue.n.01', 1),
#  ('bottle__of__ground_cloves.n.01', 1),
#  ('bottle__of__ground_mace.n.01', 1),
#  ('bottle__of__ground_nutmeg.n.01', 1),
#  ('bottle__of__hot_sauce.n.01', 1),
#  ('bottle__of__lacquer.n.01', 1),
#  ('bottle__of__lavender_oil.n.01', 1),
#  ('bottle__of__lemon_juice.n.01', 1),
#  ('bottle__of__lemon_sauce.n.01', 1),
#  ('bottle__of__lemonade.n.01', 1),
#  ('bottle__of__lime_juice.n.01', 1),
#  ('bottle__of__liquid_soap.n.01', 1),
#  ('bottle__of__lotion.n.01', 1),
#  ('bottle__of__lubricant.n.01', 1),
#  ('bottle__of__maple_syrup.n.01', 1),
#  ('bottle__of__mayonnaise.n.01', 1),
#  ('bottle__of__medicine.n.01', 1),
#  ('bottle__of__milk.n.01', 1),
#  ('bottle__of__milkshake.n.01', 1),
#  ('bottle__of__molasses.n.01', 1),
#  ('bottle__of__mushroom_sauce.n.01', 1),
#  ('bottle__of__mustard_seeds.n.01', 1),
#  ('bottle__of__mustard.n.01', 1),
#  ('bottle__of__oil.n.01', 1),
#  ('bottle__of__olive_oil.n.01', 1),
#  ('bottle__of__onion_powder.n.01', 1),
#  ('bottle__of__orange_juice.n.01', 1),
#  ('bottle__of__paint_remover.n.01', 1),
#  ('bottle__of__paint.n.01', 1),
#  ('bottle__of__papaya_juice.n.01', 1),
#  ('bottle__of__paprika.n.01', 1),
#  ('bottle__of__parsley.n.01', 1),
#  ('bottle__of__peanut_butter.n.01', 1),
#  ('bottle__of__perfume.n.01', 1),
#  ('bottle__of__pesticide.n.01', 1),
#  ('bottle__of__pesto.n.01', 1),
#  ('bottle__of__pizza_sauce.n.01', 1),
#  ('bottle__of__pop.n.01', 1),
#  ('bottle__of__poppy_seeds.n.01', 1),
#  ('bottle__of__powder.n.01', 1),
#  ('bottle__of__pumpkin_pie_spice.n.01', 1),
#  ('bottle__of__rosemary.n.01', 1),
#  ('bottle__of__rum.n.01', 1),
#  ('bottle__of__sage.n.01', 1),
#  ('bottle__of__sake.n.01', 1),
#  ('bottle__of__salsa.n.01', 1),
#  ('bottle__of__sangria.n.01', 1),
#  ('bottle__of__sealant.n.01', 1),
#  ('bottle__of__seasoning.n.01', 1),
#  ('bottle__of__sesame_oil.n.01', 1),
#  ('bottle__of__sesame_seeds.n.01', 1),
#  ('bottle__of__shampoo.n.01', 1),
#  ('bottle__of__skin_cream.n.01', 1),
#  ('bottle__of__soda.n.01', 1),
#  ('bottle__of__solvent.n.01', 1),
#  ('bottle__of__soup.n.01', 1),
#  ('bottle__of__sour_cream.n.01', 1),
#  ('bottle__of__soy_milk.n.01', 1),
#  ('bottle__of__soy_sauce.n.01', 1),
#  ('bottle__of__spice.n.01', 1),
#  ('bottle__of__sriracha.n.01', 1),
#  ('bottle__of__sunscreen.n.01', 1),
#  ('bottle__of__supplements.n.01', 1),
#  ('bottle__of__tea_leaves.n.01', 1),
#  ('bottle__of__tea.n.01', 1),
#  ('bottle__of__tequila.n.01', 1),
#  ('bottle__of__tomato_paste.n.01', 1),
#  ('bottle__of__tonic.n.01', 1),
#  ('bottle__of__vinegar.n.01', 1),
#  ('bottle__of__vodka.n.01', 1),
#  ('bottle__of__water.n.01', 1),
#  ('bottle__of__whiskey.n.01', 1),
#  ('bottle__of__wine.n.01', 1),
#  ('bottle.n.01', 1),
#  ('bottle.n.03', 1),
#  ('bouillon_cube.n.01', 1),
#  ('bouillon.n.01', 1),
#  ('boulder.n.01', 1),
#  ('bouquet.n.01', 1),
#  ('bourbon__bottle.n.01', 1),
#  ('bourbon.n.01', 1),
#  ('bourbon.n.02', 1),
#  ('bow.n.01', 1),
#  ('bow.n.02', 1),
#  ('bow.n.08', 1),
#  ('bowl.n.01', 1),
#  ('bowling_ball.n.01', 1),
#  ('box__of__almond_milk.n.01', 1),
#  ('box__of__apple_juice.n.01', 1),
#  ('box__of__baking_mix.n.01', 1),
#  ('box__of__baking_powder.n.01', 1),
#  ('box__of__baking_soda.n.01', 1),
#  ('box__of__barley.n.01', 1),
#  ('box__of__beer.n.01', 1),
#  ('box__of__brown_sugar.n.01', 1),
#  ('box__of__butter.n.01', 1),
#  ('box__of__candy.n.01', 1),
#  ('box__of__cane_sugar.n.01', 1),
#  ('box__of__cereal.n.01', 1),
#  ('box__of__champagne.n.01', 1),
#  ('box__of__chocolates.n.01', 1),
#  ('box__of__coconut_milk.n.01', 1),
#  ('box__of__coffee.n.01', 1),
#  ('box__of__cookies.n.01', 1),
#  ('box__of__corn_flakes.n.01', 1),
#  ('box__of__crackers.n.01', 1),
#  ('box__of__cream.n.01', 1),
#  ('box__of__flour.n.01', 1),
#  ('box__of__fruit.n.01', 1),
#  ('box__of__granola_bars.n.01', 1),
#  ('box__of__gum.n.01', 1),
#  ('box__of__ice_cream.n.01', 1),
#  ('box__of__lasagna.n.01', 1),
#  ('box__of__lemons.n.01', 1),
#  ('box__of__milk.n.01', 1),
#  ('box__of__oatmeal.n.01', 1),
#  ('box__of__raspberries.n.01', 1),
#  ('box__of__rice.n.01', 1),
#  ('box__of__rum.n.01', 1),
#  ('box__of__sake.n.01', 1),
#  ('box__of__salt.n.01', 1),
#  ('box__of__sanitary_napkin.n.01', 1),
#  ('box__of__shampoo.n.01', 1),
#  ('box__of__takeout.n.01', 1),
#  ('box__of__tissue.n.01', 1),
#  ('box__of__tomato_juice.n.01', 1),
#  ('box__of__vegetable_juice.n.01', 1),
#  ('box__of__whiskey.n.01', 1),
#  ('box__of__wine.n.01', 1),
#  ('box__of__yogurt.n.01', 1),
#  ('box.n.01', 1),
#  ('boxed__cake.n.01', 1),
#  ('boxed__cpu_board.n.01', 1),
#  ('boxed__ink_cartridge.n.01', 1),
#  ('boxed__router.n.01', 1),
#  ('boxed_butter.n.01', 1),
#  ('boxed_cake.n.01', 1),
#  ('boxed_chocolate.n.01', 1),
#  ('boxed_coffee.n.01', 1),
#  ('boxed_cookie.n.01', 1),
#  ('boxed_raspberries.n.01', 1),
#  ('boxing_glove.n.01', 1),
#  ('brace.n.09', 1),
#  ('bracelet.n.02', 1),
#  ('bracket.n.04', 1),
#  ('brake.n.01', 1),
#  ('brake.n.05', 1),
#  ('branch.n.02', 1),
#  ('branchlet.n.01', 1),
#  ('brandy__bottle.n.01', 1),
#  ('brandy.n.01', 1),
#  ('brass.n.02', 1),
#  ('brassiere.n.01', 1),
#  ('bratwurst.n.01', 1),
#  ('bread_slice.n.01', 1),
#  ('bread-bin.n.01', 1),
#  ('bread.n.01', 1),
#  ('breadcrumb.n.01', 1),
#  ('breakfast_table.n.01', 1),
#  ('breakfast.n.01', 1),
#  ('brick.n.01', 1),
#  ('bridge.n.01', 1),
#  ('briefcase.n.01', 1),
#  ('brisket.n.01', 1),
#  ('broccoli_rabe.n.02', 1),
#  ('broccoli.n.01', 1),
#  ('broccoli.n.02', 1),
#  ('broccolini.n.01', 1),
#  ('broken__glass.n.01', 1),
#  ('broken__light_bulb.n.01', 1),
#  ('broom.n.01', 1),
#  ('broth.n.01', 1),
#  ('brown_bread.n.02', 1),
#  ('brown_rice__sack.n.01', 1),
#  ('brown_rice.n.01', 1),
#  ('brown_sugar__box.n.01', 1),
#  ('brown_sugar__sack.n.01', 1),
#  ('brown_sugar.n.01', 1),
#  ('brownie_batter.n.01', 1),
#  ('brownie.n.03', 1),
#  ('brush.n.02', 1),
#  ('brussels_sprouts.n.01', 1),
#  ('bucket__of__paint.n.01', 1),
#  ('bucket.n.01', 1),
#  ('buckle.n.01', 1),
#  ('bulldog_clip.n.01', 1),
#  ('bulletin_board.n.02', 1),
#  ('bumper.n.02', 1),
#  ('bun.n.01', 1),
#  ('bunchgrass.n.01', 1),
#  ('bungee.n.01', 1),
#  ('burette.n.01', 1),
#  ('burlap.n.01', 1),
#  ('burner.n.02', 1),
#  ('burrito_bowl.n.01', 1),
#  ('burrito.n.01', 1),
#  ('buskin.n.01', 1),
#  ('bust.n.03', 1),
#  ('butane.n.01', 1),
#  ('butter__box.n.01', 1),
#  ('butter__package.n.01', 1),
#  ('butter_cookie.n.01', 1),
#  ('butter_knife.n.01', 1),
#  ('butter.n.01', 1),
#  ('buttermilk_pancake.n.01', 1),
#  ('buttermilk.n.01', 1),
#  ('butternut_squash.n.01', 1),
#  ('cabbage.n.03', 1),
#  ('cabinet.n.01', 1),
#  ('cabinet.n.03', 1),
#  ('cabinet.n.04', 1),
#  ('cable.n.02', 1),
#  ('cable.n.03', 1),
#  ('cactus.n.01', 1),
#  ('cafe_au_lait.n.01', 1),
#  ('caffe_latte.n.01', 1),
#  ('cake_batter.n.01', 1),
#  ('cake_mix.n.01', 1),
#  ('cake.n.03', 1),
#  ('calcium_carbonate.n.01', 1),
#  ('calculator.n.02', 1),
#  ('caldron.n.01', 1),
#  ('calendar.n.01', 1),
#  ('caliper.n.01', 1),
#  ('camera_tripod.n.01', 1),
#  ('camera.n.01', 1),
#  ('can__of__baking_mix.n.01', 1),
#  ('can__of__bay_leaves.n.01', 1),
#  ('can__of__beans.n.01', 1),
#  ('can__of__coffee.n.01', 1),
#  ('can__of__corn.n.01', 1),
#  ('can__of__icetea.n.01', 1),
#  ('can__of__oatmeal.n.01', 1),
#  ('can__of__sardines.n.01', 1),
#  ('can__of__soda.n.01', 1),
#  ('can__of__tomato_paste.n.01', 1),
#  ('can__of__tomatoes.n.01', 1),
#  ('can.n.01', 1),
#  ('candelabrum.n.01', 1),
#  ('candle.n.01', 1),
#  ('candlestick.n.01', 1),
#  ('candy__box.n.01', 1),
#  ('candy_cane.n.01', 1),
#  ('candy_dispenser_shelf.n.01', 1),
#  ('candy.n.01', 1),
#  ('cane_sugar.n.01', 1),
#  ('cane_sugar.n.02', 1),
#  ('canister.n.02', 1),
#  ('canned_food.n.01', 1),
#  ('canola_oil.n.01', 1),
#  ('canopy.n.03', 1),
#  ('cantaloup.n.02', 1),
#  ('canteen.n.01', 1),
#  ('canvas.n.01', 1),
#  ('canvas.n.02', 1),
#  ('cap.n.02', 1),
#  ('cappuccino.n.01', 1),
#  ('car_seat.n.01', 1),
#  ('car_tire.n.01', 1),
#  ('car_wheel.n.01', 1),
#  ('car.n.01', 1),
#  ('carafe.n.01', 1),
#  ('caraway_seed.n.01', 1),
#  ('carbon_black.n.01', 1),
#  ('carboy.n.01', 1),
#  ('card.n.01', 1),
#  ('card.n.03', 1),
#  ('card.n.04', 1),
#  ('cardamom.n.02', 1),
#  ('cardboard.n.01', 1),
#  ('cardigan.n.01', 1),
#  ('carne_asada.n.01', 1),
#  ('carpet_sweeper.n.01', 1),
#  ('carrel.n.02', 1),
#  ('carrot_juice.n.01', 1),
#  ('carrot.n.03', 1),
#  ('carryall.n.01', 1),
#  ('carton__of__chocolate_milk.n.01', 1),
#  ('carton__of__eggs.n.01', 1),
#  ('carton__of__milk.n.01', 1),
#  ('carton__of__orange_juice.n.01', 1),
#  ('carton__of__pineapple_juice.n.01', 1),
#  ('carton__of__soy_milk.n.01', 1),
#  ('carton.n.02', 1),
#  ('carving_knife.n.01', 1),
#  ('case__of__pop.n.01', 1),
#  ('case_shot.n.01', 1),
#  ('case.n.01', 1),
#  ('case.n.05', 1),
#  ('case.n.19', 1),
#  ('case.n.20', 1),
#  ('cash_register.n.01', 1),
#  ('cashbox.n.01', 1),
#  ('cashew.n.02', 1),
#  ('casserole.n.01', 1),
#  ('casserole.n.02', 1),
#  ('cassette.n.01', 1),
#  ('cat_food__tin.n.01', 1),
#  ('cat_food.n.01', 1),
#  ('catalog.n.01', 1),
#  ('catsup__bottle.n.01', 1),
#  ('catsup.n.01', 1),
#  ('cauliflower.n.01', 1),
#  ('cauliflower.n.02', 1),
#  ('caulk.n.01', 1),
#  ('cayenne__shaker.n.01', 1),
#  ('cayenne.n.01', 1),
#  ('cayenne.n.02', 1),
#  ('cedar_chest.n.01', 1),
#  ('ceiling_fan.n.01', 1),
#  ('ceiling_rack.n.01', 1),
#  ('ceiling.n.01', 1),
#  ('celery.n.02', 1),
#  ('cellophane.n.01', 1),
#  ('cellular_telephone.n.01', 1),
#  ('cellulose_tape.n.01', 1),
#  ('cement.n.01', 1),
#  ('centerpiece.n.02', 1),
#  ('cereal_box.n.01', 1),
#  ('cereal.n.03', 1),
#  ('chaff.n.01', 1),
#  ('chain_saw.n.01', 1),
#  ('chain.n.01', 1),
#  ('chain.n.03', 1),
#  ('chain.n.05', 1),
#  ('chair.n.01', 1),
#  ('chaise_longue.n.01', 1),
#  ('chalice.n.01', 1),
#  ('chalk.n.01', 1),
#  ('champagne__bottle.n.01', 1),
#  ('champagne.n.01', 1),
#  ('chandelier.n.01', 1),
#  ('chanterelle.n.01', 1),
#  ('charcoal.n.01', 1),
#  ('chard.n.01', 1),
#  ('chard.n.02', 1),
#  ('charger.n.02', 1),
#  ('checkout.n.03', 1),
#  ('cheddar.n.01', 1),
#  ('cheddar.n.02', 1),
#  ('cheese_pastry_filling.n.01', 1),
#  ('cheese_pastry.n.01', 1),
#  ('cheese_sauce.n.01', 1),
#  ('cheese_tart.n.01', 1),
#  ('cheese.n.01', 1),
#  ('cheesecake.n.01', 1),
#  ('cheesecloth.n.01', 1),
#  ('cherry_filling.n.01', 1),
#  ('cherry_tomato.n.02', 1),
#  ('cherry.n.03', 1),
#  ('chess_set.n.01', 1),
#  ('chest_of_drawers.n.01', 1),
#  ('chest.n.02', 1),
#  ('chestnut.n.03', 1),
#  ('chewing_gum.n.01', 1),
#  ('chia_seed__bag.n.01', 1),
#  ('chia_seed.n.01', 1),
#  ('chicken_breast.n.02', 1),
#  ('chicken_broth__carton.n.01', 1),
#  ('chicken_broth.n.01', 1),
#  ('chicken_coop.n.01', 1),
#  ('chicken_curry.n.01', 1),
#  ('chicken_leg.n.01', 1),
#  ('chicken_soup.n.01', 1),
#  ('chicken_tender.n.01', 1),
#  ('chicken_wing.n.01', 1),
#  ('chicken_wire.n.01', 1),
#  ('chicken.n.01', 1),
#  ('chickpea__can.n.01', 1),
#  ('chickpea.n.01', 1),
#  ('chickpea.n.02', 1),
#  ('chickpea.n.03', 1),
#  ('chili_powder.n.01', 1),
#  ('chili.n.02', 1),
#  ('china.n.02', 1),
#  ('chinese_anise.n.02', 1),
#  ('chinese_gooseberry.n.01', 1),
#  ('chip.n.04', 1),
#  ('chisel.n.01', 1),
#  ('chives.n.01', 1),
#  ('chlorine__bottle.n.01', 1),
#  ('chlorine.n.01', 1),
#  ('chocolate_bar.n.01', 1),
#  ('chocolate_biscuit.n.01', 1),
#  ('chocolate_box.n.01', 1),
#  ('chocolate_cake.n.01', 1),
#  ('chocolate_candy.n.01', 1),
#  ('chocolate_chip_cookie.n.01', 1),
#  ('chocolate_cookie_dough.n.01', 1),
#  ('chocolate_kiss.n.01', 1),
#  ('chocolate_milk.n.01', 1),
#  ('chocolate_sauce__bottle.n.01', 1),
#  ('chocolate_sauce.n.01', 1),
#  ('chocolate.n.02', 1),
#  ('chopped__lettuce.n.01', 1),
#  ('chopping_block.n.01', 1),
#  ('chopping_board.n.01', 1),
#  ('chopstick.n.01', 1),
#  ('chorizo.n.01', 1),
#  ('chowder.n.01', 1),
#  ('christmas_tree.n.05', 1),
#  ('cider.n.01', 1),
#  ('cigar_lighter.n.01', 1),
#  ('cigar.n.01', 1),
#  ('cigarette.n.01', 1),
#  ('cinnamon__shaker.n.01', 1),
#  ('cinnamon_bark.n.01', 1),
#  ('cinnamon_roll.n.01', 1),
#  ('cinnamon_sugar.n.01', 1),
#  ('cinnamon.n.02', 1),
#  ('cinnamon.n.03', 1),
#  ('circuit.n.01', 1),
#  ('citric_acid.n.01', 1),
#  ('citrus.n.01', 1),
#  ('clam.n.01', 1),
#  ('clamp.n.01', 1),
#  ('clay.n.01', 1),
#  ('cleansing_agent.n.01', 1),
#  ('cleaver.n.01', 1),
#  ('clip.n.03', 1),
#  ('clipboard.n.01', 1),
#  ('clipper.n.04', 1),
#  ('cloche.n.01', 1),
#  ('clock.n.01', 1),
#  ('clothes_dryer.n.01', 1),
#  ('clothesline.n.01', 1),
#  ('clothespin.n.01', 1),
#  ('clothing.n.01', 1),
#  ('clout_nail.n.01', 1),
#  ('clove__jar.n.01', 1),
#  ('clove.n.01', 1),
#  ('clove.n.03', 1),
#  ('clove.n.04', 1),
#  ('club_sandwich.n.01', 1),
#  ('coal.n.01', 1),
#  ('coaster.n.03', 1),
#  ('coat.n.01', 1),
#  ('coat.n.03', 1),
#  ('coatrack.n.01', 1),
#  ('cobweb.n.01', 1),
#  ('coca_cola.n.01', 1),
#  ('cocktail.n.01', 1),
#  ('cocoa__box.n.01', 1),
#  ('cocoa_powder__box.n.01', 1),
#  ('cocoa_powder.n.01', 1),
#  ('cocoa.n.01', 1),
#  ('cocoa.n.02', 1),
#  ('coconut_milk.n.01', 1),
#  ('coconut_oil__jar.n.01', 1),
#  ('coconut_oil.n.01', 1),
#  ('coconut.n.01', 1),
#  ('coconut.n.02', 1),
#  ('cod.n.02', 1),
#  ('coffee_bean__jar.n.01', 1),
#  ('coffee_bean.n.01', 1),
#  ('coffee_cup.n.01', 1),
#  ('coffee_filter.n.01', 1),
#  ('coffee_grounds.n.01', 1),
#  ('coffee_maker.n.01', 1),
#  ('coffee_mill.n.01', 1),
#  ('coffee_mug.n.01', 1),
#  ('coffee_table.n.01', 1),
#  ('coffee.n.01', 1),
#  ('cola__bottle.n.01', 1),
#  ('cola.n.02', 1),
#  ('colander.n.01', 1),
#  ('cold_cuts.n.01', 1),
#  ('coleslaw.n.01', 1),
#  ('collar.n.01', 1),
#  ('collards.n.01', 1),
#  ('cologne.n.02', 1),
#  ('coloring.n.01', 1),
#  ('column.n.07', 1),
#  ('comb.n.01', 1),
#  ('comic_book.n.01', 1),
#  ('common_bean.n.02', 1),
#  ('compact_disk.n.01', 1),
#  ('compost.n.01', 1),
#  ('compound_microscope.n.01', 1),
#  ('computer_game.n.01', 1),
#  ('computer.n.01', 1),
#  ('conch.n.01', 1),
#  ('conchiglie.n.01', 1),
#  ('concrete.n.01', 1),
#  ('condiment.n.01', 1),
#  ('conditioner__bottle.n.01', 1),
#  ('conditioner__dispenser.n.01', 1),
#  ('conditioner.n.03', 1),
#  ('conference_table.n.01', 1),
#  ('console_table.n.01', 1),
#  ('console.n.02', 1),
#  ('container.n.01', 1),
#  ('control_panel.n.01', 1),
#  ('convention.n.02', 1),
#  ('cooked__batter.n.01', 1),
#  ('cooked__black_bean.n.01', 1),
#  ('cooked__black_pepper.n.01', 1),
#  ('cooked__breadcrumb.n.01', 1),
#  ('cooked__brown_rice.n.01', 1),
#  ('cooked__chicken_soup.n.01', 1),
#  ('cooked__chickpea.n.01', 1),
#  ('cooked__cooking_oil.n.01', 1),
#  ('cooked__cumin.n.01', 1),
#  ('cooked__curry_powder.n.01', 1),
#  ('cooked__diced__beefsteak_tomato.n.01', 1),
#  ('cooked__diced__bell_pepper.n.01', 1),
#  ('cooked__diced__bratwurst.n.01', 1),
#  ('cooked__diced__broccoli.n.01', 1),
#  ('cooked__diced__cabbage.n.01', 1),
#  ('cooked__diced__carne_asada.n.01', 1),
#  ('cooked__diced__carrot.n.01', 1),
#  ('cooked__diced__chard.n.01', 1),
#  ('cooked__diced__chicken.n.01', 1),
#  ('cooked__diced__chili.n.01', 1),
#  ('cooked__diced__chorizo.n.01', 1),
#  ('cooked__diced__clove.n.01', 1),
#  ('cooked__diced__garlic.n.01', 1),
#  ('cooked__diced__green_onion.n.01', 1),
#  ('cooked__diced__ham.n.01', 1),
#  ('cooked__diced__pork_sausage.n.01', 1),
#  ('cooked__diced__potato.n.01', 1),
#  ('cooked__diced__steak.n.01', 1),
#  ('cooked__diced__tomato.n.01', 1),
#  ('cooked__diced__turkey.n.01', 1),
#  ('cooked__diced__vidalia_onion.n.01', 1),
#  ('cooked__diced__virginia_ham.n.01', 1),
#  ('cooked__diced__whole_potato.n.01', 1),
#  ('cooked__diced__zucchini.n.01', 1),
#  ('cooked__flour.n.01', 1),
#  ('cooked__granulated_sugar.n.01', 1),
#  ('cooked__ground_beef.n.01', 1),
#  ('cooked__kidney_bean.n.01', 1),
#  ('cooked__lemon-pepper_seasoning.n.01', 1),
#  ('cooked__marinade.n.01', 1),
#  ('cooked__marinara.n.01', 1),
#  ('cooked__melted__butter.n.01', 1),
#  ('cooked__noodle.n.01', 1),
#  ('cooked__olive_oil.n.01', 1),
#  ('cooked__onion_powder.n.01', 1),
#  ('cooked__oregano.n.01', 1),
#  ('cooked__orzo.n.01', 1),
#  ('cooked__paprika.n.01', 1),
#  ('cooked__pasta.n.01', 1),
#  ('cooked__popcorn.n.01', 1),
#  ('cooked__pumpkin_seed.n.01', 1),
#  ('cooked__quinoa.n.01', 1),
#  ('cooked__ramen.n.01', 1),
#  ('cooked__red_meat_sauce.n.01', 1),
#  ('cooked__red_wine.n.01', 1),
#  ('cooked__saffron.n.01', 1),
#  ('cooked__salsa.n.01', 1),
#  ('cooked__salt.n.01', 1),
#  ('cooked__soup.n.01', 1),
#  ('cooked__sunflower_seed.n.01', 1),
#  ('cooked__water.n.01', 1),
#  ('cooked__white_rice.n.01', 1),
#  ('cooked__white_wine.n.01', 1),
#  ('cooked__wine_sauce.n.01', 1),
#  ('cooker.n.01', 1),
#  ('cookie_cutter.n.01', 1),
#  ('cookie_dough.n.01', 1),
#  ('cookie_sheet.n.01', 1),
#  ('cookie.n.01', 1),
#  ('cooking_oil__bottle.n.01', 1),
#  ('cooking_oil.n.01', 1),
#  ('cooking_utensil.n.01', 1),
#  ('cooler.n.01', 1),
#  ('copper_mug.n.01', 1),
#  ('copper_wire.n.01', 1),
#  ('copper.n.01', 1),
#  ('cord.n.01', 1),
#  ('coriander__shaker.n.01', 1),
#  ('coriander.n.02', 1),
#  ('coriander.n.03', 1),
#  ('cork.n.01', 1),
#  ('corkscrew.n.01', 1),
#  ('corn_flake__box.n.01', 1),
#  ('corn_flake.n.01', 1),
#  ('corn_syrup.n.01', 1),
#  ('corn.n.01', 1),
#  ('cornbread.n.01', 1),
#  ('cornet.n.01', 1),
#  ('cornmeal__sack.n.01', 1),
#  ('cornmeal.n.01', 1),
#  ('cornstarch__jar.n.01', 1),
#  ('cornstarch.n.01', 1),
#  ('cosmetic.n.01', 1),
#  ('costume.n.01', 1),
#  ('cottage_cheese.n.01', 1),
#  ('cotton_ball.n.01', 1),
#  ('cotton.n.01', 1),
#  ('cotton.n.02', 1),
#  ('cotton.n.04', 1),
#  ('counter.n.01', 1),
#  ('countertop.n.01', 1),
#  ('cpu_board.n.01', 1),
#  ('crab.n.05', 1),
#  ('cracker.n.01', 1),
#  ('cranberry_juice.n.01', 1),
#  ('cranberry.n.01', 1),
#  ('cranberry.n.02', 1),
#  ('crate.n.01', 1),
#  ('crayfish.n.02', 1),
#  ('crayon.n.01', 1),
#  ('cream__carton.n.01', 1),
#  ('cream_cheese__box.n.01', 1),
#  ('cream_cheese.n.01', 1),
#  ('cream_of_tartar__shaker.n.01', 1),
#  ('cream_of_tartar.n.01', 1),
#  ('cream_pitcher.n.01', 1),
#  ('cream_soda.n.01', 1),
#  ('cream.n.02', 1),
#  ('credit_card.n.01', 1),
#  ('crescent_roll.n.01', 1),
#  ('crewneck_sweater.n.01', 1),
#  ('crib.n.01', 1),
#  ('cringle.n.01', 1),
#  ('crock_pot.n.01', 1),
#  ('crossbar.n.01', 1),
#  ('crouton.n.01', 1),
#  ('cruet.n.01', 1),
#  ('crumb.n.03', 1),
#  ('crust.n.02', 1),
#  ('crystal.n.01', 1),
#  ('crystal.n.03', 1),
#  ('cucumber.n.02', 1),
#  ('cue.n.04', 1),
#  ('cumin__shaker.n.01', 1),
#  ('cumin.n.02', 1),
#  ('cup__of__yogurt.n.01', 1),
#  ('cup_holder.n.01', 1),
#  ('cup.n.01', 1),
#  ('cup.n.03', 1),
#  ('cupboard.n.01', 1),
#  ('cupcake.n.01', 1),
#  ('curry_powder__shaker.n.01', 1),
#  ('curry_powder.n.01', 1),
#  ('curry.n.01', 1),
#  ('curtain_rod.n.01', 1),
#  ('curtain.n.01', 1),
#  ('cushion.n.03', 1),
#  ('custard.n.01', 1),
#  ('cut_of_pork.n.01', 1),
#  ('cutter.n.06', 1),
#  ('cymbal.n.01', 1),
#  ('daffodil.n.01', 1),
#  ('dahlia.n.01', 1),
#  ('dairy.n.01', 1),
#  ('danish.n.02', 1),
#  ('dart.n.01', 1),
#  ('dartboard.n.01', 1),
#  ('date.n.08', 1),
#  ('debris.n.01', 1),
#  ('decoration.n.01', 1),
#  ('deep_fryer.n.01', 1),
#  ('deep-freeze.n.01', 1),
#  ('deep-freeze.n.02', 1),
#  ('dehumidifier.n.01', 1),
#  ('dental_floss.n.01', 1),
#  ('denture.n.01', 1),
#  ('deodorant__atomizer.n.01', 1),
#  ('deodorant__stick.n.01', 1),
#  ('deodorant.n.01', 1),
#  ('desiccant.n.01', 1),
#  ('desk_phone.n.01', 1),
#  ('desk.n.01', 1),
#  ('desktop_computer.n.01', 1),
#  ('dessert_spoon.n.01', 1),
#  ('dessert.n.01', 1),
#  ('detector.n.01', 1),
#  ('detergent__atomizer.n.01', 1),
#  ('detergent__bottle.n.01', 1),
#  ('detergent.n.02', 1),
#  ('dial.n.03', 1),
#  ('diamond.n.01', 1),
#  ('diaper.n.01', 1),
#  ('diced__apple.n.01', 1),
#  ('diced__avocado.n.01', 1),
#  ('diced__beef_roast.n.01', 1),
#  ('diced__beefsteak_tomato.n.01', 1),
#  ('diced__beetroot.n.01', 1),
#  ('diced__bell_pepper.n.01', 1),
#  ('diced__bratwurst.n.01', 1),
#  ('diced__broccoli.n.01', 1),
#  ('diced__cabbage.n.01', 1),
#  ('diced__carrot.n.01', 1),
#  ('diced__celery.n.01', 1),
#  ('diced__chard.n.01', 1),
#  ('diced__cheddar.n.01', 1),
#  ('diced__cheese.n.01', 1),
#  ('diced__chicken_breast.n.01', 1),
#  ('diced__chicken.n.01', 1),
#  ('diced__chili.n.01', 1),
#  ('diced__clove.n.01', 1),
#  ('diced__cucumber.n.01', 1),
#  ('diced__feta.n.01', 1),
#  ('diced__garlic.n.01', 1),
#  ('diced__green_onion.n.01', 1),
#  ('diced__ham.n.01', 1),
#  ('diced__kiwi.n.01', 1),
#  ('diced__lemon.n.01', 1),
#  ('diced__lettuce.n.01', 1),
#  ('diced__mango.n.01', 1),
#  ('diced__pineapple.n.01', 1),
#  ('diced__pork_sausage.n.01', 1),
#  ('diced__potato.n.01', 1),
#  ('diced__spinach.n.01', 1),
#  ('diced__steak.n.01', 1),
#  ('diced__sweet_pepper.n.01', 1),
#  ('diced__tomato.n.01', 1),
#  ('diced__vidalia_onion.n.01', 1),
#  ('diced__virginia_ham.n.01', 1),
#  ('diced__watermelon.n.01', 1),
#  ('diced__whole_potato.n.01', 1),
#  ...]

# %%
from nltk.corpus import wordnet as wn
def in_wn(s):
    try:
        wn.synset(s)
        return True
    except:
        return False
    
def canonicalize(s):
    try:
        return wn.synset(s).name()
    except:
        return s

# %%
# Who has != .n.01 even though their 01 is not in wn?
def fix_syn_no(s):
    parts = s.strip().split(".")
    if parts[-1] == "01":
        return s
        
    one_below_id = "%.02d" % (int(parts[-1]) - 1)
    one_below = f"{parts[0]}.{parts[1]}.{one_below_id}"
    if in_wn(one_below):
        return s
        
    # Correct the ID
    for i in range(1, int(parts[-1])):
        candidate_id = "%.02d" % i
        candidate_s = f"{parts[0]}.{parts[1]}.{candidate_id}"
        if not in_wn(candidate_s):
            break
    else:
        raise ValueError("whoa")
            
    return candidate_s

# %%
for d in data:
    s = canonicalize(fix_syn_no(d["synset"]))
    is_custom = int(not in_wn(s))
    if is_custom:
        hypernyms = ",".join([wn.synset(x).name() for x in d["hypernyms"].split(",")]) if d["hypernyms"] else ""
    else:
        hypernyms = ",".join([x.name() for x in wn.synset(s).hypernyms()])
    is_duplicate = int(ctr[s] > 1)
    print(f'"{s}","{hypernyms}","{is_duplicate}","{is_custom}"')
# Out:
# "acetone__bottle.n.01","vessel.n.03","0","1"
# "acetone.n.01","ketone.n.01,solvent.n.01","0","0"
# "acid.n.01","compound.n.02","0","0"
# "acorn.n.01","fruit.n.01","0","0"
# "action.n.07","mechanism.n.05","0","0"
# "adapter.n.02","device.n.01","0","0"
# "address.n.05","street_sign.n.01","0","0"
# "adhesive_material.n.01","material.n.01","0","0"
# "aerosol.n.02","dispenser.n.01","0","0"
# "agave.n.01","desert_plant.n.01","0","0"
# "agent.n.01","causal_agent.n.01","0","0"
# "aioli.n.01","sauce.n.01","0","0"
# "air_conditioner.n.01","cooling_system.n.02","0","0"
# "air_filter.n.01","filter.n.01","0","0"
# "air_freshener__atomizer.n.01","dispenser.n.01","0","1"
# "alarm_clock.n.01","clock.n.01","0","0"
# "alarm.n.02","device.n.01","0","0"
# "alcohol.n.01","beverage.n.01,drug_of_abuse.n.01","0","0"
# "alga.n.01","protoctist.n.01","0","0"
# "allen_wrench.n.01","wrench.n.03","0","0"
# "allspice__shaker.n.01","container.n.01","0","1"
# "allspice.n.03","spice.n.02","0","0"
# "almond_oil.n.01","oil.n.01","0","0"
# "almond.n.02","drupe.n.01,edible_nut.n.01","0","0"
# "aluminum_foil.n.01","foil.n.01","0","0"
# "aluminum.n.01","metallic_element.n.01","0","0"
# "ammonia_water__atomizer.n.01","dispenser.n.01","0","1"
# "ammonia_water__bottle.n.01","vessel.n.03","0","1"
# "ammonia_water.n.01","liquid.n.01","0","0"
# "analgesic.n.01","medicine.n.02","0","0"
# "anchor.n.01","hook.n.04","0","0"
# "anchor.n.02","support.n.03","0","0"
# "antenna.n.01","electrical_device.n.01","0","0"
# "antifreeze.n.01","liquid.n.01","0","0"
# "antifungal.n.01","agent.n.03","0","0"
# "antihistamine.n.01","medicine.n.02","0","0"
# "antipasto.n.01","appetizer.n.01","0","0"
# "antique.n.02","antiquity.n.03","0","0"
# "antler.n.01","horn.n.02","0","0"
# "apparel.n.01","clothing.n.01","0","0"
# "appetizer.n.01","course.n.07","0","0"
# "apple_juice__bottle.n.01","vessel.n.03","0","1"
# "apple_juice.n.01","fruit_juice.n.01","0","0"
# "apple_pie.n.01","pie.n.01","0","0"
# "apple.n.01","edible_fruit.n.01,pome.n.01","0","0"
# "applesauce.n.01","dish.n.02","0","0"
# "appliance.n.02","durables.n.01","0","0"
# "apricot.n.02","edible_fruit.n.01","0","0"
# "apron.n.01","protective_garment.n.01","0","0"
# "arbor.n.03","framework.n.03","0","0"
# "arborio_rice.n.01","rice.n.01","0","1"
# "arepa.n.01","sandwich.n.01","0","1"
# "armchair.n.01","chair.n.01","0","0"
# "aroma.n.02","smell.n.01","0","0"
# "art.n.01","creation.n.02","0","0"
# "artichoke.n.01","vegetable.n.02","0","0"
# "artichoke.n.02","vegetable.n.01","0","0"
# "artwork.n.01","visual_communication.n.01","0","0"
# "arugula.n.02","salad_green.n.01","0","1"
# "ash.n.01","residue.n.01","0","0"
# "ashcan.n.01","bin.n.01","0","0"
# "ashtray.n.01","receptacle.n.01","0","0"
# "asparagus.n.02","vegetable.n.01","0","0"
# "asphalt.n.01","paving.n.01","0","0"
# "aspirin.n.01","analgesic.n.01,salicylate.n.01","0","0"
# "atomizer.n.01","dispenser.n.01","0","0"
# "audio_system.n.01","electronic_equipment.n.01,system.n.01","0","0"
# "auricularia.n.01","fungus_genus.n.01","0","0"
# "avocado.n.01","edible_fruit.n.01","0","0"
# "ax.n.01","edge_tool.n.01","0","0"
# "axle.n.01","shaft.n.03","0","0"
# "baby_buggy.n.01","wheeled_vehicle.n.01","0","0"
# "baby_corn.n.01","corn.n.01","0","1"
# "baby_oil.n.01","ointment.n.01","0","0"
# "baby_shoe.n.01","shoe.n.01","0","0"
# "background.n.02","view.n.02","0","0"
# "backpack.n.01","bag.n.01","0","0"
# "bacon.n.01","cut_of_pork.n.01","0","0"
# "bag__of__auricularia.n.01","grocery.n.02","0","1"
# "bag__of__breadcrumbs.n.01","grocery.n.02","0","1"
# "bag__of__brown_rice.n.01","grocery.n.02","0","1"
# "bag__of__chips.n.01","grocery.n.02","0","1"
# "bag__of__cocoa.n.01","grocery.n.02","0","1"
# "bag__of__cookies.n.01","grocery.n.02","0","1"
# "bag__of__cream_cheese.n.01","grocery.n.02","0","1"
# "bag__of__fertilizer.n.01","grocery.n.02","0","1"
# "bag__of__flour.n.01","grocery.n.02","0","1"
# "bag__of__ice_cream.n.01","grocery.n.02","0","1"
# "bag__of__oranges.n.01","grocery.n.02","0","1"
# "bag__of__popcorn.n.01","bag.n.01","0","1"
# "bag__of__rice.n.01","grocery.n.02","0","1"
# "bag__of__shiitake.n.01","grocery.n.02","0","1"
# "bag__of__snacks.n.01","grocery.n.02","0","1"
# "bag__of__starch.n.01","grocery.n.02","0","1"
# "bag__of__tea.n.01","grocery.n.02","0","1"
# "bag__of__yeast.n.01","grocery.n.02","0","1"
# "bag.n.01","container.n.01","0","0"
# "bag.n.04","container.n.01","0","0"
# "bag.n.06","baggage.n.01","0","0"
# "bagel_dough.n.01","dough.n.01","0","1"
# "bagel.n.01","bun.n.01","0","0"
# "baggage.n.01","case.n.05","0","0"
# "bagged__rubbish.n.01","waste.n.01","0","1"
# "bagged_chip.n.01","grocery.n.02","0","1"
# "bagged_chocolate_bar.n.01","grocery.n.02","0","1"
# "bagged_cookie.n.01","grocery.n.02","0","1"
# "bagged_ice_cream.n.01","grocery.n.02","0","1"
# "bagged_popcorn.n.01","grocery.n.02","0","1"
# "baguet.n.01","french_bread.n.01","0","0"
# "bait.n.01","temptation.n.01","0","0"
# "baked_goods.n.01","food.n.02","0","0"
# "baking_powder__jar.n.01","vessel.n.03","0","1"
# "baking_powder.n.01","leaven.n.01","0","0"
# "ball.n.01","game_equipment.n.01","0","0"
# "balloon.n.01","lighter-than-air_craft.n.01","0","0"
# "bamboo.n.01","wood.n.01","0","0"
# "banana_bread.n.01","quick_bread.n.01","0","0"
# "banana.n.02","edible_fruit.n.01","0","0"
# "band.n.07","strip.n.02","0","0"
# "bandage.n.01","dressing.n.04","0","0"
# "bandanna.n.01","handkerchief.n.01","0","0"
# "banner.n.01","flag.n.01","0","0"
# "bap.n.01","bread.n.01","0","0"
# "bar_soap.n.01","soap.n.01","0","0"
# "bar.n.02","counter.n.01","0","0"
# "bar.n.03","implement.n.01","0","0"
# "bar.n.13","support.n.10","0","0"
# "barbecue_sauce__bottle.n.01","vessel.n.03","0","1"
# "barbecue_sauce.n.01","sauce.n.01","0","0"
# "bark.n.01","covering.n.01","0","0"
# "barley.n.02","cereal.n.01","0","0"
# "barrel.n.03","cylinder.n.02","0","0"
# "barrow.n.03","handcart.n.01","1","0"
# "barrow.n.03","handcart.n.01","1","0"
# "base.n.08","support.n.10","0","0"
# "baseball_cap.n.01","cap.n.01","0","0"
# "baseball_glove.n.01","baseball_equipment.n.01","1","0"
# "baseball_glove.n.01","baseball_equipment.n.01","1","0"
# "baseball.n.02","ball.n.01,baseball_equipment.n.01","0","0"
# "baseboard.n.01","molding.n.02","0","0"
# "basil__jar.n.01","vessel.n.03","0","1"
# "basil.n.03","herb.n.02","0","0"
# "basket.n.01","container.n.01","0","0"
# "basket.n.03","basketball_equipment.n.01,goal.n.03","0","0"
# "bat.n.05","club.n.03","0","0"
# "bath_mat.n.01","bath_linen.n.01","0","0"
# "bath_towel.n.01","bath_linen.n.01,towel.n.01","0","0"
# "bathtub.n.01","vessel.n.03","0","0"
# "batter.n.02","concoction.n.01","0","0"
# "battery.n.01","artillery.n.02","0","0"
# "batting_glove.n.01","baseball_equipment.n.01,glove.n.02","0","0"
# "bay_leaf.n.01","herb.n.02","0","0"
# "bean_curd.n.01","curd.n.01","0","0"
# "bean.n.01","legume.n.03","0","0"
# "bearing.n.06","support.n.10","0","0"
# "bed_linen.n.01","linen.n.03","0","0"
# "bed.n.01","bedroom_furniture.n.01","0","0"
# "bedclothes.n.01","cloth_covering.n.01","0","0"
# "beef_broth__carton.n.01","","0","1"
# "beef_broth.n.01","broth.n.01","0","0"
# "beef_roast.n.01","roast.n.01","0","0"
# "beef_stew.n.01","stew.n.02","0","0"
# "beef.n.02","meat.n.01","0","0"
# "beefsteak_tomato.n.01","tomato.n.01","0","0"
# "beer_barrel.n.01","barrel.n.02","0","0"
# "beer_bottle.n.01","bottle.n.01","0","0"
# "beer_box.n.01","grocery.n.02","0","1"
# "beer_glass.n.01","glass.n.02","0","0"
# "beer_mug.n.01","mug.n.04","0","0"
# "beer_tap.n.01","faucet.n.01","0","1"
# "beer.n.01","brew.n.01","0","0"
# "beeswax.n.01","animal_product.n.01,wax.n.01","0","0"
# "beet.n.02","root_vegetable.n.01","0","0"
# "beetroot.n.01","beet.n.01","0","0"
# "bell_pepper.n.02","sweet_pepper.n.02","0","0"
# "bell.n.01","acoustic_device.n.01,signaling_device.n.01","0","0"
# "belt.n.01","loop.n.02","0","0"
# "belt.n.02","accessory.n.01","0","0"
# "bench_press.n.01","weightlift.n.01","0","0"
# "bench.n.01","seat.n.03","0","0"
# "berry.n.01","edible_fruit.n.01","0","0"
# "beverage.n.01","food.n.01,liquid.n.01","0","0"
# "bicycle_chain.n.01","chain.n.03","0","0"
# "bicycle_rack.n.01","rack.n.01","0","0"
# "bicycle.n.01","wheeled_vehicle.n.01","0","0"
# "bidet.n.01","basin.n.01","0","0"
# "bikini.n.02","swimsuit.n.01","0","0"
# "bin.n.01","container.n.01","0","0"
# "binder.n.01","harvester.n.02","0","0"
# "binder.n.03","protective_covering.n.01","0","0"
# "bird_feed__bag.n.01","container.n.01","0","1"
# "bird_feed.n.01","feed.n.01","0","0"
# "bird_feeder.n.01","device.n.01","0","0"
# "birdcage.n.01","cage.n.01","0","0"
# "biscuit_dough.n.01","dough.n.01","0","1"
# "biscuit.n.01","quick_bread.n.01","0","0"
# "bite.n.04","meal.n.01","1","0"
# "bite.n.04","meal.n.01","1","0"
# "black_bean.n.01","common_bean.n.02","0","0"
# "black_pepper.n.02","pepper.n.03","0","0"
# "blackberry.n.01","berry.n.01,drupelet.n.01","0","0"
# "blackboard_eraser.n.01","eraser.n.01","0","0"
# "blackboard.n.01","sheet.n.06","0","0"
# "blade.n.09","cutting_implement.n.01","0","0"
# "blanket.n.01","bedclothes.n.01","0","0"
# "blazer.n.01","jacket.n.01","0","0"
# "bleaching_agent__bottle.n.01","vessel.n.03","0","1"
# "bleaching_agent.n.01","agent.n.03","0","0"
# "blender.n.01","mixer.n.04","0","0"
# "bleu.n.01","cheese.n.01","0","0"
# "blind.n.03","protective_covering.n.01","0","0"
# "block.n.01","artifact.n.01","0","0"
# "blouse.n.01","top.n.10","0","0"
# "blower.n.01","device.n.01","0","0"
# "blueberry_compote.n.01","compote.n.01","0","1"
# "blueberry_mousse.n.01","mousse.n.01","0","1"
# "blueberry.n.02","berry.n.01","0","0"
# "board_game.n.01","parlor_game.n.01","0","0"
# "board.n.02","lumber.n.01","0","0"
# "boat.n.01","vessel.n.02","0","0"
# "bobby_pin.n.01","hairpin.n.01","0","0"
# "bok_choy.n.01","crucifer.n.01","0","0"
# "bolt.n.06","screw.n.04","0","0"
# "bone.n.01","connective_tissue.n.01","0","0"
# "bonfire.n.01","fire.n.01","0","0"
# "book.n.01","publication.n.01","0","0"
# "book.n.02","product.n.02","0","0"
# "bookcase.n.01","furniture.n.01","0","0"
# "bookend.n.01","support.n.10","0","0"
# "boot.n.01","footwear.n.02","0","0"
# "booth.n.01","table.n.02","0","0"
# "booth.n.02","closet.n.04","0","0"
# "borax.n.01","mineral.n.01","0","0"
# "bottle__of__acetone.n.01","grocery.n.02","0","1"
# "bottle__of__acid.n.01","grocery.n.02","0","1"
# "bottle__of__alcohol.n.01","grocery.n.02","0","1"
# "bottle__of__alfredo_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__allspice.n.01","grocery.n.02","0","1"
# "bottle__of__almond_oil.n.01","grocery.n.02","0","1"
# "bottle__of__ammonia.n.01","grocery.n.02","0","1"
# "bottle__of__antihistamines.n.01","grocery.n.02","0","1"
# "bottle__of__apple_cider.n.01","grocery.n.02","0","1"
# "bottle__of__apple_juice.n.01","grocery.n.02","0","1"
# "bottle__of__applesauce.n.01","grocery.n.02","0","1"
# "bottle__of__aspirin.n.01","grocery.n.02","0","1"
# "bottle__of__baby_oil.n.01","grocery.n.02","0","1"
# "bottle__of__balsamic_vinegar.n.01","grocery.n.02","0","1"
# "bottle__of__barbecue_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__beer.n.01","grocery.n.02","0","1"
# "bottle__of__black_pepper.n.01","grocery.n.02","0","1"
# "bottle__of__bleach.n.01","grocery.n.02","0","1"
# "bottle__of__brandy.n.01","grocery.n.02","0","1"
# "bottle__of__bug_repellent.n.01","grocery.n.02","0","1"
# "bottle__of__buttermilk.n.01","grocery.n.02","0","1"
# "bottle__of__carrot_juice.n.01","grocery.n.02","0","1"
# "bottle__of__catsup.n.01","grocery.n.02","0","1"
# "bottle__of__caulk.n.01","grocery.n.02","0","1"
# "bottle__of__champagne.n.01","grocery.n.02","0","1"
# "bottle__of__chili_pepper.n.01","grocery.n.02","0","1"
# "bottle__of__chocolate_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__cleaner.n.01","grocery.n.02","0","1"
# "bottle__of__cocoa.n.01","grocery.n.02","0","1"
# "bottle__of__coconut_milk.n.01","grocery.n.02","0","1"
# "bottle__of__coconut_oil.n.01","grocery.n.02","0","1"
# "bottle__of__coconut_water.n.01","grocery.n.02","0","1"
# "bottle__of__coffee.n.01","grocery.n.02","0","1"
# "bottle__of__coke.n.01","grocery.n.02","0","1"
# "bottle__of__cold_cream.n.01","grocery.n.02","0","1"
# "bottle__of__cologne.n.01","grocery.n.02","0","1"
# "bottle__of__conditioner.n.01","grocery.n.02","0","1"
# "bottle__of__cooking_oil.n.01","grocery.n.02","0","1"
# "bottle__of__cranberry_juice.n.01","grocery.n.02","0","1"
# "bottle__of__degreaser.n.01","grocery.n.02","0","1"
# "bottle__of__deicer.n.01","grocery.n.02","0","1"
# "bottle__of__detergent.n.01","grocery.n.02","0","1"
# "bottle__of__dish_soap.n.01","grocery.n.02","0","1"
# "bottle__of__disinfectant.n.01","grocery.n.02","0","1"
# "bottle__of__essential_oil.n.01","grocery.n.02","0","1"
# "bottle__of__fabric_softener.n.01","grocery.n.02","0","1"
# "bottle__of__face_cream.n.01","grocery.n.02","0","1"
# "bottle__of__fennel.n.01","grocery.n.02","0","1"
# "bottle__of__food_coloring.n.01","grocery.n.02","0","1"
# "bottle__of__frosting.n.01","grocery.n.02","0","1"
# "bottle__of__fruit_punch.n.01","grocery.n.02","0","1"
# "bottle__of__garlic_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__gin.n.01","grocery.n.02","0","1"
# "bottle__of__ginger_beer.n.01","grocery.n.02","0","1"
# "bottle__of__ginger.n.01","grocery.n.02","0","1"
# "bottle__of__glass_cleaner.n.01","grocery.n.02","0","1"
# "bottle__of__glue.n.01","grocery.n.02","0","1"
# "bottle__of__ground_cloves.n.01","grocery.n.02","0","1"
# "bottle__of__ground_mace.n.01","grocery.n.02","0","1"
# "bottle__of__ground_nutmeg.n.01","grocery.n.02","0","1"
# "bottle__of__hot_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__lacquer.n.01","grocery.n.02","0","1"
# "bottle__of__lavender_oil.n.01","grocery.n.02","0","1"
# "bottle__of__lemon_juice.n.01","grocery.n.02","0","1"
# "bottle__of__lemon_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__lemonade.n.01","grocery.n.02","0","1"
# "bottle__of__lime_juice.n.01","grocery.n.02","0","1"
# "bottle__of__liquid_soap.n.01","grocery.n.02","0","1"
# "bottle__of__lotion.n.01","grocery.n.02","0","1"
# "bottle__of__lubricant.n.01","grocery.n.02","0","1"
# "bottle__of__maple_syrup.n.01","grocery.n.02","0","1"
# "bottle__of__mayonnaise.n.01","grocery.n.02","0","1"
# "bottle__of__medicine.n.01","grocery.n.02","0","1"
# "bottle__of__milk.n.01","grocery.n.02","0","1"
# "bottle__of__milkshake.n.01","grocery.n.02","0","1"
# "bottle__of__molasses.n.01","grocery.n.02","0","1"
# "bottle__of__mushroom_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__mustard_seeds.n.01","grocery.n.02","0","1"
# "bottle__of__mustard.n.01","grocery.n.02","0","1"
# "bottle__of__oil.n.01","grocery.n.02","0","1"
# "bottle__of__olive_oil.n.01","grocery.n.02","0","1"
# "bottle__of__onion_powder.n.01","grocery.n.02","0","1"
# "bottle__of__orange_juice.n.01","grocery.n.02","0","1"
# "bottle__of__paint_remover.n.01","grocery.n.02","0","1"
# "bottle__of__paint.n.01","grocery.n.02","0","1"
# "bottle__of__papaya_juice.n.01","grocery.n.02","0","1"
# "bottle__of__paprika.n.01","grocery.n.02","0","1"
# "bottle__of__parsley.n.01","grocery.n.02","0","1"
# "bottle__of__peanut_butter.n.01","grocery.n.02","0","1"
# "bottle__of__perfume.n.01","grocery.n.02","0","1"
# "bottle__of__pesticide.n.01","grocery.n.02","0","1"
# "bottle__of__pesto.n.01","grocery.n.02","0","1"
# "bottle__of__pizza_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__pop.n.01","grocery.n.02","0","1"
# "bottle__of__poppy_seeds.n.01","grocery.n.02","0","1"
# "bottle__of__powder.n.01","grocery.n.02","0","1"
# "bottle__of__pumpkin_pie_spice.n.01","grocery.n.02","0","1"
# "bottle__of__rosemary.n.01","grocery.n.02","0","1"
# "bottle__of__rum.n.01","grocery.n.02","0","1"
# "bottle__of__sage.n.01","grocery.n.02","0","1"
# "bottle__of__sake.n.01","grocery.n.02","0","1"
# "bottle__of__salsa.n.01","grocery.n.02","0","1"
# "bottle__of__sangria.n.01","grocery.n.02","0","1"
# "bottle__of__sealant.n.01","grocery.n.02","0","1"
# "bottle__of__seasoning.n.01","grocery.n.02","0","1"
# "bottle__of__sesame_oil.n.01","grocery.n.02","0","1"
# "bottle__of__sesame_seeds.n.01","grocery.n.02","0","1"
# "bottle__of__shampoo.n.01","grocery.n.02","0","1"
# "bottle__of__skin_cream.n.01","grocery.n.02","0","1"
# "bottle__of__soda.n.01","grocery.n.02","0","1"
# "bottle__of__solvent.n.01","grocery.n.02","0","1"
# "bottle__of__soup.n.01","grocery.n.02","0","1"
# "bottle__of__sour_cream.n.01","grocery.n.02","0","1"
# "bottle__of__soy_milk.n.01","grocery.n.02","0","1"
# "bottle__of__soy_sauce.n.01","grocery.n.02","0","1"
# "bottle__of__spice.n.01","grocery.n.02","0","1"
# "bottle__of__sriracha.n.01","grocery.n.02","0","1"
# "bottle__of__sunscreen.n.01","grocery.n.02","0","1"
# "bottle__of__supplements.n.01","grocery.n.02","0","1"
# "bottle__of__tea_leaves.n.01","grocery.n.02","0","1"
# "bottle__of__tea.n.01","grocery.n.02","0","1"
# "bottle__of__tequila.n.01","grocery.n.02","0","1"
# "bottle__of__tomato_paste.n.01","grocery.n.02","0","1"
# "bottle__of__tonic.n.01","grocery.n.02","0","1"
# "bottle__of__vinegar.n.01","grocery.n.02","0","1"
# "bottle__of__vodka.n.01","grocery.n.02","0","1"
# "bottle__of__water.n.01","grocery.n.02","0","1"
# "bottle__of__whiskey.n.01","grocery.n.02","0","1"
# "bottle__of__wine.n.01","grocery.n.02","0","1"
# "bottle.n.01","vessel.n.03","0","0"
# "bottle.n.03","vessel.n.03","0","0"
# "bouillon_cube.n.01","flavorer.n.01","0","0"
# "bouillon.n.01","broth.n.02","0","0"
# "boulder.n.01","rock.n.01","0","0"
# "bouquet.n.01","flower_arrangement.n.01","0","0"
# "bourbon__bottle.n.01","vessel.n.03","1","1"
# "bourbon__bottle.n.01","","1","1"
# "bourbon.n.01","reactionary.n.01","0","0"
# "bourbon.n.02","whiskey.n.01","0","0"
# "bow.n.01","knot.n.02","0","0"
# "bow.n.02","stick.n.01","0","0"
# "bow.n.08","decoration.n.01","0","0"
# "bowl.n.01","vessel.n.03","0","0"
# "bowling_ball.n.01","ball.n.01","0","0"
# "box__of__almond_milk.n.01","grocery.n.02","0","1"
# "box__of__apple_juice.n.01","grocery.n.02","0","1"
# "box__of__baking_mix.n.01","grocery.n.02","0","1"
# "box__of__baking_powder.n.01","grocery.n.02","0","1"
# "box__of__baking_soda.n.01","grocery.n.02","0","1"
# "box__of__barley.n.01","grocery.n.02","0","1"
# "box__of__beer.n.01","grocery.n.02","0","1"
# "box__of__brown_sugar.n.01","grocery.n.02","0","1"
# "box__of__butter.n.01","grocery.n.02","0","1"
# "box__of__candy.n.01","grocery.n.02","0","1"
# "box__of__cane_sugar.n.01","grocery.n.02","0","1"
# "box__of__cereal.n.01","grocery.n.02","0","1"
# "box__of__champagne.n.01","grocery.n.02","0","1"
# "box__of__chocolates.n.01","grocery.n.02","0","1"
# "box__of__coconut_milk.n.01","grocery.n.02","0","1"
# "box__of__coffee.n.01","grocery.n.02","0","1"
# "box__of__cookies.n.01","grocery.n.02","0","1"
# "box__of__corn_flakes.n.01","grocery.n.02","0","1"
# "box__of__crackers.n.01","grocery.n.02","0","1"
# "box__of__cream.n.01","grocery.n.02","0","1"
# "box__of__flour.n.01","grocery.n.02","0","1"
# "box__of__fruit.n.01","grocery.n.02","0","1"
# "box__of__granola_bars.n.01","grocery.n.02","0","1"
# "box__of__gum.n.01","grocery.n.02","0","1"
# "box__of__ice_cream.n.01","grocery.n.02","0","1"
# "box__of__lasagna.n.01","grocery.n.02","0","1"
# "box__of__lemons.n.01","grocery.n.02","0","1"
# "box__of__milk.n.01","grocery.n.02","0","1"
# "box__of__oatmeal.n.01","grocery.n.02","0","1"
# "box__of__raspberries.n.01","grocery.n.02","0","1"
# "box__of__rice.n.01","grocery.n.02","0","1"
# "box__of__rum.n.01","grocery.n.02","0","1"
# "box__of__sake.n.01","grocery.n.02","0","1"
# "box__of__salt.n.01","grocery.n.02","0","1"
# "box__of__sanitary_napkin.n.01","grocery.n.02","0","1"
# "box__of__shampoo.n.01","grocery.n.02","0","1"
# "box__of__takeout.n.01","grocery.n.02","0","1"
# "box__of__tissue.n.01","grocery.n.02","0","1"
# "box__of__tomato_juice.n.01","grocery.n.02","0","1"
# "box__of__vegetable_juice.n.01","grocery.n.02","0","1"
# "box__of__whiskey.n.01","grocery.n.02","0","1"
# "box__of__wine.n.01","grocery.n.02","0","1"
# "box__of__yogurt.n.01","grocery.n.02","0","1"
# "box.n.01","container.n.01","0","0"
# "boxed__cake.n.01","grocery.n.02","0","1"
# "boxed__cpu_board.n.01","durables.n.01","0","1"
# "boxed__ink_cartridge.n.01","durables.n.01","0","1"
# "boxed__router.n.01","durables.n.01","0","1"
# "boxed_butter.n.01","grocery.n.02","0","1"
# "boxed_cake.n.01","grocery.n.02","0","1"
# "boxed_chocolate.n.01","grocery.n.02","0","1"
# "boxed_coffee.n.01","grocery.n.02","0","1"
# "boxed_cookie.n.01","grocery.n.02","0","1"
# "boxed_raspberries.n.01","grocery.n.02","0","1"
# "boxing_glove.n.01","boxing_equipment.n.01","0","0"
# "brace.n.09","strengthener.n.01,structural_member.n.01","0","0"
# "bracelet.n.02","jewelry.n.01","0","0"
# "bracket.n.04","support.n.10","0","0"
# "brake.n.01","restraint.n.06","0","0"
# "brake.n.05","restraint.n.06","0","0"
# "branch.n.02","stalk.n.02","0","0"
# "branchlet.n.01","branch.n.02","0","0"
# "brandy__bottle.n.01","vessel.n.03","0","1"
# "brandy.n.01","liquor.n.01","0","0"
# "brass.n.02","wind_instrument.n.01","0","0"
# "brassiere.n.01","undergarment.n.01,woman's_clothing.n.01","0","0"
# "bratwurst.n.01","pork_sausage.n.01","0","0"
# "bread_slice.n.01","bread.n.01","0","1"
# "bread-bin.n.01","container.n.01","0","0"
# "bread.n.01","baked_goods.n.01,starches.n.01","0","0"
# "breadcrumb.n.01","crumb.n.03","0","0"
# "breakfast_table.n.01","table.n.02","0","0"
# "breakfast.n.01","meal.n.01","0","0"
# "brick.n.01","building_material.n.01,ceramic.n.01","0","0"
# "bridge.n.01","structure.n.01","0","0"
# "briefcase.n.01","case.n.05","0","0"
# "brisket.n.01","cut.n.06","0","0"
# "broccoli_rabe.n.02","cruciferous_vegetable.n.01","0","0"
# "broccoli.n.01","crucifer.n.01","0","0"
# "broccoli.n.02","cruciferous_vegetable.n.01","0","0"
# "broccolini.n.01","cruciferous_vegetable.n.01","0","1"
# "broken__glass.n.01","container.n.01","0","1"
# "broken__light_bulb.n.01","electric_lamp.n.01","0","1"
# "broom.n.01","cleaning_implement.n.01","0","0"
# "broth.n.01","soup.n.01","0","0"
# "brown_bread.n.02","bread.n.01","0","0"
# "brown_rice__sack.n.01","container.n.01","0","1"
# "brown_rice.n.01","rice.n.01","0","0"
# "brown_sugar__box.n.01","grocery.n.02","0","1"
# "brown_sugar__sack.n.01","container.n.01","0","1"
# "brown_sugar.n.01","sugar.n.01","0","0"
# "brownie_batter.n.01","batter.n.02","0","1"
# "brownie.n.03","cookie.n.01","0","0"
# "brush.n.02","implement.n.01","0","0"
# "brussels_sprouts.n.01","cruciferous_vegetable.n.01","0","0"
# "bucket__of__paint.n.01","grocery.n.02","0","1"
# "bucket.n.01","vessel.n.03","0","0"
# "buckle.n.01","fastener.n.02","0","0"
# "bulldog_clip.n.01","clip.n.03","0","0"
# "bulletin_board.n.02","board.n.03","0","0"
# "bumper.n.02","mechanical_device.n.01","0","0"
# "bun.n.01","bread.n.01","0","0"
# "bunchgrass.n.01","grass.n.01","0","0"
# "bungee.n.01","rope.n.01","0","0"
# "burette.n.01","measuring_instrument.n.01","0","0"
# "burlap.n.01","sacking.n.01","0","0"
# "burner.n.02","heating_element.n.01","0","0"
# "burrito_bowl.n.01","salad.n.01","0","1"
# "burrito.n.01","dish.n.02","0","0"
# "buskin.n.01","boot.n.01","1","0"
# "buskin.n.01","boot.n.01","1","0"
# "bust.n.03","sculpture.n.01","0","0"
# "butane.n.01","fuel.n.01,gas.n.02,methane_series.n.01","0","0"
# "butter__box.n.01","grocery.n.02","0","1"
# "butter__package.n.01","container.n.01","0","1"
# "butter_cookie.n.01","cookie.n.01","0","0"
# "butter_knife.n.01","table_knife.n.01","0","0"
# "butter.n.01","dairy_product.n.01,food.n.02","0","0"
# "buttermilk_pancake.n.01","pancake.n.01","0","0"
# "buttermilk.n.01","milk.n.01","0","0"
# "butternut_squash.n.01","winter_squash.n.01","0","0"
# "cabbage.n.03","crucifer.n.01","0","0"
# "cabinet.n.01","furniture.n.01","0","0"
# "cabinet.n.03","compartment.n.02","0","0"
# "cabinet.n.04","housing.n.02","0","0"
# "cable.n.02","conductor.n.04","0","0"
# "cable.n.03","rope.n.01","0","0"
# "cactus.n.01","succulent.n.01","0","0"
# "cafe_au_lait.n.01","coffee.n.01","0","0"
# "caffe_latte.n.01","espresso.n.01","0","0"
# "cake_batter.n.01","batter.n.02","0","1"
# "cake_mix.n.01","ready-mix.n.01","0","0"
# "cake.n.03","baked_goods.n.01","0","0"
# "calcium_carbonate.n.01","carbonate.n.01","0","0"
# "calculator.n.02","machine.n.01","0","0"
# "caldron.n.01","pot.n.01","0","0"
# "calendar.n.01","arrangement.n.03","0","0"
# "caliper.n.01","measuring_instrument.n.01","0","0"
# "camera_tripod.n.01","tripod.n.01","0","0"
# "camera.n.01","photographic_equipment.n.01","0","0"
# "can__of__baking_mix.n.01","grocery.n.02","0","1"
# "can__of__bay_leaves.n.01","grocery.n.02","0","1"
# "can__of__beans.n.01","grocery.n.02","0","1"
# "can__of__coffee.n.01","grocery.n.02","0","1"
# "can__of__corn.n.01","canned_food.n.01","0","1"
# "can__of__icetea.n.01","grocery.n.02","0","1"
# "can__of__oatmeal.n.01","grocery.n.02","0","1"
# "can__of__sardines.n.01","grocery.n.02","0","1"
# "can__of__soda.n.01","grocery.n.02","0","1"
# "can__of__tomato_paste.n.01","grocery.n.02","0","1"
# "can__of__tomatoes.n.01","grocery.n.02","0","1"
# "can.n.01","container.n.01","0","0"
# "candelabrum.n.01","candlestick.n.01","0","0"
# "candle.n.01","lamp.n.01","0","0"
# "candlestick.n.01","holder.n.01","0","0"
# "candy__box.n.01","grocery.n.02","0","1"
# "candy_cane.n.01","candy.n.01","0","0"
# "candy_dispenser_shelf.n.01","dispenser.n.01","0","1"
# "candy.n.01","sweet.n.03","0","0"
# "cane_sugar.n.01","carbohydrate.n.01","0","0"
# "cane_sugar.n.02","sugar.n.01","0","0"
# "canister.n.02","container.n.01","0","0"
# "canned_food.n.01","foodstuff.n.02","0","0"
# "canola_oil.n.01","vegetable_oil.n.01","0","0"
# "canopy.n.03","shelter.n.02","0","0"
# "cantaloup.n.02","muskmelon.n.02","0","0"
# "canteen.n.01","flask.n.01","0","0"
# "canvas.n.01","fabric.n.01","0","0"
# "canvas.n.02","oil_painting.n.01","0","0"
# "cap.n.02","top.n.09","0","0"
# "cappuccino.n.01","coffee.n.01","0","0"
# "car_seat.n.01","seat.n.04","0","0"
# "car_tire.n.01","tire.n.01","0","0"
# "car_wheel.n.01","wheel.n.01","0","0"
# "car.n.01","motor_vehicle.n.01","0","0"
# "carafe.n.01","bottle.n.01","1","0"
# "carafe.n.01","bottle.n.01","1","0"
# "caraway_seed.n.01","flavorer.n.01","0","0"
# "carbon_black.n.01","carbon.n.01","1","0"
# "carbon_black.n.01","carbon.n.01","1","0"
# "carboy.n.01","bottle.n.01","0","0"
# "card.n.01","paper.n.01","0","0"
# "card.n.03","correspondence.n.01","0","0"
# "card.n.04","cardboard.n.01","0","0"
# "cardamom.n.02","flavorer.n.01","0","0"
# "cardboard.n.01","packing_material.n.01,paper.n.01","0","0"
# "cardigan.n.01","sweater.n.01","0","0"
# "carne_asada.n.01","dish.n.02","0","1"
# "carpet_sweeper.n.01","cleaning_implement.n.01","0","0"
# "carrel.n.02","alcove.n.01","0","0"
# "carrot_juice.n.01","juice.n.01","0","0"
# "carrot.n.03","root_vegetable.n.01","0","0"
# "carryall.n.01","bag.n.01","1","0"
# "carryall.n.01","bag.n.01","1","0"
# "carton__of__chocolate_milk.n.01","grocery.n.02","0","1"
# "carton__of__eggs.n.01","grocery.n.02","0","1"
# "carton__of__milk.n.01","grocery.n.02","0","1"
# "carton__of__orange_juice.n.01","grocery.n.02","0","1"
# "carton__of__pineapple_juice.n.01","grocery.n.02","0","1"
# "carton__of__soy_milk.n.01","grocery.n.02","0","1"
# "carton.n.02","box.n.01","0","0"
# "carving_knife.n.01","knife.n.01","0","0"
# "case__of__pop.n.01","grocery.n.02","0","1"
# "case_shot.n.01","ammunition.n.01","0","0"
# "case.n.01","happening.n.01","0","0"
# "case.n.05","container.n.01","0","0"
# "case.n.19","bed_linen.n.01","1","0"
# "case.n.19","bed_linen.n.01","1","0"
# "case.n.20","container.n.01","0","0"
# "cash_register.n.01","cashbox.n.01","0","0"
# "cashbox.n.01","strongbox.n.01","0","0"
# "cashew.n.02","edible_nut.n.01","0","0"
# "casserole.n.01","dish.n.02","0","0"
# "casserole.n.02","dish.n.01","0","0"
# "cassette.n.01","container.n.01","0","0"
# "cat_food__tin.n.01","container.n.01","0","1"
# "cat_food.n.01","petfood.n.01","0","0"
# "catalog.n.01","book.n.01","0","0"
# "catsup__bottle.n.01","vessel.n.03","0","1"
# "catsup.n.01","condiment.n.01","0","0"
# "cauliflower.n.01","crucifer.n.01","0","0"
# "cauliflower.n.02","cruciferous_vegetable.n.01","0","0"
# "caulk.n.01","sealant.n.01","0","0"
# "cayenne__shaker.n.01","container.n.01","0","1"
# "cayenne.n.01","capsicum.n.01","0","0"
# "cayenne.n.02","flavorer.n.01","0","0"
# "cedar_chest.n.01","chest.n.02","0","0"
# "ceiling_fan.n.01","fan.n.01","0","1"
# "ceiling_rack.n.01","rack.n.01","0","1"
# "ceiling.n.01","upper_surface.n.01","0","0"
# "celery.n.02","vegetable.n.01","0","0"
# "cellophane.n.01","plastic_wrap.n.01","0","0"
# "cellular_telephone.n.01","radiotelephone.n.02","1","0"
# "cellular_telephone.n.01","radiotelephone.n.02","1","0"
# "cellulose_tape.n.01","adhesive_tape.n.01","0","0"
# "cement.n.01","concrete.n.01","0","0"
# "centerpiece.n.02","decoration.n.01","0","0"
# "cereal_box.n.01","box.n.01","0","0"
# "cereal.n.03","breakfast_food.n.01","0","0"
# "chaff.n.01","plant_material.n.01","0","0"
# "chain_saw.n.01","power_saw.n.01","0","0"
# "chain.n.01","series.n.01","0","0"
# "chain.n.03","ligament.n.02","0","0"
# "chain.n.05","restraint.n.06","0","0"
# "chair.n.01","seat.n.03","0","0"
# "chaise_longue.n.01","chair.n.01","0","0"
# "chalice.n.01","cup.n.01","0","0"
# "chalk.n.01","calcite.n.01","0","0"
# "champagne__bottle.n.01","vessel.n.03","0","1"
# "champagne.n.01","sparkling_wine.n.01","0","0"
# "chandelier.n.01","lighting_fixture.n.01","0","0"
# "chanterelle.n.01","agaric.n.02","0","0"
# "charcoal.n.01","carbon.n.01,fuel.n.01","0","0"
# "chard.n.01","beet.n.01","0","0"
# "chard.n.02","greens.n.01","0","0"
# "charger.n.02","device.n.01","0","0"
# "checkout.n.03","counter.n.01","1","0"
# "checkout.n.03","counter.n.01","1","0"
# "cheddar.n.01","","0","0"
# "cheddar.n.02","cheese.n.01","0","0"
# "cheese_pastry_filling.n.01","","0","1"
# "cheese_pastry.n.01","","0","1"
# "cheese_sauce.n.01","white_sauce.n.01","0","0"
# "cheese_tart.n.01","tart.n.02","0","1"
# "cheese.n.01","dairy_product.n.01,food.n.02","0","0"
# "cheesecake.n.01","cake.n.03","0","0"
# "cheesecloth.n.01","gauze.n.02","0","0"
# "cherry_filling.n.01","compote.n.01","0","1"
# "cherry_tomato.n.02","tomato.n.01","0","0"
# "cherry.n.03","drupe.n.01,edible_fruit.n.01","0","0"
# "chess_set.n.01","set.n.01","0","0"
# "chest_of_drawers.n.01","furniture.n.01","0","0"
# "chest.n.02","box.n.01","0","0"
# "chestnut.n.03","edible_nut.n.01","0","0"
# "chewing_gum.n.01","sweet.n.03","0","0"
# "chia_seed__bag.n.01","container.n.01","0","1"
# "chia_seed.n.01","edible_seed.n.01","0","1"
# "chicken_breast.n.02","breast.n.03","0","1"
# "chicken_broth__carton.n.01","vessel.n.03","0","1"
# "chicken_broth.n.01","broth.n.01","0","0"
# "chicken_coop.n.01","farm_building.n.01","0","0"
# "chicken_curry.n.01","curry.n.01","0","1"
# "chicken_leg.n.01","drumstick.n.01","0","0"
# "chicken_soup.n.01","soup.n.01","0","0"
# "chicken_tender.n.01","breast.n.03","0","1"
# "chicken_wing.n.01","wing.n.09","0","0"
# "chicken_wire.n.01","net.n.06","0","0"
# "chicken.n.01","poultry.n.02","0","0"
# "chickpea__can.n.01","container.n.01","0","1"
# "chickpea.n.01","legume.n.02","0","0"
# "chickpea.n.02","legume.n.01","0","0"
# "chickpea.n.03","legume.n.03","0","0"
# "chili_powder.n.01","flavorer.n.01","0","0"
# "chili.n.02","hot_pepper.n.02","1","0"
# "chili.n.02","hot_pepper.n.02","1","0"
# "china.n.02","porcelain.n.01","0","0"
# "chinese_anise.n.02","spice.n.02","0","0"
# "chinese_gooseberry.n.01","vine.n.01","1","0"
# "chinese_gooseberry.n.01","vine.n.01","1","0"
# "chip.n.04","snack_food.n.01","0","0"
# "chisel.n.01","edge_tool.n.01","0","0"
# "chives.n.01","alliaceous_plant.n.01","0","0"
# "chlorine__bottle.n.01","vessel.n.03","0","1"
# "chlorine.n.01","chemical_element.n.01,gas.n.02,halogen.n.01","0","0"
# "chocolate_bar.n.01","chocolate_candy.n.01","0","0"
# "chocolate_biscuit.n.01","cookie.n.01","0","1"
# "chocolate_box.n.01","container.n.01","0","1"
# "chocolate_cake.n.01","cake.n.03","0","0"
# "chocolate_candy.n.01","chocolate.n.02","0","0"
# "chocolate_chip_cookie.n.01","cookie.n.01","0","0"
# "chocolate_cookie_dough.n.01","dough.n.01","0","1"
# "chocolate_kiss.n.01","chocolate_candy.n.01,kiss.n.03","0","0"
# "chocolate_milk.n.01","milk.n.01","0","0"
# "chocolate_sauce__bottle.n.01","vessel.n.03","0","1"
# "chocolate_sauce.n.01","sauce.n.01","0","0"
# "chocolate.n.02","food.n.02","0","0"
# "chopped__lettuce.n.01","lettuce.n.03","0","1"
# "chopping_block.n.01","block.n.01","0","0"
# "chopping_board.n.01","board.n.03","0","0"
# "chopstick.n.01","tableware.n.01","0","0"
# "chorizo.n.01","sausage.n.01","0","0"
# "chowder.n.01","soup.n.01","0","0"
# "christmas_tree.n.05","decoration.n.01","0","0"
# "cider.n.01","beverage.n.01","0","0"
# "cigar_lighter.n.01","lighter.n.02","0","0"
# "cigar.n.01","roll_of_tobacco.n.01","0","0"
# "cigarette.n.01","roll_of_tobacco.n.01","0","0"
# "cinnamon__shaker.n.01","container.n.01","0","1"
# "cinnamon_bark.n.01","bark.n.01","0","0"
# "cinnamon_roll.n.01","sweet_roll.n.01","0","0"
# "cinnamon_sugar.n.01","sugar.n.01","0","1"
# "cinnamon.n.02","laurel.n.01","0","0"
# "cinnamon.n.03","spice.n.02","0","0"
# "circuit.n.01","electrical_device.n.01","0","0"
# "citric_acid.n.01","acid.n.01","0","0"
# "citrus.n.01","edible_fruit.n.01","0","0"
# "clam.n.01","bivalve.n.01","0","0"
# "clamp.n.01","holding_device.n.01","0","0"
# "clay.n.01","soil.n.02","0","0"
# "cleansing_agent.n.01","formulation.n.01","0","0"
# "cleaver.n.01","knife.n.01","0","0"
# "clip.n.03","fastener.n.02","0","0"
# "clipboard.n.01","writing_board.n.01","0","0"
# "clipper.n.04","scissors.n.01","0","0"
# "cloche.n.01","protective_covering.n.01","0","0"
# "clock.n.01","timepiece.n.01","0","0"
# "clothes_dryer.n.01","dryer.n.01,white_goods.n.01","0","0"
# "clothesline.n.01","cord.n.01","0","0"
# "clothespin.n.01","fastener.n.02","0","0"
# "clothing.n.01","consumer_goods.n.01,covering.n.02","0","0"
# "clout_nail.n.01","nail.n.02","0","0"
# "clove__jar.n.01","vessel.n.03","0","1"
# "clove.n.01","flower_bud.n.01","0","0"
# "clove.n.03","garlic.n.02","0","0"
# "clove.n.04","spice.n.02","0","0"
# "club_sandwich.n.01","sandwich.n.01","0","0"
# "coal.n.01","fossil_fuel.n.01,vegetable_matter.n.01","0","0"
# "coaster.n.03","protective_covering.n.01","0","0"
# "coat.n.01","overgarment.n.01","0","0"
# "coat.n.03","hair.n.01","0","0"
# "coatrack.n.01","rack.n.01","0","0"
# "cobweb.n.01","fabric.n.01","0","0"
# "coca_cola.n.01","cola.n.02","0","0"
# "cocktail.n.01","mixed_drink.n.01","0","0"
# "cocoa__box.n.01","container.n.01","0","1"
# "cocoa_powder__box.n.01","","0","1"
# "cocoa_powder.n.01","chocolate.n.02","0","0"
# "cocoa.n.01","beverage.n.01","0","0"
# "cocoa.n.02","foodstuff.n.02","0","0"
# "coconut_milk.n.01","milk.n.04","0","0"
# "coconut_oil__jar.n.01","vessel.n.03","0","1"
# "coconut_oil.n.01","vegetable_oil.n.01","0","0"
# "coconut.n.01","food.n.02","0","0"
# "coconut.n.02","edible_nut.n.01","0","0"
# "cod.n.02","saltwater_fish.n.01","0","0"
# "coffee_bean__jar.n.01","vessel.n.03","0","1"
# "coffee_bean.n.01","seed.n.01","0","0"
# "coffee_cup.n.01","cup.n.01","0","0"
# "coffee_filter.n.01","filter.n.01","0","0"
# "coffee_grounds.n.01","grounds.n.05","0","0"
# "coffee_maker.n.01","kitchen_appliance.n.01","0","0"
# "coffee_mill.n.01","mill.n.04","0","0"
# "coffee_mug.n.01","mug.n.04","0","0"
# "coffee_table.n.01","table.n.02","0","0"
# "coffee.n.01","beverage.n.01","0","0"
# "cola__bottle.n.01","vessel.n.03","0","1"
# "cola.n.02","soft_drink.n.01","0","0"
# "colander.n.01","strainer.n.01","0","0"
# "cold_cuts.n.01","meat.n.01","0","0"
# "coleslaw.n.01","salad.n.01","0","0"
# "collar.n.01","band.n.07","0","0"
# "collards.n.01","kale.n.03","0","0"
# "cologne.n.02","perfume.n.02","0","0"
# "coloring.n.01","foodstuff.n.02","0","0"
# "column.n.07","upright.n.01","0","0"
# "comb.n.01","device.n.01","0","0"
# "comic_book.n.01","magazine.n.01","0","0"
# "common_bean.n.02","bean.n.01","0","0"
# "compact_disk.n.01","optical_disk.n.01,recording.n.03","1","0"
# "compact_disk.n.01","optical_disk.n.01,recording.n.03","1","0"
# "compost.n.01","composition.n.03","0","0"
# "compound_microscope.n.01","light_microscope.n.01","0","0"
# "computer_game.n.01","game.n.03","0","0"
# "computer.n.01","machine.n.01","0","0"
# "conch.n.01","gastropod.n.01","0","0"
# "conchiglie.n.01","pasta.n.02","0","1"
# "concrete.n.01","building_material.n.01,paving.n.01","0","0"
# "condiment.n.01","flavorer.n.01","0","0"
# "conditioner__bottle.n.01","vessel.n.03","0","1"
# "conditioner__dispenser.n.01","dispenser.n.01","0","1"
# "conditioner.n.03","softener.n.01","0","0"
# "conference_table.n.01","table.n.02","0","0"
# "console_table.n.01","table.n.02","0","0"
# "console.n.02","scientific_instrument.n.01","0","0"
# "container.n.01","instrumentality.n.03","0","0"
# "control_panel.n.01","electrical_device.n.01","0","0"
# "convention.n.02","practice.n.05","0","0"
# "cooked__batter.n.01","concoction.n.01","0","1"
# "cooked__black_bean.n.01","dish.n.02","0","1"
# "cooked__black_pepper.n.01","pepper.n.03","0","1"
# "cooked__breadcrumb.n.01","crumb.n.03","0","1"
# "cooked__brown_rice.n.01","rice.n.01","0","1"
# "cooked__chicken_soup.n.01","soup.n.01","0","1"
# "cooked__chickpea.n.01","legume.n.01","1","1"
# "cooked__chickpea.n.01","","1","1"
# "cooked__cooking_oil.n.01","vegetable_oil.n.01","0","1"
# "cooked__cumin.n.01","edible_seed.n.01","0","1"
# "cooked__curry_powder.n.01","flavorer.n.01","0","1"
# "cooked__diced__beefsteak_tomato.n.01","tomato.n.01","0","1"
# "cooked__diced__bell_pepper.n.01","sweet_pepper.n.02","0","1"
# "cooked__diced__bratwurst.n.01","sausage.n.01","0","1"
# "cooked__diced__broccoli.n.01","cruciferous_vegetable.n.01","0","1"
# "cooked__diced__cabbage.n.01","crucifer.n.01","0","1"
# "cooked__diced__carne_asada.n.01","dish.n.02","0","1"
# "cooked__diced__carrot.n.01","","0","1"
# "cooked__diced__chard.n.01","beet.n.01","0","1"
# "cooked__diced__chicken.n.01","poultry.n.02","0","1"
# "cooked__diced__chili.n.01","hot_pepper.n.02","0","1"
# "cooked__diced__chorizo.n.01","sausage.n.01","0","1"
# "cooked__diced__clove.n.01","garlic.n.02","0","1"
# "cooked__diced__garlic.n.01","flavorer.n.01","0","1"
# "cooked__diced__green_onion.n.01","onion.n.03","0","1"
# "cooked__diced__ham.n.01","","0","1"
# "cooked__diced__pork_sausage.n.01","","0","1"
# "cooked__diced__potato.n.01","root_vegetable.n.01","0","1"
# "cooked__diced__steak.n.01","cut.n.06","0","1"
# "cooked__diced__tomato.n.01","solanaceous_vegetable.n.01","0","1"
# "cooked__diced__turkey.n.01","poultry.n.02","0","1"
# "cooked__diced__vidalia_onion.n.01","onion.n.03","0","1"
# "cooked__diced__virginia_ham.n.01","ham.n.01","0","1"
# "cooked__diced__whole_potato.n.01","","0","1"
# "cooked__diced__zucchini.n.01","summer_squash.n.02","0","1"
# "cooked__flour.n.01","","0","1"
# "cooked__granulated_sugar.n.01","sugar.n.01","0","1"
# "cooked__ground_beef.n.01","beef.n.02","0","1"
# "cooked__kidney_bean.n.01","common_bean.n.01","0","1"
# "cooked__lemon-pepper_seasoning.n.01","","0","1"
# "cooked__marinade.n.01","condiment.n.01","0","1"
# "cooked__marinara.n.01","spaghetti_sauce.n.01","0","1"
# "cooked__melted__butter.n.01","","0","1"
# "cooked__noodle.n.01","pasta.n.02","0","1"
# "cooked__olive_oil.n.01","vegetable_oil.n.01","0","1"
# "cooked__onion_powder.n.01","flavorer.n.01","0","1"
# "cooked__oregano.n.01","origanum.n.01","0","1"
# "cooked__orzo.n.01","pasta.n.02","0","1"
# "cooked__paprika.n.01","flavorer.n.01","0","1"
# "cooked__pasta.n.01","food.n.02","0","1"
# "cooked__popcorn.n.01","corn.n.01","0","1"
# "cooked__pumpkin_seed.n.01","edible_seed.n.01","0","1"
# "cooked__quinoa.n.01","grain.n.01","0","1"
# "cooked__ramen.n.01","dish.n.02","0","1"
# "cooked__red_meat_sauce.n.01","spaghetti_sauce.n.01","0","1"
# "cooked__red_wine.n.01","wine.n.01","0","1"
# "cooked__saffron.n.01","flavorer.n.01","0","1"
# "cooked__salsa.n.01","condiment.n.01","0","1"
# "cooked__salt.n.01","flavorer.n.01","0","1"
# "cooked__soup.n.01","dish.n.02","0","1"
# "cooked__sunflower_seed.n.01","edible_seed.n.01","0","1"
# "cooked__water.n.01","food.n.01","0","1"
# "cooked__white_rice.n.01","rice.n.01","0","1"
# "cooked__white_wine.n.01","wine.n.01","0","1"
# "cooked__wine_sauce.n.01","","0","1"
# "cooker.n.01","cooking_utensil.n.01","0","0"
# "cookie_cutter.n.01","kitchen_utensil.n.01","0","0"
# "cookie_dough.n.01","dough.n.01","0","1"
# "cookie_sheet.n.01","cooking_utensil.n.01","1","0"
# "cookie_sheet.n.01","cooking_utensil.n.01","1","0"
# "cookie.n.01","cake.n.03","0","0"
# "cooking_oil__bottle.n.01","vessel.n.03","0","1"
# "cooking_oil.n.01","vegetable_oil.n.01","0","0"
# "cooking_utensil.n.01","kitchen_utensil.n.01","0","0"
# "cooler.n.01","refrigerator.n.01","0","0"
# "copper_mug.n.01","mug.n.01","0","1"
# "copper_wire.n.01","","0","1"
# "copper.n.01","conductor.n.02,metallic_element.n.01","0","0"
# "cord.n.01","line.n.18","0","0"
# "coriander__shaker.n.01","container.n.01","0","1"
# "coriander.n.02","flavorer.n.01","0","0"
# "coriander.n.03","herb.n.02","0","0"
# "cork.n.01","bark.n.01,plant_material.n.01","0","0"
# "corkscrew.n.01","bottle_opener.n.01","0","0"
# "corn_flake__box.n.01","container.n.01","0","1"
# "corn_flake.n.01","cold_cereal.n.01","0","0"
# "corn_syrup.n.01","syrup.n.01","0","0"
# "corn.n.01","cereal.n.01","0","0"
# "cornbread.n.01","quick_bread.n.01","0","0"
# "cornet.n.01","brass.n.02","0","0"
# "cornmeal__sack.n.01","container.n.01","0","1"
# "cornmeal.n.01","meal.n.03","0","0"
# "cornstarch__jar.n.01","vessel.n.03","0","1"
# "cornstarch.n.01","starch.n.01","0","0"
# "cosmetic.n.01","toiletry.n.01","0","0"
# "costume.n.01","attire.n.01","0","0"
# "cottage_cheese.n.01","cheese.n.01","0","0"
# "cotton_ball.n.01","plant_disease.n.01","0","0"
# "cotton.n.01","plant_fiber.n.01","0","0"
# "cotton.n.02","fabric.n.01","0","0"
# "cotton.n.04","thread.n.01","0","0"
# "counter.n.01","table.n.02","0","0"
# "countertop.n.01","tabletop.n.01","0","0"
# "cpu_board.n.01","circuit_board.n.01","0","0"
# "crab.n.05","shellfish.n.01","0","0"
# "cracker.n.01","bread.n.01","0","0"
# "cranberry_juice.n.01","fruit_juice.n.01","0","0"
# "cranberry.n.01","shrub.n.01","0","0"
# "cranberry.n.02","berry.n.01,berry.n.02","0","0"
# "crate.n.01","box.n.01","0","0"
# "crayfish.n.02","shellfish.n.01","0","0"
# "crayon.n.01","writing_implement.n.01","0","0"
# "cream__carton.n.01","vessel.n.03","0","1"
# "cream_cheese__box.n.01","container.n.01","0","1"
# "cream_cheese.n.01","cheese.n.01","0","0"
# "cream_of_tartar__shaker.n.01","container.n.01","0","1"
# "cream_of_tartar.n.01","salt.n.01","0","0"
# "cream_pitcher.n.01","pitcher.n.02","0","0"
# "cream_soda.n.01","soft_drink.n.01","0","0"
# "cream.n.02","dairy_product.n.01","0","0"
# "credit_card.n.01","open-end_credit.n.01,positive_identification.n.01","0","0"
# "crescent_roll.n.01","bun.n.01","0","0"
# "crewneck_sweater.n.01","sweater.n.01","0","1"
# "crib.n.01","baby_bed.n.01","0","0"
# "cringle.n.01","fastener.n.02","0","0"
# "crock_pot.n.01","cooker.n.01","0","0"
# "crossbar.n.01","bar.n.03","0","0"
# "crouton.n.01","bread.n.01","0","0"
# "cruet.n.01","bottle.n.01","0","0"
# "crumb.n.03","morsel.n.02","0","0"
# "crust.n.02","covering.n.01","0","0"
# "crystal.n.01","solid.n.01","0","0"
# "crystal.n.03","rock.n.01","0","0"
# "cucumber.n.02","vegetable.n.01","0","0"
# "cue.n.04","sports_implement.n.01","0","0"
# "cumin__shaker.n.01","container.n.01","0","1"
# "cumin.n.02","edible_seed.n.01","0","0"
# "cup__of__yogurt.n.01","grocery.n.02","0","1"
# "cup_holder.n.01","holder.n.01","0","1"
# "cup.n.01","container.n.01,crockery.n.01","0","0"
# "cup.n.03","concave_shape.n.01","0","0"
# "cupboard.n.01","storage_space.n.01","0","0"
# "cupcake.n.01","cake.n.03","0","0"
# "curry_powder__shaker.n.01","container.n.01","0","1"
# "curry_powder.n.01","flavorer.n.01","0","0"
# "curry.n.01","dish.n.02","0","0"
# "curtain_rod.n.01","rod.n.01","0","1"
# "curtain.n.01","blind.n.03,furnishing.n.02","0","0"
# "cushion.n.03","padding.n.01","0","0"
# "custard.n.01","dish.n.02","0","0"
# "cut_of_pork.n.01","cut.n.06","0","0"
# "cutter.n.06","cutting_implement.n.01","0","0"
# "cymbal.n.01","percussion_instrument.n.01","0","0"
# "daffodil.n.01","narcissus.n.01","0","0"
# "dahlia.n.01","flower.n.01","0","0"
# "dairy.n.01","farm.n.01","0","0"
# "danish.n.02","sweet_roll.n.01","0","0"
# "dart.n.01","projectile.n.01","0","0"
# "dartboard.n.01","board.n.09","0","0"
# "date.n.08","edible_fruit.n.01","0","0"
# "debris.n.01","rubbish.n.01","0","0"
# "decoration.n.01","artifact.n.01","0","0"
# "deep_fryer.n.01","kitchen_appliance.n.01","0","1"
# "deep-freeze.n.01","electric_refrigerator.n.01","0","0"
# "deep-freeze.n.02","refrigerator.n.01","0","1"
# "dehumidifier.n.01","appliance.n.02","0","1"
# "dental_floss.n.01","thread.n.01","0","0"
# "denture.n.01","dental_appliance.n.01","0","0"
# "deodorant__atomizer.n.01","dispenser.n.01","0","1"
# "deodorant__stick.n.01","grocery.n.02","0","1"
# "deodorant.n.01","toiletry.n.01","0","0"
# "desiccant.n.01","chemical_agent.n.01","0","0"
# "desk_phone.n.01","telephone.n.01","0","0"
# "desk.n.01","table.n.02","0","0"
# "desktop_computer.n.01","personal_computer.n.01","0","0"
# "dessert_spoon.n.01","spoon.n.01","0","0"
# "dessert.n.01","course.n.07","0","0"
# "detector.n.01","device.n.01","0","0"
# "detergent__atomizer.n.01","dispenser.n.01","0","1"
# "detergent__bottle.n.01","vessel.n.03","1","1"
# "detergent__bottle.n.01","container.n.01","1","1"
# "detergent.n.02","cleansing_agent.n.01","0","0"
# "dial.n.03","indicator.n.03","0","0"
# "diamond.n.01","jewel.n.01","0","0"
# "diaper.n.01","garment.n.01","0","0"
# "diced__apple.n.01","","0","1"
# "diced__avocado.n.01","edible_fruit.n.01","0","1"
# "diced__beef_roast.n.01","roast.n.01","0","1"
# "diced__beefsteak_tomato.n.01","tomato.n.01","0","1"
# "diced__beetroot.n.01","beet.n.01","0","1"
# "diced__bell_pepper.n.01","sweet_pepper.n.02","0","1"
# "diced__bratwurst.n.01","pork_sausage.n.01","0","1"
# "diced__broccoli.n.01","cruciferous_vegetable.n.01","0","1"
# "diced__cabbage.n.01","crucifer.n.01","0","1"
# "diced__carrot.n.01","root_vegetable.n.01","0","1"
# "diced__celery.n.01","","0","1"
# "diced__chard.n.01","","0","1"
# "diced__cheddar.n.01","cheese.n.01","0","1"
# "diced__cheese.n.01","dairy_product.n.01","0","1"
# "diced__chicken_breast.n.01","poultry.n.02","0","1"
# "diced__chicken.n.01","poultry.n.02","0","1"
# "diced__chili.n.01","hot_pepper.n.02","0","1"
# "diced__clove.n.01","garlic.n.02","0","1"
# "diced__cucumber.n.01","vegetable.n.01","0","1"
# "diced__feta.n.01","cheese.n.01","0","1"
# "diced__garlic.n.01","flavorer.n.01","0","1"
# "diced__green_onion.n.01","onion.n.03","0","1"
# "diced__ham.n.01","","0","1"
# "diced__kiwi.n.01","","1","1"
# "diced__kiwi.n.01","edible_fruit.n.01","1","1"
# "diced__lemon.n.01","citrus.n.01","0","1"
# "diced__lettuce.n.01","salad_green.n.01","0","1"
# "diced__mango.n.01","edible_fruit.n.01","0","1"
# "diced__pineapple.n.01","edible_fruit.n.01","0","1"
# "diced__pork_sausage.n.01","","0","1"
# "diced__potato.n.01","root_vegetable.n.01","0","1"
# "diced__spinach.n.01","greens.n.01","0","1"
# "diced__steak.n.01","cut.n.06","0","1"
# "diced__sweet_pepper.n.01","","0","1"
# "diced__tomato.n.01","solanaceous_vegetable.n.01","0","1"
# "diced__vidalia_onion.n.01","onion.n.03","0","1"
# "diced__virginia_ham.n.01","ham.n.01","0","1"
# "diced__watermelon.n.01","melon.n.01","0","1"
# "diced__whole_potato.n.01","","0","1"
# "diced__zucchini.n.01","summer_squash.n.02","0","1"
# "die.n.01","cube.n.05","1","0"
# "die.n.01","cube.n.05","1","0"
# "digital_camera.n.01","camera.n.01","0","0"
# "dinner_napkin.n.01","napkin.n.01","0","0"
# "dinner_plate.n.01","plate.n.04","0","0"
# "dinner.n.01","meal.n.01","0","0"
# "dip.n.07","candle.n.01","0","0"
# "dipper.n.01","ladle.n.01","0","0"
# "dirt.n.02","dirtiness.n.01","0","0"
# "dish_rack.n.01","rack.n.01","0","0"
# "dish.n.01","container.n.01,crockery.n.01","0","0"
# "dish.n.02","nutriment.n.01","0","0"
# "dishtowel.n.01","towel.n.01","0","0"
# "dishwasher.n.01","white_goods.n.01","0","0"
# "disinfectant__bottle.n.01","vessel.n.03","0","1"
# "disinfectant.n.01","agent.n.03","0","0"
# "disk_drive.n.01","drive.n.10","0","0"
# "disk.n.01","round_shape.n.01","0","0"
# "dispenser.n.01","container.n.01","0","0"
# "display_panel.n.01","display.n.06","0","0"
# "disposal.n.04","kitchen_appliance.n.01","0","0"
# "diving_board.n.01","springboard.n.01","0","0"
# "dixie_cup.n.01","cup.n.01","0","0"
# "document.n.01","writing.n.02","0","0"
# "dog_collar.n.01","collar.n.06","0","0"
# "dog_food__bag.n.01","container.n.01","0","1"
# "dog_food__can.n.01","","0","1"
# "dog_food.n.01","petfood.n.01","0","0"
# "doily.n.01","linen.n.03","0","0"
# "doll.n.01","plaything.n.01","0","0"
# "door.n.01","movable_barrier.n.01","0","0"
# "double_boiler.n.01","saucepan.n.01","0","0"
# "dough.n.01","concoction.n.01","0","0"
# "doughnut.n.02","friedcake.n.01","0","0"
# "dowel.n.01","fastener.n.02","0","0"
# "drawers.n.01","underpants.n.01","0","0"
# "dreidel.n.01","top.n.08","0","1"
# "dress_shirt.n.01","shirt.n.01","0","0"
# "dress.n.01","woman's_clothing.n.01","0","0"
# "dressing.n.01","sauce.n.01","0","0"
# "dried_apricot.n.01","dried_fruit.n.01","0","0"
# "dried_fruit.n.01","edible_fruit.n.01","0","0"
# "drill.n.01","tool.n.01","0","0"
# "drink_dispenser.n.01","dispenser.n.01","0","1"
# "drinking_fountain.n.01","fountain.n.01","0","0"
# "drinking_fountain.n.02","structure.n.01","0","1"
# "drip_coffee.n.01","coffee.n.01","0","0"
# "drip_pot.n.01","coffeepot.n.01","0","0"
# "driveway.n.01","road.n.01","0","0"
# "drug.n.01","agent.n.03","0","0"
# "drum.n.01","percussion_instrument.n.01","0","0"
# "drumstick.n.01","helping.n.01","0","0"
# "drumstick.n.02","stick.n.01","0","0"
# "dry_food_dispenser_shelf.n.01","dispenser.n.01","0","1"
# "dryer.n.01","appliance.n.02","0","0"
# "drying_rack.n.01","rack.n.01","0","1"
# "duck.n.03","poultry.n.02","0","0"
# "duct_tape.n.01","adhesive_tape.n.01","0","0"
# "duffel_bag.n.01","drawstring_bag.n.01","0","0"
# "dumpling.n.01","pasta.n.02","0","0"
# "dumpling.n.02","dessert.n.01","0","0"
# "durian.n.02","edible_fruit.n.01","0","0"
# "dust.n.01","particulate.n.01","0","0"
# "dustcloth.n.01","piece_of_cloth.n.01","0","0"
# "dustpan.n.02","receptacle.n.01","0","0"
# "dutch_oven.n.01","oven.n.01","0","0"
# "dutch_oven.n.02","pot.n.01","0","0"
# "dye.n.01","coloring_material.n.01","0","0"
# "eames_chair.n.01","chair.n.01","0","0"
# "easel.n.01","tripod.n.01","0","0"
# ...
# "spatula.n.02","hand_tool.n.01","0","0"
# "specimen_bottle.n.01","bottle.n.01","0","0"
# "spectacles.n.01","optical_instrument.n.01","0","0"
# "spice_cookie_dough.n.01","","0","1"
# "spice_cookie.n.01","cookie.n.01","0","0"
# "spice.n.02","flavorer.n.01","0","0"
# "spike_lavender.n.01","lavender.n.01","0","0"
# "spinach.n.02","greens.n.01","0","0"
# "spirit_lamp.n.01","lamp.n.01","0","0"
# "sponge_cake.n.01","cake.n.03","0","0"
# "sponge.n.01","absorbent_material.n.01","0","0"
# "spoon.n.01","container.n.01,cutlery.n.02","0","0"
# "sport_utility.n.01","car.n.01","0","0"
# "sports_equipment.n.01","equipment.n.01","0","0"
# "spotlight.n.02","lamp.n.01","0","0"
# "spray_paint__can.n.01","dispenser.n.01","0","1"
# "spray_paint.n.01","paint.n.01","0","0"
# "spread.n.05","condiment.n.01","0","0"
# "sprinkler.n.01","mechanical_device.n.01","0","0"
# "sprout.n.01","plant_organ.n.01","0","0"
# "square.n.08","hand_tool.n.01","0","0"
# "squash.n.02","vegetable.n.01","0","0"
# "squeegee.n.01","cleaning_implement.n.01","0","0"
# "squid.n.01","seafood.n.01","0","0"
# "stain.n.01","appearance.n.01","0","0"
# "stake.n.05","post.n.04","0","0"
# "stalk.n.02","plant_organ.n.01","1","0"
# "stalk.n.02","plant_organ.n.01","1","0"
# "stamp.n.03","symbol.n.01","0","0"
# "stand.n.04","table.n.02","0","0"
# "stand.n.10","tiered_seat.n.01","0","0"
# "staple_gun.n.01","machine.n.01","0","0"
# "staple.n.04","nail.n.02","0","0"
# "staple.n.05","paper_fastener.n.01","0","0"
# "stapler.n.01","machine.n.01","0","0"
# "starch.n.01","polysaccharide.n.01","0","0"
# "statue.n.01","sculpture.n.01","0","0"
# "steak.n.01","cut.n.06","0","0"
# "steam.n.01","vapor.n.01","0","0"
# "steamer.n.02","cooking_utensil.n.01","0","0"
# "steel_wool.n.01","abrasive.n.01","0","0"
# "steel.n.03","sharpener.n.01","0","0"
# "steering_wheel.n.01","handwheel.n.02","0","0"
# "stencil.n.01","sheet.n.06","0","0"
# "step.n.04","support.n.10","0","0"
# "stereo.n.01","reproducer.n.01","0","0"
# "stew__carton.n.01","vessel.n.03","0","1"
# "stew.n.02","dish.n.02","0","0"
# "stick.n.01","implement.n.01","0","0"
# "sticky_note.n.01","pad.n.01","0","1"
# "stirrer.n.02","implement.n.01","0","0"
# "stocking.n.01","hosiery.n.01","0","0"
# "stockpot.n.01","pot.n.01","0","0"
# "stool.n.01","seat.n.03","0","0"
# "storage_organizer.n.01","","0","1"
# "store.n.02","accumulation.n.04","0","0"
# "stove.n.01","kitchen_appliance.n.01","0","0"
# "straight_chair.n.01","chair.n.01","0","0"
# "straight_pin.n.01","pin.n.09","0","0"
# "straightener.n.01","device.n.01","0","0"
# "strainer.n.01","filter.n.01","0","0"
# "straw.n.04","tube.n.01","0","0"
# "strawberry.n.01","berry.n.01","0","0"
# "string.n.01","cord.n.01","0","0"
# "stucco.n.01","plaster.n.01","0","0"
# "stud.n.02","decoration.n.01","0","0"
# "stuffing.n.01","concoction.n.01","0","0"
# "succulent.n.01","vascular_plant.n.01","0","0"
# "suede.n.01","leather.n.01","0","0"
# "sugar__sack.n.01","container.n.01","0","1"
# "sugar_coffee_scrub.n.01","soap.n.01","0","1"
# "sugar_cookie_dough.n.01","","0","1"
# "sugar_cookie.n.01","cookie.n.01","0","0"
# "sugar_syrup__bottle.n.01","vessel.n.03","0","1"
# "sugar_syrup.n.01","syrup.n.01","0","0"
# "sugar.n.01","sweetening.n.01","0","0"
# "suit.n.01","garment.n.01","0","0"
# "summer_squash.n.01","squash.n.01","0","0"
# "sunflower_seed__bag.n.01","container.n.01","0","1"
# "sunflower_seed.n.01","edible_seed.n.01","0","0"
# "sunflower.n.01","flower.n.01","0","0"
# "sunglass.n.01","converging_lens.n.01","0","0"
# "sunglasses.n.01","spectacles.n.01","0","0"
# "sunglasses.n.02","optical_instrument.n.01","0","1"
# "sunscreen__bottle.n.01","vessel.n.03","0","1"
# "sunscreen.n.01","cream.n.03","0","0"
# "supply.n.01","indefinite_quantity.n.01","0","0"
# "sushi.n.01","dish.n.02","0","0"
# "swab.n.02","cleaning_implement.n.01","1","0"
# "swab.n.02","cleaning_implement.n.01","1","0"
# "sweat_suit.n.01","garment.n.01","0","0"
# "sweater.n.01","garment.n.01","0","0"
# "sweatshirt.n.01","pullover.n.01","0","0"
# "sweet_corn.n.02","corn.n.03","0","0"
# "sweet_pepper.n.01","capsicum.n.01","0","0"
# "sweet_potato.n.01","morning_glory.n.01","0","0"
# "sweetening.n.01","flavorer.n.01","0","0"
# "swimming_pool.n.01","athletic_facility.n.01,pool.n.01","0","0"
# "swimsuit.n.01","garment.n.01","0","0"
# "swing.n.02","mechanical_device.n.01,plaything.n.01","0","0"
# "swiss_cheese.n.01","cheese.n.01","0","0"
# "switch.n.01","control.n.09","0","0"
# "swivel_chair.n.01","chair.n.01","0","0"
# "syringe.n.01","medical_instrument.n.01","0","0"
# "syrup.n.01","sweetening.n.01","0","0"
# "table_knife.n.01","cutlery.n.02,knife.n.01","0","0"
# "table_lamp.n.01","lamp.n.02","0","0"
# "table_linen.n.01","linen.n.03","0","0"
# "table.n.02","furniture.n.01","0","0"
# "tablecloth.n.01","table_linen.n.01","0","0"
# "tablefork.n.01","fork.n.01","0","0"
# "tablespoon.n.02","spoon.n.01","0","0"
# "tablet.n.03","cake.n.01","0","0"
# "taboret.n.01","stool.n.01","0","0"
# "tack.n.02","nail.n.02","0","0"
# "taco.n.02","dish.n.02","0","0"
# "tag.n.01","label.n.04","0","0"
# "tag.n.02","label.n.04","0","0"
# "talcum.n.02","toilet_powder.n.01","0","0"
# "tank_top.n.01","shirt.n.01","0","0"
# "tank.n.02","vessel.n.03","0","0"
# "tap.n.06","plug.n.01","0","0"
# "tape.n.01","strip.n.02","0","0"
# "tape.n.04","measuring_instrument.n.01","1","0"
# "tape.n.04","measuring_instrument.n.01","1","0"
# "tarnish.n.01","stain.n.01","0","0"
# "tarpaulin.n.01","canvas.n.01","0","0"
# "tart.n.02","pie.n.01","0","0"
# "tartar.n.04","crust.n.02","0","0"
# "tartlet.n.01","tart.n.02","0","0"
# "tassel.n.01","adornment.n.01","0","0"
# "tea_bag.n.01","tea.n.05","0","0"
# "tea.n.01","beverage.n.01","0","0"
# "tea.n.05","herb.n.02","1","0"
# "tea.n.05","herb.n.02","1","0"
# "teacup.n.02","cup.n.01","0","0"
# "teapot.n.01","pot.n.01","0","0"
# "teaspoon.n.02","spoon.n.01","0","0"
# "teddy.n.01","plaything.n.01","0","0"
# "television_receiver.n.01","receiver.n.01","0","0"
# "tenderloin.n.02","cut.n.06","0","0"
# "tennis_ball.n.01","ball.n.01","0","0"
# "tennis_racket.n.01","racket.n.04","0","0"
# "tent.n.01","shelter.n.01","0","0"
# "tequila__bottle.n.01","vessel.n.03","0","1"
# "tequila.n.01","liquor.n.01","0","0"
# "terrarium.n.01","vivarium.n.01","0","0"
# "test_tube_rack.n.01","rack.n.01","0","1"
# "test_tube.n.01","tube.n.01","0","0"
# "textbook.n.01","book.n.01","0","0"
# "thermometer.n.01","measuring_instrument.n.01","0","0"
# "thermos.n.01","vacuum_flask.n.01","0","0"
# "thermostat.n.01","regulator.n.01","0","0"
# "thread.n.01","cord.n.01","0","0"
# "throw.n.04","bedclothes.n.01","0","0"
# "thumbtack.n.01","paper_fastener.n.01,tack.n.02","0","0"
# "thyme__shaker.n.01","container.n.01","0","1"
# "thyme.n.02","herb.n.02","0","0"
# "ticket.n.01","commercial_document.n.01","0","0"
# "tie.n.09","cord.n.01","0","0"
# "tights.n.01","hosiery.n.01","0","0"
# "tile.n.01","slab.n.01","0","0"
# "timer.n.03","governor.n.02","0","0"
# "tinsel.n.02","thread.n.01","0","0"
# "tiramisu.n.01","dessert.n.01","0","0"
# "tire.n.01","hoop.n.02","0","0"
# "tissue_dispenser.n.01","dispenser.n.01","0","1"
# "tissue.n.02","paper.n.01","0","0"
# "toast.n.01","bread.n.01","0","0"
# "toaster_oven.n.01","kitchen_appliance.n.01","0","0"
# "toaster.n.02","kitchen_appliance.n.01","0","0"
# "toasting_fork.n.01","fork.n.01","0","0"
# "tofu.n.02","curd.n.01","0","1"
# "toilet_paper_dispenser.n.01","home_appliance.n.01","0","1"
# "toilet_paper_holder.n.01","holder.n.01","0","1"
# "toilet_soap__bottle.n.01","vessel.n.03","0","1"
# "toilet_soap.n.01","soap.n.01","0","0"
# "toilet_tissue.n.01","tissue.n.02","0","0"
# "toilet.n.01","room.n.01","0","0"
# "toilet.n.02","plumbing_fixture.n.01","0","0"
# "toiletry.n.01","instrumentality.n.03","0","0"
# "tomato_juice__bottle.n.01","vessel.n.03","0","1"
# "tomato_juice.n.01","juice.n.01","0","0"
# "tomato_paste__can.n.01","container.n.01","0","1"
# "tomato_paste.n.01","ingredient.n.03","0","0"
# "tomato_rice.n.01","","0","1"
# "tomato_sauce__jar.n.01","vessel.n.03","0","1"
# "tomato_sauce.n.01","spaghetti_sauce.n.01","0","0"
# "tomato.n.01","solanaceous_vegetable.n.01","0","0"
# "tongs.n.01","device.n.01","0","0"
# "tonic.n.01","soft_drink.n.01","0","0"
# "toolbox.n.01","chest.n.02","0","0"
# "toothbrush.n.01","brush.n.02,toiletry.n.01","0","0"
# "toothpaste.n.01","dentifrice.n.01","0","0"
# "toothpick.n.01","pick.n.06,strip.n.05","0","0"
# "tortilla_chip.n.01","corn_chip.n.01","0","0"
# "tortilla.n.01","pancake.n.01","0","0"
# "towel_rack.n.01","rack.n.01","0","0"
# "towel.n.01","piece_of_cloth.n.01","0","0"
# "toy_box.n.01","chest.n.02","0","0"
# "toy_figure.n.01","plaything.n.01","0","1"
# "trailer.n.03","conveyance.n.03","0","0"
# "train_set.n.01","plaything.n.01","0","0"
# "trampoline.n.01","gymnastic_apparatus.n.01","0","0"
# "trap.n.01","device.n.01","0","0"
# "tray.n.01","receptacle.n.01","0","0"
# "treadmill.n.01","exercise_device.n.01","0","0"
# "tree.n.01","woody_plant.n.01","0","0"
# "trimmer.n.02","machine.n.01","0","0"
# "tripod.n.01","rack.n.05","0","0"
# "trombone.n.01","brass.n.02","0","0"
# "trophy_case.n.01","case.n.20","0","0"
# "trophy.n.02","award.n.02","0","0"
# "trouser.n.01","garment.n.01","1","0"
# "trouser.n.01","garment.n.01","1","0"
# "trout.n.02","food_fish.n.01,salmonid.n.01","0","0"
# "trowel.n.01","hand_tool.n.01","0","0"
# "truck.n.01","motor_vehicle.n.01","0","0"
# "trunk.n.01","stalk.n.02","0","0"
# "tub.n.02","vessel.n.03","0","0"
# "tube__of__lotion.n.01","grocery.n.02","0","1"
# "tube__of__toothpaste.n.01","grocery.n.02","0","1"
# "tube.n.01","conduit.n.01","0","0"
# "tuber.n.01","stalk.n.02","0","0"
# "tulip.n.01","liliaceous_plant.n.01","0","0"
# "tumbler.n.02","glass.n.02","0","0"
# "tuna.n.02","saltwater_fish.n.01","0","0"
# "tupperware.n.01","container.n.01","0","1"
# "turf.n.01","land.n.02","0","0"
# "turkey_leg.n.01","drumstick.n.01","0","0"
# "turkey.n.01","domestic_fowl.n.01","0","0"
# "turkey.n.04","poultry.n.02","0","0"
# "turmeric.n.02","flavorer.n.01","0","0"
# "turnip.n.01","turnip_plant.n.01","0","0"
# "turnip.n.02","cruciferous_vegetable.n.01,root_vegetable.n.01","0","0"
# "turnstile.n.01","gate.n.01","0","0"
# "turnstile.n.02","movable_barrier.n.01","0","1"
# "turtleneck.n.01","jersey.n.03,sweater.n.01","0","0"
# "tweezers.n.01","hand_tool.n.01","0","1"
# "umbrella_rack.n.01","rack.n.01","0","1"
# "umbrella.n.01","canopy.n.03","0","0"
# "underwear.n.01","undergarment.n.01","0","0"
# "urinal.n.01","plumbing_fixture.n.01","0","0"
# "utensil.n.01","implement.n.01","0","0"
# "utility_knife.n.01","knife.n.01","0","1"
# "vacuum.n.04","home_appliance.n.01","0","0"
# "valve.n.01","structure.n.04","0","0"
# "van.n.05","truck.n.01","0","0"
# "vanilla__bottle.n.01","vessel.n.03","0","1"
# "vanilla.n.01","orchid.n.01","0","0"
# "vanilla.n.02","flavorer.n.01","0","0"
# "varnish.n.01","coating.n.01","0","0"
# "vase.n.01","jar.n.01","0","0"
# "vaseline.n.01","petrolatum.n.01","0","0"
# "veal.n.01","meat.n.01","0","0"
# "vegetable_oil__bottle.n.01","vessel.n.03","0","1"
# "vegetable_oil.n.01","edible_fat.n.01","0","0"
# "vegetable.n.01","produce.n.01","0","0"
# "vegetable.n.02","herb.n.01","0","0"
# "velcro.n.01","fabric.n.01","0","0"
# "velvet.n.01","fabric.n.01","0","0"
# "vending_machine.n.01","slot_machine.n.01","0","0"
# "venison.n.01","game.n.07","0","0"
# "vent.n.01","hole.n.02","0","0"
# "ventilator.n.01","device.n.01","0","0"
# "verdigris.n.02","patina.n.01","0","0"
# "vessel.n.03","container.n.01","0","0"
# "vest.n.01","garment.n.01","0","0"
# "vidalia_onion.n.01","onion.n.03","0","0"
# "videodisk.n.01","optical_disk.n.01","0","0"
# "vine.n.01","vascular_plant.n.01","0","0"
# "vinegar__atomizer.n.01","dispenser.n.01","0","1"
# "vinegar__bottle.n.01","vessel.n.03","0","1"
# "vinegar_cleaning_solution.n.01","cleansing_agent.n.01","0","1"
# "vinegar.n.01","condiment.n.01","0","0"
# "vinyl.n.02","plastic.n.01","0","0"
# "violin_case.n.01","case.n.05","0","1"
# "violin.n.01","bowed_stringed_instrument.n.01","0","0"
# "virgin_birth.n.02","theological_doctrine.n.01","0","0"
# "virginia_ham.n.01","ham.n.01","0","0"
# "vitamin_pill__bottle.n.01","vessel.n.03","0","1"
# "vitamin_pill.n.01","dietary_supplement.n.01,pill.n.01","0","0"
# "vodka__bottle.n.01","vessel.n.03","0","1"
# "vodka_bottle.n.01","vessel.n.03","0","1"
# "vodka.n.01","liquor.n.01","0","0"
# "volleyball_net.n.01","net.n.05","0","0"
# "volleyball.n.02","ball.n.01","0","0"
# "wading_pool.n.01","pool.n.01","0","0"
# "wafer.n.02","cookie.n.01","0","0"
# "waffle_batter.n.01","","0","1"
# "waffle_iron.n.01","kitchen_appliance.n.01","0","0"
# "waffle.n.01","cake.n.03","0","0"
# "wagon.n.04","wheeled_vehicle.n.01","0","0"
# "walker.n.04","shoe.n.01","0","0"
# "walking_shoe.n.01","shoe.n.01","0","0"
# "wall_clock.n.01","clock.n.01","0","0"
# "wall_socket.n.01","receptacle.n.03","1","0"
# "wall_socket.n.01","receptacle.n.03","1","0"
# "wall.n.01","partition.n.01","0","0"
# "wallboard.n.01","board.n.03","0","0"
# "wallet.n.01","case.n.05","0","0"
# "wallpaper.n.01","paper.n.01","0","0"
# "walnut.n.01","edible_nut.n.01","0","0"
# "wardrobe.n.01","furniture.n.01","0","0"
# "washer.n.03","white_goods.n.01","0","0"
# "watch.n.01","timepiece.n.01","0","0"
# "water__atomizer.n.01","dispenser.n.01","0","1"
# "water_bottle.n.01","bottle.n.01","0","0"
# "water_cooler.n.01","device.n.01","0","0"
# "water_dispenser.n.01","dispenser.n.01","0","1"
# "water_faucet.n.01","faucet.n.01,plumbing_fixture.n.01","0","0"
# "water_filter.n.01","filter.n.01","0","0"
# "water_glass.n.02","glass.n.02","0","0"
# "water.n.06","food.n.01,liquid.n.01,nutrient.n.02","0","0"
# "watering_can.n.01","container.n.01","0","0"
# "watermelon.n.02","melon.n.01","0","0"
# "wax__jar.n.01","vessel.n.03","0","1"
# "wax_paper.n.01","paper.n.01","0","0"
# "wax.n.01","lipid.n.01","0","0"
# "webcam.n.01","digital_camera.n.01","0","0"
# "webcam.n.02","camera.n.01","0","1"
# "weed.n.01","vascular_plant.n.01","0","0"
# "weight.n.02","sports_equipment.n.01","0","0"
# "wheat.n.02","grain.n.02","0","0"
# "wheel.n.01","machine.n.04","0","0"
# "whetstone.n.01","stone.n.02","0","0"
# "whipped_cream__atomizer.n.01","dispenser.n.01","0","1"
# "whipped_cream__can.n.01","dispenser.n.01","0","1"
# "whipped_cream.n.01","topping.n.01","0","0"
# "whisk.n.01","mixer.n.04","0","0"
# "whiskey__bottle.n.01","vessel.n.03","0","1"
# "whiskey_bottle.n.01","bottle.n.01","0","0"
# "whiskey_stone.n.01","rock.n.01","0","1"
# "whiskey.n.01","liquor.n.01","0","0"
# "whistle.n.01","sound.n.04","0","0"
# "whistle.n.04","acoustic_device.n.01,signaling_device.n.01","0","0"
# "white_bread.n.01","bread.n.01","0","0"
# "white_chocolate.n.01","chocolate.n.02","0","0"
# "white_rice__sack.n.01","container.n.01","0","1"
# "white_rice.n.01","rice.n.01","0","0"
# "white_sauce__bottle.n.01","vessel.n.03","0","1"
# "white_sauce.n.01","sauce.n.01","0","0"
# "white_turnip.n.02","turnip.n.02","0","0"
# "white_wine.n.01","wine.n.01","0","0"
# "whitewall_tire.n.01","tire.n.01","0","1"
# "whole_milk.n.01","milk.n.01","0","0"
# "whole_potato.n.01","","0","1"
# "wick.n.02","cord.n.01","0","0"
# "wicker_basket.n.01","basket.n.01","0","0"
# "wind_chime.n.01","decoration.n.01","0","0"
# "window_blind.n.01","blind.n.03","0","0"
# "window.n.01","framework.n.03","0","0"
# "windshield.n.01","screen.n.05","0","0"
# "wine_bottle.n.01","bottle.n.01","0","0"
# "wine_sauce__bottle.n.01","vessel.n.03","0","1"
# "wine_sauce.n.01","sauce.n.01","0","0"
# "wine.n.01","alcohol.n.01","0","0"
# "wineglass.n.01","glass.n.02","0","0"
# "wire_cutter.n.01","edge_tool.n.01","0","0"
# "wire.n.01","ligament.n.02","0","0"
# "wire.n.02","conductor.n.04","0","0"
# "wok.n.01","pan.n.01","0","0"
# "wood_chip.n.01","matchwood.n.01","0","1"
# "wood.n.01","plant_material.n.01","0","0"
# "wooden_spoon.n.01","booby_prize.n.01","0","0"
# "wooden_spoon.n.02","spoon.n.01,woodenware.n.01","0","0"
# "wool_coat.n.01","coat.n.01","0","1"
# "wool.n.01","fabric.n.01","0","0"
# "worcester_sauce.n.01","sauce.n.01","0","0"
# "worktable.n.01","table.n.02","0","0"
# "wrapped_hamburger.n.01","grocery.n.02","0","1"
# "wrapping_paper.n.01","paper.n.01","0","0"
# "wrapping.n.01","covering.n.02","0","0"
# "wreath.n.01","flower_arrangement.n.01","0","0"
# "wrench.n.03","hand_tool.n.01","0","0"
# "wrinkle.n.01","depression.n.08","0","0"
# "writing_paper.n.01","paper.n.01","0","0"
# "yam.n.01","tuber.n.01","0","0"
# "yam.n.03","sweet_potato.n.02","0","0"
# "yard.n.02","field.n.01","0","0"
# "yeast__bottle.n.01","vessel.n.03","0","1"
# "yeast__jar.n.01","vessel.n.03","0","1"
# "yeast.n.01","leaven.n.01","0","0"
# "yoga_mat.n.01","exercise_device.n.01","0","1"
# "yogurt__carton.n.01","vessel.n.03","0","1"
# "yogurt__cup.n.01","cup.n.01","0","1"
# "yogurt.n.01","dairy_product.n.01,food.n.02","0","0"
# "zucchini.n.02","summer_squash.n.02","0","0"

# %%
with open(r"D:\BEHAVIOR-1K\asset_pipeline\metadata\category_mapping.csv", "r") as f:
    category_mapping = list(csv.DictReader(f))

# %%
for r in category_mapping:
    if r["synset"] not in ctr:
        print(r["synset"])
# Out:
# mashed_potatoes.n.02

# %%
import networkx as nx
from nltk.corpus import wordnet as wn
import csv

def get_synset_graph():
    """
    Build the synset graph that includes all wordnet and custom synsets
    returns:
        G: the synset graph
    """
    # Build the legit-synset graph
    G = nx.DiGraph()
    G.add_nodes_from(x.name() for x in wn.all_synsets())
    for parent in wn.all_synsets():
        for child in parent.hyponyms():
            G.add_edge(parent.name(), child.name())
            
    # Add the illegit-synset (custom) graph
    with open(r"D:\BEHAVIOR-1K\asset_pipeline\metadata\custom_synsets.csv") as f:
        reader = csv.DictReader(f)
        for row in reader:
            child = row["synset"].strip()
            parents = row["hypernyms"].strip().split(",")
            custom = bool(int(row["is_custom"].strip()))
            if not custom or not parents:
                continue
            canonical_parent = wn.synset(parent).name()
            if canonical_parent != parent:
                print(f"Parent {parent} of {child} is not canonical in wordnet, using {canonical_parent} instead")
            if child in G.nodes:
                continue
            assert canonical_parent in G.nodes, f"Could not find {canonical_parent}"
            assert child not in G.nodes, f"Custom synset {child} already in wordnet!"
            G.add_edge(canonical_parent, child)
    return G


def canonicalize(s):
    try:
        return wn.synset(s).name()
    except:
        return s


def wn_synset_exists(synset):
  try:
    wn.synset(synset)
    return True
  except:
    return False

# %%
G = get_synset_graph()
