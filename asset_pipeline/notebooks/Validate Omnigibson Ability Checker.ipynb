# %%
import omnigibson as og
og.launch()

from omnigibson.utils.asset_utils import get_all_object_category_models_with_abilities
# Out:
# [INFO] [omnigibson.simulator] ----- Starting OmniGibson. This will take 10-30 seconds... -----
# Starting kit application with the following args:  ['/home/cgokmen/.local/share/ov/pkg/isaac_sim-2023.1.1/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/cgokmen/.local/share/ov/pkg/isaac_sim-2023.1.1/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/cgokmen/.local/share/ov/pkg/isaac_sim-2023.1.1/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=False', '--/app/fastShutdown=True', '--ext-folder', '/home/cgokmen/.local/share/ov/pkg/isaac_sim-2023.1.1/exts', '--ext-folder', '/home/cgokmen/.local/share/ov/pkg/isaac_sim-2023.1.1/apps', '--/physics/cudaDevice=0', '--portable']
# Passing the following args to the base kit application:  ['--ip=127.0.0.1', '--stdin=9008', '--control=9006', '--hb=9005', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"a3ce8065-5810-4406-9a98-3c3397ec706f"', '--shell=9007', '--transport="tcp"', '--iopub=9009', '--f=/home/cgokmen/.local/share/jupyter/runtime/kernel-v2-4803luWnLH33KjS1.json']
# [Info] [carb] Logging to file: /home/cgokmen/.local/share/ov/pkg/isaac_sim-2023.1.1/kit/logs/Kit/Isaac-Sim/2023.1/kit_20240314_151023.log
# 2024-03-14 22:10:23 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.036s] [ext: omni.kit.async_engine-0.0.0] startup
# [DEBUG] [asyncio] Using selector: EpollSelector
# [0.246s] [ext: omni.activity.core-1.0.1] startup
# [0.248s] [ext: omni.assets.plugins-0.0.0] startup
# [0.249s] [ext: omni.stats-0.0.0] startup
# [0.250s] [ext: omni.client-1.0.1] startup
# [0.255s] [ext: omni.activity.profiler-1.0.2] startup
# [0.256s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.262s] [ext: omni.rtx.shadercache.vulkan-1.0.0] startup
# [0.263s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.269s] [ext: omni.kit.renderer.init-0.0.0] startup
# 2024-03-14 22:10:23 s] [Error] [gpu.foundation.plugin] Multiple Installable Client Drivers (ICDs) are found for the same GPU on the system. This causes the same GPU to be reported multiple times by more than one driver and leads to instability or crash.
# For NVIDIA drivers, please follow troubleshooting docs to uninstall and completely purge Linux-distribution-provided driver packages, and then reinstall your driver cleanly via .run package. Otherwise, updating Ubuntu software may reinstall a secondary ICD or override the existing NVIDIA driver.
#
# To verify the proper NVIDIA driver installation, only one of the following icd.d folders should contain nvidia_icd.json file:
# /etc/vulkan/icd.d: Location of ICDs installed from non-Linux-distribution-provided packages
# /usr/share/vulkan/icd.d : Location of ICDs installed from Linux-distribution-provided packages
# [INFO] [omni.kit.telemetry.impl.sentry_extension] sentry is disabled for external build
# [INFO] [omni.kit.telemetry.impl.sentry_extension] sentry is disabled for external build
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 525.60.11     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          |        |     | 24810   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | e4cffc53.. |
# |     |                                  |        |     |            | 41        |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | NVIDIA GeForce RTX 4090          |        |     | 24810   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | e4cffc53.. |
# |     |                                  |        |     |            | 41        |            |
# |---------------------------------------------------------------------------------------------|
# | 2   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24810   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | de1d43a8.. |
# |     |                                  |        |     |            | 61        |            |
# |---------------------------------------------------------------------------------------------|
# | 3   | NVIDIA GeForce RTX 4090          |        |     | 24810   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | de1d43a8.. |
# |     |                                  |        |     |            | 61        |            |
# |=============================================================================================|
# | OS: 22.04.2 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.2, Kernel: 5.19.0-43-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: AMD Ryzen Threadripper PRO 5955WX 16-Cores | Cores: 16 | Logical: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 128646 | Free Memory: 99582
# | Total Page/Swap (MB): 65535 | Free Page/Swap: 53494
# |---------------------------------------------------------------------------------------------|
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin] IOMMU is enabled. Found 72 items in /sys/kernel/iommu_groups/.
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin] An input-output memory management unit (IOMMU) appears to be enabled on this system.
# On bare-metal Linux systems, CUDA and the display driver do not support IOMMU-enabled PCIe peer to peer memory copy.
# If you are on a bare-metal Linux system, please disable the IOMMU. Otherwise you risk image corruption and program instability.
# This typically can be controlled via BIOS settings (Intel Virtualization Technology for Directed I/O (VT-d) or AMD I/O Virtualization Technology (AMD-Vi)) and kernel parameters (iommu, intel_iommu, amd_iommu).
# Note that in virtual machines with GPU pass-through (vGPU) the IOMMU needs to be enabled.
# Since we can not reliably detect whether this system is bare-metal or a virtual machine, we show this warning in any case when an IOMMU appears to be enabled.
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin]
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin] -----------------------------------------------------------------------
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin] !!!!! Local system validation failed! Incorrect configuration detected.
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin]       Summary below. Details above.
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin] -----------------------------------------------------------------------
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin]
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin]  - ECC:                         OK
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin]  - IOMMU:                       FAILED
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin]
# 2024-03-14 22:10:24 s] [Warning] [gpu.foundation.plugin] -----------------------------------------------------------------------
# [1.097s] [ext: omni.kit.pipapi-0.0.0] startup
# [1.098s] [ext: omni.kit.pip_archive-0.0.0] startup
# [1.098s] [ext: omni.pip.compute-1.2.0] startup
# [1.099s] [ext: omni.pip.cloud-1.0.1] startup
# [1.100s] [ext: omni.isaac.core_archive-2.2.1] startup
# [1.101s] [ext: omni.pip.torch-2_0_1-2.0.2] startup
# [1.114s] [ext: omni.kit.telemetry-0.5.0] startup
# [1.136s] [ext: omni.kit.loop-isaac-1.1.0] startup
# [1.137s] [ext: omni.kit.test-0.0.0] startup
# [1.138s] [ext: omni.isaac.ml_archive-1.1.3] startup
# [1.139s] [ext: omni.mtlx-0.1.0] startup
# [1.139s] [ext: omni.usd.config-1.0.3] startup
# [1.143s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.143s] [ext: omni.usd.libs-1.0.0] startup
# [1.239s] [ext: omni.appwindow-1.1.5] startup
# [1.866s] [ext: omni.kit.renderer.core-0.0.0] startup
# [6.915s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [6.917s] [ext: omni.kit.renderer.imgui-0.0.0] startup
# [7.213s] [ext: carb.audio-0.1.0] startup
# [7.217s] [ext: omni.ui-2.18.5] startup
# [7.224s] [ext: omni.uiaudio-1.0.0] startup
# [7.225s] [ext: omni.kit.mainwindow-1.0.1] startup
# [7.226s] [ext: omni.kit.uiapp-0.0.0] startup
# [7.226s] [ext: omni.usd.schema.physics-0.0.0] startup
# [7.303s] [ext: omni.usd.schema.audio-0.0.0] startup
# [7.310s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [7.315s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [7.321s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [7.322s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [7.329s] [ext: omni.usd.schema.physx-0.0.0] startup
# [7.348s] [ext: omni.usd.schema.anim-0.0.0] startup
# [7.366s] [ext: omni.anim.navigation.schema-105.2.0] startup
# [7.369s] [ext: omni.anim.graph.schema-105.2.2] startup
# [7.375s] [ext: omni.usd.schema.isaac-2.0.1] startup
# [7.381s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [7.384s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [7.390s] [ext: omni.resourcemonitor-105.0.0] startup
# [7.391s] [ext: omni.timeline-1.0.9] startup
# [7.392s] [ext: omni.usd_resolver-1.0.1] startup
# [7.398s] [ext: omni.kit.window.popup_dialog-2.0.23] startup
# [7.400s] [ext: omni.graph.exec-0.3.0] startup
# [7.401s] [ext: omni.kit.actions.core-1.0.0] startup
# [7.402s] [ext: omni.usd.core-1.1.8] startup
# [7.408s] [ext: omni.kit.widget.nucleus_connector-1.1.4] startup
# [7.409s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [7.410s] [ext: omni.kit.exec.core-0.5.0] startup
# [7.411s] [ext: omni.kit.commands-1.4.6] startup
# [7.413s] [ext: omni.hydra.usdrt_delegate-7.2.34] startup
# [7.434s] [ext: omni.hydra.scene_delegate-0.3.2] startup
# [7.445s] [ext: omni.usd-1.10.18] startup
# [7.489s] [ext: omni.kit.widget.versioning-1.4.6] startup
# [7.491s] [ext: omni.kit.helper.file_utils-0.1.6] startup
# [7.505s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [7.505s] [ext: omni.kit.widget.filebrowser-2.3.35] startup
# [7.508s] [ext: omni.kit.search_core-1.0.5] startup
# [7.508s] [ext: omni.kit.widget.path_field-2.0.8] startup
# [7.509s] [ext: omni.kit.widget.search_delegate-1.0.4] startup
# [7.509s] [ext: omni.kit.widget.browser_bar-2.0.9] startup
# [7.510s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [7.510s] [ext: omni.kit.menu.utils-1.5.6] startup
# [7.516s] [ext: omni.kit.collaboration.channel_manager-1.0.11] startup
# [7.517s] [ext: omni.ui.scene-1.7.0] startup
# [7.520s] [ext: omni.kit.notification_manager-1.0.6] startup
# [7.521s] [ext: omni.kit.clipboard-1.0.3] startup
# [7.521s] [ext: omni.kit.widget.options_menu-1.0.5] startup
# [7.522s] [ext: omni.kit.usd.layers-2.1.27] startup
# [7.531s] [ext: omni.kit.window.filepicker-2.10.13] startup
# [7.535s] [ext: omni.kit.widget.filter-1.1.2] startup
# [7.535s] [ext: omni.kit.menu.create-1.0.11] startup
# [7.536s] [ext: omni.kit.window.file_exporter-1.0.22] startup
# [7.537s] [ext: omni.kit.hotkeys.core-1.3.0] startup
# [7.540s] [ext: omni.kit.context_menu-1.6.8] startup
# [7.541s] [ext: omni.kit.widget.stage-2.9.6] startup
# [7.547s] [ext: omni.kit.primitive.mesh-1.0.15] startup
# [7.549s] [ext: omni.kit.usd_undo-0.1.2] startup
# [7.549s] [ext: omni.kit.stage_templates-1.1.20] startup
# [7.550s] [ext: omni.kit.widget.searchfield-1.1.3] startup
# [7.550s] [ext: omni.kit.widget.highlight_label-1.0.1] startup
# [7.551s] [ext: omni.kit.window.file_importer-1.0.22] startup
# [7.551s] [ext: omni.kit.window.property-1.9.6] startup
# [7.553s] [ext: omni.ui_query-1.1.1] startup
# [7.553s] [ext: omni.inspect-1.0.1] startup
# [7.555s] [ext: usdrt.scenegraph-7.2.34] startup
# [7.588s] [ext: omni.graph.tools-1.41.3] startup
# [7.598s] [ext: omni.graph.core-2.139.12] startup
# [7.603s] [ext: omni.kit.window.file-1.3.44] startup
# [7.604s] [ext: omni.graph-1.106.1] startup
# [7.632s] [ext: omni.kvdb-0.0.0] startup
# [7.633s] [ext: omni.convexdecomposition-105.1.12-5.1] startup
# [7.640s] [ext: omni.localcache-0.0.0] startup
# [7.641s] [ext: omni.iray.libs-0.0.0] startup
# [7.645s] [ext: omni.physx.foundation-105.1.12-5.1] startup
# [7.645s] [ext: omni.usdphysics-105.1.12-5.1] startup
# [7.650s] [ext: omni.mdl.neuraylib-0.2.0] startup
# [7.651s] [ext: omni.isaac.version-1.0.3] startup
# [7.652s] [ext: omni.physx.cooking-105.1.12-5.1] startup
# [7.664s] [ext: omni.mdl-0.2.1] startup
# [7.675s] [ext: omni.physics.tensors-0.1.0] startup
# [7.683s] [ext: omni.physx-105.1.12-5.1] startup
# 2024-03-14 22:10:31 [7,688ms] [Warning] [omni.stageupdate.plugin] Deprecated: direct use of IStageUpdate callbacks is deprecated. Use IStageUpdate::getStageUpdate instead.
# [7.699s] [ext: omni.kit.material.library-1.3.41] startup
# [7.703s] [ext: omni.volume-0.4.0] startup
# [7.704s] [ext: omni.physx.tensors-0.1.0] startup
# [7.794s] [ext: omni.kit.numpy.common-0.1.2] startup
# [7.795s] [ext: omni.hydra.rtx-0.1.0] startup
# [7.810s] [ext: omni.warp.core-1.0.0-beta.2] startup
# Warp 1.0.0-beta.2 initialized:
#    CUDA Toolkit: 11.5, Driver: 12.0
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA GeForce RTX 4090 (sm_89)
#      "cuda:1" | NVIDIA GeForce RTX 4090 (sm_89)
#    Kernel cache: /home/cgokmen/.cache/warp/1.0.0-beta.2
# [7.893s] [ext: omni.isaac.dynamic_control-1.2.6] startup
# [7.903s] [ext: omni.debugdraw-0.1.2] startup
# [7.910s] [ext: omni.isaac.core-3.3.2] startup
# [8.646s] [ext: omni.hydra.pxr-1.1.6] startup
# [8.654s] [ext: omni.kit.collaboration.presence_layer-1.0.8] startup
# [8.656s] [ext: omni.kit.widget.prompt-1.0.6] startup
# [8.657s] [ext: omni.kit.hydra_texture-1.1.12] startup
# [8.666s] [ext: omni.hydra.engine.stats-1.0.1] startup
# [8.673s] [ext: omni.kit.viewport.legacy_gizmos-1.0.14] startup
# [8.680s] [ext: omni.kit.widget.viewport-105.1.7] startup
# [8.684s] [ext: omni.kit.widget.searchable_combobox-1.0.5] startup
# [8.685s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [8.686s] [ext: omni.kit.viewport.registry-104.0.5] startup
# [8.687s] [ext: omni.kit.widget.settings-1.0.6] startup
# [8.688s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [8.690s] [ext: omni.kit.viewport.window-105.1.12] startup
# [8.706s] [ext: omni.kit.window.preferences-1.3.23] startup
# [8.711s] [ext: omni.kit.widget.graph-1.8.4] startup
# [8.715s] [ext: omni.kit.window.content_browser-2.7.17] startup
# [8.724s] [ext: omni.kit.viewport.utility-1.0.16] startup
# [8.726s] [ext: omni.kit.widget.live_session_management-1.2.22] startup
# [8.730s] [ext: omni.kit.window.extensions-1.3.0] startup
# [8.734s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [8.736s] [ext: omni.kit.property.usd-3.21.15] startup
# [8.745s] [ext: omni.kit.manipulator.viewport-104.0.9] startup
# [8.746s] [ext: omni.graph.ui-1.48.0] startup
# [8.761s] [ext: omni.kit.ui_test-1.2.13] startup
# [8.763s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [8.776s] [ext: omni.graph.action-1.55.1] startup
# [8.819s] [ext: omni.isaac.ui-0.13.5] startup
# [8.826s] [ext: omni.isaac.surface_gripper-0.7.0] startup
# [8.837s] [ext: omni.isaac.lula-2.1.0] startup
# [8.844s] [ext: omni.kit.graph.delegate.default-1.1.1] startup
# [8.845s] [ext: omni.isaac.manipulators-1.1.0] startup
# [8.850s] [ext: omni.isaac.motion_generation-6.1.0] startup
# [8.857s] [ext: omni.kit.graph.editor.core-1.5.1] startup
# [8.859s] [ext: omni.kit.graph.delegate.modern-1.9.1] startup
# [8.861s] [ext: omni.isaac.franka-0.4.0] startup
# [8.863s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [8.865s] [ext: omni.kit.graph.usd.commands-1.3.0] startup
# [8.866s] [ext: omni.isaac.universal_robots-0.3.3] startup
# [8.868s] [ext: omni.isaac.cortex-0.3.5] startup
# [8.870s] [ext: omni.graph.window.core-1.84.0] startup
# [8.879s] [ext: omni.isaac.dofbot-0.3.1] startup
# [8.882s] [ext: omni.isaac.cortex.sample_behaviors-1.0.4] startup
# [8.884s] [ext: omni.graph.window.generic-1.9.3] startup
# [8.889s] [ext: omni.isaac.kit-1.4.7] startup
# [8.889s] [ext: omni.graph.window.action-1.11.2] startup
# [8.894s] [ext: omni.kit.widget.zoombar-1.0.5] startup
# [8.895s] [ext: omni.graph.image.core-0.1.0] startup
# [8.897s] [ext: omni.kit.window.cursor-1.1.2] startup
# [8.898s] [ext: omni.kit.browser.core-2.3.10] startup
# [8.905s] [ext: omni.kit.widget.spinner-1.0.6] startup
# [8.907s] [ext: omni.graph.nodes-1.106.3] startup
# [9.068s] [ext: omni.kit.widget.material_preview-1.0.8] startup
# [9.071s] [ext: omni.kit.browser.folder.core-1.9.7] startup
# [9.074s] [ext: omni.kit.viewport.menubar.core-105.0.19] startup
# [9.092s] [ext: omni.kit.renderer.cuda_interop-1.0.1] startup
# [9.094s] [ext: omni.kit.window.material_graph-1.8.11] startup
# [9.109s] [ext: omni.kit.browser.sample-1.4.6] startup
# [9.111s] [ext: omni.syntheticdata-0.4.10] startup
# [9.137s] [ext: omni.kit.livestream.core-2.3.0] startup
# [9.140s] [ext: omni.kit.streamsdk.plugins-2.5.2] startup
# [9.140s] [ext: omni.warp-1.0.0-beta.2] startup
# [9.195s] [ext: omni.graph.scriptnode-1.1.6] startup
# [9.201s] [ext: omni.command.usd-1.0.2] startup
# [9.203s] [ext: omni.kit.livestream.native-2.4.0] startup
#
# Active user not found. Using default user [kiosk]
# 2024-03-14 22:10:32 [9,286ms] [Error] [carb.livestream.plugin] Stream Server: starting the server failed, 0x800B1002
# 2024-03-14 22:10:32 [9,286ms] [Error] [carb.livestream.plugin] Could not initialize streaming components
# 2024-03-14 22:10:32 [9,286ms] [Error] [carb.livestream.plugin] Couldn't initialize the capture device.
# [9.298s] [ext: omni.replicator.core-1.10.20] startup
# 2024-03-14 22:10:32 [9,310ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [9.451s] [ext: omni.kit.viewport.menubar.lighting-105.0.7] startup
# [9.454s] [ext: omni.isaac.urdf-1.1.0] startup
# 2024-03-14 22:10:32 [9,444ms] [Warning] [omni.isaac.urdf] The extension omni.isaac.urdf has been deprecated. Please use omni.importer.urdf instead.
# [9.454s] [ext: omni.isaac.core_nodes-1.7.1] startup
# [9.481s] [ext: omni.isaac.cloner-0.7.2] startup
# [9.482s] [ext: omni.isaac.utils-0.6.0] startup
# [9.491s] [ext: omni.isaac.wheeled_robots-0.9.0] startup
# [WARNING] [omni.kit.profiler.window] remove _SpanInstance.__lt__ and use insort 'key' arg instead
# [9.507s] [ext: omni.isaac.gym-0.10.0] startup
# [9.509s] [ext: omni.kit.selection-0.1.3] startup
# [9.510s] [ext: omni.kit.menu.common-1.1.4] startup
# [9.511s] [ext: omni.kit.widget.layers-1.6.32] startup
# [9.519s] [ext: omni.kit.menu.edit-1.1.14] startup
# [9.522s] [ext: omni.kit.menu.file-1.1.7] startup
# [9.524s] [ext: omni.kit.property.layer-1.1.5] startup
# [9.526s] [ext: semantics.schema.editor-0.3.4] startup
# [9.528s] [ext: omni.kit.property.camera-1.0.5] startup
# [9.529s] [ext: omni.kit.property.audio-1.0.9] startup
# [9.533s] [ext: omni.kit.profiler.window-2.1.2] startup
# 2024-03-14 22:10:32 [9,611ms] [Warning] [omni.kit.profiler.window] remove _SpanInstance.__lt__ and use insort 'key' arg instead
# [9.624s] [ext: omni.kit.widget.stage_icons-1.0.4] startup
# [9.625s] [ext: omni.hydra.scene_api-0.1.2] startup
# [9.638s] [ext: omni.kit.property.light-1.0.8] startup
# [9.640s] [ext: omni.kit.property.skel-1.0.4] startup
# [9.642s] [ext: omni.kit.window.stage-2.4.4] startup
# [9.645s] [ext: omni.kit.property.transform-1.3.10] startup
# [9.648s] [ext: omni.kit.property.render-1.1.1] startup
# [9.650s] [ext: omni.kit.property.material-1.8.36] startup
# [9.653s] [ext: omni.kit.property.geometry-1.2.11] startup
# [9.656s] [ext: omni.isaac.debug_draw-0.6.1] startup
# 2024-03-14 22:10:32 [9,653ms] [Warning] [omni.stageupdate.plugin] Deprecated: direct use of IStageUpdate callbacks is deprecated. Use IStageUpdate::getStageUpdate instead.
# 2024-03-14 22:10:32 [9,654ms] [Warning] [omni.stageupdate.plugin] Deprecated: direct use of IStageUpdate callbacks is deprecated. Use IStageUpdate::getStageUpdate instead.
# [9.666s] [ext: omni.kit.menu.stage-1.2.3] startup
# [9.668s] [ext: omni.kit.property.bundle-1.2.9] startup
# [9.670s] [ext: omni.kit.property.isaac-0.2.2] startup
# [9.672s] [ext: omni.isaac.occupancy_map-0.3.2] startup
# [9.691s] [ext: omni.isaac.mjcf-1.0.0] startup
# 2024-03-14 22:10:33 [9,682ms] [Warning] [omni.isaac.mjcf] The extension omni.isaac.mjcf has been deprecated. Please use omni.importer.mjcf instead.
# [9.692s] [ext: omni.kit.viewport.actions-105.1.6] startup
# [9.696s] [ext: omni.kit.widget.toolbar-1.5.6] startup
# [9.701s] [ext: omni.kit.raycast.query-1.0.1] startup
# [9.715s] [ext: omni.kit.manipulator.transform-104.6.15] startup
# [9.716s] [ext: omni.rtx.window.settings-0.6.9] startup
# [9.720s] [ext: omni.kit.viewport.menubar.display-105.1.0] startup
# [9.722s] [ext: omni.kit.manipulator.tool.snap-1.4.2] startup
# [9.727s] [ext: omni.hydra.pxr.settings-1.0.5] startup
# [9.728s] [ext: omni.activity.pump-1.0.0] startup
# [9.730s] [ext: omni.physx.commands-105.1.12-5.1] startup
# [9.732s] [ext: omni.usdphysics.ui-105.1.12-5.1] startup
# [9.764s] [ext: omni.kit.widget.live-2.1.6] startup
# [9.766s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [9.766s] [ext: omni.kit.viewport.ready-1.0.5] startup
# [9.767s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [9.767s] [ext: omni.physx.ui-105.1.12-5.1] startup
# [9.796s] [ext: omni.kit.widget.cache_indicator-2.0.8] startup
# [9.798s] [ext: usdrt.gf-1.0.2] startup
# [9.798s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [9.800s] [ext: omni.kit.window.commands-0.2.4] startup
# [9.801s] [ext: omni.kit.window.console-0.2.10] startup
# [9.815s] [ext: omni.kit.property.physx-0.1.0] startup
# [9.879s] [ext: omni.kit.actions.window-1.1.0] startup
# [9.882s] [ext: omni.physx.demos-105.1.12-5.1] startup
# [9.885s] [ext: omni.kit.manipulator.prim-105.0.11] startup
# [9.891s] [ext: omni.kit.window.toolbar-1.5.4] startup
# [9.894s] [ext: omni.kit.manipulator.selection-104.0.8] startup
# [9.895s] [ext: omni.kit.window.script_editor-1.7.4] startup
# [9.898s] [ext: omni.kit.hotkeys.window-1.4.1] startup
# [9.902s] [ext: omni.physx.camera-105.1.12-5.1] startup
# [9.913s] [ext: omni.physx.cct-105.1.12-5.1] startup
# [9.930s] [ext: omni.physx.graph-105.1.12-5.1] startup
# [9.946s] [ext: omni.physx.supportui-105.1.12-5.1] startup
# [9.966s] [ext: omni.physx.vehicle-105.1.12-5.1] startup
# [9.981s] [ext: omni.kit.stage_column.payload-1.0.12] startup
# [9.983s] [ext: omni.graph.ui_nodes-1.5.10] startup
# [10.013s] [ext: omni.sensors.nv.common-1000.0.0-isaacsim.2023.1.1] startup
# [10.027s] [ext: omni.sensors.nv.materials-1000.0.0-isaacsim.2023.1.1] startup
# [10.029s] [ext: omni.sensors.nv.wpm-1000.0.0-isaacsim.2023.1.1] startup
# [10.030s] [ext: omni.kit.window.status_bar-0.1.6] startup
# [10.038s] [ext: omni.physx.bundle-105.1.12-5.1] startup
# [10.038s] [ext: omni.graph.bundle.action-2.0.4] startup
# [10.038s] [ext: omni.isaac.range_sensor-2.0.2] startup
# [10.080s] [ext: omni.sensors.nv.lidar-1000.0.1-isaacsim.2023.1.1] startup
# [10.089s] [ext: omni.sensors.nv.radar-1000.0.0-isaacsim.2023.1.1] startup
# [10.097s] [ext: omni.kit.window.title-1.1.3] startup
# [10.098s] [ext: omni.replicator.composer-1.2.17] startup
# [10.108s] [ext: omni.replicator.isaac-1.11.3] startup
# [10.132s] [ext: omni.kit.manipulator.camera-105.0.4] startup
# [10.135s] [ext: omni.kit.viewport.menubar.camera-105.1.9] startup
# [10.140s] [ext: omni.isaac.sensor-9.11.1] startup
# [10.203s] [ext: omni.kit.viewport.menubar.render-105.1.1] startup
# [10.206s] [ext: omni.kit.viewport.menubar.settings-105.0.9] startup
# [10.210s] [ext: omni.replicator.replicator_yaml-2.0.4] startup
# [10.219s] [ext: omni.rtx.settings.core-0.5.13] startup
# [10.224s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [10.226s] [ext: omni.isaac.quadruped-1.4.1] startup
# [10.236s] [ext: semantics.schema.property-1.0.2] startup
# [10.239s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [10.239s] [ext: omni.isaac.scene_blox-0.1.0] startup
# [10.241s] [ext: omni.importer.urdf-1.6.1] startup
# [10.283s] [ext: omni.importer.mjcf-1.1.0] startup
# [10.295s] [ext: omni.kit.window.stats-0.1.4] startup
# [10.296s] [ext: omni.isaac.sim.python-2023.1.1] startup
# [10.298s] Simulation App Starting
# 2024-03-14 22:10:33 [10,311ms] [Warning] [omni.kit.widget.settings.settings_model] a value for setting /rtx/ecoMode/enabled has been requested but is not available
# 2024-03-14 22:10:33 [10,312ms] [Warning] [omni.kit.widget.settings.settings_model] a value for setting /rtx/directLighting/enabled has been requested but is not available
# 2024-03-14 22:10:33 [10,312ms] [Warning] [omni.kit.widget.settings.settings_model] a value for setting /rtx/reflections/enabled has been requested but is not available
# 2024-03-14 22:10:33 [10,312ms] [Warning] [omni.kit.widget.settings.settings_model] a value for setting /rtx/translucency/enabled has been requested but is not available
# 2024-03-14 22:10:33 [10,312ms] [Warning] [omni.kit.widget.settings.settings_model] a value for setting /rtx/raytracing/subsurface/enabled has been requested but is not available
# 2024-03-14 22:10:33 [10,313ms] [Warning] [omni.kit.widget.settings.settings_model] a value for setting /rtx/caustics/enabled has been requested but is not available
# 2024-03-14 22:10:33 [10,354ms] [Warning] [omni.kvdb.plugin] wasn't able to load the meta database, trying to repair it ...
# 2024-03-14 22:10:33 [10,434ms] [Warning] [omni.kvdb.plugin] repair failed
# [12.815s] app ready
# [13.582s] Simulation App Startup Complete
# [13.593s] [ext: omni.usd.schema.flow-105.1.18] startup
# [13.595s] [ext: omni.flowusd-105.1.45] startup
# 2024-03-14 22:10:36 [13,592ms] [Warning] [omni.stageupdate.plugin] Deprecated: direct use of IStageUpdate callbacks is deprecated. Use IStageUpdate::getStageUpdate instead.
# [13.614s] [ext: omni.ramp-105.1.14] startup
# [13.623s] [ext: omni.scene.visualization.core-105.4.10] startup
# [13.637s] [ext: omni.particle.system.core-105.1.6] startup
# 2024-03-14 22:10:36 [13,635ms] [Warning] [omni.particle.system.core.scripts.extension]
#             ATTENTION!: omni.particle.system.core is currently undergoing extensive (breaking) changes.
#             Please be aware that systems built with the existing extension will need to be rebuilt in
#             the USD Composer 2023.2 release.
# [13.650s] [ext: omni.particle.system.ui-105.1.10] startup
# [13.747s] [ext: omni.graph.window.particle.system-105.1.18] startup
# DYNAMICS_TODO:
#   Make sure "omni.particle.system.core2" is a proper dependency.
#   For now, it can just be set to autoload.
# DYNAMICS_TODO:
#   Make sure "omni.particle.system.core2" is a proper dependency.
#   For now, it can just be set to autoload.
# [13.779s] [ext: omni.particle.system.bundle-105.1.0] startup
# 2024-03-14 22:10:37 [14,404ms] [Warning] [omni.fabric.plugin] No source has valid data array=0x24d62d30 usdValid=0 cpuValid=0
# [INFO] [omnigibson.simulator] ---------- Welcome to OmniGibson! ----------
# 2024-03-14 22:10:38 [15,385ms] [Warning] [omni.kvdb.plugin] wasn't able to load the meta database, trying to repair it ...
# 2024-03-14 22:10:38 [15,464ms] [Warning] [omni.kvdb.plugin] repair failed
#
#                    ____________
#                   /          / \
#                  /          / /__
#                 /          / /  /\
#                /__________/ /__/  \
#                \   _____  \ \__\  /
#                 \  \  / \  \ \_/ /
#                  \  \/___\  \   /
#                   \__________\_/
#        ___                  _  ____ _ _
#       / _ \ _ __ ___  _ __ (_)/ ___(_) |__  ___  ___  _ __
#      | | | | '_ ` _ \| '_ \| | |  _| | '_ \/ __|/ _ \| '_ \
#      | |_| | | | | | | | | | | |_| | | |_) \__ \ (_) | | | |
#       \___/|_| |_| |_|_| |_|_|\____|_|_.__/|___/\___/|_| |_|

# %%
from bddl.knowledge_base import *
# Out:
# 2024-03-14 22:10:38 [15,544ms] [Error] [omni.kit.app.plugin] Can't delay app ready event, it was already sent. Requester name: omni.usd
# [WARNING] [bddl.knowledge_base.processing] Loading BDDL knowledge base... This may take a few seconds.
# [nltk_data] Downloading package wordnet to /home/cgokmen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 2024-03-14 22:10:38 [15,622ms] [Warning] [bddl.knowledge_base.processing] Loading BDDL knowledge base... This may take a few seconds.

# %%
tro_synsets = {s for s in Synset.all_objects() if len(s.tasks) > 0 and s.state != STATE_SUBSTANCE}

# %%
from bddl.object_taxonomy import ObjectTaxonomy
OT = ObjectTaxonomy()

# %%
no_good_obj = {
  s for s in tro_synsets
  if all(
    len(get_all_object_category_models_with_abilities(c.name, OT.get_abilities(c.synset.name))) == 0
    for c in {obj.category for obj in s.matching_objects}
  ) 
}
sorted(no_good_obj)
# Out:
# [Synset(name='desktop_computer.n.01'),
#  Synset(name='paper_lantern.n.01'),
#  Synset(name='wardrobe.n.01'),
#  Synset(name='webcam.n.02'),
#  Synset(name='window_blind.n.01')]

# %%
len(no_good_obj)
# Out:
# 5
