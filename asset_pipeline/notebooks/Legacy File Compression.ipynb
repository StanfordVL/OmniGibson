# %%
import glob, os

# %%
counts = {}
for x in glob.glob(r"C:\Users\cgokmen\research\ig_dataset\objects\*"):
    counts[os.path.basename(x)] = len(os.listdir(x))

# %%
sorted(counts.items(), key=lambda x: -x[1])
# Out:
# [('bottom_cabinet', 61),
#  ('swivel_chair', 42),
#  ('pop', 35),
#  ('straight_chair', 29),
#  ('lid', 22),
#  ('toy', 22),
#  ('breakfast_table', 21),
#  ('armchair', 20),
#  ('table_lamp', 20),
#  ('bed', 19),
#  ('jar', 19),
#  ('picture', 19),
#  ('desk', 18),
#  ('pot_plant', 18),
#  ('board_game', 16),
#  ('bottom_cabinet_no_top', 15),
#  ('door', 14),
#  ('toilet', 14),
#  ('top_cabinet', 14),
#  ('trash_can', 14),
#  ('bowl', 13),
#  ('coffee_table', 13),
#  ('pop_case', 13),
#  ('video_game', 13),
#  ('oven', 12),
#  ('shelf', 12),
#  ('window', 12),
#  ('gym_shoe', 10),
#  ('sofa', 10),
#  ('basket', 9),
#  ('bench', 9),
#  ('sink', 9),
#  ('medicine', 8),
#  ('standing_tv', 8),
#  ('stove', 8),
#  ('walker', 8),
#  ('bathtub', 7),
#  ('dishwasher', 7),
#  ('floor_lamp', 7),
#  ('notebook', 7),
#  ('pencil', 7),
#  ('shampoo', 7),
#  ('spoon', 7),
#  ('canned_food', 6),
#  ('dryer', 6),
#  ('fridge', 6),
#  ('microwave', 6),
#  ('pillow', 6),
#  ('tape', 6),
# ...

# %%
batches = []

# %%
import binpacking
bins = binpacking.to_constant_volume(counts, 100)

# %%
len(bins)
# Out:
# 13
