# %%
import glob, os

# %%
import collections
counts = collections.Counter()
for x in glob.glob(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_*"):
    counts[os.path.basename(x).split("-")[0].replace("legacy_", "")] += 1

# %%
sorted(counts.items(), key=lambda x: -x[1])
# Out:
# [('bottom_cabinet', 61),
#  ('swivel_chair', 42),
#  ('pop', 35),
#  ('straight_chair', 29),
#  ('lid', 22),
#  ('toy', 22),
#  ('breakfast_table', 21),
#  ('armchair', 20),
#  ('table_lamp', 20),
#  ('bed', 19),
#  ('jar', 19),
#  ('picture', 19),
#  ('desk', 18),
#  ('pot_plant', 18),
#  ('board_game', 16),
#  ('bottom_cabinet_no_top', 15),
#  ('toilet', 14),
#  ('top_cabinet', 14),
#  ('trash_can', 14),
#  ('bowl', 13),
#  ('coffee_table', 13),
#  ('pop_case', 13),
#  ('video_game', 13),
#  ('door', 12),
#  ('oven', 12),
#  ('shelf', 12),
#  ('window', 12),
#  ('gym_shoe', 10),
#  ('sofa', 10),
#  ('basket', 9),
#  ('bench', 9),
#  ('sink', 9),
#  ('medicine', 8),
#  ('standing_tv', 8),
#  ('stove', 8),
#  ('walker', 8),
#  ('bathtub', 7),
#  ('dishwasher', 7),
#  ('floor_lamp', 7),
#  ('notebook', 7),
#  ('pencil', 7),
#  ('shampoo', 7),
#  ('spoon', 7),
#  ('canned_food', 6),
#  ('dryer', 6),
#  ('fridge', 6),
#  ('microwave', 6),
#  ('pillow', 6),
#  ('tape', 6),
#  ('washer', 6),
#  ('cereal', 5),
#  ('cup', 5),
#  ('foot_rule', 5),
#  ('pedestal_table', 5),
#  ('platter', 5),
#  ('sandal', 5),
#  ('stool', 5),
#  ('apple', 4),
#  ('bean', 4),
#  ('bell_pepper', 4),
#  ('briefcase', 4),
#  ('chopping_board', 4),
#  ('console_table', 4),
#  ('dishtowel', 4),
#  ('guitar', 4),
#  ('hat', 4),
#  ('kettle', 4),
#  ('paint', 4),
#  ('potato', 4),
#  ('protein_powder', 4),
#  ('range_hood', 4),
#  ('vidalia_onion', 4),
#  ('bath_towel', 3),
#  ('bucket', 3),
#  ('carving_knife', 3),
#  ('chaise_longue', 3),
#  ('chestnut', 3),
#  ('chives', 3),
#  ('coconut', 3),
#  ('cord', 3),
#  ('folding_chair', 3),
#  ('glove', 3),
#  ('grandfather_clock', 3),
#  ('grape', 3),
#  ('heater', 3),
#  ('ink_cartridge', 3),
#  ('olive_oil', 3),
#  ('piano', 3),
#  ('pineapple', 3),
#  ('pomegranate', 3),
#  ('rail_fence', 3),
#  ('rocking_chair', 3),
#  ('shower', 3),
#  ('speaker_system', 3),
#  ('stand', 3),
#  ('towel_rack', 3),
#  ('vacuum', 3),
#  ('wall_mounted_tv', 3),
#  ('wine_bottle', 3),
#  ('zucchini', 3),
#  ('apricot', 2),
#  ('blender', 2),
#  ('bulletin_board', 2),
#  ('burner', 2),
#  ('chest', 2),
#  ('chili', 2),
#  ('coat', 2),
#  ('coffee_pouch', 2),
#  ('detergent', 2),
#  ('folder', 2),
#  ('glass', 2),
#  ('hard_drive', 2),
#  ('highchair', 2),
#  ('jeans', 2),
#  ('kitchen_analog_scale', 2),
#  ('kiwi', 2),
#  ('lemon', 2),
#  ('loudspeaker', 2),
#  ('monitor', 2),
#  ('mushroom', 2),
#  ('olive', 2),
#  ('orange', 2),
#  ('package', 2),
#  ('painting', 2),
#  ('peach', 2),
#  ('pear', 2),
#  ('pen', 2),
#  ('pencil_box', 2),
#  ('plum', 2),
#  ('pomelo', 2),
#  ('pumpkin', 2),
#  ('radish', 2),
#  ('rag', 2),
#  ('roller', 2),
#  ('scarf', 2),
#  ('scissors', 2),
#  ('screwdriver', 2),
#  ('soup_ladle', 2),
#  ('straw', 2),
#  ('strawberry', 2),
#  ('sunglass', 2),
#  ('sweater', 2),
#  ('tablefork', 2),
#  ('table_knife', 2),
#  ('tile', 2),
#  ('toasting_fork', 2),
#  ('tomato', 2),
#  ('toothbrush', 2),
#  ('treadmill', 2),
#  ('umbrella', 2),
#  ('wall_clock', 2),
#  ('walnut', 2),
#  ('watermelon', 2),
#  ('alarm', 1),
#  ('almond', 1),
#  ('artichoke', 1),
#  ('atomizer', 1),
#  ('backpack', 1),
#  ('bagel', 1),
#  ('baguette', 1),
#  ('ball', 1),
#  ('banana', 1),
#  ('baseboard', 1),
#  ('basil', 1),
#  ('beef', 1),
#  ('beer', 1),
#  ('beet', 1),
#  ('bell', 1),
#  ('bow', 1),
#  ('bracelet', 1),
#  ('broccoli', 1),
#  ('broom', 1),
#  ('bulldog_clip', 1),
#  ('butter', 1),
#  ('calculator', 1),
#  ('caliper', 1),
#  ('candle', 1),
#  ('candy_cane', 1),
#  ('cantaloup', 1),
#  ('carafe', 1),
#  ('carpet', 1),
#  ('carpet_sweeper', 1),
#  ('carrot', 1),
#  ('carton', 1),
#  ('casserole', 1),
#  ('catsup', 1),
#  ('cauldron', 1),
#  ('celery', 1),
#  ('cheese', 1),
#  ('cherry', 1),
#  ('chicken', 1),
#  ('chip', 1),
#  ('chocolate_box', 1),
#  ('chopstick', 1),
#  ('christmas_tree', 1),
#  ('christmas_tree_decorated', 1),
#  ('cinnamon', 1),
#  ('clout_nail', 1),
#  ('clove', 1),
#  ('coatrack', 1),
#  ('coffee_cup', 1),
#  ('coffee_maker', 1),
#  ('colander', 1),
#  ('cologne', 1),
#  ('comb', 1),
#  ('conditioner', 1),
#  ('container_cranberry', 1),
#  ('container_date', 1),
#  ('cookie', 1),
#  ('countertop', 1),
#  ('cpu_board', 1),
#  ('crab', 1),
#  ('cracker_box', 1),
#  ('cream', 1),
#  ('cream_pitcher', 1),
#  ('crib', 1),
#  ('cruet', 1),
#  ('crumb', 1),
#  ('cucumber', 1),
#  ('cupcake', 1),
#  ('dart', 1),
#  ('dartboard', 1),
#  ('dental_floss', 1),
#  ('digital_scale', 1),
#  ('dinner_napkin', 1),
#  ('dipper', 1),
#  ('dish_rack', 1),
#  ('document', 1),
#  ('dress', 1),
#  ('drill', 1),
#  ('drumstick', 1),
#  ('duffel_bag', 1),
#  ('dustpan', 1),
#  ('egg', 1),
#  ('eggplant', 1),
#  ('envelope', 1),
#  ('eraser', 1),
#  ('facsimile', 1),
#  ('fillet', 1),
#  ('fish', 1),
#  ('flour', 1),
#  ('folderal', 1),
#  ('frying_pan', 1),
#  ('gaming_table', 1),
#  ('ginger', 1),
#  ('gingerbread', 1),
#  ('gooseberry', 1),
#  ('grater', 1),
#  ('green_onion', 1),
#  ('green_onion_chopped', 1),
#  ('griddle', 1),
#  ('grill', 1),
#  ('guacamole', 1),
#  ('hairbrush', 1),
#  ('hamburger', 1),
#  ('hammer', 1),
#  ('hand_towel', 1),
#  ('hanger', 1),
#  ('hardback', 1),
#  ('headset', 1),
#  ('head_cabbage', 1),
#  ('highlighter', 1),
#  ('hinge', 1),
#  ('honing_steel', 1),
#  ('hook', 1),
#  ('hose', 1),
#  ('ice_cube', 1),
#  ('iron', 1),
#  ('jam', 1),
#  ('jewel', 1),
#  ('juice', 1),
#  ('keyboard', 1),
#  ('ladder', 1),
#  ('laptop', 1),
#  ('lasagna', 1),
#  ('lawn_mower', 1),
#  ('lettuce', 1),
#  ('light_bulb', 1),
#  ('lime', 1),
#  ('lipstick', 1),
#  ('lollipop', 1),
#  ('lotion', 1),
#  ('magazine', 1),
#  ('martini', 1),
#  ('mat', 1),
#  ('mayonnaise', 1),
#  ('milk', 1),
#  ('mirror', 1),
#  ('modem', 1),
#  ('mouse', 1),
#  ('mousetrap', 1),
#  ('muffin', 1),
#  ('mug', 1),
#  ('necklace', 1),
#  ('newspaper', 1),
#  ('oatmeal', 1),
#  ('paintbrush', 1),
#  ('pajamas', 1),
#  ('paper_bag', 1),
#  ('paper_clip', 1),
#  ('paper_towel', 1),
#  ('paper_towel_holder', 1),
#  ('parsley', 1),
#  ('pasta', 1),
#  ('pea', 1),
#  ('pegboard', 1),
#  ('pepper_grinder', 1),
#  ('perfume', 1),
#  ('pistachio', 1),
#  ('plate', 1),
#  ('plywood', 1),
#  ('pocketknife', 1),
#  ('pool', 1),
#  ('pool_table', 1),
#  ('pork', 1),
#  ('powder_bottle', 1),
#  ('pretzel', 1),
#  ('printer', 1),
#  ('prosciutto', 1),
#  ('puree', 1),
#  ('rake', 1),
#  ('raspberry', 1),
#  ('razor', 1),
#  ('rib', 1),
#  ('ribbon', 1),
#  ('ring', 1),
#  ('rosehip', 1),
#  ('router', 1),
#  ('salad', 1),
#  ('salt', 1),
#  ('saucepan', 1),
#  ('sausage', 1),
#  ('saw', 1),
#  ('scanner', 1),
#  ('scraper', 1),
#  ('scrub_brush', 1),
#  ('sheet', 1),
#  ('shoulder_bag', 1),
#  ('soap', 1),
#  ('sock', 1),
#  ('soup', 1),
#  ('spaghetti_sauce', 1),
#  ('spatula', 1),
#  ('spinach', 1),
#  ('steak', 1),
#  ('sticky_note', 1),
#  ('stocking', 1),
#  ('straight_pin', 1),
#  ('sugar_jar', 1),
#  ('sunscreen', 1),
#  ('sushi', 1),
#  ('sweet_corn', 1),
#  ('tart', 1),
#  ('teapot', 1),
#  ('tea_bag', 1),
#  ('thumbtack', 1),
#  ('tinsel', 1),
#  ('toaster', 1),
#  ('tongs', 1),
#  ('toothpaste', 1),
#  ('toothpick', 1),
#  ('tray', 1),
#  ('trowel', 1),
#  ('turnip', 1),
#  ('t_shirt', 1),
#  ('underwear', 1),
#  ('vinegar', 1),
#  ('wall_socket', 1),
#  ('watch', 1),
#  ('water', 1),
#  ('whiteboard', 1),
#  ('wrapped_gift', 1),
#  ('wreath', 1),
#  ('yogurt', 1)]

# %%
batches = []

# %%
import binpacking
bins = binpacking.to_constant_volume(counts, 100)

# %%
bins
# Out:
# [{'bottom_cabinet': 61, 'pop': 35, 'apple': 4},
#  {'swivel_chair': 42, 'straight_chair': 29, 'lid': 22, 'bathtub': 7},
#  {'toy': 22,
#   'breakfast_table': 21,
#   'armchair': 20,
#   'table_lamp': 20,
#   'board_game': 16,
#   'alarm': 1},
#  {'bed': 19,
#   'jar': 19,
#   'picture': 19,
#   'desk': 18,
#   'pot_plant': 18,
#   'dishwasher': 7},
#  {'bottom_cabinet_no_top': 15,
#   'toilet': 14,
#   'top_cabinet': 14,
#   'trash_can': 14,
#   'bowl': 13,
#   'coffee_table': 13,
#   'pop_case': 13,
#   'bean': 4},
#  {'video_game': 13,
#   'door': 12,
#   'oven': 12,
#   'shelf': 12,
#   'window': 12,
#   'gym_shoe': 10,
#   'sofa': 10,
#   'basket': 9,
#   'bench': 9,
#   'almond': 1},
#  {'sink': 9,
#   'medicine': 8,
#   'standing_tv': 8,
#   'stove': 8,
#   'walker': 8,
#   'floor_lamp': 7,
#   'notebook': 7,
#   'pencil': 7,
#   'shampoo': 7,
#   'spoon': 7,
#   'canned_food': 6,
#   'dryer': 6,
#   'fridge': 6,
#   'microwave': 6},
#  {'pillow': 6,
#   'tape': 6,
#   'washer': 6,
#   'cereal': 5,
#   'cup': 5,
#   'foot_rule': 5,
#   'pedestal_table': 5,
#   'platter': 5,
#   'sandal': 5,
#   'stool': 5,
#   'bell_pepper': 4,
#   'briefcase': 4,
#   'chopping_board': 4,
#   'console_table': 4,
#   'dishtowel': 4,
#   'guitar': 4,
#   'hat': 4,
#   'kettle': 4,
#   'paint': 4,
#   'potato': 4,
#   'protein_powder': 4,
#   'bath_towel': 3},
#  {'range_hood': 4,
#   'vidalia_onion': 4,
#   'bucket': 3,
#   'carving_knife': 3,
#   'chaise_longue': 3,
#   'chestnut': 3,
#   'chives': 3,
#   'coconut': 3,
#   'cord': 3,
#   'folding_chair': 3,
#   'glove': 3,
#   'grandfather_clock': 3,
#   'grape': 3,
#   'heater': 3,
#   'ink_cartridge': 3,
#   'olive_oil': 3,
#   'piano': 3,
#   'pineapple': 3,
#   'pomegranate': 3,
#   'rail_fence': 3,
#   'rocking_chair': 3,
#   'shower': 3,
#   'speaker_system': 3,
#   'stand': 3,
#   'towel_rack': 3,
#   'vacuum': 3,
#   'wall_mounted_tv': 3,
#   'wine_bottle': 3,
#   'zucchini': 3,
#   'apricot': 2,
#   'blender': 2,
#   'bulletin_board': 2,
#   'burner': 2,
#   'chest': 2,
#   'artichoke': 1},
#  {'chili': 2,
#   'coat': 2,
#   'coffee_pouch': 2,
#   'detergent': 2,
#   'folder': 2,
#   'glass': 2,
#   'hard_drive': 2,
#   'highchair': 2,
#   'jeans': 2,
#   'kitchen_analog_scale': 2,
#   'kiwi': 2,
#   'lemon': 2,
#   'loudspeaker': 2,
#   'monitor': 2,
#   'mushroom': 2,
#   'olive': 2,
#   'orange': 2,
#   'package': 2,
#   'painting': 2,
#   'peach': 2,
#   'pear': 2,
#   'pen': 2,
#   'pencil_box': 2,
#   'plum': 2,
#   'pomelo': 2,
#   'pumpkin': 2,
#   'radish': 2,
#   'rag': 2,
#   'roller': 2,
#   'scarf': 2,
#   'scissors': 2,
#   'screwdriver': 2,
#   'soup_ladle': 2,
#   'straw': 2,
#   'strawberry': 2,
#   'sunglass': 2,
#   'sweater': 2,
#   'tablefork': 2,
#   'table_knife': 2,
#   'tile': 2,
#   'toasting_fork': 2,
#   'tomato': 2,
#   'toothbrush': 2,
#   'treadmill': 2,
#   'umbrella': 2,
#   'wall_clock': 2,
#   'walnut': 2,
#   'watermelon': 2,
#   'atomizer': 1,
#   'backpack': 1,
#   'bagel': 1,
#   'baguette': 1},
#  {'ball': 1,
#   'banana': 1,
#   'baseboard': 1,
#   'basil': 1,
#   'beef': 1,
#   'beer': 1,
#   'beet': 1,
#   'bell': 1,
#   'bow': 1,
#   'bracelet': 1,
#   'broccoli': 1,
#   'broom': 1,
#   'bulldog_clip': 1,
#   'butter': 1,
#   'calculator': 1,
#   'caliper': 1,
#   'candle': 1,
#   'candy_cane': 1,
#   'cantaloup': 1,
#   'carafe': 1,
#   'carpet': 1,
#   'carpet_sweeper': 1,
#   'carrot': 1,
#   'carton': 1,
#   'casserole': 1,
#   'catsup': 1,
#   'cauldron': 1,
#   'celery': 1,
#   'cheese': 1,
#   'cherry': 1,
#   'chicken': 1,
#   'chip': 1,
#   'chocolate_box': 1,
#   'chopstick': 1,
#   'christmas_tree': 1,
#   'christmas_tree_decorated': 1,
#   'cinnamon': 1,
#   'clout_nail': 1,
#   'clove': 1,
#   'coatrack': 1,
#   'coffee_cup': 1,
#   'coffee_maker': 1,
#   'colander': 1,
#   'cologne': 1,
#   'comb': 1,
#   'conditioner': 1,
#   'container_cranberry': 1,
#   'container_date': 1,
#   'cookie': 1,
#   'countertop': 1,
#   'cpu_board': 1,
#   'crab': 1,
#   'cracker_box': 1,
#   'cream': 1,
#   'cream_pitcher': 1,
#   'crib': 1,
#   'cruet': 1,
#   'crumb': 1,
#   'cucumber': 1,
#   'cupcake': 1,
#   'dart': 1,
#   'dartboard': 1,
#   'dental_floss': 1,
#   'digital_scale': 1,
#   'dinner_napkin': 1,
#   'dipper': 1,
#   'dish_rack': 1,
#   'document': 1,
#   'dress': 1,
#   'drill': 1,
#   'drumstick': 1,
#   'duffel_bag': 1,
#   'dustpan': 1,
#   'egg': 1,
#   'eggplant': 1,
#   'envelope': 1,
#   'eraser': 1,
#   'facsimile': 1,
#   'fillet': 1,
#   'fish': 1,
#   'flour': 1,
#   'folderal': 1,
#   'frying_pan': 1,
#   'gaming_table': 1,
#   'ginger': 1,
#   'gingerbread': 1,
#   'gooseberry': 1,
#   'grater': 1,
#   'green_onion': 1,
#   'green_onion_chopped': 1,
#   'griddle': 1,
#   'grill': 1,
#   'guacamole': 1,
#   'hairbrush': 1,
#   'hamburger': 1,
#   'hammer': 1,
#   'hand_towel': 1,
#   'hanger': 1,
#   'hardback': 1,
#   'headset': 1},
#  {'head_cabbage': 1,
#   'highlighter': 1,
#   'hinge': 1,
#   'honing_steel': 1,
#   'hook': 1,
#   'hose': 1,
#   'ice_cube': 1,
#   'iron': 1,
#   'jam': 1,
#   'jewel': 1,
#   'juice': 1,
#   'keyboard': 1,
#   'ladder': 1,
#   'laptop': 1,
#   'lasagna': 1,
#   'lawn_mower': 1,
#   'lettuce': 1,
#   'light_bulb': 1,
#   'lime': 1,
#   'lipstick': 1,
#   'lollipop': 1,
#   'lotion': 1,
#   'magazine': 1,
#   'martini': 1,
#   'mat': 1,
#   'mayonnaise': 1,
#   'milk': 1,
#   'mirror': 1,
#   'modem': 1,
#   'mouse': 1,
#   'mousetrap': 1,
#   'muffin': 1,
#   'mug': 1,
#   'necklace': 1,
#   'newspaper': 1,
#   'oatmeal': 1,
#   'paintbrush': 1,
#   'pajamas': 1,
#   'paper_bag': 1,
#   'paper_clip': 1,
#   'paper_towel': 1,
#   'paper_towel_holder': 1,
#   'parsley': 1,
#   'pasta': 1,
#   'pea': 1,
#   'pegboard': 1,
#   'pepper_grinder': 1,
#   'perfume': 1,
#   'pistachio': 1,
#   'plate': 1,
#   'plywood': 1,
#   'pocketknife': 1,
#   'pool': 1,
#   'pool_table': 1,
#   'pork': 1,
#   'powder_bottle': 1,
#   'pretzel': 1,
#   'printer': 1,
#   'prosciutto': 1,
#   'puree': 1,
#   'rake': 1,
#   'raspberry': 1,
#   'razor': 1,
#   'rib': 1,
#   'ribbon': 1,
#   'ring': 1,
#   'rosehip': 1,
#   'router': 1,
#   'salad': 1,
#   'salt': 1,
#   'saucepan': 1,
#   'sausage': 1,
#   'saw': 1,
#   'scanner': 1,
#   'scraper': 1,
#   'scrub_brush': 1,
#   'sheet': 1,
#   'shoulder_bag': 1,
#   'soap': 1,
#   'sock': 1,
#   'soup': 1,
#   'spaghetti_sauce': 1,
#   'spatula': 1,
#   'spinach': 1,
#   'steak': 1,
#   'sticky_note': 1,
#   'stocking': 1,
#   'straight_pin': 1,
#   'sugar_jar': 1,
#   'sunscreen': 1,
#   'sushi': 1,
#   'sweet_corn': 1,
#   'tart': 1,
#   'teapot': 1,
#   'tea_bag': 1,
#   'thumbtack': 1,
#   'tinsel': 1,
#   'toaster': 1,
#   'tongs': 1,
#   'toothpaste': 1},
#  {'toothpick': 1,
#   'tray': 1,
#   'trowel': 1,
#   'turnip': 1,
#   't_shirt': 1,
#   'underwear': 1,
#   'vinegar': 1,
#   'wall_socket': 1,
#   'watch': 1,
#   'water': 1,
#   'whiteboard': 1,
#   'wrapped_gift': 1,
#   'wreath': 1,
#   'yogurt': 1}]

# %%
len(bins)
# Out:
# 13

# %%
bin_lists = [list(x.keys()) for x in bins]

# %%
bin_lists
# Out:
# [['bottom_cabinet', 'pop', 'apple'],
#  ['swivel_chair', 'straight_chair', 'lid', 'bathtub'],
#  ['toy', 'breakfast_table', 'armchair', 'table_lamp', 'board_game', 'alarm'],
#  ['bed', 'jar', 'picture', 'desk', 'pot_plant', 'dishwasher'],
#  ['bottom_cabinet_no_top',
#   'toilet',
#   'top_cabinet',
#   'trash_can',
#   'bowl',
#   'coffee_table',
#   'pop_case',
#   'bean'],
#  ['video_game',
#   'door',
#   'oven',
#   'shelf',
#   'window',
#   'gym_shoe',
#   'sofa',
#   'basket',
#   'bench',
#   'almond'],
#  ['sink',
#   'medicine',
#   'standing_tv',
#   'stove',
#   'walker',
#   'floor_lamp',
#   'notebook',
#   'pencil',
#   'shampoo',
#   'spoon',
#   'canned_food',
#   'dryer',
#   'fridge',
#   'microwave'],
#  ['pillow',
#   'tape',
#   'washer',
#   'cereal',
#   'cup',
#   'foot_rule',
#   'pedestal_table',
#   'platter',
#   'sandal',
#   'stool',
#   'bell_pepper',
#   'briefcase',
#   'chopping_board',
#   'console_table',
#   'dishtowel',
#   'guitar',
#   'hat',
#   'kettle',
#   'paint',
#   'potato',
#   'protein_powder',
#   'bath_towel'],
#  ['range_hood',
#   'vidalia_onion',
#   'bucket',
#   'carving_knife',
#   'chaise_longue',
#   'chestnut',
#   'chives',
#   'coconut',
#   'cord',
#   'folding_chair',
#   'glove',
#   'grandfather_clock',
#   'grape',
#   'heater',
#   'ink_cartridge',
#   'olive_oil',
#   'piano',
#   'pineapple',
#   'pomegranate',
#   'rail_fence',
#   'rocking_chair',
#   'shower',
#   'speaker_system',
#   'stand',
#   'towel_rack',
#   'vacuum',
#   'wall_mounted_tv',
#   'wine_bottle',
#   'zucchini',
#   'apricot',
#   'blender',
#   'bulletin_board',
#   'burner',
#   'chest',
#   'artichoke'],
#  ['chili',
#   'coat',
#   'coffee_pouch',
#   'detergent',
#   'folder',
#   'glass',
#   'hard_drive',
#   'highchair',
#   'jeans',
#   'kitchen_analog_scale',
#   'kiwi',
#   'lemon',
#   'loudspeaker',
#   'monitor',
#   'mushroom',
#   'olive',
#   'orange',
#   'package',
#   'painting',
#   'peach',
#   'pear',
#   'pen',
#   'pencil_box',
#   'plum',
#   'pomelo',
#   'pumpkin',
#   'radish',
#   'rag',
#   'roller',
#   'scarf',
#   'scissors',
#   'screwdriver',
#   'soup_ladle',
#   'straw',
#   'strawberry',
#   'sunglass',
#   'sweater',
#   'tablefork',
#   'table_knife',
#   'tile',
#   'toasting_fork',
#   'tomato',
#   'toothbrush',
#   'treadmill',
#   'umbrella',
#   'wall_clock',
#   'walnut',
#   'watermelon',
#   'atomizer',
#   'backpack',
#   'bagel',
#   'baguette'],
#  ['ball',
#   'banana',
#   'baseboard',
#   'basil',
#   'beef',
#   'beer',
#   'beet',
#   'bell',
#   'bow',
#   'bracelet',
#   'broccoli',
#   'broom',
#   'bulldog_clip',
#   'butter',
#   'calculator',
#   'caliper',
#   'candle',
#   'candy_cane',
#   'cantaloup',
#   'carafe',
#   'carpet',
#   'carpet_sweeper',
#   'carrot',
#   'carton',
#   'casserole',
#   'catsup',
#   'cauldron',
#   'celery',
#   'cheese',
#   'cherry',
#   'chicken',
#   'chip',
#   'chocolate_box',
#   'chopstick',
#   'christmas_tree',
#   'christmas_tree_decorated',
#   'cinnamon',
#   'clout_nail',
#   'clove',
#   'coatrack',
#   'coffee_cup',
#   'coffee_maker',
#   'colander',
#   'cologne',
#   'comb',
#   'conditioner',
#   'container_cranberry',
#   'container_date',
#   'cookie',
#   'countertop',
#   'cpu_board',
#   'crab',
#   'cracker_box',
#   'cream',
#   'cream_pitcher',
#   'crib',
#   'cruet',
#   'crumb',
#   'cucumber',
#   'cupcake',
#   'dart',
#   'dartboard',
#   'dental_floss',
#   'digital_scale',
#   'dinner_napkin',
#   'dipper',
#   'dish_rack',
#   'document',
#   'dress',
#   'drill',
#   'drumstick',
#   'duffel_bag',
#   'dustpan',
#   'egg',
#   'eggplant',
#   'envelope',
#   'eraser',
#   'facsimile',
#   'fillet',
#   'fish',
#   'flour',
#   'folderal',
#   'frying_pan',
#   'gaming_table',
#   'ginger',
#   'gingerbread',
#   'gooseberry',
#   'grater',
#   'green_onion',
#   'green_onion_chopped',
#   'griddle',
#   'grill',
#   'guacamole',
#   'hairbrush',
#   'hamburger',
#   'hammer',
#   'hand_towel',
#   'hanger',
#   'hardback',
#   'headset'],
#  ['head_cabbage',
#   'highlighter',
#   'hinge',
#   'honing_steel',
#   'hook',
#   'hose',
#   'ice_cube',
#   'iron',
#   'jam',
#   'jewel',
#   'juice',
#   'keyboard',
#   'ladder',
#   'laptop',
#   'lasagna',
#   'lawn_mower',
#   'lettuce',
#   'light_bulb',
#   'lime',
#   'lipstick',
#   'lollipop',
#   'lotion',
#   'magazine',
#   'martini',
#   'mat',
#   'mayonnaise',
#   'milk',
#   'mirror',
#   'modem',
#   'mouse',
#   'mousetrap',
#   'muffin',
#   'mug',
#   'necklace',
#   'newspaper',
#   'oatmeal',
#   'paintbrush',
#   'pajamas',
#   'paper_bag',
#   'paper_clip',
#   'paper_towel',
#   'paper_towel_holder',
#   'parsley',
#   'pasta',
#   'pea',
#   'pegboard',
#   'pepper_grinder',
#   'perfume',
#   'pistachio',
#   'plate',
#   'plywood',
#   'pocketknife',
#   'pool',
#   'pool_table',
#   'pork',
#   'powder_bottle',
#   'pretzel',
#   'printer',
#   'prosciutto',
#   'puree',
#   'rake',
#   'raspberry',
#   'razor',
#   'rib',
#   'ribbon',
#   'ring',
#   'rosehip',
#   'router',
#   'salad',
#   'salt',
#   'saucepan',
#   'sausage',
#   'saw',
#   'scanner',
#   'scraper',
#   'scrub_brush',
#   'sheet',
#   'shoulder_bag',
#   'soap',
#   'sock',
#   'soup',
#   'spaghetti_sauce',
#   'spatula',
#   'spinach',
#   'steak',
#   'sticky_note',
#   'stocking',
#   'straight_pin',
#   'sugar_jar',
#   'sunscreen',
#   'sushi',
#   'sweet_corn',
#   'tart',
#   'teapot',
#   'tea_bag',
#   'thumbtack',
#   'tinsel',
#   'toaster',
#   'tongs',
#   'toothpaste'],
#  ['toothpick',
#   'tray',
#   'trowel',
#   'turnip',
#   't_shirt',
#   'underwear',
#   'vinegar',
#   'wall_socket',
#   'watch',
#   'water',
#   'whiteboard',
#   'wrapped_gift',
#   'wreath',
#   'yogurt']]
