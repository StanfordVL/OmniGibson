# %% [markdown]
# # Synset / object mapping validation

# %% [markdown]
# ## Loading data

# %% [markdown]
# ### Load synset tree

# %%
import json, csv
from nltk.corpus import wordnet as wn
import networkx as nx

# Build the legit-synset graph
G = nx.DiGraph()
G.add_nodes_from(x.name() for x in wn.all_synsets())
for parent in wn.all_synsets():
    for child in parent.hyponyms():
        G.add_edge(parent.name(), child.name())
        
# Add the illegit-synset graph
with open(r"D:\ig_pipeline\metadata\custom_synsets.csv") as f:
    reader = csv.DictReader(f)
    for row in reader:
        child = row["custom_synset"].strip()
        parent = wn.synset(row["hypernyms"].strip()).name()
        assert parent in G.nodes, "Could not find " + parent
        G.add_edge(parent, child)
        
legit_synsets = set(G.nodes)

# %%
def is_leaf_synset(x):
    return G.out_degree[x] == 0

# %%
def canonicalize(s):
    try:
        return wn.synset(s).name()
    except:
        return s

# %% [markdown]
# ### Load list of task-required synsets

# %%
with open(r"D:\ig_pipeline\metadata\b200_objects.json", "r") as f:
    obj_mapping = json.load(f)
activities = set(obj_mapping.keys())
activities_list = sorted(activities)
task_required_synsets_by_activity = {k: [canonicalize(x) for x in obj_mapping[k] if x != "agent.n.01"] for k in activities}
task_required_synsets = {x for objs in task_required_synsets_by_activity.values() for x in objs}
synset_requiring_tasks = {s: [t for t, ss in task_required_synsets_by_activity.items() if s in ss] for s in task_required_synsets}

# %% [markdown]
# ### Load list of categories matching each synset

# %%
import csv
from collections import defaultdict
# Get the category - synset mapping
pairs = {}
synset_to_cat = defaultdict(list)
with open(r"D:\ig_pipeline\metadata\category_mapping.csv", newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        category = row["category"].strip()
        synset = row["synset"].strip()
        if not synset or not category:
            print(f"Skipping problematic row: {row}")
            continue
        canonical_synset = canonicalize(synset)
        if canonical_synset != synset:
            print(f"Non-canonical synset {synset} in category mapping replaced with canonical synset {canonical_synset}")
        synset = canonical_synset
        pairs[category] = synset
        synset_to_cat[synset].append(category)
found_synsets = set(pairs.values())
found_categories = set(pairs.keys())
# Out:
# Non-canonical synset smoke_alarm.n.01 in category mapping replaced with canonical synset fire_alarm.n.02
# Non-canonical synset skeletal_frame.n.01 in category mapping replaced with canonical synset skeleton.n.04
# Non-canonical synset ottoman.n.04 in category mapping replaced with canonical synset footstool.n.01
# Non-canonical synset popsicle.n.01 in category mapping replaced with canonical synset ice_lolly.n.01
# Non-canonical synset freezer.n.01 in category mapping replaced with canonical synset deep-freeze.n.01
# Non-canonical synset creamer.n.01 in category mapping replaced with canonical synset cream_pitcher.n.01
# Non-canonical synset soymilk.n.01 in category mapping replaced with canonical synset soya_milk.n.01
# Non-canonical synset free_weight.n.01 in category mapping replaced with canonical synset weight.n.02
# Non-canonical synset checkout_counter.n.01 in category mapping replaced with canonical synset checkout.n.03
# Non-canonical synset stem.n.02 in category mapping replaced with canonical synset stalk.n.02
# Non-canonical synset buret.n.01 in category mapping replaced with canonical synset burette.n.01
# Non-canonical synset cubicle.n.02 in category mapping replaced with canonical synset carrel.n.02
# Non-canonical synset hosepipe.n.01 in category mapping replaced with canonical synset hose.n.03
# Non-canonical synset screen.n.08 in category mapping replaced with canonical synset screen_door.n.01
# Non-canonical synset gym_mat.n.01 in category mapping replaced with canonical synset mat.n.03
# Non-canonical synset basketball_hoop.n.01 in category mapping replaced with canonical synset basket.n.03
# Non-canonical synset exhaust_hood.n.01 in category mapping replaced with canonical synset hood.n.06
# Non-canonical synset skeletal_frame.n.01 in category mapping replaced with canonical synset skeleton.n.04
# Non-canonical synset grating.n.01 in category mapping replaced with canonical synset grate.n.03
# Non-canonical synset coal.n.02 in category mapping replaced with canonical synset ember.n.01
# Non-canonical synset rockery.n.01 in category mapping replaced with canonical synset rock_garden.n.01
# Non-canonical synset pergola.n.01 in category mapping replaced with canonical synset arbor.n.03
# Non-canonical synset soymilk.n.01 in category mapping replaced with canonical synset soya_milk.n.01
# Non-canonical synset robe.n.02 in category mapping replaced with canonical synset gown.n.05
# Non-canonical synset suitcase.n.01 in category mapping replaced with canonical synset bag.n.06
# Non-canonical synset pant.n.02 in category mapping replaced with canonical synset trouser.n.01
# Non-canonical synset peppercorn.n.01 in category mapping replaced with canonical synset pepper.n.03
# Non-canonical synset seasoning.n.01 in category mapping replaced with canonical synset flavorer.n.01
# Non-canonical synset tea_leaf.n.01 in category mapping replaced with canonical synset tea.n.05
# Non-canonical synset chili_pepper.n.02 in category mapping replaced with canonical synset chili.n.02
# Non-canonical synset flower_petal.n.01 in category mapping replaced with canonical synset petal.n.01
# Non-canonical synset deicer.n.01 in category mapping replaced with canonical synset defroster.n.01
# Non-canonical synset decanter.n.01 in category mapping replaced with canonical synset carafe.n.01
# Non-canonical synset dice.n.01 in category mapping replaced with canonical synset die.n.01
# Non-canonical synset dish_towel.n.01 in category mapping replaced with canonical synset dishtowel.n.01
# Non-canonical synset kiosk.n.01 in category mapping replaced with canonical synset booth.n.02
# Non-canonical synset Dutch_oven.n.02 in category mapping replaced with canonical synset dutch_oven.n.02
# Non-canonical synset duvet.n.01 in category mapping replaced with canonical synset eiderdown.n.01
# Non-canonical synset DVD.n.01 in category mapping replaced with canonical synset videodisk.n.01
# Non-canonical synset Easter_egg.n.01 in category mapping replaced with canonical synset easter_egg.n.01
# Non-canonical synset pine_tree.n.01 in category mapping replaced with canonical synset pine.n.01
# Non-canonical synset food_coloring.n.01 in category mapping replaced with canonical synset coloring.n.01
# Non-canonical synset framing.n.02 in category mapping replaced with canonical synset frame.n.10
# Non-canonical synset paper_bag.n.01 in category mapping replaced with canonical synset sack.n.01
# Non-canonical synset lemon_tree.n.01 in category mapping replaced with canonical synset lemon.n.03
# Non-canonical synset glove.n.01 in category mapping replaced with canonical synset baseball_glove.n.01
# Non-canonical synset garlic_clove.n.01 in category mapping replaced with canonical synset clove.n.03
# Non-canonical synset beer_keg.n.01 in category mapping replaced with canonical synset beer_barrel.n.01
# Non-canonical synset coffee_grinder.n.01 in category mapping replaced with canonical synset coffee_mill.n.01
# Non-canonical synset desert_boot.n.01 in category mapping replaced with canonical synset buskin.n.01
# Non-canonical synset juicer.n.02 in category mapping replaced with canonical synset reamer.n.01
# Non-canonical synset roast_beef.n.01 in category mapping replaced with canonical synset beef_roast.n.01
# Non-canonical synset adhesive.n.01 in category mapping replaced with canonical synset adhesive_material.n.01
# Non-canonical synset arugula.n.01 in category mapping replaced with canonical synset rocket.n.03
# Non-canonical synset baking_tray.n.01 in category mapping replaced with canonical synset cookie_sheet.n.01
# Non-canonical synset insect_repellent.n.01 in category mapping replaced with canonical synset insectifuge.n.01
# Non-canonical synset champagne_flute.n.01 in category mapping replaced with canonical synset flute.n.02
# Non-canonical synset chicken_breast.n.01 in category mapping replaced with canonical synset pigeon_breast.n.01
# Non-canonical synset chili_pepper.n.02 in category mapping replaced with canonical synset chili.n.02
# Non-canonical synset tape_measure.n.01 in category mapping replaced with canonical synset tape.n.04
# Non-canonical synset jumpsuit.n.01 in category mapping replaced with canonical synset jump_suit.n.01
# Non-canonical synset liner.n.02 in category mapping replaced with canonical synset lining.n.01
# Non-canonical synset pillowcase.n.01 in category mapping replaced with canonical synset case.n.19
# Non-canonical synset flowerpot.n.01 in category mapping replaced with canonical synset pot.n.04
# Non-canonical synset outlet.n.02 in category mapping replaced with canonical synset wall_socket.n.01
# Non-canonical synset purse.n.01 in category mapping replaced with canonical synset bag.n.04
# Non-canonical synset roast_beef.n.01 in category mapping replaced with canonical synset beef_roast.n.01
# Non-canonical synset shorts.n.01 in category mapping replaced with canonical synset short_pants.n.01
# Non-canonical synset sticker.n.02 in category mapping replaced with canonical synset gummed_label.n.01
# Non-canonical synset stroller.n.02 in category mapping replaced with canonical synset baby_buggy.n.01
# Non-canonical synset tackle.n.03 in category mapping replaced with canonical synset fishing_gear.n.01
# Non-canonical synset tea_leaf.n.01 in category mapping replaced with canonical synset tea.n.05
# Non-canonical synset tote_bag.n.01 in category mapping replaced with canonical synset carryall.n.01
# Non-canonical synset snack.n.01 in category mapping replaced with canonical synset bite.n.04
# Non-canonical synset zipper.n.01 in category mapping replaced with canonical synset slide_fastener.n.01

# %%
def is_synset_available(s):
    child_synsets = [s] + list(nx.descendants(G, s))
    for cs in child_synsets:
        if cs in found_synsets:
            return True
        
    return False

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Problem 1: Task-required synsets that are not included in the WN hiearchy

# %%
illegal_task_required_synsets = {x for x in task_required_synsets - legit_synsets}
legit_task_required_synsets = task_required_synsets - illegal_task_required_synsets
print(f"{len(illegal_task_required_synsets)}/{len(task_required_synsets)} task required synsets missing in hierarchy.\n")
print(illegal_task_required_synsets)
# Out:
# 185/1300 task required synsets missing in hierarchy.
#
# {'vitamin_pill__container.n.01', 'electrical_refrigerator.n.01', 'brown_sugar__sack.n.01', 'half__potato.n.01', 'brown_rice__sack.n.01', 'cooked__white_rice.n.01', 'feta__box.n.01', 'diced__garlic.n.02', '?', 'granulated__sugar.n.01', 'pottable__marigold.n.01', 'whiskey__bottle.n.01', 'ink__bottle.n.01', 'shampoo__container.n.01', 'cleansing_agent__container.n.01', 'bleaching_agent__bottle.n.01', 'cooked__pasta.n.02', 'diced__chili.n.02', 'iced', 'liquid_soap.n.01_1', 'diced__beet.n.01', 'broken__glass.n.02', 'rubbing_alcohol__bottle.n.01', 'paprika__shaker.n.02', 'cooked__quinoa.n.01', 'quinoa__container.n.01', 'glaze__bottle.n.01', 'rosemary__shaker.n.01', 'half__log.n.01', 'diced__cheese.n.01', 'pasta__box.n.02', 'margarine__box.n.01', 'milk__carton.n.01', 'diced__tomato.n.01', 'water__sodium_carbonate.n.01', 'acetone__container.n.01', 'diced__bratwurst.n.01', 'chia_seed__bag.n.01', 'chicken_broth__carton.n.01', 'melted__white_chocolate.n.01', 'mayonnaise__jar.n.01', 'diced__feta.n.01', 'yeast__jar.n.01', 'parmesan__bottle.n.01', 'chickpea__can.n.02', 'red_wine__container.n.01', 'lubricant__bottle.n.01', 'cream_cheese__container.n.01', 'soap__bottle.n.01', 'eggnog', 'diced__steak.n.01', 'sugar__sack.n.01', 'diced__cabbage.n.03', 'half__cake.n.03', 'shampoo__bottle.n.01', 'sodium_carbonate__jar.n.01', 'hot__coffee.n.01', 'house_paint__can.n.01', 'pellet__bag.n.01', 'black_pepper__container.n.01', 'thyme__shaker.n.02', 'hot__soup.n.01', 'maple_syrup__jar.n.01', 'hummus__box.n.01', 'essential_oil__container.n.01', 'disinfectant__bottle.n.01', 'chlorine__bottle.n.01', 'baking_powder__jar.n.01', 'diced__carrot.n.03', 'granola__container.n.01', 'diced__lemon.n.01', 'half__bell_pepper.n.02', 'coffee_bean__container.n.01', 'apple_juice__bottle.n.01', 'lemonade__bottle.n.01', 'curtain_rod.n.01', 'vanilla__container.n.01', 'oil__container.n.01', 'fried_egg.n.02', 'vinegar__bottle.n.01', 'bird_feed__bag.n.01', 'ground_beef__package.n.01', 'peanut_butter__jar.n.01', 'cooked__diced__chicken.n.01', 'coffee_grounds__container.n.01', 'spray_paint__can.n.01', 'diced__onion.n.03', 'conditioner__bottle.n.03', 'sesame_seed__bottle.n.01', 'acetone__bottle.n.01', 'alcohol__container.n.01', 'diced__bell_pepper.n.02', 'mustard__bottle.n.02', 'diced__spinach.n.02', 'tequila__bottle.n.01', 'soil__bag.n.02', 'olive_oil__bottle.n.01', 'pottable__cactus.n.01', 'petfood__bag.n.01', 'whitewalls_tire.n.01', 'walls_socket.n.01', 'corn_flake__container.n.01', 'diced__sweet_pepper.n.02', 'broken__light_bulb.n.01', 'granulated_sugar__sack.n.01', 'soy_sauce__bottle.n.01', 'jam__jar.n.01', 'melted__butter.n.01', 'diced__ham.n.01', 'chocolate_candy__container.n.01', 'acorn__bag.n.01', 'mustard__bottle.n.01', 'beef__container.n.01', 'melted__cheese.n.01', 'vodka_bottle.n.01', 'hydrogen_peroxide__bottle.n.01', 'yogurt__carton.n.01', 'cocoa__box.n.01', 'sesame_oil__bottle.n.01', 'cooking_oil__bottle.n.01', 'sealant__tube.n.01', 'diced__watermelon.n.02', 'half__orange.n.01', 'diced__chard.n.01', 'ammonia_water__bottle.n.01', 'pottable__daffodil.n.01', 'half__eggplant.n.01', 'rubbish__container.n.01', 'mulch__container.n.01', 'ice_cream__carton.n.01', 'diced__chicken.n.01', 'half__apple.n.01', 'barbecue_sauce__bottle.n.01', 'tomato_sauce__jar.n.01', 'brandy__container.n.01', 'diced__beef.n.01', 'half__tomato.n.01', 'lentil__container.n.01', 'diced__cucumber.n.02', 'kayak_rack.n.01', 'diced__potato.n.01', 'diced__avocado.n.01', 'melted__parmesan.n.01', 'pottable__dahlia.n.01', 'soda_water__bottle.n.01', 'catsup__bottle.n.01', 'wine_sauce__bottle.n.01', 'salt__bottle.n.01', 'diced__zucchini.n.02', 'stew__container.n.01', 'half__zucchini.n.02', 'cream__carton.n.01', 'syrup__bottle.n.01', 'diced__clove.n.03', 'polish__bottle.n.03', 'chia_seed__container.n.01', 'diced__lettuce.n.03', 'solvent__bottle.n.01', 'diced__broccoli.n.02', 'cinnamon__bottle.n.01', 'frosting__jar.n.01', 'pumpkin_seed__bag.n.01', 'jelly_bean__jar.n.01', 'marinara__jar.n.01', 'tofu.n.02', 'fertilizer ...

# %% [markdown]
# ### Problem 2: Category-mapped synsets that are not included in the WN hiearchy

# %%
found_invalid_synsets = {x for x in found_synsets if x not in legit_synsets and canonicalize(x) not in legit_synsets}
print(f"{len(found_invalid_synsets)}/{len(found_synsets)} category-mapped synsets are illegal.")
print("\n".join(found_invalid_synsets))
# Out:
# 0/1152 category-mapped synsets are illegal.

# %% [markdown]
# ### Problem 3: Categories are mapped to non-leaf synsets

# %%
nonleaf_cats = {cat for cat, s in pairs.items() if not is_leaf_synset(s) and any(cs in found_synsets for cs in nx.descendants(G, s))}
leaf_cats = found_categories - nonleaf_cats
print(f"{len(nonleaf_cats)} / {len(pairs)} categories mapped to non-leaf synsets.\n")
print("\n\n".join(f"{cat}: {pairs[cat]}. Descendants: {sorted(x for x in nx.descendants(G, pairs[cat]) if x in found_synsets)}" for cat in sorted(nonleaf_cats)))
# Out:
# 272 / 1426 categories mapped to non-leaf synsets.
#
# adhesive: adhesive_material.n.01. Descendants: ['glue.n.01']
#
# alcohol: alcohol.n.01. Descendants: ['beer.n.01', 'brandy.n.01', 'champagne.n.01', 'fruit_punch.n.01', 'gin.n.01', 'martini.n.01', 'red_wine.n.01', 'rum.n.01', 'sake.n.02', 'tequila.n.01', 'vodka.n.01', 'whiskey.n.01', 'wine.n.01']
#
# almond_milk: milk.n.01. Descendants: ['buttermilk.n.01', 'chocolate_milk.n.01']
#
# baby_bottle: bottle.n.01. Descendants: ['carafe.n.01', 'carboy.n.01', 'cruet.n.01', 'erlenmeyer_flask.n.01', 'flask.n.01', 'lemon_juice__bottle.n.01', 'pill_bottle.n.01', 'pop_bottle.n.01', 'specimen_bottle.n.01', 'water_bottle.n.01', 'whiskey_bottle.n.01', 'wine_bottle.n.01']
#
# baby_monitor: detector.n.01. Descendants: ['photoelectric_cell.n.01']
#
# bag_of_bread: bread.n.01. Descendants: ['bagel.n.01', 'baguet.n.01', 'biscuit.n.01', 'bun.n.01', 'cracker.n.01', 'crescent_roll.n.01', 'crouton.n.01', 'danish.n.02', 'meat_loaf.n.01', 'muffin.n.01', 'pretzel.n.01', 'scone.n.01']
#
# bag_of_cookie: cookie.n.01. Descendants: ['brownie.n.03', 'granola_bar.n.01', 'wafer.n.02']
#
# bag_of_tea: tea.n.05. Descendants: ['green_tea.n.01', 'tea_bag.n.01']
#
# ball: ball.n.01. Descendants: ['baseball.n.02', 'bowling_ball.n.01', 'punching_bag.n.02', 'soccer_ball.n.01', 'softball.n.01', 'tennis_ball.n.01']
#
# bar_cart: handcart.n.01. Descendants: ['shopping_cart.n.01']
#
# basket: basket.n.01. Descendants: ['shopping_basket.n.01']
#
# bath_salt: salt.n.01. Descendants: ['aspirin.n.01', 'sodium_carbonate.n.01']
#
# bathtub: bathtub.n.01. Descendants: ['hot_tub.n.01']
#
# bean: bean.n.01. Descendants: ['black_bean.n.01', 'green_bean.n.01']
#
# bed: bed.n.01. Descendants: ['hammock.n.02', 'hospital_bed.n.01']
#
# bedding: bedclothes.n.01. Descendants: ['blanket.n.01', 'eiderdown.n.01', 'mattress_cover.n.01', 'quilt.n.01']
#
# beef: beef.n.02. Descendants: ['ground_beef.n.01']
#
# bench: bench.n.01. Descendants: ['flat_bench.n.01']
#
# blinds: blind.n.03. Descendants: ['curtain.n.01', 'shutter.n.02', 'window_blind.n.01']
#
# boat: boat.n.01. Descendants: ['kayak.n.01']
#
# body_scrub: soap.n.01. Descendants: ['liquid_soap.n.01']
#
# boot: boot.n.01. Descendants: ['buskin.n.01', 'rubber_boot.n.01']
#
# bottle: bottle.n.01. Descendants: ['carafe.n.01', 'carboy.n.01', 'cruet.n.01', 'erlenmeyer_flask.n.01', 'flask.n.01', 'lemon_juice__bottle.n.01', 'pill_bottle.n.01', 'pop_bottle.n.01', 'specimen_bottle.n.01', 'water_bottle.n.01', 'whiskey_bottle.n.01', 'wine_bottle.n.01']
#
# bottle_of_coffee: coffee.n.01. Descendants: ['cappuccino.n.01', 'iced_coffee.n.01']
#
# bottle_of_milk: milk.n.01. Descendants: ['buttermilk.n.01', 'chocolate_milk.n.01']
#
# bottle_of_soup: soup.n.01. Descendants: ['chowder.n.01', 'gazpacho.n.01']
#
# box: box.n.01. Descendants: ['carton.n.02', 'cash_register.n.01', 'chest.n.02', 'crate.n.01', 'litter_box.n.01', 'mailbox.n.01', 'matchbox.n.01', 'pencil_box.n.01', 'pizza_box.n.01', 'shoebox.n.02', 'toolbox.n.01', 'toy_box.n.01']
#
# box_of_cake: cake.n.03. Descendants: ['brownie.n.03', 'chocolate_cake.n.01', 'cookie.n.01', 'cupcake.n.01', 'doughnut.n.02', 'gingerbread.n.01', 'granola_bar.n.01', 'pancake.n.01', 'tortilla.n.01', 'wafer.n.02', 'waffle.n.01']
#
# box_of_cookie: cookie.n.01. Descendants: ['brownie.n.03', 'granola_bar.n.01', 'wafer.n.02']
#
# box_of_fruit: fruit.n.01. Descendants: ['almond.n.02', 'apple.n.01', 'apricot.n.02', 'avocado.n.01', 'banana.n.02', 'blueberry.n.02', 'cantaloup.n.02', 'cherry.n.03', 'chestnut.n.03', 'citrus.n.01', 'coffee_bean.n.01', 'cranberry.n.02', 'cumin.n.02', 'date.n.08', 'dried_apricot.n.01', 'durian.n.02', 'fig.n.04', 'grape.n.01', 'grapefruit.n.02', 'hip.n.05', 'kiwi.n.03', 'lemon.n.01', 'lime.n.06', 'mango.n.02', 'melon.n.01', 'nectarine.n.02', 'olive.n.04', 'orange.n.01', 'peach.n.03', 'peanut.n.01', 'pear.n.01', 'pineapple.n.02', 'pistachio.n.02', 'plum.n.02', 'pomegranate.n.02', 'pomelo.n.02', 'raisin.n.01', 'raspberry.n.02', 'strawberry.n.01', 'walnut.n.01', 'watermelon.n.02']
#
# box_of_milk: milk.n.01. Descendants: ['buttermilk.n.01', 'chocolate_milk.n.01']
#
# box_of_perfume: perfume.n.02. Descendants: ['cologne.n.02']
#
# box_of_tea: tea.n.05. Descendants: ['green_tea.n.01', 'tea_bag.n.01']
#
# box_of_tissue: tissue.n.02. Descendants: ['toilet_tissue.n.01']
#
# box_of_wine: wine.n.01. Descendants: ['champagne.n.01', 'red_wine.n.01']
#
# bread: bread.n.01. Descendants: ['bagel.n.01', 'baguet.n.01', 'biscuit.n.01', 'bun.n.01', 'cracker.n.01', 'crescent_roll.n.01', 'crouton.n.01', 'danish.n.02', 'meat_loaf.n.01', 'muffin.n.01', 'pretzel.n.01', 'scone.n.01']
#
# bun: bun.n.01. Descendants: ['bagel.n.01', 'crescent_roll.n.01', 'danish.n.02']
#
# bush: shrub.n.01. Descendants: ['gooseberry.n.01', 'poinsettia.n.01', 'rose.n.01']
#
# cake: cake.n.03. Descendants: ['brownie.n.03', 'chocolate_cake.n.01', 'cookie.n.01', 'cupcake.n.01', 'doughnut.n.02', 'gingerbread.n.01', 'granola_bar.n.01', 'pancake.n.01', 'tortilla.n.01', 'wafer.n.02', 'waffle.n.01']
#
# camera: camera.n.01. Descendants: ['webcam.n.01']
#
# candy: candy.n.01. Descendants: ['candy_cane.n.01', 'easter_egg.n.01', 'jelly_bean.n.01', 'lollipop.n.02', 'marshmallow.n.01']
#
# candy_box: candy.n.01. Descendants: ['candy_cane.n.01', 'easter_egg.n.01', 'jelly_bean.n.01', 'lollipop.n.02', 'marshmallow.n.01']
#
# candy_dispenser_shelf: dispenser.n.01. Descendants: ['atomizer.n.01', 'inhaler.n.01', 'soap_dispenser.n.01']
#
# canned_beans: bean.n.01. Descendants: ['black_bean.n.01', 'green_bean.n.01']
#
# canned_coffee: can.n.01. Descendants: ['soda_can.n.01']
#
# canned_sardines: can.n.01. Descendants: ['soda_can.n.01']
#
# canned_tomatoes: can.n.01. Descendants: ['soda_can.n.01']
#
# canner: cooker.n.01. Descendants: ['crock_pot.n.01', 'popper.n.03']
#
# canner_lid: cooker.n.01. Descendants: ['crock_pot.n.01', 'popper.n.03']
#
# canvas: canvas.n.01. Descendants: ['tarpaulin.n.01']
#
# car: car.n.01. Descendants: ['sedan.n.01', 'sport_utility.n.01']
#
# cardstock: card.n.03. Descendants: ['postcard.n.01']
#
# carpet: rug.n.01. Descendants: ['runner.n.08']
#
# cart: handcart.n.01. Descendants: ['shopping_cart.n.01']
#
# carton_of_milk: milk.n.01. Descendants: ['buttermilk.n.01', 'chocolate_milk.n.01']
#
# ceiling_fan: fan.n.01. Descendants: ['electric_fan.n.01']
#
# ceiling_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# cereal: cereal.n.03. Descendants: ['corn_flake.n.01', 'granola.n.01']
#
# cheese: cheese.n.01. Descendants: ['cream_cheese.n.01', 'parmesan.n.01']
#
# chest: chest.n.02. Descendants: ['toolbox.n.01', 'toy_box.n.01']
#
# chocolate_bar: chocolate.n.02. Descendants: ['cocoa_powder.n.01', 'white_chocolate.n.01']
#
# chocolate_box: chocolate.n.02. Descendants: ['cocoa_powder.n.01', 'white_chocolate.n.01']
#
# chocolate_chip: chocolate.n.02. Descendants: ['cocoa_powder.n.01', 'white_chocolate.n.01']
#
# citrus: citrus.n.01. Descendants: ['grapefruit.n.02', 'lemon.n.01', 'lime.n.06', 'orange.n.01', 'pomelo.n.02']
#
# classroom_mock_up: model.n.04. Descendants: ['globe.n.03', 'mannequin.n.02']
#
# clip: clip.n.03. Descendants: ['bulldog_clip.n.01', 'paper_clip.n.01']
#
# clock: clock.n.01. Descendants: ['alarm_clock.n.01', 'grandfather_clock.n.01', 'wall_clock.n.01']
#
# coal_heater: heater.n.01. Descendants: ['defroster.n.01']
#
# coat: coat.n.01. Descendants: ['blazer.n.01', 'jacket.n.01', 'raincoat.n.01']
#
# coffee: coffee.n.01. Descendants: ['cappuccino.n.01', 'iced_coffee.n.01']
#
# coffee_box: coffee.n.01. Descendants: ['cappuccino.n.01', 'iced_coffee.n.01']
#
# coffee_cup: coffee.n.01. Descendants: ['cappuccino.n.01', 'iced_coffee.n.01']
#
# coffee_maker: coffee_maker.n.01. Descendants: ['espresso_maker.n.01']
#
# coffee_pouch: coffee.n.01. Descendants: ['cappuccino.n.01', 'iced_coffee.n.01']
#
# conserve: conserve.n.01. Descendants: ['jam.n.01']
#
# cooked_ham: ham.n.01. Descendants: ['prosciutto.n.01']
#
# cookie: cookie.n.01. Descendants: ['brownie.n.03', 'granola_bar.n.01', 'wafer.n.02']
#
# cord: cord.n.01. Descendants: ['clothesline.n.01', 'dental_floss.n.01', 'string.n.01', 'thread.n.01', 'tinsel.n.02']
#
# corn: corn.n.01. Descendants: ['popcorn.n.01']
#
# counter: counter.n.01. Descendants: ['bar.n.02', 'checkout.n.03']
#
# cracker: cracker.n.01. Descendants: ['pretzel.n.01']
#
# cracker_box: cracker.n.01. Descendants: ['pretzel.n.01']
#
# cream: cream.n.02. Descendants: ['sour_cream.n.01']
#
# creamer_single: cream.n.02. Descendants: ['sour_cream.n.01']
#
# crumb: crumb.n.03. Descendants: ['breadcrumb.n.01']
#
# cup: cup.n.01. Descendants: ['dixie_cup.n.01', 'teacup.n.02']
#
# curtain_rod: rod.n.01. Descendants: ['fishing_rod.n.01', 'pole.n.01']
#
# decoration: decoration.n.01. Descendants: ['banner.n.01', 'baseboard.n.01', 'bouquet.n.01', 'bow.n.08', 'bracelet.n.02', 'christmas_tree.n.05', 'diamond.n.01', 'engagement_ring.n.01', 'flag.n.01', 'folderal.n.01', 'frosting.n.01', 'interior_decoration.n.01', 'jewel.n.01', 'jewelry.n.01', 'meringue.n.01', 'necklace.n.01', 'pearl.n.01', 'ring.n.08', 'tassel.n.01', 'wreath.n.01']
#
# degreaser: cleansing_agent.n.01. Descendants: ['detergent.n.02', 'liquid_soap.n.01', 'shampoo.n.01', 'soap.n.01', 'toothpaste.n.01']
#
# dish_soap: soap.n.01. Descendants: ['liquid_soap.n.01']
#
# display_case: case.n.20. Descendants: ['trophy_case.n.01']
#
# display_fridge: electric_refrigerator.n.01. Descendants: ['deep-freeze.n.01']
#
# disposable_container: container.n.01. Descendants: ['ashcan.n.01', 'ashtray.n.01', 'atomizer.n.01', 'baby_buggy.n.01', 'backpack.n.01', 'bag.n.01', 'bag.n.04', 'bag.n.06', 'basket.n.01', 'bathtub.n.01', 'beer_barrel.n.01', 'beer_mug.n.01', 'bicycle.n.01', 'bidet.n.01', 'bottle.n.01', 'bowl.n.01', 'box.n.01', 'briefcase.n.01', 'bucket.n.01', 'caldron.n.01', 'can.n.01', 'canister.n.02', 'car.n.01', 'carafe.n.01', 'carboy.n.01', 'carryall.n.01', 'carton.n.02', 'case.n.05', 'case.n.20', 'cash_register.n.01', 'casserole.n.02', 'chest.n.02', 'coffeepot.n.01', 'crate.n.01', 'cream_pitcher.n.01', 'cruet.n.01', 'cup.n.01', 'dipper.n.01', 'dispenser.n.01', 'dixie_cup.n.01', 'drawer.n.01', 'duffel_bag.n.01', 'dustpan.n.02', 'dutch_oven.n.02', 'envelope.n.01', 'erlenmeyer_flask.n.01', 'flask.n.01', 'flute.n.02', 'glass.n.02', 'goblet.n.01', 'gravy_boat.n.01', 'grocery_bag.n.01', 'handcart.n.01', 'hot_tub.n.01', 'inhaler.n.01', 'jar.n.01', 'kettle.n.01', 'ladle.n.01', 'lemon_juice__bottle.n.01', 'litter_box.n.01', 'mailbox.n.01', 'mason_jar.n.01', 'matchbox.n.01', 'measuring_cup.n.01', 'mixing_bowl.n.01', 'mortar.n.03', 'motorcycle.n.01', 'mug.n.04', 'package.n.02', 'pencil_box.n.01', 'pepper_shaker.n.01', 'petri_dish.n.01', 'pickup.n.01', 'pill_bottle.n.01', 'pitcher.n.02', 'pizza_box.n.01', 'planter.n.03', 'plastic_bag.n.01', 'pop_bottle.n.01', 'pot.n.04', 'pressure_cooker.n.01', 'recycling_bin.n.01', 'sack.n.01', 'saltshaker.n.01', 'saucepot.n.01', 'sedan.n.01', 'shaker.n.03', 'shoebox.n.02', 'shopping_basket.n.01', 'shopping_cart.n.01', 'shot_glass.n.01', 'shoulder_bag.n.01', 'skateboard.n.01', 'soap_dispenser.n.01', 'soda_can.n.01', 'soup_ladle.n.01', 'specimen_bottle.n.01', 'spoon.n.01', 'sport_utility.n.01', 'stockpot.n.01', 'teacup.n.02', 'teapot.n.01', 'teaspoon.n.02', 'toolbox.n.01', 'toy_box.n.01', 'tray.n.01', 'trophy_case.n.01', 'truck.n.01', 'tupperware.n.01', 'tureen.n.01', 'vase.n.01', 'wallet.n.01', 'water_bottle.n.01', 'water_glass.n.02', 'watering_can.n.01', 'whiskey_bottle.n.01', 'wine_bottle.n.01', 'wineglass.n.01']
#
# document: document.n.01. Descendants: ['ticket.n.01']
#
# door: door.n.01. Descendants: ['screen_door.n.01']
#
# dough: dough.n.01. Descendants: ['pastry.n.01']
#
# drink_dispenser: dispenser.n.01. Descendants: ['atomizer.n.01', 'inhaler.n.01', 'soap_dispenser.n.01']
#
# drumset: percussion_instrument.n.01. Descendants: ['cymbal.n.01', 'piano.n.01']
#
# dry_food_dispenser_shelf: dispenser.n.01. Descendants: ['atomizer.n.01', 'inhaler.n.01', 'soap_dispenser.n.01']
#
# dryer: dryer.n.01. Descendants: ['hand_blower.n.01']
#
# drying_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# electric_mixer: mixer.n.04. Descendants: ['blender.n.01', 'eggbeater.n.02', 'electric_mixer.n.01', 'whisk.n.01']
#
# eraser: eraser.n.01. Descendants: ['blackboard_eraser.n.01']
#
# eyeglasses: spectacles.n.01. Descendants: ['goggles.n.01', 'sunglasses.n.01']
#
# female_restroom_door: door.n.01. Descendants: ['screen_door.n.01']
#
# fence: fence.n.01. Descendants: ['hedge.n.01', 'rail_fence.n.01']
#
# fertilizer_bag: fertilizer.n.01. Descendants: ['manure.n.01']
#
# fire_extinguisher_label: label.n.04. Descendants: ['gummed_label.n.01', 'name_tag.n.01', 'price_tag.n.01', 'tag.n.01']
#
# firework: firework.n.01. Descendants: ['sparkler.n.02']
#
# flask: flask.n.01. Descendants: ['erlenmeyer_flask.n.01']
#
# fountain: fountain.n.01. Descendants: ['drinking_fountain.n.01']
#
# free_weight_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# french_press: coffee_maker.n.01. Descendants: ['espresso_maker.n.01']
#
# fridge: electric_refrigerator.n.01. Descendants: ['deep-freeze.n.01']
#
# fry_holder: sack.n.01. Descendants: ['grocery_bag.n.01']
#
# frying_pan: frying_pan.n.01. Descendants: ['electric_frying_pan.n.01']
#
# fuel_can: container.n.01. Descendants: ['ashcan.n.01', 'ashtray.n.01', 'atomizer.n.01', 'baby_buggy.n.01', 'backpack.n.01', 'bag.n.01', 'bag.n.04', 'bag.n.06', 'basket.n.01', 'bathtub.n.01', 'beer_barrel.n.01', 'beer_mug.n.01', 'bicycle.n.01', 'bidet.n.01', 'bottle.n.01', 'bowl.n.01', 'box.n.01', 'briefcase.n.01', 'bucket.n.01', 'caldron.n.01', 'can.n.01', 'canister.n.02', 'car.n.01', 'carafe.n.01', 'carboy.n.01', 'carryall.n.01', 'carton.n.02', 'case.n.05', 'case.n.20', 'cash_register.n.01', 'casserole.n.02', 'chest.n.02', 'coffeepot.n.01', 'crate.n.01', 'cream_pitcher.n.01', 'cruet.n.01', 'cup.n.01', 'dipper.n.01', 'dispenser.n.01', 'dixie_cup.n.01', 'drawer.n.01', 'duffel_bag.n.01', 'dustpan.n.02', 'dutch_oven.n.02', 'envelope.n.01', 'erlenmeyer_flask.n.01', 'flask.n.01', 'flute.n.02', 'glass.n.02', 'goblet.n.01', 'gravy_boat.n.01', 'grocery_bag.n.01', 'handcart.n.01', 'hot_tub.n.01', 'inhaler.n.01', 'jar.n.01', 'kettle.n.01', 'ladle.n.01', 'lemon_juice__bottle.n.01', 'litter_box.n.01', 'mailbox.n.01', 'mason_jar.n.01', 'matchbox.n.01', 'measuring_cup.n.01', 'mixing_bowl.n.01', 'mortar.n.03', 'motorcycle.n.01', 'mug.n.04', 'package.n.02', 'pencil_box.n.01', 'pepper_shaker.n.01', 'petri_dish.n.01', 'pickup.n.01', 'pill_bottle.n.01', 'pitcher.n.02', 'pizza_box.n.01', 'planter.n.03', 'plastic_bag.n.01', 'pop_bottle.n.01', 'pot.n.04', 'pressure_cooker.n.01', 'recycling_bin.n.01', 'sack.n.01', 'saltshaker.n.01', 'saucepot.n.01', 'sedan.n.01', 'shaker.n.03', 'shoebox.n.02', 'shopping_basket.n.01', 'shopping_cart.n.01', 'shot_glass.n.01', 'shoulder_bag.n.01', 'skateboard.n.01', 'soap_dispenser.n.01', 'soda_can.n.01', 'soup_ladle.n.01', 'specimen_bottle.n.01', 'spoon.n.01', 'sport_utility.n.01', 'stockpot.n.01', 'teacup.n.02', 'teapot.n.01', 'teaspoon.n.02', 'toolbox.n.01', 'toy_box.n.01', 'tray.n.01', 'trophy_case.n.01', 'truck.n.01', 'tupperware.n.01', 'tureen.n.01', 'vase.n.01', 'wallet.n.01', 'water_bottle.n.01', 'water_glass.n.02', 'watering_can.n.01', 'whiskey_bottle.n.01', 'wine_bottle.n.01', 'wineglass.n.01']
#
# garage_door: gate.n.01. Descendants: ['turnstile.n.01']
#
# garden_umbrella: canopy.n.03. Descendants: ['umbrella.n.01']
#
# gate: gate.n.01. Descendants: ['turnstile.n.01']
#
# gift_bag: bag.n.01. Descendants: ['backpack.n.01', 'carryall.n.01', 'duffel_bag.n.01', 'grocery_bag.n.01', 'plastic_bag.n.01', 'sack.n.01']
#
# gift_box: box.n.01. Descendants: ['carton.n.02', 'cash_register.n.01', 'chest.n.02', 'crate.n.01', 'litter_box.n.01', 'mailbox.n.01', 'matchbox.n.01', 'pencil_box.n.01', 'pizza_box.n.01', 'shoebox.n.02', 'toolbox.n.01', 'toy_box.n.01']
#
# glass: glass.n.02. Descendants: ['flute.n.02', 'goblet.n.01', 'shot_glass.n.01', 'water_glass.n.02', 'wineglass.n.01']
#
# glass_cleaner: cleansing_agent.n.01. Descendants: ['detergent.n.02', 'liquid_soap.n.01', 'shampoo.n.01', 'soap.n.01', 'toothpaste.n.01']
#
# glove: glove.n.02. Descendants: ['batting_glove.n.01', 'goalkeeper_gloves.n.01']
#
# grass_patch: grass.n.01. Descendants: ['barley.n.02', 'corn.n.01', 'popcorn.n.01']
#
# half_tomato: tomato.n.01. Descendants: ['cherry_tomato.n.02']
#
# hall_tree: wardrobe.n.01. Descendants: ['armoire.n.01']
#
# hammam_bench: bench.n.01. Descendants: ['flat_bench.n.01']
#
# hand_dryer: dryer.n.01. Descendants: ['hand_blower.n.01']
#
# heater: heater.n.01. Descendants: ['defroster.n.01']
#
# heatgun: heater.n.01. Descendants: ['defroster.n.01']
#
# honey_jar: jar.n.01. Descendants: ['mason_jar.n.01', 'vase.n.01']
#
# hotdog_bun: bun.n.01. Descendants: ['bagel.n.01', 'crescent_roll.n.01', 'danish.n.02']
#
# ink_jar: jar.n.01. Descendants: ['mason_jar.n.01', 'vase.n.01']
#
# jacket: jacket.n.01. Descendants: ['blazer.n.01']
#
# jar: jar.n.01. Descendants: ['mason_jar.n.01', 'vase.n.01']
#
# jelly_jar: jar.n.01. Descendants: ['mason_jar.n.01', 'vase.n.01']
#
# jersey: jersey.n.03. Descendants: ['turtleneck.n.01']
#
# jewel: jewel.n.01. Descendants: ['diamond.n.01', 'pearl.n.01']
#
# jewelry: jewelry.n.01. Descendants: ['bracelet.n.02', 'diamond.n.01', 'engagement_ring.n.01', 'jewel.n.01', 'necklace.n.01', 'pearl.n.01', 'ring.n.08']
#
# jewelry_cleaner: cleansing_agent.n.01. Descendants: ['detergent.n.02', 'liquid_soap.n.01', 'shampoo.n.01', 'soap.n.01', 'toothpaste.n.01']
#
# jug: pitcher.n.02. Descendants: ['cream_pitcher.n.01']
#
# juice: juice.n.01. Descendants: ['carrot_juice.n.01', 'lime_juice.n.01', 'papaya_juice.n.01', 'tomato_juice.n.01']
#
# kiosk: booth.n.02. Descendants: ['shower_stall.n.01']
#
# knife: knife.n.01. Descendants: ['carving_knife.n.01', 'cleaver.n.01', 'pocketknife.n.01', 'table_knife.n.01']
#
# lab_exhaust_hood: hood.n.06. Descendants: ['range_hood.n.01']
#
# ladle: ladle.n.01. Descendants: ['dipper.n.01', 'soup_ladle.n.01']
#
# laurel_leaf: herb.n.01. Descendants: ['barley.n.02', 'cauliflower.n.01', 'chard.n.01', 'corn.n.01', 'grass.n.01', 'okra.n.02', 'popcorn.n.01', 'rocket.n.03']
#
# lemon_sauce: sauce.n.01. Descendants: ['aioli.n.01', 'barbecue_sauce.n.01', 'chocolate_sauce.n.01', 'hot_sauce.n.01', 'mayonnaise.n.01', 'mushroom_sauce.n.01', 'pesto.n.01', 'spaghetti_sauce.n.01', 'tomato_sauce.n.01']
#
# lighter: lighter.n.02. Descendants: ['match.n.01']
#
# male_restroom_door: door.n.01. Descendants: ['screen_door.n.01']
#
# marker: marker.n.03. Descendants: ['highlighter.n.02']
#
# massage_bed: bed.n.01. Descendants: ['hammock.n.02', 'hospital_bed.n.01']
#
# mat: mat.n.07. Descendants: ['place_mat.n.01']
#
# medicine: medicine.n.02. Descendants: ['antihistamine.n.01', 'aspirin.n.01', 'baby_oil.n.01', 'lip_balm.n.01', 'pill.n.02', 'powder.n.03']
#
# melon: melon.n.01. Descendants: ['cantaloup.n.02', 'watermelon.n.02']
#
# mesh_bag: bag.n.01. Descendants: ['backpack.n.01', 'carryall.n.01', 'duffel_bag.n.01', 'grocery_bag.n.01', 'plastic_bag.n.01', 'sack.n.01']
#
# microscope: microscope.n.01. Descendants: ['hand_glass.n.02']
#
# milk: milk.n.01. Descendants: ['buttermilk.n.01', 'chocolate_milk.n.01']
#
# mug: mug.n.04. Descendants: ['beer_mug.n.01']
#
# nail: nail.n.02. Descendants: ['clout_nail.n.01', 'thumbtack.n.01']
#
# onion: onion.n.03. Descendants: ['green_onion.n.01', 'vidalia_onion.n.01']
#
# orange_sauce: sauce.n.01. Descendants: ['aioli.n.01', 'barbecue_sauce.n.01', 'chocolate_sauce.n.01', 'hot_sauce.n.01', 'mayonnaise.n.01', 'mushroom_sauce.n.01', 'pesto.n.01', 'spaghetti_sauce.n.01', 'tomato_sauce.n.01']
#
# oven: oven.n.01. Descendants: ['broiler.n.01']
#
# pancake: pancake.n.01. Descendants: ['tortilla.n.01']
#
# pants: trouser.n.01. Descendants: ['jean.n.01', 'short_pants.n.01']
#
# paper_bag: sack.n.01. Descendants: ['grocery_bag.n.01']
#
# paper_towel_dispenser: dispenser.n.01. Descendants: ['atomizer.n.01', 'inhaler.n.01', 'soap_dispenser.n.01']
#
# paper_towel_holder: holder.n.01. Descendants: ['candelabrum.n.01']
#
# pasta: pasta.n.02. Descendants: ['dumpling.n.01', 'noodle.n.01']
#
# pastry_brush: kitchen_utensil.n.01. Descendants: ['blender.n.01', 'caldron.n.01', 'coffeepot.n.01', 'cooker.n.01', 'cookie_cutter.n.01', 'cookie_sheet.n.01', 'crock_pot.n.01', 'dutch_oven.n.02', 'eggbeater.n.02', 'electric_frying_pan.n.01', 'electric_mixer.n.01', 'frying_pan.n.01', 'grater.n.01', 'griddle.n.01', 'kettle.n.01', 'masher.n.02', 'mixer.n.04', 'pan.n.01', 'popper.n.03', 'reamer.n.01', 'rolling_pin.n.01', 'saucepan.n.01', 'saucepot.n.01', 'skimmer.n.02', 'spatula.n.01', 'steamer.n.02', 'stockpot.n.01', 'teapot.n.01', 'whisk.n.01', 'wok.n.01']
#
# pastry_cutter: cutter.n.06. Descendants: ['ax.n.01', 'carving_knife.n.01', 'chisel.n.01', 'cleaver.n.01', 'knife.n.01', 'pocketknife.n.01', 'razor.n.01', 'scissors.n.01', 'table_knife.n.01', 'wire_cutter.n.01']
#
# pencil_holder: holder.n.01. Descendants: ['candelabrum.n.01']
#
# perfume: perfume.n.02. Descendants: ['cologne.n.02']
#
# pesticide: pesticide.n.01. Descendants: ['spray.n.01']
#
# pet_food: petfood.n.01. Descendants: ['cat_food.n.01', 'dog_food.n.01']
#
# pin: pin.n.09. Descendants: ['bobby_pin.n.01', 'straight_pin.n.01']
#
# pitcher: pitcher.n.02. Descendants: ['cream_pitcher.n.01']
#
# pizza_dough: dough.n.01. Descendants: ['pastry.n.01']
#
# plant_pot: pot.n.04. Descendants: ['planter.n.03']
#
# plant_stem: stalk.n.02. Descendants: ['branch.n.02', 'onion.n.01', 'yam.n.01']
#
# plastic_wrap: plastic_wrap.n.01. Descendants: ['cellophane.n.01']
#
# platform: platform.n.01. Descendants: ['pallet.n.02']
#
# plush_toy: plaything.n.01. Descendants: ['dreidel.n.01', 'sandbox.n.02', 'swing.n.02', 'teddy.n.01', 'train_set.n.01']
#
# pot_plant_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# potato: potato.n.01. Descendants: ['french_fries.n.01']
#
# poultry_seasoning: flavorer.n.01. Descendants: ['aioli.n.01', 'allspice.n.03', 'barbecue_sauce.n.01', 'basil.n.03', 'bay_leaf.n.01', 'brown_sugar.n.01', 'catsup.n.01', 'chinese_anise.n.02', 'chocolate_sauce.n.01', 'cinnamon.n.03', 'clove.n.03', 'clove.n.04', 'curry_powder.n.01', 'dill_seed.n.01', 'fennel.n.04', 'ginger.n.02', 'green_tea.n.01', 'guacamole.n.01', 'hot_sauce.n.01', 'hummus.n.01', 'mace.n.03', 'maple_syrup.n.01', 'mayonnaise.n.01', 'mint.n.04', 'miso.n.01', 'molasses.n.01', 'mushroom_sauce.n.01', 'mustard.n.02', 'mustard_seed.n.01', 'nutmeg.n.02', 'olive.n.04', 'paprika.n.02', 'parsley.n.02', 'peanut_butter.n.01', 'pepper.n.03', 'pesto.n.01', 'pickle.n.01', 'poppy_seed.n.01', 'pumpkin_pie_spice.n.01', 'rosemary.n.02', 'sage.n.02', 'salsa.n.01', 'salt.n.02', 'sauce.n.01', 'sesame_seed.n.01', 'spaghetti_sauce.n.01', 'spice.n.02', 'sugar.n.01', 'tea.n.05', 'tea_bag.n.01', 'tomato_sauce.n.01', 'vinegar.n.01']
#
# purse: bag.n.04. Descendants: ['shoulder_bag.n.01']
#
# quilt: quilt.n.01. Descendants: ['eiderdown.n.01']
#
# rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# racket: racket.n.04. Descendants: ['tennis_racket.n.01']
#
# rice: rice.n.01. Descendants: ['brown_rice.n.01']
#
# rice_bag: rice.n.01. Descendants: ['brown_rice.n.01']
#
# rice_box: rice.n.01. Descendants: ['brown_rice.n.01']
#
# rice_cooker: cooker.n.01. Descendants: ['crock_pot.n.01', 'popper.n.03']
#
# ring: ring.n.08. Descendants: ['engagement_ring.n.01']
#
# roasting_pan: pan.n.01. Descendants: ['electric_frying_pan.n.01', 'frying_pan.n.01', 'saucepan.n.01', 'wok.n.01']
#
# rock: rock.n.01. Descendants: ['crystal.n.03', 'stepping_stone.n.01']
#
# room_divider: partition.n.01. Descendants: ['wall.n.01']
#
# round_bathtub: bathtub.n.01. Descendants: ['hot_tub.n.01']
#
# round_bottom_flask: flask.n.01. Descendants: ['erlenmeyer_flask.n.01']
#
# rug: rug.n.01. Descendants: ['runner.n.08']
#
# ruler: rule.n.12. Descendants: ['foot_rule.n.01']
#
# sandwich: sandwich.n.01. Descendants: ['hamburger.n.01', 'hotdog.n.02']
#
# sauna_bench: bench.n.01. Descendants: ['flat_bench.n.01']
#
# sauna_heater: heater.n.01. Descendants: ['defroster.n.01']
#
# sausage: sausage.n.01. Descendants: ['bratwurst.n.01', 'chorizo.n.01', 'kielbasa.n.01']
#
# savory_spice: spice.n.02. Descendants: ['allspice.n.03', 'chinese_anise.n.02', 'cinnamon.n.03', 'clove.n.04', 'fennel.n.04', 'ginger.n.02', 'mace.n.03', 'nutmeg.n.02', 'pumpkin_pie_spice.n.01']
#
# screw: screw.n.04. Descendants: ['bolt.n.06']
#
# sculpture: sculpture.n.01. Descendants: ['statue.n.01']
#
# seafood: seafood.n.01. Descendants: ['crab.n.05', 'crayfish.n.02', 'mussel.n.01', 'squid.n.01', 'tuna.n.02']
#
# shaker: shaker.n.03. Descendants: ['pepper_shaker.n.01', 'saltshaker.n.01']
#
# shirt: shirt.n.01. Descendants: ['jersey.n.03', 'polo_shirt.n.01', 'tank_top.n.01', 'turtleneck.n.01']
#
# shoe: shoe.n.01. Descendants: ['gym_shoe.n.01', 'sandal.n.01', 'walker.n.04']
#
# shrub: shrub.n.01. Descendants: ['gooseberry.n.01', 'poinsettia.n.01', 'rose.n.01']
#
# sign: sign.n.02. Descendants: ['poster.n.01']
#
# slow_cooker: cooker.n.01. Descendants: ['crock_pot.n.01', 'popper.n.03']
#
# snack_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# snow_globe: plaything.n.01. Descendants: ['dreidel.n.01', 'sandbox.n.02', 'swing.n.02', 'teddy.n.01', 'train_set.n.01']
#
# snow_pants: trouser.n.01. Descendants: ['jean.n.01', 'short_pants.n.01']
#
# soap: soap.n.01. Descendants: ['liquid_soap.n.01']
#
# soup: soup.n.01. Descendants: ['chowder.n.01', 'gazpacho.n.01']
#
# spaghetti_sauce: spaghetti_sauce.n.01. Descendants: ['tomato_sauce.n.01']
#
# spice: spice.n.02. Descendants: ['allspice.n.03', 'chinese_anise.n.02', 'cinnamon.n.03', 'clove.n.04', 'fennel.n.04', 'ginger.n.02', 'mace.n.03', 'nutmeg.n.02', 'pumpkin_pie_spice.n.01']
#
# spoon: spoon.n.01. Descendants: ['teaspoon.n.02']
#
# squash: squash.n.02. Descendants: ['zucchini.n.02']
#
# stairs: stairs.n.01. Descendants: ['ladder.n.01']
#
# sticky_note: pad.n.01. Descendants: ['notepad.n.01']
#
# stool: stool.n.01. Descendants: ['footstool.n.01']
#
# storage_box: box.n.01. Descendants: ['carton.n.02', 'cash_register.n.01', 'chest.n.02', 'crate.n.01', 'litter_box.n.01', 'mailbox.n.01', 'matchbox.n.01', 'pencil_box.n.01', 'pizza_box.n.01', 'shoebox.n.02', 'toolbox.n.01', 'toy_box.n.01']
#
# sugar: sugar.n.01. Descendants: ['brown_sugar.n.01']
#
# sugar_jar: sugar.n.01. Descendants: ['brown_sugar.n.01']
#
# sweater: sweater.n.01. Descendants: ['cardigan.n.01', 'sweatshirt.n.01', 'turtleneck.n.01']
#
# swimsuit: swimsuit.n.01. Descendants: ['bikini.n.02']
#
# t-shirt: jersey.n.03. Descendants: ['turtleneck.n.01']
#
# tag: tag.n.01. Descendants: ['name_tag.n.01', 'price_tag.n.01']
#
# tape: tape.n.01. Descendants: ['duct_tape.n.01']
#
# tea: tea.n.05. Descendants: ['green_tea.n.01', 'tea_bag.n.01']
#
# tea_bottle: tea.n.01. Descendants: ['ice_tea.n.01']
#
# tea_leaf: tea.n.05. Descendants: ['green_tea.n.01', 'tea_bag.n.01']
#
# tea_leaves: tea.n.05. Descendants: ['green_tea.n.01', 'tea_bag.n.01']
#
# test_tube_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# thermometer: thermometer.n.01. Descendants: ['meat_thermometer.n.01']
#
# thread: thread.n.01. Descendants: ['dental_floss.n.01', 'tinsel.n.02']
#
# tire: tire.n.01. Descendants: ['whitewall_tire.n.01']
#
# tissue_dispenser: tissue.n.02. Descendants: ['toilet_tissue.n.01']
#
# toilet_paper_dispenser: dispenser.n.01. Descendants: ['atomizer.n.01', 'inhaler.n.01', 'soap_dispenser.n.01']
#
# toilet_paper_holder: holder.n.01. Descendants: ['candelabrum.n.01']
#
# tomato: tomato.n.01. Descendants: ['cherry_tomato.n.02']
#
# tortilla_chips: tortilla_chip.n.01. Descendants: ['nacho.n.01']
#
# towel: towel.n.01. Descendants: ['bath_towel.n.01', 'dishtowel.n.01', 'hand_towel.n.01', 'paper_towel.n.01']
#
# toy: plaything.n.01. Descendants: ['dreidel.n.01', 'sandbox.n.02', 'swing.n.02', 'teddy.n.01', 'train_set.n.01']
#
# tree: tree.n.01. Descendants: ['hazelnut.n.01', 'holly.n.01', 'lemon.n.03', 'papaya.n.01', 'pine.n.01']
#
# truck: truck.n.01. Descendants: ['pickup.n.01']
#
# turnip: turnip.n.02. Descendants: ['rutabaga.n.01']
#
# ukranian_flag: flag.n.01. Descendants: ['banner.n.01']
#
# umbrella_rack: rack.n.01. Descendants: ['coatrack.n.01', 'dish_rack.n.01', 'towel_rack.n.01']
#
# underwear: underwear.n.01. Descendants: ['lingerie.n.01']
#
# us_flag: flag.n.01. Descendants: ['banner.n.01']
#
# utility_knife: knife.n.01. Descendants: ['carving_knife.n.01', 'cleaver.n.01', 'pocketknife.n.01', 'table_knife.n.01']
#
# vegetable_juice: juice.n.01. Descendants: ['carrot_juice.n.01', 'lime_juice.n.01', 'papaya_juice.n.01', 'tomato_juice.n.01']
#
# vegetable_oil: vegetable_oil.n.01. Descendants: ['coconut_oil.n.01', 'cooking_oil.n.01', 'olive_oil.n.01', 'sesame_oil.n.01']
#
# violin_case: case.n.05. Descendants: ['bag.n.06', 'briefcase.n.01', 'wallet.n.01']
#
# wardrobe: wardrobe.n.01. Descendants: ['armoire.n.01']
#
# water_dispenser: dispenser.n.01. Descendants: ['atomizer.n.01', 'inhaler.n.01', 'soap_dispenser.n.01']
#
# wax: wax.n.01. Descendants: ['beeswax.n.01', 'paraffin.n.01']
#
# wine_fridge: electric_refrigerator.n.01. Descendants: ['deep-freeze.n.01']
#
# wineglass: wineglass.n.01. Descendants: ['flute.n.02']
#
# wood: wood.n.01. Descendants: ['bamboo.n.01', 'log.n.01']
#
# wrapped_gift: wrapping.n.01. Descendants: ['cellophane.n.01', 'plastic_wrap.n.01']
#
# wrench: wrench.n.03. Descendants: ['allen_wrench.n.01']

# %% [markdown]
# ### Problem 4: Task-required synsets that don't have any categories mapping to them?
# Caveat: substances are included too

# %%
# How many of the required synsets exist:
from collections import defaultdict
found_task_required_synsets = set()
for s in legit_task_required_synsets:
    if is_synset_available(s):
        found_task_required_synsets.add(s)  # Only add the sought-after synset, not children

not_found_task_required_synsets = legit_task_required_synsets - found_task_required_synsets
print(f"{len(not_found_task_required_synsets)}/{len(legit_task_required_synsets)} legitimate task-required synsets don't have corresponding category entries.\n")
print("\n".join(f"{s}: [{', '.join(act for act in activities_list if s in task_required_synsets_by_activity[act])}]" for s in not_found_task_required_synsets))
# Out:
# 282/1115 legitimate task-required synsets don't have corresponding category entries.
#
# chalice.n.01: [cleaning_cups_in_living_room, cleaning_glasses_off_bar, pour_a_glass_of_wine, prepare_a_slow_dinner_party]
# gravy.n.01: [putting_roast_in_oven, serving_food_at_a_homeless_shelter]
# yam.n.03: [make_yams]
# ramen.n.01: [cook_ramen_noodles]
# stain.n.01: [bringing_laundry, clean_a_baking_stone, clean_a_broiler_pan, clean_a_chicken_coop, clean_a_coffee_maker, clean_a_dirty_tent, clean_a_faucet, clean_a_fence, clean_a_flat_panel_monitor, clean_a_garden_sprayer, clean_a_glass_pipe, clean_a_glass_windshield, clean_a_grill_pan, clean_a_hamper, clean_a_keyboard, clean_a_kitchen_sink, clean_a_knife, clean_a_loofah_or_natural_sponge, clean_a_mattress, clean_a_pickup_truck, clean_a_pizza_stone, clean_a_popcorn_machine, clean_a_purse, clean_a_quilt, clean_a_raincoat, clean_a_sauna, clean_a_sauna_suit, clean_a_shower, clean_a_sponge, clean_a_stainless_steel_dishwasher, clean_a_teddy_bear, clean_a_tie, clean_a_toaster_oven, clean_a_wood_pipe, clean_an_electric_kettle, clean_baby_toys, clean_clear_plastic, clean_copper_mugs, clean_cork_mats, clean_couch_pillows, clean_dentures, clean_dog_collars, clean_fishing_lures, clean_flip_flops, clean_fur, clean_garden_gloves, clean_gold, clean_jewels, clean_leather_sandals, clean_nickel, clean_outdoor_tiles, clean_pearls, clean_pennies, clean_reusable_shopping_bags, clean_sheets, clean_soot_from_glass_lanterns, clean_suede_gloves, clean_synthetic_hiking_gear, clean_tennis_balls, clean_the_exterior_of_your_garage, clean_the_interior_of_your_car, clean_the_outside_of_a_house, clean_tweed, clean_vans, clean_vases, clean_wine_glasses, clean_wood_doors, clean_wood_pallets, clean_your_cleaning_supplies, cleaning_barbecue_grill, cleaning_bathrooms, cleaning_bathtub, cleaning_boat, cleaning_carpets, cleaning_fishing_gear, cleaning_floors, cleaning_freezer, cleaning_garage, cleaning_garden_tools, cleaning_glasses_off_bar, cleaning_microwave_oven, cleaning_oven, cleaning_shoes, cleaning_sneakers, cleaning_stove, cleaning_table_after_clearing, cleaning_the_hot_tub, cleaning_the_pool, cleaning_toilet, cleaning_up_after_a_meal, cleaning_up_refrigerator, defrosting_freezer, doing_laundry, hand_washing_clothing, loading_the_dishwasher, mopping_floors, polish_cymbals, polish_gold, polishing_shoes, prepare_a_boat_for_fishing, remove_hard_water_spots, remove_scorch_marks, remove_spots_from_linen, shampooing_carpet, sorting_clothing, spring_clean_your_skateboard, throwing_out_used_napkins, treating_spot, treating_stains, wash_a_backpack, wash_a_baseball_cap, wash_a_bra, wash_a_leotard, wash_delicates_in_the_laundry, wash_dog_toys, wash_duvets, wash_jeans, wash_your_bike, wash_your_rings, washing_bowls, washing_curtains, washing_fabrics, washing_floor, washing_outside_walls, washing_outside_windows, washing_pots_and_pans]
# aluminum_foil.n.01: [cleaning_up_plates_and_food, cook_bacon, cook_sweet_potatoes, freeze_lasagna, freeze_quiche, roast_meat, warm_tortillas]
# sugar_syrup.n.01: [preserving_fruit]
# pellet.n.01: [set_up_a_guinea_pig_cage]
# flagpole.n.02: [hanging_flags]
# instant_coffee__jar.n.01: [make_a_blended_iced_cappuccino, make_a_cappuccino, make_a_frappe, make_a_sugar_and_coffee_scrub_, set_up_a_coffee_station_in_your_kitchen]
# swab.n.02: [clean_a_sauna, clean_household_cleaning_tools, clean_outdoor_tiles, cleaning_boat, mopping_floors, mopping_the_kitchen_floor, polish_wood_floors]
# broth.n.01: [make_fish_stock, make_seafood_stew, make_soup, make_tomato_rice]
# jelly.n.02: [make_a_sandwich]
# legging.n.01: [tidying_bathroom]
# pepperoni.n.01: [make_pizza]
# ash.n.01: [emptying_ashtray]
# money.n.01: [buy_a_air_conditioner, buy_a_belt, buy_a_good_avocado, buy_a_microwave_oven, buy_alcohol, buy_basic_garden_tools, buy_boxes_for_packing, buy_candle_making_supplies, buy_dog_food, buy_eggs, buy_fish, buy_food_for_a_party, buy_food_for_camping, buy_food_for_vegetarians, buy_good_chocolate, buy_meat_from_a_butcher, buy_mulch, buy_natural_beef, buy_natural_supplements, buy_pet_food_for_less, buy_rechargeable_batteries, buy_salad_greens, buy_school_supplies, buy_school_supplies_for_high_school, buy_used_gardening_equipment, buying_cleaning_supplies, buying_groceries, buying_groceries_for_a_feast, buying_postage_stamps, pack_for_the_pool, packing_car_for_trip, paying_for_purchases, returning_consumer_goods]
# black_pepper.n.02: [cook_ham_hocks, cook_spinach, cook_turkey_drumsticks, make_a_steak, make_gazpacho, make_lamb_stew, make_lemon_pepper_seasoning, make_poultry_seasoning]
# dirt.n.02: [clean_a_bicycle_chain, clean_a_softball_bat, clean_a_suitcase, clean_a_watch, clean_apples, clean_bok_choy, clean_cabbage, clean_cement, clean_green_beans, clean_greens, clean_kale, clean_mushrooms, clean_oysters, clean_pine_cones, clean_potatoes, clean_pottery, clean_quarters, clean_quartz, clean_raw_denim, clean_rubber, clean_silver_coins, cleaning_lawnmowers, cleaning_patio_furniture, mopping_the_kitchen_floor, scrubbing_bathroom_floor, wash_an_infant_car_seat, wash_fruit_and_vegetables, wash_grapes, wash_lettuce, wash_towels, washing_walls]
# dip.n.07: [decorating_for_religious_ceremony, set_a_fancy_table]
# granulated_sugar.n.01: [filling_sugar, preparing_existing_coffee, preserving_fruit, setting_table_for_coffee]
# daffodil.n.01: [store_daffodil_bulbs]
# air_filter.n.01: [clean_an_air_filter]
# bottle.n.03: [wash_baby_bottles]
# pumpkin_seed.n.01: [cook_pumpkin_seeds, planting_vegetables]
# espresso.n.01: [clean_an_espresso_machine, make_a_cappuccino, make_an_iced_espresso, setting_table_for_coffee]
# pruning_saw.n.01: [put_togethera_basic_pruning_kit]
# bicycle_rack.n.01: [hang_a_bike_on_the_wall, unpacking_recreational_vehicle_for_trip]
# cereal_box.n.01: [putting_shopping_away]
# ginger.n.03: [make_pumpkin_pie_spice]
# vegetable_oil__bottle.n.01: [cook_kabobs, cooking_food_for_adult, fry_pot_stickers, make_carne_asada, prepare_and_cook_scallops, prepare_baking_pans, putting_shopping_away]
# license_plate.n.01: [putting_on_license_plates, putting_on_registration_stickers, putting_on_tags_(car)]
# cotton.n.02: [clean_marker_off_a_doll]
# tarnish.n.01: [clean_the_bottom_of_an_iron, clean_vinyl_shutters]
# arepa.n.01: [cook_arepas]
# postage.n.02: [buying_postage_stamps, getting_package_from_post_office]
# lotion.n.02: [clean_an_electric_razor]
# cork.n.01: [bottling_wine]
# dog_collar.n.01: [clean_dog_collars]
# jerky.n.01: [loading_shopping_into_car, stash_snacks_in_your_room]
# house_paint.n.01: [painting_porch]
# turkey_leg.n.01: [cook_turkey_drumsticks]
# soy_sauce.n.01: [cook_beef_and_onions, cook_bok_choy, make_beef_and_broccoli, make_fried_rice, putting_roast_in_oven]
# dairy.n.01: [buying_everyday_consumer_goods]
# icetray.n.01: [make_ice]
# wrinkle.n.01: [adding_fabric_softener, fold_a_cloth_napkin, iron_a_tie, iron_curtains, ironing_bedsheets, ironing_clothes, ironing_curtains, treating_clothes]
# chicken_broth.n.01: [cook_chicken, cook_ham_hocks, prepare_quinoa, serving_food_at_a_homeless_shelter]
# cactus.n.01: [dust_houseplants, place_houseplants_around_your_home]
# lampshade.n.01: [clean_paper_lampshades, unloading_shopping_items]
# shell.n.02: [clean_prawns, clean_seashells]
# instant_coffee.n.01: [make_a_blended_iced_cappuccino, make_a_cappuccino, make_a_frappe, make_instant_coffee]
# fecal_matter.n.01: [clean_a_small_pet_cage, clean_out_a_guinea_pigs_hutch]
# ice.n.01: [de_ice_a_car, remove_ice_from_gutters, removing_ice_from_walkways]
# spray_paint.n.01: [painting_house_exterior]
# gum__box.n.01: [prepare_an_emergency_school_kit]
# board.n.02: [clean_decking, make_a_wiener_schnitzle]
# cabbage.n.03: [clean_cabbage, cook_cabbage]
# throw.n.04: [setting_up_room_for_a_movie]
# broccolini.n.01: [cook_broccolini]
# wooden_spoon.n.01: [rearranging_kitchen_furniture]
# casserole.n.01: [cook_broccoli, make_macaroni_and_cheese]
# mold.n.05: [clean_a_gravestone, clean_a_mattress, clean_a_sauna, clean_stucco, clean_up_water_damage, clean_your_laundry_room, cleaning_fan, make_popsicles]
# toast.n.01: [clean_a_toaster_oven, make_an_egg_tomato_and_toast_breakfast, prepare_a_breakfast_bar]
# solution.n.01: [clean_pearls]
# hydrogen_peroxide.n.01: [clean_vans]
# packing_box.n.02: [clean_a_turkey, cleaning_garden_tools, distributing_groceries_at_food_bank, donating_toys, hang_a_dartboard, make_a_christmas_gift_box, organizing_volunteer_materials, praeparing_lunch_box, putting_away_games, set_up_two_computer_monitors, sorting_items_for_garage_sale, sorting_volunteer_materials, store_christmas_lights, store_dahlia_bulbs, store_tulip_bulbs, tidying_bathroom, unpacking_car_for_trip]
# cola.n.02: [mixing_drinks]
# cream_soda.n.01: [make_cream_soda]
# person.n.01: [putting_in_a_pool]
# plum.n.01: [make_stewed_fruit]
# potato_salad.n.01: [serving_food_at_a_homeless_shelter]
# address.n.05: [hanging_address_numbers]
# bourbon.n.01: [make_warm_drinks_for_the_holidays]
# dumpling.n.02: [fry_pot_stickers]
# tank.n.02: [clean_a_garden_sprayer, setup_a_fish_tank]
# freshener.n.01: [tidying_bathroom]
# mildew.n.02: [clean_a_birdcage, clean_a_drain, clean_a_sauna, clean_a_sponge, clean_rubber_bathmats, cleaning_patio_furniture]
# oregano.n.01: [cook_mussels, make_pasta_sauce, make_pizza, make_pizza_sauce, make_red_beans_and_rice, make_seafood_stew]
# ink.n.01: [clean_a_whiteboard, clean_marker_off_a_doll, staining_wood_furniture]
# mat.n.01: [clean_cork_mats, clean_rubber_bathmats, prepare_your_garden_for_a_cat]
# thyme.n.02: [cook_turkey_drumsticks, cooking_food_for_adult, make_lamb_stew, make_poultry_seasoning]
# ham_hock.n.01: [cook_ham_hocks]
# yogurt__cup.n.01: [make_a_chia_breakfast_bowl, putting_shopping_away, unloading_groceries]
# pewter.n.01: [polish_pewter]
# champagne__bottle.n.01: [passing_out_drinks, setup_a_garden_party]
# label.n.01: [buy_natural_beef]
# lint.n.01: [clean_an_iron, clean_an_office_chair, doing_housework_for_adult, removing_lint_from_dryer, sweeping_steps, wash_a_wool_coat]
# post-it.n.01: [organizing_office_documents]
# honey.n.01: [make_an_afternoon_tea_with_strawberries, make_chocolate_spread, make_granola, make_oatmeal, make_popsicles, make_warm_drinks_for_the_holidays, roast_meat]
# doll.n.01: [clean_marker_off_a_doll, make_dinosaur_goody_bags, make_gift_bags_for_baby_showers, setup_a_baby_crib]
# bread_slice.n.01: [cooking_lunch]
# filling.n.03: [make_cake_filling]
# sieve.n.01: [clean_a_sieve, make_fish_stock]
# burrito_bowl.n.01: [make_burrito_bowls]
# green_pea.n.01: [cook_peas]
# frappe.n.01: [make_a_frappe]
# wheel.n.01: [clean_skateboard_bearings]
# incision.n.01: [polisha_car, repairs_to_furniture, sanding_wood_furniture]
# pecan.n.03: [make_granola]
# gift.n.01: [decorating_outside_for_parties, setting_up_for_an_event]
# blackberry.n.01: [collecting_berries, make_a_chia_breakfast_bowl]
# bow.n.01: [decorating_outside_for_holidays, decorating_outside_for_parties]
# limeade.n.01: [make_limeade]
# scallop.n.02: [clean_scallops, make_seafood_stew, prepare_and_cook_scallops]
# seed.n.02: [make_homemade_bird_food]
# cornmeal.n.01: [make_cornbread]
# bok_choy.n.01: [clean_bok_choy, cook_bok_choy, sorting_potatoes, sorting_vegetables]
# pajama.n.01: [putting_laundry_in_drawer, store_baby_clothes]
# acetone.n.01: [clean_marker_off_a_doll, spring_clean_your_skateboard]
# caffe_latte.n.01: [make_green_tea_latte]
# quinoa.n.01: [prepare_quinoa]
# carne_asada.n.01: [make_carne_asada]
# portrait.n.02: [setting_up_silent_auction]
# charger.n.02: [buy_rechargeable_batteries, packing_recreational_vehicle_for_trip]
# chickpea.n.02: [make_a_salad, serving_food_on_the_table]
# dustcloth.n.01: [buying_cleaning_supplies, clean_a_flat_panel_monitor, clean_paper_lampshades, clean_piano_keys, clean_your_cleaning_supplies, cleaning_tools_and_equipment, setting_up_living_room_for_guest]
# bust.n.03: [setting_up_silent_auction]
# seawater.n.01: [cook_mussels, cook_pasta, cook_potatoes, make_a_basic_brine, prepare_sea_salt_soak]
# handbook.n.01: [sorting_volunteer_materials]
# margarine.n.01: [grease_and_flour_a_pan]
# chain.n.03: [polish_gold]
# white_rice.n.01: [clean_a_rice_cooker, filling_pepper, make_bento, make_fried_rice, make_tomato_rice]
# butter_knife.n.01: [clean_a_candle_jar, cleaning_kitchen_knives, putting_out_condiments, set_a_fancy_table, set_a_table_for_a_tea_party]
# first-aid_kit.n.01: [buy_home_use_medical_supplies]
# ammonia_water.n.01: [clean_jewels, clean_soot_from_glass_lanterns]
# fur_coat.n.01: [clean_fur, store_a_fur_coat]
# wool_coat.n.01: [clean_tweed, wash_a_wool_coat]
# dinner_plate.n.01: [drying_dishes, making_a_meal, prepare_a_filling_breakfast, prepare_a_slow_dinner_party, prepare_and_cook_prawns, serving_food_at_a_homeless_shelter, serving_food_on_the_table, set_a_dinner_table, set_a_fancy_table]
# copper_mug.n.01: [clean_copper_mugs]
# glaze.n.01: [cook_a_ham, glaze_a_ham]
# cream_of_tartar.n.01: [make_blueberry_mousse]
# white_wine.n.01: [make_white_wine_sauce, prepare_wine_and_cheese, setup_a_bar_for_a_cocktail_party]
# rubbish.n.01: [sweeping_steps, taking_trash_outside]
# gin__bottle.n.01: [setup_a_bar_for_a_cocktail_party, stock_a_bar]
# salad_plate.n.01: [drying_dishes, set_a_dinner_table, set_a_fancy_table]
# mallet.n.03: [make_a_wiener_schnitzle]
# acorn.n.01: [planting_trees]
# rum__bottle.n.01: [make_a_mojito, stock_a_bar]
# cayenne.n.02: [make_jamaican_jerk_seasoning, prepare_and_cook_swiss_chard]
# white_sauce.n.01: [cook_snap_peas]
# polish__bottle.n.01: [store_silver_coins]
# coriander.n.03: [cook_kabobs]
# sweet_potato.n.01: [buy_food_for_vegetarians, cook_sweet_potatoes, sorting_potatoes]
# trunk.n.01: [vacuuming_vehicles]
# clipper.n.04: [disinfect_nail_clippers]
# chicken_wire.n.01: [cleaning_shed]
# liner.n.03: [clean_a_small_pet_cage]
# gourd.n.02: [clean_gourds]
# polish.n.03: [clean_a_bowling_ball, clean_a_leather_belt, clean_brass, clean_brass_casings, clean_silver_coins, polish_copper, polish_cymbals, polish_gold, polish_pewter, polish_rocks, polish_wood_floors, polisha_car]
# cookie_dough.n.01: [make_cookie_dough, make_edible_chocolate_chip_cookie_dough]
# centerpiece.n.02: [decorating_outside_for_parties]
# lace.n.01: [organizing_skating_stuff]
# emery_paper.n.01: [clean_the_bottom_of_an_iron, clean_your_rusty_garden_tools, remove_scorch_marks, repairs_to_furniture, sanding_wood_furniture]
# squeegee.n.01: [washing_windows]
# beer_bottle.n.01: [buy_alcohol, passing_out_drinks, pour_beer, setup_a_bar_for_a_cocktail_party, stock_a_bar_cart, store_beer]
# debris.n.01: [clean_a_trombone, clean_a_vacuum, cleaning_debris_out_of_car]
# rust.n.01: [clean_copper_wire, clean_your_rusty_garden_tools]
# toilet.n.01: [tidying_bathroom]
# tablespoon.n.02: [laying_restaurant_table_for_dinner, make_cinnamon_sugar, make_poultry_seasoning, make_stewed_fruit, make_warm_drinks_for_the_holidays, prepare_sea_salt_soak, serving_food_on_the_table, set_a_fancy_table, wrap_silverware]
# glue__bottle.n.01: [buy_school_supplies, sorting_art_supplies]
# paella.n.01: [cook_seafood_paella]
# dust.n.01: [brushing_lint_off_clothing, buy_a_microwave_oven, clean_a_LED_screen, clean_a_air_conditioner, clean_a_backpack, clean_a_book, clean_a_bowling_ball, clean_a_box_fan, clean_a_company_office, clean_a_computer_monitor, clean_a_couch, clean_a_felt_pool_table_top, clean_a_flat_iron, clean_a_flat_panel_monitor, clean_a_guitar, clean_a_hat, clean_a_hot_water_dispenser, clean_a_kitchen_table, clean_a_knife_block, clean_a_leather_belt, clean_a_light_bulb, clean_a_longboard, clean_a_mousepad, clean_a_patio, clean_a_piano, clean_a_pumpkin, clean_a_razor_blade, clean_a_rug, clean_a_saxophone, clean_a_sofa, clean_a_trumpet, clean_a_vacuum, clean_a_violin, clean_an_air_filter, clean_an_eraser, clean_an_iron, clean_an_office_chair, clean_black_rims, clean_boxing_gloves, clean_broccoli_rabe, clean_brooms, clean_carpets, clean_conch_shells, clean_deer_antlers, clean_eggs, clean_gas_logs, clean_gourds, clean_household_cleaning_tools, clean_jade, clean_leather_boots, clean_mirrors, clean_paper_lampshades, clean_piano_keys, clean_strawberries, clean_sunglasses, clean_synthetic_hiking_gear, clean_the_interior_of_your_car, clean_vintage_stereo_equipment, clean_wooden_blocks, clean_your_baseboard_radiators, clean_your_cleaning_supplies, clean_your_electronics, clean_your_kitty_litter_box, clean_your_laundry_room, clean_your_pencil_case, cleaning_around_pool_in_garden, cleaning_barbecue_grill, cleaning_bedroom, cleaning_camperORRV, cleaning_computer, cleaning_cups_in_living_room, cleaning_fan, cleaning_floors, cleaning_garage, cleaning_garden_path, cleaning_garden_tools, cleaning_high_chair, cleaning_kitchen_cupboard, cleaning_microwave_oven, cleaning_mushrooms, cleaning_pavement, cleaning_shed, cleaning_shoes, cleaning_sneakers, cleaning_stove, cleaning_tools_and_equipment, cleaning_up_refrigerator, cleaning_vehicles, cleaning_windows, doing_housework_for_adult, dust_houseplants, dusting_rugs, lube_a_bicycle_chain, mopping_the_kitchen_floor, polish_pewter, polish_rocks, polishing_furniture, polishing_silver, removing_lint_from_dryer, setting_up_living_room_for_guest, store_rugs, sweeping_floors, sweeping_garage, sweeping_outside_entrance, vacuuming_floors, vacuuming_vehicles, wash_a_wool_coat, wash_an_infant_car_seat, wash_delicates_in_the_laundry, wash_dog_toys, wash_fruit_and_vegetables, wash_your_bike, washing_floor, waxing_floors]
# leek.n.01: [sorting_vegetables]
# soil.n.02: [fertilizing_garden, make_a_small_vegetable_garden, planting_trees, planting_vegetables, prepare_a_raised_bed_garden]
# radiator.n.01: [clean_your_baseboard_radiators]
# chocolate_biscuit.n.01: [make_chocolate_biscuits, stash_snacks_in_your_room]
# mousepad.n.01: [clean_a_mousepad]
# bird_feeder.n.01: [filling_the_bird_feeder]
# artichoke.n.01: [picking_vegetables_in_garden, sorting_vegetables]
# chia_seed.n.01: [make_a_chia_breakfast_bowl, make_a_tropical_breakfast]
# quiche.n.02: [freeze_quiche]
# leftovers.n.01: [boxing_food_after_dinner, clean_up_after_a_dinner_party, cleaning_up_after_an_event, clearing_food_from_table_into_fridge, clearing_table_after_supper]
# rubbing_alcohol.n.01: [clean_wood_siding, removing_ice_from_walkways]
# pruner.n.02: [buy_used_gardening_equipment, buying_gardening_supplies, cleaning_garden_tools, cleaning_up_branches_and_twigs, put_togethera_basic_pruning_kit]
# detergent__bottle.n.01: [clean_a_quilt, clean_a_raincoat, clean_a_sauna_suit, clean_a_shower, clean_a_stainless_steel_dishwasher, clean_a_tie, clean_batting_gloves, clean_cement, clean_couch_pillows, clean_garden_gloves, clean_geodes, clean_household_cleaning_tools, clean_place_mats, clean_raw_denim, clean_reusable_shopping_bags, clean_rubber_bathmats, clean_sheets, clean_your_goal_keeper_gloves, cleaning_boat, cleaning_camperORRV, cleaning_vehicles, doing_laundry, hand_washing_clothing, polish_gold, prepare_a_boat_for_fishing, putting_away_cleaning_supplies, remove_spots_from_linen, sorting_household_items, treating_spot, treating_stains, unloading_shopping_items, wash_a_baseball_cap, wash_a_bra, wash_a_leotard, wash_a_wool_coat, wash_delicates_in_the_laundry, wash_dog_toys, wash_duvets, wash_jeans]
# hamper.n.02: [bringing_laundry, clean_a_hamper, doing_laundry, fold_towels, hanging_clothes_on_clothesline, ironing_clothes, making_the_bed, sorting_clothing, sorting_laundry, taking_clothes_off_of_the_drying_rack, taking_clothes_off_the_line, taking_clothes_out_of_the_dryer, tidying_bathroom, wash_a_leotard, wash_duvets]
# stereo.n.01: [clean_vintage_stereo_equipment]
# sunflower_seed__bag.n.01: [toast_sunflower_seeds]
# shell.n.08: [clean_brass_casings]
# meatball.n.01: [making_a_meal]
# hot_sauce__bottle.n.01: [preparing_food_for_a_fundraiser]
# coca_cola.n.01: [setting_up_room_for_a_movie]
# cotton_ball.n.01: [clean_a_leather_belt]
# lemon_juice.n.01: [clean_copper_wire, cook_asparagus, cook_clams, make_a_cheese_pastry, make_a_strawberry_slushie, make_a_vinegar_cleaning_solution, make_applesauce, make_blueberry_mousse, make_cake_filling, make_frozen_lemonade, make_gazpacho, make_lemon_pepper_seasoning, make_lemon_stain_remover, make_lemonade, make_popsicles, make_warm_drinks_for_the_holidays, make_watermelon_punch, polish_cymbals, remove_spots_from_linen]
# whipped_cream.n.01: [make_blueberry_mousse, make_strawberries_and_cream]
# feta.n.01: [cook_eggplant, prepare_make_ahead_breakfast_bowls, prepare_wine_and_cheese, store_feta_cheese]
# batter.n.02: [make_batter, make_brownies, make_cake_mix, make_muffins, make_onion_ring_batter]
# wine_sauce.n.01: [cook_a_duck, make_white_wine_sauce]
# chopping_block.n.01: [chopping_wood]
# shears.n.01: [buying_gardening_supplies, put_togethera_basic_pruning_kit, putting_away_yard_equipment]
# saffron.n.02: [cook_seafood_paella]
# oat.n.01: [make_granola, make_oatmeal]
# tub.n.02: [clean_your_goal_keeper_gloves, wash_a_wool_coat]
# beef.n.01: [make_beef_and_broccoli]
# sax.n.02: [clean_a_saxophone]
# foil.n.01: [glaze_a_ham]
# snow.n.01: [cleaning_skis, decorating_outside_for_holidays, scraping_snow_off_vehicle, shoveling_snow]
# stucco.n.01: [clean_stucco, spray_stucco]
# perfume__bottle.n.01: [make_the_ultimate_spa_basket, prepare_an_emergency_school_kit]
# mud.n.01: [clean_a_baseball_glove, clean_a_dirty_baseball, clean_a_golf_club, clean_a_lobster, clean_a_longboard, clean_a_turkey, clean_batting_gloves, clean_decking, clean_geodes, clean_snap_peas, clean_white_wall_tires, clean_your_goal_keeper_gloves, cleaning_camperORRV, cleaning_garden_tools, cleaning_vehicles, wash_a_motorcycle, wash_goalkeeper_gloves]
# sleeping_bag.n.01: [clean_synthetic_hiking_gear, packing_hiking_equipment_into_car, unpacking_recreational_vehicle_for_trip]
# wooden_spoon.n.02: [cook_ground_beef, make_muffins]
# lamb.n.01: [cook_lamb, laying_out_a_feast, make_lamb_stew]
# fish_stew.n.01: [make_seafood_stew]
# beef_broth.n.01: [make_lamb_stew, make_stew]
# oxtail.n.01: [cook_oxtails]
# chinese_gooseberry.n.01: [make_a_tropical_breakfast]
# cat_food__tin.n.01: [putting_out_cat_food, stock_grocery_shelves]
# lotion__bottle.n.01: [make_a_military_care_package, make_the_ultimate_spa_basket, unloading_shopping_items]
# soup__can.n.01: [preparing_food_for_a_fundraiser]
# copper.n.01: [clean_copper_wire, polish_copper]
# mail.n.04: [bringing_in_mail, clean_up_your_desk, getting_package_from_post_office, sorting_newspapers_for_recycling]
# snow_pea.n.02: [clean_snow_peas]
# popper.n.01: [clean_a_popcorn_machine]
# honey__jar.n.01: [roast_meat, set_a_table_for_a_tea_party, store_honey]
# fried_egg.n.01: [cook_eggs, cooking_breakfast]
# gelatin.n.02: [make_blueberry_mousse]
# chlorine.n.01: [adding_chemicals_to_hot_tub, chlorinating_the_pool]
# pipe.n.02: [clean_a_glass_pipe, clean_a_wood_pipe]
# barrow.n.03: [carrying_out_garden_furniture, remove_sod]
# screen.n.03: [clean_a_LED_screen, replacing_screens]
# gasoline.n.01: [clean_up_gasoline]
# sunflower_seed.n.01: [toast_sunflower_seeds]
# water.n.01: [clean_snow_peas, remove_ice_from_gutters]
# mildew.n.01: [clean_the_outside_of_a_house]
# belt.n.01: [buy_a_belt, clean_a_leather_belt, tidying_up_wardrobe]
# stew.n.02: [make_lamb_stew, make_stew, serving_food_at_a_homeless_shelter]
# herbicide.n.01: [adding_chemicals_to_lawn, applying_pesticides]
# applesauce.n.01: [make_applesauce]
# soda_water.n.01: [make_a_mojito, make_cream_soda]
# car_wheel.n.01: [clean_black_rims]
# bleaching_agent.n.01: [clean_a_sauna, clean_decking, clean_outdoor_tiles, clean_stucco, clean_your_house_after_a_wild_party]
# card.n.01: [setting_up_silent_auction]
# sunscreen__bottle.n.01: [pack_a_beach_bag, packing_picnic_into_car]
# hair.n.01: [clean_an_electric_razor, cleaning_pet_bed]
# deodorant__atomizer.n.01: [sorting_household_items, tidying_bathroom]
# tablecloth.n.01: [folding_clean_laundry, putting_tablecloth_on_table, selling_products_at_flea_market, serving_food_on_the_table, set_a_dinner_table, set_a_fancy_table, set_up_a_buffet, set_up_a_hot_dog_bar, setting_the_table, setting_up_for_an_event]
# egg_white.n.01: [make_blueberry_mousse]
# crust.n.02: [make_pizza]
# vanilla.n.02: [baking_cookies_for_the_PTA_bake_sale, baking_sugar_cookies, make_a_cheese_pastry, make_brownies, make_cake_mix, make_chocolate_syrup, make_cookie_dough, make_cookies, make_edible_chocolate_chip_cookie_dough, make_eggnog, make_hot_cocoa, make_iced_chocolate, make_waffles]
# keg.n.02: [buy_a_keg, clean_a_beer_keg]
# macaroni_and_cheese.n.01: [make_macaroni_and_cheese]
# grocery.n.02: [buying_groceries_for_a_feast, unloading_shopping_from_car]
# clam.n.01: [clean_clams, cook_clams, cook_seafood_paella, make_clam_chowder, make_seafood_stew]
# foam.n.01: [make_a_cappuccino]
# windshield.n.01: [clean_a_glass_windshield]
# toaster_oven.n.01: [clean_a_toaster_oven, rearranging_kitchen_furniture]
# cornstarch.n.01: [clean_copper_wire, make_cake_filling]
# jimmies.n.01: [make_party_favors_from_candy]
# turkey.n.04: [clean_a_turkey, cook_a_turkey, make_red_beans_and_rice, prepare_a_slow_dinner_party, store_an_uncooked_turkey]
# car_seat.n.01: [wash_an_infant_car_seat]
# curry.n.01: [make_chicken_curry, make_curry_rice]
# orange_juice__carton.n.01: [bag_groceries, prepare_a_breakfast_bar, putting_food_in_fridge, setup_a_bar_for_a_cocktail_party]
# baby_shoe.n.01: [store_baby_clothes]
# chickpea.n.01: [cook_chickpeas]
# concrete.n.01: [clean_cement, installing_a_fence]
# lemon_peel.n.01: [make_lemon_pepper_seasoning]
# recreational_vehicle.n.01: [cleaning_camperORRV, packing_recreational_vehicle_for_trip, unpacking_recreational_vehicle_for_trip]
# marinade.n.01: [grill_vegetables]
# wind_chime.n.01: [hanging_up_wind_chimes]
# coal.n.01: [shoveling_coal]
# lobster.n.01: [clean_a_lobster, make_a_louisiana_seafood_boil]
# cornbread.n.01: [make_cornbread, preparing_food_for_a_fundraiser]
# bicycle_chain.n.01: [lube_a_bicycle_chain]
# suede.n.01: [clean_suede_gloves]
# vodka__bottle.n.01: [make_a_military_care_package, setup_a_bar_for_a_cocktail_party, stock_a_bar, store_vodka]
# dutch_oven.n.01: [cook_quail, make_lamb_stew]
# leotard.n.01: [wash_a_leotard]
# veal.n.01: [make_a_wiener_schnitzle]
# mashed_potato.n.01: [serving_food_at_a_homeless_shelter]
# marinara.n.01: [preparing_food_for_company, putting_dirty_dishes_in_sink]
# cheddar.n.01: [prepare_wine_and_cheese]
# lemon-pepper_seasoning.n.01: [make_lemon_pepper_seasoning, make_lemon_pepper_wings]
# marigold.n.01: [prepare_a_raised_bed_garden]
# sand.n.01: [buy_and_clean_mussels, clean_a_crab, clean_a_fish, clean_clams, clean_conch_shells, clean_mussels, clean_oysters, clean_scallops, clean_seashells, clean_shrimp, fill_a_punching_bag, sweeping_garage, sweeping_patio, sweeping_porch]
# broccoli_rabe.n.02: [clean_broccoli_rabe]
# funnel.n.01: [filling_salt]
# laundry.n.01: [bringing_laundry]
# writing_paper.n.01: [picking_up_prescriptions]
# salad_fork.n.01: [set_a_fancy_table]
# novel.n.02: [setting_up_living_room_for_guest]
# trampoline.n.01: [setup_a_trampoline]

# %% [markdown]
# ### Problem 5: Task-required synsets map to objects from their descendants too (might have unexpected examples)

# %%
descendant_mapper_count = sum(1 for s in found_task_required_synsets if set(synset_to_cat[s]) != {cat for cs in set(nx.descendants(G, s)) | {s} for cat in synset_to_cat[cs]})
print(f"{descendant_mapper_count} / {len(found_task_required_synsets)} map to objects from descendants.")

for s in found_task_required_synsets:
    own_cats = set(synset_to_cat[s])
    subtree = set(nx.descendants(G, s)) | {s}
    desc_cats = {cat for cs in subtree for cat in synset_to_cat[cs]}
    if own_cats == desc_cats:
        continue
        
    print(f"\nSynset {s} gets the below objects:")
    for cs in sorted(subtree):
        if not synset_to_cat[cs]:
            continue
        print(f"From {cs}:", ", ".join(synset_to_cat[cs]))
# Out:
# 233 / 833 map to objects from descendants.
#
# Synset electric_lamp.n.01 gets the below objects:
# From flashlight.n.01: flashlight
# From light_bulb.n.01: light_bulb, bulb
#
# Synset screw.n.04 gets the below objects:
# From bolt.n.06: bolt
# From screw.n.04: screw
#
# Synset candy.n.01 gets the below objects:
# From candy.n.01: candy_box, candy
# From candy_cane.n.01: candy_cane
# From easter_egg.n.01: easter_egg
# From jelly_bean.n.01: jelly_bean
# From lollipop.n.02: lollipop
# From marshmallow.n.01: marshmallow
#
# Synset cereal.n.03 gets the below objects:
# From cereal.n.03: cereal
# From corn_flake.n.01: box_of_corn_flake
# From granola.n.01: granola_pile
#
# Synset boot.n.01 gets the below objects:
# From boot.n.01: boot
# From buskin.n.01: hiking_boots
# From rubber_boot.n.01: rainboot
#
# Synset wood.n.01 gets the below objects:
# From bamboo.n.01: bamboo
# From log.n.01: tree_log, log
# From wood.n.01: wood
#
# Synset container.n.01 gets the below objects:
# From ashcan.n.01: trash_can
# From ashtray.n.01: ashtray
# From atomizer.n.01: atomizer
# From baby_buggy.n.01: stroller
# From backpack.n.01: backpack
# From bag.n.01: gift_bag, mesh_bag
# From bag.n.04: purse
# From bag.n.06: suitcase
# From basket.n.01: basket
# From bathtub.n.01: bathtub, round_bathtub
# From beer_barrel.n.01: beer_keg
# From beer_mug.n.01: beer_glass
# From bicycle.n.01: bicycle
# From bidet.n.01: bidet
# From bottle.n.01: bottle, baby_bottle
# From bowl.n.01: bowl
# From box.n.01: storage_box, gift_box, box
# From briefcase.n.01: briefcase
# From bucket.n.01: bucket, ice_bucket
# From caldron.n.01: cauldron
# From can.n.01: canned_coffee, canned_sardines, canned_tomatoes
# From canister.n.02: canister
# From car.n.01: car
# From carafe.n.01: carafe, fragrance_decanter, decanter
# From carboy.n.01: reagent_bottle
# From carryall.n.01: tote
# From carton.n.02: carton
# From case.n.05: violin_case
# From case.n.20: display_case
# From cash_register.n.01: credit_card_terminal, cash_register
# From casserole.n.02: casserole
# From chest.n.02: chest
# From coffeepot.n.01: coffeepot
# From container.n.01: disposable_container, fuel_can
# From crate.n.01: crate
# From cream_pitcher.n.01: cream_pitcher, creamer
# From cruet.n.01: cruet
# From cup.n.01: cup
# From dipper.n.01: dipper
# From dispenser.n.01: toilet_paper_dispenser, paper_towel_dispenser, candy_dispenser_shelf, dry_food_dispenser_shelf, drink_dispenser, water_dispenser
# From dixie_cup.n.01: paper_cup, soda_cup
# From drawer.n.01: waist_height_drawers
# From duffel_bag.n.01: duffel_bag
# From dustpan.n.02: dustpan
# From dutch_oven.n.02: dutch_oven
# From envelope.n.01: envelope
# From erlenmeyer_flask.n.01: erlenmeyer_flask
# From flask.n.01: round_bottom_flask, flask, flask
# From flute.n.02: champagne_flute
# From glass.n.02: glass
# From goblet.n.01: chalice, goblet
# From gravy_boat.n.01: gravy_boat
# From grocery_bag.n.01: grocery_bag
# From handcart.n.01: cart, bar_cart
# From hot_tub.n.01: hot_tub
# From inhaler.n.01: inhaler
# From jar.n.01: jar, honey_jar, ink_jar, jelly_jar
# From kettle.n.01: kettle, electric_kettle
# From ladle.n.01: ladle
# From lemon_juice__bottle.n.01: lemon_juice_bottle
# From litter_box.n.01: litter_boxh
# From mailbox.n.01: mailbox
# From mason_jar.n.01: mason_jar
# From matchbox.n.01: match_box
# From measuring_cup.n.01: measuring_cup
# From mixing_bowl.n.01: mixing_bowl
# From mortar.n.03: mortar
# From motorcycle.n.01: motorcycle
# From mug.n.04: mug
# From package.n.02: package
# From pencil_box.n.01: pencil_box, pencil_case
# From pepper_shaker.n.01: pepper_shaker
# From petri_dish.n.01: petri_dish
# From pickup.n.01: pickup_truck
# From pill_bottle.n.01: pill_bottle
# From pitcher.n.02: jug, pitcher
# From pizza_box.n.01: pizza_box
# From planter.n.03: hanging_basket
# From plastic_bag.n.01: plastic_bag
# From pop_bottle.n.01: pop_bottle, coke_bottle
# From pot.n.04: plant_pot
# From pressure_cooker.n.01: pressure_cooker
# From recycling_bin.n.01: compost_bin
# From sack.n.01: paper_bag, fry_holder
# From saltshaker.n.01: salt_shaker
# From saucepot.n.01: saucepot
# From sedan.n.01: sedan
# From shaker.n.03: shaker
# From shoebox.n.02: shoe_box
# From shopping_basket.n.01: shopping_basket
# From shopping_cart.n.01: shopping_cart
# From shot_glass.n.01: jigger
# From shoulder_bag.n.01: shoulder_bag
# From skateboard.n.01: longboard
# From soap_dispenser.n.01: soap_dispenser, wall_mounted_soap_dispenser
# From soda_can.n.01: soda_can
# From soup_ladle.n.01: soup_ladle
# From specimen_bottle.n.01: specimen_bottle
# From spoon.n.01: spoon
# From sport_utility.n.01: suv
# From stockpot.n.01: stockpot
# From teacup.n.02: teacup
# From teapot.n.01: teapot
# From teaspoon.n.02: teaspoon
# From toolbox.n.01: toolbox
# From toy_box.n.01: toy_box
# From tray.n.01: tray
# From trophy_case.n.01: trophy_case
# From truck.n.01: truck
# From tupperware.n.01: tupperware
# From tureen.n.01: tureen
# From vase.n.01: vase
# From wallet.n.01: wallet
# From water_bottle.n.01: water_bottle
# From water_glass.n.02: water_glass
# From watering_can.n.01: watering_can
# From whiskey_bottle.n.01: whiskey_bottle
# From wine_bottle.n.01: wine_bottle
# From wineglass.n.01: wineglass
#
# Synset bread.n.01 gets the below objects:
# From bagel.n.01: bagel
# From baguet.n.01: baguette
# From biscuit.n.01: biscuit
# From bread.n.01: bag_of_bread, bread
# From bun.n.01: bun, hotdog_bun
# From cracker.n.01: cracker_box, cracker
# From crescent_roll.n.01: croissant
# From crouton.n.01: crouton, crouton
# From danish.n.02: cheese_danish
# From meat_loaf.n.01: meatloaf
# From muffin.n.01: muffin
# From pretzel.n.01: pretzel
# From scone.n.01: scone
#
# Synset beef.n.02 gets the below objects:
# From beef.n.02: beef
# From ground_beef.n.01: ground_beef, ground_beaf
#
# Synset squeezer.n.01 gets the below objects:
# From reamer.n.01: juicer
#
# Synset coffee.n.01 gets the below objects:
# From cappuccino.n.01: cappuccino
# From coffee.n.01: coffee_pouch, coffee_cup, coffee_box, bottle_of_coffee, coffee
# From iced_coffee.n.01: frappuccino
#
# Synset beet.n.01 gets the below objects:
# From chard.n.01: chard
#
# Synset tea.n.01 gets the below objects:
# From ice_tea.n.01: can_of_icetea
# From tea.n.01: tea_bottle
#
# Synset grass.n.01 gets the below objects:
# From barley.n.02: barley
# From corn.n.01: corn
# From grass.n.01: grass_patch
# From popcorn.n.01: popcorn
#
# Synset document.n.01 gets the below objects:
# From document.n.01: document
# From ticket.n.01: ticket
#
# Synset heater.n.01 gets the below objects:
# From defroster.n.01: deicer
# From heater.n.01: heater, sauna_heater, coal_heater, heatgun
#
# Synset linen.n.03 gets the below objects:
# From bath_mat.n.01: bath_rug
# From bath_towel.n.01: bath_towel
# From case.n.19: pillowcase
# From dinner_napkin.n.01: dinner_napkin
# From place_mat.n.01: place_mat
# From sheet.n.03: sheet, bedsheet
#
# Synset pork_sausage.n.01 gets the below objects:
# From bratwurst.n.01: bratwurst
#
# Synset onion.n.03 gets the below objects:
# From green_onion.n.01: green_onion, green_onion_chopped
# From onion.n.03: onion
# From vidalia_onion.n.01: half_vidalia_onion, vidalia_onion
#
# Synset plant.n.02 gets the below objects:
# From barley.n.02: barley
# From butternut_squash.n.01: butternut_squash
# From cauliflower.n.01: cauliflower
# From chard.n.01: chard
# From chives.n.01: chives
# From corn.n.01: corn
# From dahlia.n.01: dahlia_flower
# From garden_plant.n.01: garden_plant
# From garlic.n.01: garlic_whole
# From gooseberry.n.01: gooseberry
# From grass.n.01: grass_patch
# From hazelnut.n.01: hazelnut, hazlenut
# From herb.n.01: laurel_leaf
# From holly.n.01: holly, holly
# From ivy.n.01: ivy
# From lemon.n.03: lemon_tree
# From loofah.n.02: loofah
# From okra.n.02: okra
# From papaya.n.01: papaya
# From pine.n.01: evergreen_tree
# From poinsettia.n.01: poinsettia
# From popcorn.n.01: popcorn
# From pot_plant.n.01: pot_plant, hanging_plant, pot_plan
# From rocket.n.03: arugula
# From rose.n.01: rose
# From shrub.n.01: bush, shrub
# From succulent.n.01: succulent
# From sunflower.n.01: sunflower
# From tree.n.01: tree
# From tulip.n.01: tulip
# From weed.n.01: weed
#
# Synset baseball_equipment.n.01 gets the below objects:
# From baseball.n.02: baseball
# From baseball_glove.n.01: garden_glove, baseball_glove
# From batting_glove.n.01: batting_gloves
#
# Synset alarm.n.02 gets the below objects:
# From fire_alarm.n.02: alarm
#
# Synset tape.n.01 gets the below objects:
# From duct_tape.n.01: duct_tape
# From tape.n.01: tape
#
# Synset rack.n.01 gets the below objects:
# From coatrack.n.01: coatrack
# From dish_rack.n.01: dish_rack
# From rack.n.01: ceiling_rack, umbrella_rack, snack_rack, pot_plant_rack, free_weight_rack, test_tube_rack, drying_rack, rack
# From towel_rack.n.01: towel_rack
#
# Synset bench.n.01 gets the below objects:
# From bench.n.01: bench, sauna_bench, hammam_bench
# From flat_bench.n.01: flat_bench
#
# Synset bun.n.01 gets the below objects:
# From bagel.n.01: bagel
# From bun.n.01: bun, hotdog_bun
# From crescent_roll.n.01: croissant
# From danish.n.02: cheese_danish
#
# Synset mixed_drink.n.01 gets the below objects:
# From fruit_punch.n.01: fruit_punch
# From martini.n.01: martini
#
# Synset case.n.05 gets the below objects:
# From bag.n.06: suitcase
# From briefcase.n.01: briefcase
# From case.n.05: violin_case
# From wallet.n.01: wallet
#
# Synset rice.n.01 gets the below objects:
# From brown_rice.n.01: brown_rice
# From rice.n.01: rice_box, rice_bag, rice
#
# Synset syrup.n.01 gets the below objects:
# From maple_syrup.n.01: maple_syrup
# From molasses.n.01: molasses
#
# Synset door.n.01 gets the below objects:
# From door.n.01: door, male_restroom_door, female_restroom_door
# From screen_door.n.01: bed_screen
#
# Synset edible_fruit.n.01 gets the below objects:
# From apple.n.01: apple, half_apple, apple_heap
# From apricot.n.02: apricot, half_apricot
# From avocado.n.01: avocado
# From banana.n.02: banana, bunch_of_bananas
# From blueberry.n.02: blueberry
# From cantaloup.n.02: cantaloup
# From cherry.n.03: cherry
# From citrus.n.01: citrus
# From cranberry.n.02: container_cranberry, cranberry, dried_cranberry
# From date.n.08: container_date
# From dried_apricot.n.01: dried_apricot
# From durian.n.02: durian
# From fig.n.04: fig
# From grape.n.01: grape
# From grapefruit.n.02: grapefruit
# From kiwi.n.03: half_kiwi, kiwi
# From lemon.n.01: half_lemon, lemon, box_of_lemons
# From lime.n.06: lime
# From mango.n.02: mango
# From melon.n.01: melon
# From nectarine.n.02: nectarine
# From orange.n.01: half_orange, orange, orange_heap, bag_of_oranges
# From peach.n.03: half_peach, peach
# From pear.n.01: half_pear, pear, pear_heap
# From pineapple.n.02: half_pineapple, pineapple
# From plum.n.02: half_plum, plum
# From pomegranate.n.02: half_pomegranate, pomegranate
# From pomelo.n.02: half_pomelo, pomelo
# From raisin.n.01: raisins_pile
# From raspberry.n.02: raspberry, box_of_raspberries, raspberries
# From strawberry.n.01: half_strawberry, strawberry, strawberries
# From watermelon.n.02: watermelon
#
# Synset vegetable.n.01 gets the below objects:
# From artichoke.n.02: artichoke
# From asparagus.n.02: asparagus
# From bean.n.01: bean, canned_beans
# From beet.n.02: beet
# From bell_pepper.n.02: bell_pepper
# From black_bean.n.01: black_beans
# From broccoli.n.02: broccoli
# From brussels_sprouts.n.01: brussels_sprouts
# From carrot.n.03: carrot
# From celery.n.02: celery
# From cherry_tomato.n.02: cherry_tomato
# From chili.n.02: chili, crushed_chili_pepper, chilli_pepper
# From cucumber.n.02: cucumber, cucumber_slice
# From eggplant.n.01: eggplant
# From french_fries.n.01: piece_of_fries
# From green_bean.n.01: green_bean
# From green_onion.n.01: green_onion, green_onion_chopped
# From head_cabbage.n.02: head_cabbage
# From kale.n.03: kale
# From lettuce.n.03: lettuce, chopped_lettuce
# From mushroom.n.05: half_mushroom, mushroom
# From mustard.n.03: mustard_greens
# From onion.n.03: onion
# From pea.n.01: pea, peas
# From pieplant.n.01: rhubarb
# From potato.n.01: potato
# From pumpkin.n.02: pumpkin
# From radish.n.01: radish
# From rutabaga.n.01: rutabaga
# From spinach.n.02: spinach
# From squash.n.02: squash
# From tomato.n.01: half_tomato, tomato
# From turnip.n.02: turnip
# From vidalia_onion.n.01: half_vidalia_onion, vidalia_onion
# From zucchini.n.02: zucchini
#
# Synset cookie.n.01 gets the below objects:
# From brownie.n.03: brownie
# From cookie.n.01: cookie, bag_of_cookie, box_of_cookie
# From granola_bar.n.01: box_of_granola_bar, granola_bar
# From wafer.n.02: wafer
#
# Synset sausage.n.01 gets the below objects:
# From bratwurst.n.01: bratwurst
# From chorizo.n.01: chorizo
# From kielbasa.n.01: kielbasa
# From sausage.n.01: sausage
#
# Synset plaything.n.01 gets the below objects:
# From dreidel.n.01: dreidel
# From plaything.n.01: toy, plush_toy, snow_globe
# From sandbox.n.02: sandbox
# From swing.n.02: swing
# From teddy.n.01: teddy_bear
# From train_set.n.01: toy_train
#
# Synset soft_drink.n.01 gets the below objects:
# From pop.n.02: pop, pop_case
# From tonic.n.01: bottle_of_tonic
#
# Synset corn.n.01 gets the below objects:
# From corn.n.01: corn
# From popcorn.n.01: popcorn
#
# Synset glass.n.02 gets the below objects:
# From flute.n.02: champagne_flute
# From glass.n.02: glass
# From goblet.n.01: chalice, goblet
# From shot_glass.n.01: jigger
# From water_glass.n.02: water_glass
# From wineglass.n.01: wineglass
#
# Synset dessert.n.01 gets the below objects:
# From blueberry_mousse.n.01: blueberry_mousse
# From ice_cream.n.01: bag_of_ice_cream, box_of_ice_cream
# From ice_lolly.n.01: popsicle
# From tiramisu.n.01: tiramisu
#
# Synset jewelry.n.01 gets the below objects:
# From bracelet.n.02: bracelet
# From diamond.n.01: diamond, diamond
# From engagement_ring.n.01: engagement_ring
# From jewel.n.01: jewel
# From jewelry.n.01: jewelry
# From necklace.n.01: necklace
# From pearl.n.01: pearl
# From ring.n.08: ring
#
# Synset underwear.n.01 gets the below objects:
# From lingerie.n.01: lingerie
# From underwear.n.01: underwear
#
# Synset block.n.01 gets the below objects:
# From die.n.01: dice
# From ice_cube.n.01: ice_cube
# From tablet.n.03: tablet
# From tile.n.01: tile, ceramic_tile
#
# Synset wrench.n.03 gets the below objects:
# From allen_wrench.n.01: allen_wrench
# From wrench.n.03: wrench
#
# Synset beverage.n.01 gets the below objects:
# From alcohol.n.01: alcohol
# From apple_juice.n.01: apple_juice
# From beer.n.01: beer, beer_box
# From brandy.n.01: brandy
# From buttermilk.n.01: buttermilk
# From cappuccino.n.01: cappuccino
# From champagne.n.01: champagne_bottle, box_of_champagne
# From chocolate_milk.n.01: chocolate_milk
# From cider.n.01: apple_cider
# From cocoa.n.01: hot_chocolate
# From coffee.n.01: coffee_pouch, coffee_cup, coffee_box, bottle_of_coffee, coffee
# From cranberry_juice.n.01: cranberry_juice
# From fruit_punch.n.01: fruit_punch
# From gin.n.01: gin_bottle
# From ginger_beer.n.01: ginger_beer
# From ice_tea.n.01: can_of_icetea
# From iced_coffee.n.01: frappuccino
# From lemonade.n.01: bottle_of_lemonade
# From martini.n.01: martini
# From milk.n.01: milk, bottle_of_milk, carton_of_milk, box_of_milk, almond_milk
# From orange_juice.n.01: carton_of_orange_juice, bottle_of_orange_juice, orange_juice
# From pineapple_juice.n.01: carton_of_pineapple_juice
# From pop.n.02: pop, pop_case
# From red_wine.n.01: red_wine
# From rum.n.01: rum_bottle, box_of_rum, rum
# From sake.n.02: box_of_sake, sake_bottle
# From smoothie.n.02: smoothie
# From tea.n.01: tea_bottle
# From tequila.n.01: tequilla
# From tonic.n.01: bottle_of_tonic
# From vodka.n.01: vodka
# From whiskey.n.01: box_of_whiskey
# From wine.n.01: box_of_wine
#
# Synset pasta.n.02 gets the below objects:
# From dumpling.n.01: dumpling
# From noodle.n.01: box_of_noodles, pack_of_ramen, noodle
# From pasta.n.02: pasta
#
# Synset bowl.n.03 gets the below objects:
# From mixing_bowl.n.01: mixing_bowl
#
# Synset blind.n.03 gets the below objects:
# From blind.n.03: blinds
# From curtain.n.01: curtain
# From shutter.n.02: shutter
# From window_blind.n.01: window_blind
#
# Synset garlic.n.02 gets the below objects:
# From clove.n.03: clove, garlic_clove
#
# Synset mug.n.04 gets the below objects:
# From beer_mug.n.01: beer_glass
# From mug.n.04: mug
#
# Synset chair.n.01 gets the below objects:
# From armchair.n.01: armchair
# From chaise_longue.n.01: chaise_longue
# From eames_chair.n.01: eames_chair
# From folding_chair.n.01: folding_chair
# From highchair.n.01: highchair
# From lawn_chair.n.01: garden_chair
# From rocking_chair.n.01: rocking_chair
# From straight_chair.n.01: straight_chair
# From swivel_chair.n.01: swivel_chair
#
# Synset garment.n.01 gets the below objects:
# From bikini.n.02: bikini
# From blazer.n.01: blazer
# From brassiere.n.01: bra
# From cardigan.n.01: cardigan
# From coat.n.01: coat
# From diaper.n.01: diaper
# From jacket.n.01: jacket
# From jean.n.01: jeans
# From jersey.n.03: t-shirt, jersey
# From jump_suit.n.01: onesie
# From lingerie.n.01: lingerie
# From necktie.n.01: necktie
# From polo_shirt.n.01: polo_shirt
# From raincoat.n.01: raincoat
# From scarf.n.01: scarf
# From shawl.n.01: shawl
# From shirt.n.01: shirt
# From short_pants.n.01: shorts
# From sweat_suit.n.01: sauna_suit
# From sweater.n.01: sweater
# From sweatshirt.n.01: hoodie, sweatshirt
# From swimsuit.n.01: swimsuit
# From tank_top.n.01: tank_top
# From trouser.n.01: pants, snow_pants
# From turtleneck.n.01: turtleneck
# From underwear.n.01: underwear
# From vest.n.01: vest
#
# Synset plastic_wrap.n.01 gets the below objects:
# From cellophane.n.01: cellophane
# From plastic_wrap.n.01: plastic_wrap
#
# Synset stool.n.01 gets the below objects:
# From footstool.n.01: ottoman
# From stool.n.01: stool
#
# Synset flag.n.01 gets the below objects:
# From banner.n.01: banner, hanging_banners
# From flag.n.01: us_flag, ukranian_flag
#
# Synset electric_refrigerator.n.01 gets the below objects:
# From deep-freeze.n.01: freezer
# From electric_refrigerator.n.01: fridge, wine_fridge, display_fridge
#
# Synset swimsuit.n.01 gets the below objects:
# From bikini.n.02: bikini
# From swimsuit.n.01: swimsuit
#
# Synset ball.n.01 gets the below objects:
# From ball.n.01: ball
# From baseball.n.02: baseball
# From bowling_ball.n.01: bowling_ball
# From punching_bag.n.02: punching_bag
# From soccer_ball.n.01: soccer_ball
# From softball.n.01: softball
# From tennis_ball.n.01: tennis_ball
#
# Synset stone.n.02 gets the below objects:
# From gravestone.n.01: headstone
# From paving_stone.n.01: paver
#
# Synset ham.n.01 gets the below objects:
# From ham.n.01: cooked_ham
# From prosciutto.n.01: prosciutto
#
# Synset makeup.n.01 gets the below objects:
# From eyeshadow.n.01: eyeshadow, eyeshadow
# From lipstick.n.01: lipstick
#
# Synset firework.n.01 gets the below objects:
# From firework.n.01: firework
# From sparkler.n.02: sparkler
#
# Synset frying_pan.n.01 gets the below objects:
# From electric_frying_pan.n.01: deep_fryer
# From frying_pan.n.01: frying_pan
#
# Synset juice.n.01 gets the below objects:
# From carrot_juice.n.01: carrot_juice
# From juice.n.01: juice, vegetable_juice
# From lime_juice.n.01: lime_juice
# From papaya_juice.n.01: bottle_of_papaya_juice
# From tomato_juice.n.01: tomato_juice
#
# Synset marker.n.03 gets the below objects:
# From highlighter.n.02: highlighter
# From marker.n.03: marker
#
# Synset punch.n.02 gets the below objects:
# From fruit_punch.n.01: fruit_punch
#
# Synset cocktail.n.01 gets the below objects:
# From martini.n.01: martini
#
# Synset camera.n.01 gets the below objects:
# From camera.n.01: camera
# From webcam.n.01: webcam
#
# Synset lens.n.01 gets the below objects:
# From sunglass.n.01: sunglass
#
# Synset vegetable.n.02 gets the below objects:
# From chard.n.01: chard
#
# Synset filter.n.01 gets the below objects:
# From coffee_filter.n.01: coffee_filter, portafilter
# From colander.n.01: colander
# From water_filter.n.01: water_filter
#
# Synset candlestick.n.01 gets the below objects:
# From candelabrum.n.01: candle_holder
#
# Synset fan.n.01 gets the below objects:
# From electric_fan.n.01: electric_fan
# From fan.n.01: ceiling_fan
#
# Synset hand_tool.n.01 gets the below objects:
# From allen_wrench.n.01: allen_wrench
# From corkscrew.n.01: corkscrew
# From hammer.n.02: hammer
# From pestle.n.03: pestle
# From pliers.n.01: plier
# From putty_knife.n.01: putty_knife
# From saw.n.02: saw
# From scraper.n.01: scraper
# From screwdriver.n.01: screwdriver
# From shovel.n.01: shovel
# From toothpick.n.01: toothpick
# From trowel.n.01: trowel
# From wrench.n.03: wrench
#
# Synset counter.n.01 gets the below objects:
# From bar.n.02: bar
# From checkout.n.03: checkout_counter
# From counter.n.01: counter
#
# Synset nut.n.01 gets the below objects:
# From almond.n.02: almond
# From chestnut.n.03: chestnut, half_chestnut
# From pistachio.n.02: pistachio
# From walnut.n.01: walnut
#
# Synset rug.n.01 gets the below objects:
# From rug.n.01: carpet, rug
# From runner.n.08: table_runner
#
# Synset meat.n.01 gets the below objects:
# From bacon.n.01: bacon
# From beef.n.02: beef
# From beef_roast.n.01: roast_beef_slice, roast_beaf_slice
# From bratwurst.n.01: bratwurst
# From brisket.n.01: brisket
# From chicken.n.01: chicken, chicken_wing
# From chorizo.n.01: chorizo
# From duck.n.03: duck
# From ground_beef.n.01: ground_beef, ground_beaf
# From ham.n.01: cooked_ham
# From kielbasa.n.01: kielbasa
# From pork.n.01: pork
# From porkchop.n.01: pork_chop
# From prosciutto.n.01: prosciutto
# From quail.n.01: quail_breast, quail_breast_raw, quail_leg
# From rib.n.03: rib, pork_rib
# From sausage.n.01: sausage
# From steak.n.01: steak
#
# Synset card.n.03 gets the below objects:
# From card.n.03: cardstock
# From postcard.n.01: postcard
#
# Synset wineglass.n.01 gets the below objects:
# From flute.n.02: champagne_flute
# From wineglass.n.01: wineglass
#
# Synset dough.n.01 gets the below objects:
# From dough.n.01: dough, dough, pizza_dough
# From pastry.n.01: pastry
#
# Synset potato.n.01 gets the below objects:
# From french_fries.n.01: piece_of_fries
# From potato.n.01: potato
#
# Synset cage.n.01 gets the below objects:
# From birdcage.n.01: birdcage
# From hutch.n.01: hutch
#
# Synset spoon.n.01 gets the below objects:
# From spoon.n.01: spoon
# From teaspoon.n.02: teaspoon
#
# Synset pancake.n.01 gets the below objects:
# From pancake.n.01: pancake
# From tortilla.n.01: tortilla
#
# Synset knife.n.01 gets the below objects:
# From carving_knife.n.01: carving_knife
# From cleaver.n.01: cleaver
# From knife.n.01: knife, utility_knife
# From pocketknife.n.01: pocketknife
# From table_knife.n.01: table_knife
#
# Synset sugar.n.01 gets the below objects:
# From brown_sugar.n.01: brown_sugar, box_of_brown_sugar
# From sugar.n.01: sugar_jar, sugar
#
# Synset blower.n.01 gets the below objects:
# From hand_blower.n.01: hair_dryer
#
# Synset handcart.n.01 gets the below objects:
# From handcart.n.01: cart, bar_cart
# From shopping_cart.n.01: shopping_cart
#
# Synset bed.n.01 gets the below objects:
# From bed.n.01: bed, massage_bed
# From hammock.n.02: hammock
# From hospital_bed.n.01: hospital_bed
#
# Synset alcohol.n.01 gets the below objects:
# From alcohol.n.01: alcohol
# From beer.n.01: beer, beer_box
# From brandy.n.01: brandy
# From champagne.n.01: champagne_bottle, box_of_champagne
# From fruit_punch.n.01: fruit_punch
# From gin.n.01: gin_bottle
# From martini.n.01: martini
# From red_wine.n.01: red_wine
# From rum.n.01: rum_bottle, box_of_rum, rum
# From sake.n.02: box_of_sake, sake_bottle
# From tequila.n.01: tequilla
# From vodka.n.01: vodka
# From whiskey.n.01: box_of_whiskey
# From wine.n.01: box_of_wine
#
# Synset plastic_art.n.01 gets the below objects:
# From sculpture.n.01: sculpture
# From statue.n.01: statue, garden_statue
#
# Synset pesticide.n.01 gets the below objects:
# From pesticide.n.01: pesticide
# From spray.n.01: spray_bottle
#
# Synset pie.n.01 gets the below objects:
# From apple_pie.n.01: apple_pie
# From tart.n.02: tart
#
# Synset bean.n.01 gets the below objects:
# From bean.n.01: bean, canned_beans
# From black_bean.n.01: black_beans
# From green_bean.n.01: green_bean
#
# Synset tissue.n.02 gets the below objects:
# From tissue.n.02: tissue_dispenser, box_of_tissue
# From toilet_tissue.n.01: toilet_paper
#
# Synset bed_linen.n.01 gets the below objects:
# From case.n.19: pillowcase
# From sheet.n.03: sheet, bedsheet
#
# Synset jersey.n.03 gets the below objects:
# From jersey.n.03: t-shirt, jersey
# From turtleneck.n.01: turtleneck
#
# Synset dish.n.02 gets the below objects:
# From burrito.n.01: burrito
# From chip.n.04: chip
# From chowder.n.01: chowder
# From custard.n.01: custard_bowl
# From french_toast.n.01: french_toast
# From gazpacho.n.01: gazpacho
# From hamburger.n.01: hamburger
# From hotdog.n.02: hotdog
# From kabob.n.01: kebab
# From lasagna.n.01: lasagna, box_of_lasagna
# From meat_loaf.n.01: meatloaf
# From nacho.n.01: nachos
# From oatmeal.n.01: oatmeal, box_of_oatmeal, oatmeal_pile
# From omelet.n.01: omelet
# From pizza.n.01: pizza
# From ramekin.n.01: ramekin
# From risotto.n.01: risotto
# From salad.n.01: salad
# From sandwich.n.01: sandwich
# From schnitzel.n.01: schnitzel
# From scrambled_eggs.n.01: scrambled_eggs
# From soup.n.01: soup, bottle_of_soup
# From spaghetti.n.01: spaghetti
# From sushi.n.01: sushi
# From taco.n.02: taco
# From tortilla_chip.n.01: tortilla_chips
#
# Synset ring.n.08 gets the below objects:
# From engagement_ring.n.01: engagement_ring
# From ring.n.08: ring
#
# Synset cube.n.05 gets the below objects:
# From die.n.01: dice
# From ice_cube.n.01: ice_cube
#
# Synset cracker.n.01 gets the below objects:
# From cracker.n.01: cracker_box, cracker
# From pretzel.n.01: pretzel
#
# Synset stick.n.01 gets the below objects:
# From bat.n.05: baseball_bat
# From drumstick.n.02: drumstick
#
# Synset brush.n.02 gets the below objects:
# From hairbrush.n.01: hairbrush
# From paintbrush.n.01: paintbrush
# From scrub_brush.n.01: scrub_brush
# From toothbrush.n.01: toothbrush
#
# Synset shelter.n.01 gets the below objects:
# From tent.n.01: tent
#
# Synset quilt.n.01 gets the below objects:
# From eiderdown.n.01: duvet
# From quilt.n.01: quilt
#
# Synset sweet_pepper.n.02 gets the below objects:
# From bell_pepper.n.02: bell_pepper
#
# Synset tortilla_chip.n.01 gets the below objects:
# From nacho.n.01: nachos
# From tortilla_chip.n.01: tortilla_chips
#
# Synset pitcher.n.02 gets the below objects:
# From cream_pitcher.n.01: cream_pitcher, creamer
# From pitcher.n.02: jug, pitcher
#
# Synset fruit_tree.n.01 gets the below objects:
# From lemon.n.03: lemon_tree
# From papaya.n.01: papaya
#
# Synset utensil.n.01 gets the below objects:
# From blender.n.01: blender
# From caldron.n.01: cauldron
# From china.n.02: china
# From coffeepot.n.01: coffeepot
# From cooker.n.01: canner, canner_lid, rice_cooker, slow_cooker
# From cookie_cutter.n.01: cookie_cutter
# From cookie_sheet.n.01: baking_sheet
# From crock_pot.n.01: oden_cooker, crock_pot, instant_pot
# From dutch_oven.n.02: dutch_oven
# From eggbeater.n.02: eggbeater
# From electric_frying_pan.n.01: deep_fryer
# From electric_mixer.n.01: electric_hand_mixer
# From frying_pan.n.01: frying_pan
# From funnel.n.02: funnel
# From grater.n.01: grater
# From griddle.n.01: griddle
# From kettle.n.01: kettle, electric_kettle
# From kitchen_utensil.n.01: pastry_brush
# From masher.n.02: potato_masher
# From mixer.n.04: electric_mixer
# From pan.n.01: roasting_pan
# From popper.n.03: popcorn_machine
# From reamer.n.01: juicer
# From rolling_pin.n.01: rolling_pin
# From saucepan.n.01: saucepan
# From saucepot.n.01: saucepot
# From server.n.04: pasta_server
# From skimmer.n.02: skimmer
# From spatula.n.01: spatula
# From steamer.n.02: steamer, zhenglong, steamer_basket
# From stockpot.n.01: stockpot
# From teapot.n.01: teapot
# From whisk.n.01: whisk
# From wok.n.01: wok
#
# Synset game.n.01 gets the below objects:
# From board_game.n.01: board_game
#
# Synset cup.n.01 gets the below objects:
# From cup.n.01: cup
# From dixie_cup.n.01: paper_cup, soda_cup
# From teacup.n.02: teacup
#
# Synset greens.n.01 gets the below objects:
# From lettuce.n.03: lettuce, chopped_lettuce
# From spinach.n.02: spinach
#
# Synset trouser.n.01 gets the below objects:
# From jean.n.01: jeans
# From short_pants.n.01: shorts
# From trouser.n.01: pants, snow_pants
#
# Synset apparel.n.01 gets the below objects:
# From jean.n.01: jeans
#
# Synset shaker.n.03 gets the below objects:
# From pepper_shaker.n.01: pepper_shaker
# From saltshaker.n.01: salt_shaker
# From shaker.n.03: shaker
#
# Synset soap.n.01 gets the below objects:
# From liquid_soap.n.01: body_wash
# From soap.n.01: soap, body_scrub, dish_soap
#
# Synset pad.n.01 gets the below objects:
# From notepad.n.01: notepad
# From pad.n.01: sticky_note
#
# Synset sauce.n.01 gets the below objects:
# From aioli.n.01: garlic_sauce
# From barbecue_sauce.n.01: barbecue_sauce
# From chocolate_sauce.n.01: chocolate_syrup
# From hot_sauce.n.01: hot_sauce, sriracha
# From mayonnaise.n.01: mayonnaise
# From mushroom_sauce.n.01: mushroom_sauce
# From pesto.n.01: pesto
# From sauce.n.01: orange_sauce, lemon_sauce
# From spaghetti_sauce.n.01: spaghetti_sauce
# From tomato_sauce.n.01: tomato_sauce
#
# Synset decoration.n.01 gets the below objects:
# From banner.n.01: banner, hanging_banners
# From baseboard.n.01: baseboard
# From bouquet.n.01: bouquet
# From bow.n.08: bow
# From bracelet.n.02: bracelet
# From christmas_tree.n.05: christmas_tree, christmas_tree_decorated
# From decoration.n.01: decoration
# From diamond.n.01: diamond, diamond
# From engagement_ring.n.01: engagement_ring
# From flag.n.01: us_flag, ukranian_flag
# From folderal.n.01: folderal
# From frosting.n.01: frosting_bottle
# From interior_decoration.n.01: interior_decoration
# From jewel.n.01: jewel
# From jewelry.n.01: jewelry
# From meringue.n.01: meringue
# From necklace.n.01: necklace
# From pearl.n.01: pearl
# From ring.n.08: ring
# From tassel.n.01: tassel
# From wreath.n.01: wreath, valentine_wreath
#
# Synset nozzle.n.01 gets the below objects:
# From showerhead.n.01: showerhead
#
# Synset chest.n.02 gets the below objects:
# From chest.n.02: chest
# From toolbox.n.01: toolbox
# From toy_box.n.01: toy_box
#
# Synset tea.n.05 gets the below objects:
# From green_tea.n.01: green_tea, matcha
# From tea.n.05: tea, box_of_tea, bag_of_tea, tea_leaf, tea_leaves
# From tea_bag.n.01: tea_bag
#
# Synset ladle.n.01 gets the below objects:
# From dipper.n.01: dipper
# From ladle.n.01: ladle
# From soup_ladle.n.01: soup_ladle
#
# Synset chocolate.n.02 gets the below objects:
# From chocolate.n.02: chocolate_box, chocolate_bar, chocolate_chip
# From cocoa_powder.n.01: cocoa_powder
# From white_chocolate.n.01: white_chocolate
#
# Synset pot.n.04 gets the below objects:
# From planter.n.03: hanging_basket
# From pot.n.04: plant_pot
#
# Synset sack.n.01 gets the below objects:
# From grocery_bag.n.01: grocery_bag
# From sack.n.01: paper_bag, fry_holder
#
# Synset vegetable_oil.n.01 gets the below objects:
# From coconut_oil.n.01: coconut_oil
# From cooking_oil.n.01: cooking_oil, cooking_spray
# From olive_oil.n.01: olive_oil
# From sesame_oil.n.01: sesame_oil
# From vegetable_oil.n.01: vegetable_oil
#
# Synset truck.n.01 gets the below objects:
# From pickup.n.01: pickup_truck
# From truck.n.01: truck
#
# Synset tomato.n.01 gets the below objects:
# From cherry_tomato.n.02: cherry_tomato
# From tomato.n.01: half_tomato, tomato
#
# Synset vascular_plant.n.01 gets the below objects:
# From barley.n.02: barley
# From butternut_squash.n.01: butternut_squash
# From cauliflower.n.01: cauliflower
# From chard.n.01: chard
# From chives.n.01: chives
# From corn.n.01: corn
# From dahlia.n.01: dahlia_flower
# From garlic.n.01: garlic_whole
# From gooseberry.n.01: gooseberry
# From grass.n.01: grass_patch
# From hazelnut.n.01: hazelnut, hazlenut
# From herb.n.01: laurel_leaf
# From holly.n.01: holly, holly
# From ivy.n.01: ivy
# From lemon.n.03: lemon_tree
# From loofah.n.02: loofah
# From okra.n.02: okra
# From papaya.n.01: papaya
# From pine.n.01: evergreen_tree
# From poinsettia.n.01: poinsettia
# From popcorn.n.01: popcorn
# From rocket.n.03: arugula
# From rose.n.01: rose
# From shrub.n.01: bush, shrub
# From succulent.n.01: succulent
# From sunflower.n.01: sunflower
# From tree.n.01: tree
# From tulip.n.01: tulip
# From weed.n.01: weed
#
# Synset wardrobe.n.01 gets the below objects:
# From armoire.n.01: armoire
# From wardrobe.n.01: hall_tree, wardrobe
#
# Synset cooker.n.01 gets the below objects:
# From cooker.n.01: canner, canner_lid, rice_cooker, slow_cooker
# From crock_pot.n.01: oden_cooker, crock_pot, instant_pot
# From popper.n.03: popcorn_machine
#
# Synset canvas.n.01 gets the below objects:
# From canvas.n.01: canvas
# From tarpaulin.n.01: tarp
#
# Synset towel.n.01 gets the below objects:
# From bath_towel.n.01: bath_towel
# From dishtowel.n.01: dishtowel, dish_towel
# From hand_towel.n.01: hand_towel
# From paper_towel.n.01: paper_towel
# From towel.n.01: towel
#
# Synset fence.n.01 gets the below objects:
# From fence.n.01: fence
# From hedge.n.01: hedge
# From rail_fence.n.01: rail_fence
#
# Synset wax.n.01 gets the below objects:
# From beeswax.n.01: beeswax
# From paraffin.n.01: paraffin_wax
# From wax.n.01: wax
#
# Synset bottle.n.01 gets the below objects:
# From bottle.n.01: bottle, baby_bottle
# From carafe.n.01: carafe, fragrance_decanter, decanter
# From carboy.n.01: reagent_bottle
# From cruet.n.01: cruet
# From erlenmeyer_flask.n.01: erlenmeyer_flask
# From flask.n.01: round_bottom_flask, flask, flask
# From lemon_juice__bottle.n.01: lemon_juice_bottle
# From pill_bottle.n.01: pill_bottle
# From pop_bottle.n.01: pop_bottle, coke_bottle
# From specimen_bottle.n.01: specimen_bottle
# From water_bottle.n.01: water_bottle
# From whiskey_bottle.n.01: whiskey_bottle
# From wine_bottle.n.01: wine_bottle
#
# Synset spice.n.02 gets the below objects:
# From allspice.n.03: allspice
# From chinese_anise.n.02: star_anise
# From cinnamon.n.03: cinnamon
# From clove.n.04: ground_clove
# From fennel.n.04: fennel
# From ginger.n.02: ginger
# From mace.n.03: ground_mace
# From nutmeg.n.02: ground_nutmeg
# From pumpkin_pie_spice.n.01: pumpkin_pie_spice
# From spice.n.02: spice, savory_spice
#
# Synset holder.n.01 gets the below objects:
# From candelabrum.n.01: candle_holder
# From holder.n.01: paper_towel_holder, pencil_holder, toilet_paper_holder
#
# Synset mixer.n.04 gets the below objects:
# From blender.n.01: blender
# From eggbeater.n.02: eggbeater
# From electric_mixer.n.01: electric_hand_mixer
# From mixer.n.04: electric_mixer
# From whisk.n.01: whisk
#
# Synset game_equipment.n.01 gets the below objects:
# From ball.n.01: ball
# From baseball.n.02: baseball
# From basket.n.03: ceiling_mounted_basketball_hoop
# From bowling_ball.n.01: bowling_ball
# From pool_table.n.01: pool_table
# From punching_bag.n.02: punching_bag
# From puzzle.n.02: puzzle, puzzle_piece
# From soccer_ball.n.01: soccer_ball
# From softball.n.01: softball
# From tennis_ball.n.01: tennis_ball
# From volleyball_net.n.01: volleyball_net
#
# Synset sweater.n.01 gets the below objects:
# From cardigan.n.01: cardigan
# From sweater.n.01: sweater
# From sweatshirt.n.01: hoodie, sweatshirt
# From turtleneck.n.01: turtleneck
#
# Synset napkin.n.01 gets the below objects:
# From dinner_napkin.n.01: dinner_napkin
#
# Synset cashbox.n.01 gets the below objects:
# From cash_register.n.01: credit_card_terminal, cash_register
#
# Synset jacket.n.01 gets the below objects:
# From blazer.n.01: blazer
# From jacket.n.01: jacket
#
# Synset racket.n.04 gets the below objects:
# From racket.n.04: racket
# From tennis_racket.n.01: tennis_racket
#
# Synset shoe.n.01 gets the below objects:
# From gym_shoe.n.01: gym_shoe, sneakers, vans
# From sandal.n.01: sandal, sandals
# From shoe.n.01: shoe
# From walker.n.04: walker
#
# Synset perfume.n.02 gets the below objects:
# From cologne.n.02: cologne
# From perfume.n.02: perfume, box_of_perfume
#
# Synset table_linen.n.01 gets the below objects:
# From dinner_napkin.n.01: dinner_napkin
# From place_mat.n.01: place_mat
#
# Synset dryer.n.01 gets the below objects:
# From dryer.n.01: dryer, hand_dryer
# From hand_blower.n.01: hair_dryer
#
# Synset tripod.n.01 gets the below objects:
# From easel.n.01: easel
#
# Synset yard.n.02 gets the below objects:
# From playground.n.02: playground
#
# Synset car.n.01 gets the below objects:
# From car.n.01: car
# From sedan.n.01: sedan
# From sport_utility.n.01: suv
#
# Synset produce.n.01 gets the below objects:
# From apple.n.01: apple, half_apple, apple_heap
# From apricot.n.02: apricot, half_apricot
# From artichoke.n.02: artichoke
# From asparagus.n.02: asparagus
# From avocado.n.01: avocado
# From banana.n.02: banana, bunch_of_bananas
# From bean.n.01: bean, canned_beans
# From beet.n.02: beet
# From bell_pepper.n.02: bell_pepper
# From black_bean.n.01: black_beans
# From blueberry.n.02: blueberry
# From broccoli.n.02: broccoli
# From brussels_sprouts.n.01: brussels_sprouts
# From cantaloup.n.02: cantaloup
# From carrot.n.03: carrot
# From celery.n.02: celery
# From cherry.n.03: cherry
# From cherry_tomato.n.02: cherry_tomato
# From chili.n.02: chili, crushed_chili_pepper, chilli_pepper
# From citrus.n.01: citrus
# From cranberry.n.02: container_cranberry, cranberry, dried_cranberry
# From cucumber.n.02: cucumber, cucumber_slice
# From date.n.08: container_date
# From dried_apricot.n.01: dried_apricot
# From durian.n.02: durian
# From eggplant.n.01: eggplant
# From fig.n.04: fig
# From french_fries.n.01: piece_of_fries
# From grape.n.01: grape
# From grapefruit.n.02: grapefruit
# From green_bean.n.01: green_bean
# From green_onion.n.01: green_onion, green_onion_chopped
# From head_cabbage.n.02: head_cabbage
# From kale.n.03: kale
# From kiwi.n.03: half_kiwi, kiwi
# From lemon.n.01: half_lemon, lemon, box_of_lemons
# From lettuce.n.03: lettuce, chopped_lettuce
# From lime.n.06: lime
# From mango.n.02: mango
# From melon.n.01: melon
# From mushroom.n.05: half_mushroom, mushroom
# From mustard.n.03: mustard_greens
# From nectarine.n.02: nectarine
# From onion.n.03: onion
# From orange.n.01: half_orange, orange, orange_heap, bag_of_oranges
# From pea.n.01: pea, peas
# From peach.n.03: half_peach, peach
# From pear.n.01: half_pear, pear, pear_heap
# From pieplant.n.01: rhubarb
# From pineapple.n.02: half_pineapple, pineapple
# From plum.n.02: half_plum, plum
# From pomegranate.n.02: half_pomegranate, pomegranate
# From pomelo.n.02: half_pomelo, pomelo
# From potato.n.01: potato
# From pumpkin.n.02: pumpkin
# From radish.n.01: radish
# From raisin.n.01: raisins_pile
# From raspberry.n.02: raspberry, box_of_raspberries, raspberries
# From rutabaga.n.01: rutabaga
# From spinach.n.02: spinach
# From squash.n.02: squash
# From strawberry.n.01: half_strawberry, strawberry, strawberries
# From tomato.n.01: half_tomato, tomato
# From turnip.n.02: turnip
# From vidalia_onion.n.01: half_vidalia_onion, vidalia_onion
# From watermelon.n.02: watermelon
# From zucchini.n.02: zucchini
#
# Synset fruit.n.01 gets the below objects:
# From almond.n.02: almond
# From apple.n.01: apple, half_apple, apple_heap
# From apricot.n.02: apricot, half_apricot
# From avocado.n.01: avocado
# From banana.n.02: banana, bunch_of_bananas
# From blueberry.n.02: blueberry
# From cantaloup.n.02: cantaloup
# From cherry.n.03: cherry
# From chestnut.n.03: chestnut, half_chestnut
# From citrus.n.01: citrus
# From coffee_bean.n.01: coffee_bean
# From cranberry.n.02: container_cranberry, cranberry, dried_cranberry
# From cumin.n.02: cumin
# From date.n.08: container_date
# From dried_apricot.n.01: dried_apricot
# From durian.n.02: durian
# From fig.n.04: fig
# From fruit.n.01: box_of_fruit
# From grape.n.01: grape
# From grapefruit.n.02: grapefruit
# From hip.n.05: rosehip
# From kiwi.n.03: half_kiwi, kiwi
# From lemon.n.01: half_lemon, lemon, box_of_lemons
# From lime.n.06: lime
# From mango.n.02: mango
# From melon.n.01: melon
# From nectarine.n.02: nectarine
# From olive.n.04: olive
# From orange.n.01: half_orange, orange, orange_heap, bag_of_oranges
# From peach.n.03: half_peach, peach
# From peanut.n.01: peanut
# From pear.n.01: half_pear, pear, pear_heap
# From pineapple.n.02: half_pineapple, pineapple
# From pistachio.n.02: pistachio
# From plum.n.02: half_plum, plum
# From pomegranate.n.02: half_pomegranate, pomegranate
# From pomelo.n.02: half_pomelo, pomelo
# From raisin.n.01: raisins_pile
# From raspberry.n.02: raspberry, box_of_raspberries, raspberries
# From strawberry.n.01: half_strawberry, strawberry, strawberries
# From walnut.n.01: walnut
# From watermelon.n.02: watermelon
#
# Synset adhesive_material.n.01 gets the below objects:
# From adhesive_material.n.01: adhesive
# From glue.n.01: glue
#
# Synset food.n.02 gets the below objects:
# From apple.n.01: apple, half_apple, apple_heap
# From apple_pie.n.01: apple_pie
# From apricot.n.02: apricot, half_apricot
# From artichoke.n.02: artichoke
# From asparagus.n.02: asparagus
# From avocado.n.01: avocado
# From bacon.n.01: bacon
# From bagel.n.01: bagel
# From baguet.n.01: baguette
# From banana.n.02: banana, bunch_of_bananas
# From bean.n.01: bean, canned_beans
# From beef.n.02: beef
# From beef_roast.n.01: roast_beef_slice, roast_beaf_slice
# From beet.n.02: beet
# From bell_pepper.n.02: bell_pepper
# From biscuit.n.01: biscuit
# From black_bean.n.01: black_beans
# From blueberry.n.02: blueberry
# From bratwurst.n.01: bratwurst
# From bread.n.01: bag_of_bread, bread
# From brisket.n.01: brisket
# From broccoli.n.02: broccoli
# From brownie.n.03: brownie
# From brussels_sprouts.n.01: brussels_sprouts
# From bun.n.01: bun, hotdog_bun
# From butter.n.01: butter, box_of_butter
# From cake.n.03: box_of_cake, cake
# From cantaloup.n.02: cantaloup
# From carrot.n.03: carrot
# From celery.n.02: celery
# From cereal.n.03: cereal
# From cheese.n.01: cheese
# From cherry.n.03: cherry
# From cherry_tomato.n.02: cherry_tomato
# From chicken.n.01: chicken, chicken_wing
# From chili.n.02: chili, crushed_chili_pepper, chilli_pepper
# From chocolate.n.02: chocolate_box, chocolate_bar, chocolate_chip
# From chocolate_cake.n.01: chocolate_cake_slice
# From chorizo.n.01: chorizo
# From citrus.n.01: citrus
# From cocoa_powder.n.01: cocoa_powder
# From coconut.n.01: coconut, half_coconut
# From cookie.n.01: cookie, bag_of_cookie, box_of_cookie
# From corn_flake.n.01: box_of_corn_flake
# From crab.n.05: crab
# From cracker.n.01: cracker_box, cracker
# From cranberry.n.02: container_cranberry, cranberry, dried_cranberry
# From crayfish.n.02: crawfish
# From cream_cheese.n.01: bag_of_cream_cheese
# From crescent_roll.n.01: croissant
# From crouton.n.01: crouton, crouton
# From cucumber.n.02: cucumber, cucumber_slice
# From cupcake.n.01: cupcake
# From danish.n.02: cheese_danish
# From date.n.08: container_date
# From doughnut.n.02: donut
# From dried_apricot.n.01: dried_apricot
# From duck.n.03: duck
# From dumpling.n.01: dumpling
# From durian.n.02: durian
# From eggplant.n.01: eggplant
# From fig.n.04: fig
# From fish.n.02: fish
# From french_fries.n.01: piece_of_fries
# From gingerbread.n.01: gingerbread
# From granola.n.01: granola_pile
# From granola_bar.n.01: box_of_granola_bar, granola_bar
# From grape.n.01: grape
# From grapefruit.n.02: grapefruit
# From green_bean.n.01: green_bean
# From green_onion.n.01: green_onion, green_onion_chopped
# From ground_beef.n.01: ground_beef, ground_beaf
# From ham.n.01: cooked_ham
# From head_cabbage.n.02: head_cabbage
# From kale.n.03: kale
# From kielbasa.n.01: kielbasa
# From kiwi.n.03: half_kiwi, kiwi
# From lemon.n.01: half_lemon, lemon, box_of_lemons
# From lettuce.n.03: lettuce, chopped_lettuce
# From lime.n.06: lime
# From mango.n.02: mango
# From meat_loaf.n.01: meatloaf
# From melon.n.01: melon
# From muffin.n.01: muffin
# From mushroom.n.05: half_mushroom, mushroom
# From mussel.n.01: mussel
# From mustard.n.03: mustard_greens
# From nectarine.n.02: nectarine
# From noodle.n.01: box_of_noodles, pack_of_ramen, noodle
# From onion.n.03: onion
# From orange.n.01: half_orange, orange, orange_heap, bag_of_oranges
# From pancake.n.01: pancake
# From parmesan.n.01: parmesan_cheese
# From pasta.n.02: pasta
# From pea.n.01: pea, peas
# From peach.n.03: half_peach, peach
# From pear.n.01: half_pear, pear, pear_heap
# From pieplant.n.01: rhubarb
# From pineapple.n.02: half_pineapple, pineapple
# From plum.n.02: half_plum, plum
# From pomegranate.n.02: half_pomegranate, pomegranate
# From pomelo.n.02: half_pomelo, pomelo
# From pork.n.01: pork
# From porkchop.n.01: pork_chop
# From potato.n.01: potato
# From pretzel.n.01: pretzel
# From prosciutto.n.01: prosciutto
# From pumpkin.n.02: pumpkin
# From quail.n.01: quail_breast, quail_breast_raw, quail_leg
# From radish.n.01: radish
# From raisin.n.01: raisins_pile
# From raspberry.n.02: raspberry, box_of_raspberries, raspberries
# From rib.n.03: rib, pork_rib
# From rutabaga.n.01: rutabaga
# From sausage.n.01: sausage
# From scone.n.01: scone
# From seafood.n.01: seafood
# From spinach.n.02: spinach
# From squash.n.02: squash
# From squid.n.01: squid
# From steak.n.01: steak
# From strawberry.n.01: half_strawberry, strawberry, strawberries
# From tart.n.02: tart
# From tomato.n.01: half_tomato, tomato
# From tortilla.n.01: tortilla
# From tuna.n.02: tuna
# From turnip.n.02: turnip
# From vidalia_onion.n.01: half_vidalia_onion, vidalia_onion
# From wafer.n.02: wafer
# From waffle.n.01: waffle
# From watermelon.n.02: watermelon
# From white_chocolate.n.01: white_chocolate
# From yogurt.n.01: yogurt, box_of_yogurt
# From zucchini.n.02: zucchini
#
# Synset computer.n.01 gets the below objects:
# From desktop_computer.n.01: desktop_computer
# From laptop.n.01: laptop
#
# Synset meal.n.01 gets the below objects:
# From bite.n.04: trail_mix
#
# Synset softener.n.01 gets the below objects:
# From conditioner.n.03: conditioner, fabric_softener
#
# Synset box.n.01 gets the below objects:
# From box.n.01: storage_box, gift_box, box
# From carton.n.02: carton
# From cash_register.n.01: credit_card_terminal, cash_register
# From chest.n.02: chest
# From crate.n.01: crate
# From litter_box.n.01: litter_boxh
# From mailbox.n.01: mailbox
# From matchbox.n.01: match_box
# From pencil_box.n.01: pencil_box, pencil_case
# From pizza_box.n.01: pizza_box
# From shoebox.n.02: shoe_box
# From toolbox.n.01: toolbox
# From toy_box.n.01: toy_box
#
# Synset edge_tool.n.01 gets the below objects:
# From ax.n.01: axe
# From carving_knife.n.01: carving_knife
# From chisel.n.01: chisel
# From cleaver.n.01: cleaver
# From knife.n.01: knife, utility_knife
# From pocketknife.n.01: pocketknife
# From razor.n.01: razor
# From scissors.n.01: scissors
# From table_knife.n.01: table_knife
# From wire_cutter.n.01: wire_cutter
#
# Synset dispenser.n.01 gets the below objects:
# From atomizer.n.01: atomizer
# From dispenser.n.01: toilet_paper_dispenser, paper_towel_dispenser, candy_dispenser_shelf, dry_food_dispenser_shelf, drink_dispenser, water_dispenser
# From inhaler.n.01: inhaler
# From soap_dispenser.n.01: soap_dispenser, wall_mounted_soap_dispenser
#
# Synset game.n.09 gets the below objects:
# From puzzle.n.02: puzzle, puzzle_piece
#
# Synset oven.n.01 gets the below objects:
# From broiler.n.01: broiler
# From oven.n.01: oven
#
# Synset sign.n.02 gets the below objects:
# From poster.n.01: poster
# From sign.n.02: sign
#
# Synset lamp.n.02 gets the below objects:
# From floor_lamp.n.01: floor_lamp, garden_light
# From table_lamp.n.01: table_lamp
#
# Synset foodstuff.n.02 gets the below objects:
# From aioli.n.01: garlic_sauce
# From allspice.n.03: allspice
# From bagel.n.01: bagel
# From baguet.n.01: baguette
# From barbecue_sauce.n.01: barbecue_sauce
# From basil.n.03: basil, basil_leaf
# From bay_leaf.n.01: bay_leaf, bay_leaves
# From biscuit.n.01: biscuit
# From bread.n.01: bag_of_bread, bread
# From brown_rice.n.01: brown_rice
# From brown_sugar.n.01: brown_sugar, box_of_brown_sugar
# From bun.n.01: bun, hotdog_bun
# From butter.n.01: butter, box_of_butter
# From buttermilk.n.01: buttermilk
# From canned_food.n.01: canned_food
# From carrot_juice.n.01: carrot_juice
# From catsup.n.01: catsup, ketchup
# From cheese.n.01: cheese
# From chinese_anise.n.02: star_anise
# From chocolate_milk.n.01: chocolate_milk
# From chocolate_sauce.n.01: chocolate_syrup
# From cinnamon.n.03: cinnamon
# From clove.n.03: clove, garlic_clove
# From clove.n.04: ground_clove
# From cocoa.n.02: bag_of_cocoa
# From coconut_milk.n.01: coconut_water, coconut_milk
# From coloring.n.01: food_coloring
# From cracker.n.01: cracker_box, cracker
# From cream.n.02: cream, creamer_single
# From cream_cheese.n.01: bag_of_cream_cheese
# From crescent_roll.n.01: croissant
# From crouton.n.01: crouton, crouton
# From curry_powder.n.01: curry_powder
# From danish.n.02: cheese_danish
# From dill_seed.n.01: dill_seed
# From dough.n.01: dough, dough, pizza_dough
# From egg.n.02: egg, egg_carton
# From fennel.n.04: fennel
# From flavorer.n.01: poultry_seasoning
# From flour.n.01: flour, bag_of_flour
# From french_fries.n.01: piece_of_fries
# From ginger.n.02: ginger
# From green_tea.n.01: green_tea, matcha
# From guacamole.n.01: guacamole
# From hot_sauce.n.01: hot_sauce, sriracha
# From hummus.n.01: hummus
# From juice.n.01: juice, vegetable_juice
# From lime_juice.n.01: lime_juice
# From mace.n.03: ground_mace
# From maple_syrup.n.01: maple_syrup
# From mayonnaise.n.01: mayonnaise
# From meat_loaf.n.01: meatloaf
# From milk.n.01: milk, bottle_of_milk, carton_of_milk, box_of_milk, almond_milk
# From mint.n.04: mint_leaf, mint
# From miso.n.01: miso
# From mix.n.01: mix
# From molasses.n.01: molasses
# From muffin.n.01: muffin
# From mushroom_sauce.n.01: mushroom_sauce
# From mustard.n.02: mustard
# From mustard_seed.n.01: mustard_seed
# From nutmeg.n.02: ground_nutmeg
# From olive.n.04: olive
# From papaya_juice.n.01: bottle_of_papaya_juice
# From paprika.n.02: paprika, paprika
# From parmesan.n.01: parmesan_cheese
# From parsley.n.02: parsley
# From pastry.n.01: pastry
# From peanut_butter.n.01: peanut_butter
# From pepper.n.03: peppercorn, pepper, peppercorn
# From pesto.n.01: pesto
# From pickle.n.01: pickle
# From popcorn.n.02: bag_of_popcorn
# From poppy_seed.n.01: poppy_seed
# From potato.n.01: potato
# From pretzel.n.01: pretzel
# From pumpkin_pie_spice.n.01: pumpkin_pie_spice
# From rice.n.01: rice_box, rice_bag, rice
# From rosemary.n.02: rosemary
# From sage.n.02: sage, sage
# From salsa.n.01: salsa
# From salt.n.02: salt, box_of_salt
# From sauce.n.01: orange_sauce, lemon_sauce
# From scone.n.01: scone
# From sesame_seed.n.01: sesame_seed, sesame_seeds
# ...
# From stool.n.01: stool
# From straight_chair.n.01: straight_chair
# From swivel_chair.n.01: swivel_chair
#
# Synset coat.n.01 gets the below objects:
# From blazer.n.01: blazer
# From coat.n.01: coat
# From jacket.n.01: jacket
# From raincoat.n.01: raincoat
#
# Synset leaf.n.01 gets the below objects:
# From greenery.n.01: greenery
# From petal.n.01: flower_petal
#
# Synset cleansing_agent.n.01 gets the below objects:
# From cleansing_agent.n.01: degreaser, glass_cleaner, jewelry_cleaner
# From detergent.n.02: detergent
# From liquid_soap.n.01: body_wash
# From shampoo.n.01: shampoo
# From soap.n.01: soap, body_scrub, dish_soap
# From toothpaste.n.01: toothpaste
#
# Synset eraser.n.01 gets the below objects:
# From blackboard_eraser.n.01: blackboard_eraser
# From eraser.n.01: eraser
#
# Synset coffee_maker.n.01 gets the below objects:
# From coffee_maker.n.01: coffee_maker, french_press
# From espresso_maker.n.01: espresso_machine
#
# Synset bin.n.01 gets the below objects:
# From ashcan.n.01: trash_can
# From recycling_bin.n.01: compost_bin
#
# Synset book.n.02 gets the below objects:
# From hardback.n.01: hardback
# From notebook.n.01: notebook
# From paperback_book.n.01: paperback_book
#
# Synset baggage.n.01 gets the below objects:
# From bag.n.06: suitcase
#
# Synset medicine.n.02 gets the below objects:
# From antihistamine.n.01: antihistamines
# From aspirin.n.01: aspirin
# From baby_oil.n.01: baby_oil
# From lip_balm.n.01: lip_balm
# From medicine.n.02: medicine
# From pill.n.02: pill
# From powder.n.03: powder_bottle
#
# Synset sandwich.n.01 gets the below objects:
# From hamburger.n.01: hamburger
# From hotdog.n.02: hotdog
# From sandwich.n.01: sandwich
#
# Synset milk.n.01 gets the below objects:
# From buttermilk.n.01: buttermilk
# From chocolate_milk.n.01: chocolate_milk
# From milk.n.01: milk, bottle_of_milk, carton_of_milk, box_of_milk, almond_milk
#
# Synset toiletry.n.01 gets the below objects:
# From cold_cream.n.01: face_cream, moisture_wash
# From cologne.n.02: cologne
# From deodorant.n.01: deodorant
# From eyeshadow.n.01: eyeshadow, eyeshadow
# From hair_spray.n.01: hair_spray, hair_conditioner
# From lipstick.n.01: lipstick
# From lotion.n.01: lotion
# From nail_polish.n.01: nail_polish
# From perfume.n.02: perfume, box_of_perfume
# From powder.n.03: powder_bottle
# From sunscreen.n.01: sunscreen
# From toothbrush.n.01: toothbrush
#
# Synset soup.n.01 gets the below objects:
# From chowder.n.01: chowder
# From gazpacho.n.01: gazpacho
# From soup.n.01: soup, bottle_of_soup
#
# Synset edible_nut.n.01 gets the below objects:
# From almond.n.02: almond
# From chestnut.n.03: chestnut, half_chestnut
# From pistachio.n.02: pistachio
# From walnut.n.01: walnut
#
# Synset bathtub.n.01 gets the below objects:
# From bathtub.n.01: bathtub, round_bathtub
# From hot_tub.n.01: hot_tub
#
# Synset tree.n.01 gets the below objects:
# From hazelnut.n.01: hazelnut, hazlenut
# From holly.n.01: holly, holly
# From lemon.n.03: lemon_tree
# From papaya.n.01: papaya
# From pine.n.01: evergreen_tree
# From tree.n.01: tree
#
# Synset food.n.01 gets the below objects:
# From aioli.n.01: garlic_sauce
# From alcohol.n.01: alcohol
# From allspice.n.03: allspice
# From apple_juice.n.01: apple_juice
# From bagel.n.01: bagel
# From baguet.n.01: baguette
# From barbecue_sauce.n.01: barbecue_sauce
# From basil.n.03: basil, basil_leaf
# From bay_leaf.n.01: bay_leaf, bay_leaves
# From beer.n.01: beer, beer_box
# From bird_feed.n.01: birdseed
# From biscuit.n.01: biscuit
# From bite.n.04: trail_mix
# From blueberry_mousse.n.01: blueberry_mousse
# From brandy.n.01: brandy
# From bread.n.01: bag_of_bread, bread
# From brown_rice.n.01: brown_rice
# From brown_sugar.n.01: brown_sugar, box_of_brown_sugar
# From bun.n.01: bun, hotdog_bun
# From burrito.n.01: burrito
# From butter.n.01: butter, box_of_butter
# From buttermilk.n.01: buttermilk
# From candy.n.01: candy_box, candy
# From candy_cane.n.01: candy_cane
# From canned_food.n.01: canned_food
# From cappuccino.n.01: cappuccino
# From carrot_juice.n.01: carrot_juice
# From cat_food.n.01: cat_food
# From catsup.n.01: catsup, ketchup
# From champagne.n.01: champagne_bottle, box_of_champagne
# From cheese.n.01: cheese
# From chinese_anise.n.02: star_anise
# From chip.n.04: chip
# From chocolate_milk.n.01: chocolate_milk
# From chocolate_sauce.n.01: chocolate_syrup
# From chowder.n.01: chowder
# From cider.n.01: apple_cider
# From cinnamon.n.03: cinnamon
# From clove.n.03: clove, garlic_clove
# From clove.n.04: ground_clove
# From cocoa.n.01: hot_chocolate
# From cocoa.n.02: bag_of_cocoa
# From coconut_milk.n.01: coconut_water, coconut_milk
# From coffee.n.01: coffee_pouch, coffee_cup, coffee_box, bottle_of_coffee, coffee
# From coloring.n.01: food_coloring
# From conserve.n.01: conserve
# From cracker.n.01: cracker_box, cracker
# From cranberry_juice.n.01: cranberry_juice
# From cream.n.02: cream, creamer_single
# From cream_cheese.n.01: bag_of_cream_cheese
# From crescent_roll.n.01: croissant
# From crouton.n.01: crouton, crouton
# From curry_powder.n.01: curry_powder
# From custard.n.01: custard_bowl
# From danish.n.02: cheese_danish
# From dill_seed.n.01: dill_seed
# From dog_food.n.01: dog_food, dog_food
# From dough.n.01: dough, dough, pizza_dough
# From easter_egg.n.01: easter_egg
# From egg.n.02: egg, egg_carton
# From fennel.n.04: fennel
# From flavorer.n.01: poultry_seasoning
# From flour.n.01: flour, bag_of_flour
# From french_fries.n.01: piece_of_fries
# From french_toast.n.01: french_toast
# From fruit_punch.n.01: fruit_punch
# From gazpacho.n.01: gazpacho
# From gin.n.01: gin_bottle
# From ginger.n.02: ginger
# From ginger_beer.n.01: ginger_beer
# From green_tea.n.01: green_tea, matcha
# From guacamole.n.01: guacamole
# From hamburger.n.01: hamburger
# From hay.n.01: haystack
# From hot_sauce.n.01: hot_sauce, sriracha
# From hotdog.n.02: hotdog
# From hummus.n.01: hummus
# From ice_cream.n.01: bag_of_ice_cream, box_of_ice_cream
# From ice_lolly.n.01: popsicle
# From ice_tea.n.01: can_of_icetea
# From iced_coffee.n.01: frappuccino
# From jam.n.01: jam, jam_dispenser
# From jelly_bean.n.01: jelly_bean
# From juice.n.01: juice, vegetable_juice
# From kabob.n.01: kebab
# From lasagna.n.01: lasagna, box_of_lasagna
# From lemonade.n.01: bottle_of_lemonade
# From lime_juice.n.01: lime_juice
# From lollipop.n.02: lollipop
# From mace.n.03: ground_mace
# From maple_syrup.n.01: maple_syrup
# From marshmallow.n.01: marshmallow
# From martini.n.01: martini
# From mayonnaise.n.01: mayonnaise
# From meat_loaf.n.01: meatloaf
# From milk.n.01: milk, bottle_of_milk, carton_of_milk, box_of_milk, almond_milk
# From mint.n.04: mint_leaf, mint
# From miso.n.01: miso
# From mix.n.01: mix
# From molasses.n.01: molasses
# From muffin.n.01: muffin
# From mushroom_sauce.n.01: mushroom_sauce
# From mustard.n.02: mustard
# From mustard_seed.n.01: mustard_seed
# From nacho.n.01: nachos
# From nutmeg.n.02: ground_nutmeg
# From oatmeal.n.01: oatmeal, box_of_oatmeal, oatmeal_pile
# From olive.n.04: olive
# From omelet.n.01: omelet
# From orange_juice.n.01: carton_of_orange_juice, bottle_of_orange_juice, orange_juice
# From papaya_juice.n.01: bottle_of_papaya_juice
# From paprika.n.02: paprika, paprika
# From parmesan.n.01: parmesan_cheese
# From parsley.n.02: parsley
# From pastry.n.01: pastry
# From peanut_butter.n.01: peanut_butter
# From pepper.n.03: peppercorn, pepper, peppercorn
# From pesto.n.01: pesto
# From petfood.n.01: pet_food
# From pickle.n.01: pickle
# From pineapple_juice.n.01: carton_of_pineapple_juice
# From pizza.n.01: pizza
# From pop.n.02: pop, pop_case
# From popcorn.n.02: bag_of_popcorn
# From poppy_seed.n.01: poppy_seed
# From potato.n.01: potato
# From pretzel.n.01: pretzel
# From pumpkin_pie_spice.n.01: pumpkin_pie_spice
# From puree.n.01: puree
# From ramekin.n.01: ramekin
# From red_wine.n.01: red_wine
# From rice.n.01: rice_box, rice_bag, rice
# From risotto.n.01: risotto
# From rosemary.n.02: rosemary
# From rum.n.01: rum_bottle, box_of_rum, rum
# From sage.n.02: sage, sage
# From sake.n.02: box_of_sake, sake_bottle
# From salad.n.01: salad
# From salsa.n.01: salsa
# From salt.n.02: salt, box_of_salt
# From sandwich.n.01: sandwich
# From sauce.n.01: orange_sauce, lemon_sauce
# From schnitzel.n.01: schnitzel
# From scone.n.01: scone
# From scrambled_eggs.n.01: scrambled_eggs
# From sesame_seed.n.01: sesame_seed, sesame_seeds
# From smoothie.n.02: smoothie
# From soup.n.01: soup, bottle_of_soup
# From sour_cream.n.01: sour_cream
# From soya_milk.n.01: bottle_of_soy_milk, carton_of_soy_milk, soy_milk
# From spaghetti.n.01: spaghetti
# From spaghetti_sauce.n.01: spaghetti_sauce
# From spice.n.02: spice, savory_spice
# From sugar.n.01: sugar_jar, sugar
# From sushi.n.01: sushi
# From sweet_corn.n.02: sweet_corn, canned_corn
# From taco.n.02: taco
# From tea.n.01: tea_bottle
# From tea.n.05: tea, box_of_tea, bag_of_tea, tea_leaf, tea_leaves
# From tea_bag.n.01: tea_bag
# From tequila.n.01: tequilla
# From tiramisu.n.01: tiramisu
# From tomato_juice.n.01: tomato_juice
# From tomato_paste.n.01: tomato_paste, tomato_puree
# From tomato_sauce.n.01: tomato_sauce
# From tonic.n.01: bottle_of_tonic
# From tortilla_chip.n.01: tortilla_chips
# From vinegar.n.01: vinegar, balsamic_vinegar
# From vitamin_pill.n.01: vitamin
# From vodka.n.01: vodka
# From water.n.06: water
# From whiskey.n.01: box_of_whiskey
# From wine.n.01: box_of_wine
# From yogurt.n.01: yogurt, box_of_yogurt
#
# Synset flavorer.n.01 gets the below objects:
# From aioli.n.01: garlic_sauce
# From allspice.n.03: allspice
# From barbecue_sauce.n.01: barbecue_sauce
# From basil.n.03: basil, basil_leaf
# From bay_leaf.n.01: bay_leaf, bay_leaves
# From brown_sugar.n.01: brown_sugar, box_of_brown_sugar
# From catsup.n.01: catsup, ketchup
# From chinese_anise.n.02: star_anise
# From chocolate_sauce.n.01: chocolate_syrup
# From cinnamon.n.03: cinnamon
# From clove.n.03: clove, garlic_clove
# From clove.n.04: ground_clove
# From curry_powder.n.01: curry_powder
# From dill_seed.n.01: dill_seed
# From fennel.n.04: fennel
# From flavorer.n.01: poultry_seasoning
# From ginger.n.02: ginger
# From green_tea.n.01: green_tea, matcha
# From guacamole.n.01: guacamole
# From hot_sauce.n.01: hot_sauce, sriracha
# From hummus.n.01: hummus
# From mace.n.03: ground_mace
# From maple_syrup.n.01: maple_syrup
# From mayonnaise.n.01: mayonnaise
# From mint.n.04: mint_leaf, mint
# From miso.n.01: miso
# From molasses.n.01: molasses
# From mushroom_sauce.n.01: mushroom_sauce
# From mustard.n.02: mustard
# From mustard_seed.n.01: mustard_seed
# From nutmeg.n.02: ground_nutmeg
# From olive.n.04: olive
# From paprika.n.02: paprika, paprika
# From parsley.n.02: parsley
# From peanut_butter.n.01: peanut_butter
# From pepper.n.03: peppercorn, pepper, peppercorn
# From pesto.n.01: pesto
# From pickle.n.01: pickle
# From poppy_seed.n.01: poppy_seed
# From pumpkin_pie_spice.n.01: pumpkin_pie_spice
# From rosemary.n.02: rosemary
# From sage.n.02: sage, sage
# From salsa.n.01: salsa
# From salt.n.02: salt, box_of_salt
# From sauce.n.01: orange_sauce, lemon_sauce
# From sesame_seed.n.01: sesame_seed, sesame_seeds
# From spaghetti_sauce.n.01: spaghetti_sauce
# From spice.n.02: spice, savory_spice
# From sugar.n.01: sugar_jar, sugar
# From tea.n.05: tea, box_of_tea, bag_of_tea, tea_leaf, tea_leaves
# From tea_bag.n.01: tea_bag
# From tomato_sauce.n.01: tomato_sauce
# From vinegar.n.01: vinegar, balsamic_vinegar
#
# Synset paper.n.01 gets the below objects:
# From notepad.n.01: notepad
# From pad.n.01: sticky_note
# From sheet.n.02: paper_sheet
# From tissue.n.02: tissue_dispenser, box_of_tissue
# From toilet_tissue.n.01: toilet_paper
# From wallpaper.n.01: wallpaper
# From wax_paper.n.01: parchment_paper
# From wrapping_paper.n.01: wrapping_paper
#
# Synset lighter.n.02 gets the below objects:
# From lighter.n.02: lighter
# From match.n.01: match
#
# Synset pan.n.01 gets the below objects:
# From electric_frying_pan.n.01: deep_fryer
# From frying_pan.n.01: frying_pan
# From pan.n.01: roasting_pan
# From saucepan.n.01: saucepan
# From wok.n.01: wok
#
# Synset holding_device.n.01 gets the below objects:
# From candelabrum.n.01: candle_holder
# From clamp.n.01: buret_clamp, flask_clamp, test_tube_clamp, clamp
# From holder.n.01: paper_towel_holder, pencil_holder, toilet_paper_holder
#
# Synset printer.n.03 gets the below objects:
# From printer.n.02: printer
#
# Synset sports_equipment.n.01 gets the below objects:
# From baseball.n.02: baseball
# From baseball_glove.n.01: garden_glove, baseball_glove
# From basket.n.03: ceiling_mounted_basketball_hoop
# From batting_glove.n.01: batting_gloves
# From boxing_glove.n.01: boxing_gloves
# From golf_club.n.02: golf_club
# From hockey_stick.n.01: hockey_stick
# From ice_skate.n.01: ice_skates, skates
# From mat.n.03: gym_mat
# From parallel_bars.n.01: parallel_bars
# From pommel_horse.n.01: pommel_horse
# From weight.n.02: free_weight
#
# Synset shirt.n.01 gets the below objects:
# From jersey.n.03: t-shirt, jersey
# From polo_shirt.n.01: polo_shirt
# From shirt.n.01: shirt
# From tank_top.n.01: tank_top
# From turtleneck.n.01: turtleneck
#
# Synset lamp.n.01 gets the below objects:
# From candle.n.01: candle
# From flashlight.n.01: flashlight
# From lantern.n.01: lantern
# From light_bulb.n.01: light_bulb, bulb
# From spirit_lamp.n.01: spirit_lamp
# From spotlight.n.02: spotlight
#
# Synset bag.n.04 gets the below objects:
# From bag.n.04: purse
# From shoulder_bag.n.01: shoulder_bag
#
# Synset cooking_utensil.n.01 gets the below objects:
# From caldron.n.01: cauldron
# From coffeepot.n.01: coffeepot
# From cooker.n.01: canner, canner_lid, rice_cooker, slow_cooker
# From cookie_sheet.n.01: baking_sheet
# From crock_pot.n.01: oden_cooker, crock_pot, instant_pot
# From dutch_oven.n.02: dutch_oven
# From electric_frying_pan.n.01: deep_fryer
# From frying_pan.n.01: frying_pan
# From griddle.n.01: griddle
# From kettle.n.01: kettle, electric_kettle
# From pan.n.01: roasting_pan
# From popper.n.03: popcorn_machine
# From saucepan.n.01: saucepan
# From saucepot.n.01: saucepot
# From skimmer.n.02: skimmer
# From spatula.n.01: spatula
# From steamer.n.02: steamer, zhenglong, steamer_basket
# From stockpot.n.01: stockpot
# From teapot.n.01: teapot
# From wok.n.01: wok
#
# Synset rock.n.01 gets the below objects:
# From crystal.n.03: crystal
# From rock.n.01: rock
# From stepping_stone.n.01: stepping_stone
#
# Synset crumb.n.03 gets the below objects:
# From breadcrumb.n.01: breadcrumbs
# From crumb.n.03: crumb
#
# Synset cushion.n.03 gets the below objects:
# From pillow.n.01: pillow
#
# Synset wrapping.n.01 gets the below objects:
# From cellophane.n.01: cellophane
# From plastic_wrap.n.01: plastic_wrap
# From wrapping.n.01: wrapped_gift
#
# Synset book.n.01 gets the below objects:
# From textbook.n.01: textbook
#
# Synset flask.n.01 gets the below objects:
# From erlenmeyer_flask.n.01: erlenmeyer_flask
# From flask.n.01: round_bottom_flask, flask, flask
#
# Synset can.n.01 gets the below objects:
# From can.n.01: canned_coffee, canned_sardines, canned_tomatoes
# From soda_can.n.01: soda_can
#
# Synset boat.n.01 gets the below objects:
# From boat.n.01: boat
# From kayak.n.01: kayak
#
# Synset fertilizer.n.01 gets the below objects:
# From fertilizer.n.01: fertilizer_bag
# From manure.n.01: manure
#
# Synset slab.n.01 gets the below objects:
# From tile.n.01: tile, ceramic_tile
#
# Synset loaf_of_bread.n.01 gets the below objects:
# From meat_loaf.n.01: meatloaf
#
# Synset baked_goods.n.01 gets the below objects:
# From apple_pie.n.01: apple_pie
# From bagel.n.01: bagel
# From baguet.n.01: baguette
# From biscuit.n.01: biscuit
# From bread.n.01: bag_of_bread, bread
# From brownie.n.03: brownie
# From bun.n.01: bun, hotdog_bun
# From cake.n.03: box_of_cake, cake
# From chocolate_cake.n.01: chocolate_cake_slice
# From cookie.n.01: cookie, bag_of_cookie, box_of_cookie
# From cracker.n.01: cracker_box, cracker
# From crescent_roll.n.01: croissant
# From crouton.n.01: crouton, crouton
# From cupcake.n.01: cupcake
# From danish.n.02: cheese_danish
# From doughnut.n.02: donut
# From gingerbread.n.01: gingerbread
# From granola_bar.n.01: box_of_granola_bar, granola_bar
# From meat_loaf.n.01: meatloaf
# From muffin.n.01: muffin
# From pancake.n.01: pancake
# From pretzel.n.01: pretzel
# From scone.n.01: scone
# From tart.n.02: tart
# From tortilla.n.01: tortilla
# From wafer.n.02: wafer
# From waffle.n.01: waffle
#
# Synset petfood.n.01 gets the below objects:
# From cat_food.n.01: cat_food
# From dog_food.n.01: dog_food, dog_food
# From petfood.n.01: pet_food
#
# Synset cream.n.02 gets the below objects:
# From cream.n.02: cream, creamer_single
# From sour_cream.n.01: sour_cream
#
# Synset glove.n.02 gets the below objects:
# From batting_glove.n.01: batting_gloves
# From glove.n.02: glove
# From goalkeeper_gloves.n.01: goalkeeper_gloves
