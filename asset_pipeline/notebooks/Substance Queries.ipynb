# %%
from bddl.knowledge_base import *
# Out:
# Loading BDDL knowledge base... This may take a few seconds.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cgokmen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Complained object qwoqqr does not exist in the database. Skipping.
# Complained object dnypbe does not exist in the database. Skipping.
# Complained object upmkjr does not exist in the database. Skipping.
# Complained object wmchsj does not exist in the database. Skipping.
# Complained object uqusgj does not exist in the database. Skipping.
# Complained object urmqxk does not exist in the database. Skipping.
# Complained object aginyz does not exist in the database. Skipping.
# Complained object pcpvvu does not exist in the database. Skipping.
# Complained object fveyao does not exist in the database. Skipping.
# Complained object knunaz does not exist in the database. Skipping.
# Complained object didlbp does not exist in the database. Skipping.
# Complained object didlbp does not exist in the database. Skipping.
# Complained object zmodhv does not exist in the database. Skipping.
# Complained object zmodhv does not exist in the database. Skipping.
# Complained object oxglnt does not exist in the database. Skipping.
# Complained object gfgnbf does not exist in the database. Skipping.
# Complained object gfgnbf does not exist in the database. Skipping.
# Complained object iomnix does not exist in the database. Skipping.
# Complained object iomnix does not exist in the database. Skipping.
# Complained object obvwkc does not exist in the database. Skipping.
# Complained object iiugii does not exist in the database. Skipping.
# Complained object qnciwe does not exist in the database. Skipping.
# Complained object vbwsci does not exist in the database. Skipping.
# Complained object ociqav does not exist in the database. Skipping.
# Complained object wxodip does not exist in the database. Skipping.
# Complained object hkwatn does not exist in the database. Skipping.
# Complained object qkuaff does not exist in the database. Skipping.
# Complained object tnchbi does not exist in the database. Skipping.
# Complained object tqbfsl does not exist in the database. Skipping.
# Complained object bjyvil does not exist in the database. Skipping.
# Complained object smlors does not exist in the database. Skipping.
# Complained object yzplpe does not exist in the database. Skipping.
# Complained object dddvjo does not exist in the database. Skipping.
# Complained object glbxff does not exist in the database. Skipping.
# Complained object fwlxwe does not exist in the database. Skipping.
# Complained object asjalm does not exist in the database. Skipping.
# Complained object orntct does not exist in the database. Skipping.
# Complained object orntct does not exist in the database. Skipping.
# Complained object udyhsc does not exist in the database. Skipping.
# Complained object vbjpad does not exist in the database. Skipping.
# Complained object cstgzt does not exist in the database. Skipping.
# Complained object acugsx does not exist in the database. Skipping.
# Complained object autzye does not exist in the database. Skipping.
# Complained object avbnnx does not exist in the database. Skipping.
# Complained object cegpja does not exist in the database. Skipping.
# Complained object dohvvk does not exist in the database. Skipping.
# Complained object edumiy does not exist in the database. Skipping.
# Complained object ffybck does not exist in the database. Skipping.
# Complained object hltkbe does not exist in the database. Skipping.
# Complained object iobzfe does not exist in the database. Skipping.
# Complained object ispfoo does not exist in the database. Skipping.
# Complained object jamapi does not exist in the database. Skipping.
# Complained object keugzu does not exist in the database. Skipping.
# Complained object klcxyf does not exist in the database. Skipping.
# Complained object kuhhbl does not exist in the database. Skipping.
# Complained object ndfsrm does not exist in the database. Skipping.
# Complained object nnxsjd does not exist in the database. Skipping.
# Complained object nvykqp does not exist in the database. Skipping.
# Complained object ogrxqz does not exist in the database. Skipping.
# Complained object onrszv does not exist in the database. Skipping.
# Complained object orjpqs does not exist in the database. Skipping.
# Complained object penqpk does not exist in the database. Skipping.
# Complained object pffhuv does not exist in the database. Skipping.
# Complained object pohzfc does not exist in the database. Skipping.
# Complained object potacy does not exist in the database. Skipping.
# Complained object pqbutt does not exist in the database. Skipping.
# Complained object qwwinf does not exist in the database. Skipping.
# Complained object rqcytb does not exist in the database. Skipping.
# Complained object rstyxz does not exist in the database. Skipping.
# Complained object tcrhve does not exist in the database. Skipping.
# Complained object tghwgm does not exist in the database. Skipping.
# Complained object vqgvuw does not exist in the database. Skipping.
# Complained object vtwnqs does not exist in the database. Skipping.
# Complained object xayqcu does not exist in the database. Skipping.
# Complained object xsfcrp does not exist in the database. Skipping.
# Complained object yijzob does not exist in the database. Skipping.
# Complained object ynporc does not exist in the database. Skipping.
# Complained object yorsom does not exist in the database. Skipping.
# Complained object zpsuqe does not exist in the database. Skipping.
# Complained object ovzepp does not exist in the database. Skipping.

# %%
# Get the substance synsets that are missing a system
for s in Synset.all_objects():
  if s.is_substance and len(s.matching_particle_systems) == 0:
    print(s)

# %%
# Get the particle systems that are missing a particle
missing_particle = ParticleSystem.view_error_missing_particle()
print(len(missing_particle))
# Out:
# 57

# %%
# Remove the particle systems that are cooked
missing_particle_not_cooked = [ps for ps in missing_particle if "cooked__" not in ps.name]
print(len(missing_particle_not_cooked))
print(missing_particle_not_cooked)
# Out:
# 28
# [ParticleSystem(name='clove', parameters='{"type": "granular", "particle_density": 1050.0}'), ParticleSystem(name='coconut', parameters='{"type": "macro_physical_particle", "particle_density": 1000.0}'), ParticleSystem(name='diced__apple', parameters='{"type": "macro_physical_particle", "particle_density": 465.0}'), ParticleSystem(name='diced__avocado', parameters='{"type": "macro_physical_particle", "particle_density": 634.0}'), ParticleSystem(name='diced__beefsteak_tomato', parameters='{"type": "macro_physical_particle", "particle_density": 630.0}'), ParticleSystem(name='diced__beet', parameters='{"type": "macro_physical_particle", "particle_density": 575.0}'), ParticleSystem(name='diced__bell_pepper', parameters='{"type": "macro_physical_particle", "particle_density": 630.0}'), ParticleSystem(name='diced__carrot', parameters='{"type": "macro_physical_particle", "particle_density": 465.0}'), ParticleSystem(name='diced__cheddar', parameters='{"type": "macro_physical_particle", "particle_density": 947.0}'), ParticleSystem(name='diced__chicken', parameters='{"type": "macro_physical_particle", "particle_density": 866.0}'), ParticleSystem(name='diced__chili', parameters='{"type": "macro_physical_particle", "particle_density": 634.0}'), ParticleSystem(name='diced__clove', parameters='{"type": "macro_physical_particle", "particle_density": 575.0}'), ParticleSystem(name='diced__cucumber', parameters='{"type": "macro_physical_particle", "particle_density": 562.0}'), ParticleSystem(name='diced__feta', parameters='{"type": "macro_physical_particle", "particle_density": 473.0}'), ParticleSystem(name='diced__kiwi', parameters='{"type": "macro_physical_particle", "particle_density": 748.0}'), ParticleSystem(name='diced__lemon', parameters='{"type": "macro_physical_particle", "particle_density": 761.0}'), ParticleSystem(name='diced__lettuce', parameters='{"type": "macro_physical_particle", "particle_density": 148.0}'), ParticleSystem(name='diced__mango', parameters='{"type": "macro_physical_particle", "particle_density": 697.0}'), ParticleSystem(name='diced__pineapple', parameters='{"type": "macro_physical_particle", "particle_density": 732.0}'), ParticleSystem(name='diced__potato', parameters='{"type": "macro_physical_particle", "particle_density": 562.0}'), ParticleSystem(name='diced__spinach', parameters='{"type": "macro_physical_particle", "particle_density": 127.0}'), ParticleSystem(name='diced__vidalia_onion', parameters='{"type": "macro_physical_particle", "particle_density": 676.0}'), ParticleSystem(name='diced__virginia_ham', parameters='{"type": "macro_physical_particle", "particle_density": 592.0}'), ParticleSystem(name='diced__watermelon', parameters='{"type": "macro_physical_particle", "particle_density": 642.0}'), ParticleSystem(name='diced__zucchini', parameters='{"type": "macro_physical_particle", "particle_density": 524.0}'), ParticleSystem(name='granola', parameters='{"type": "macro_physical_particle", "particle_density": 467.0}'), ParticleSystem(name='kidney_bean', parameters='{"type": "macro_physical_particle", "particle_density": 748.0}'), ParticleSystem(name='orzo', parameters='{"type": "macro_physical_particle", "particle_density": 710.0}')]

# %%
# Remove the particle systems that are not diced
missing_particle_not_cooked_not_diced = [ps for ps in missing_particle_not_cooked if "diced__" not in ps.name]
print(len(missing_particle_not_cooked_not_diced))
print(missing_particle_not_cooked_not_diced)
# Out:
# 5
# [ParticleSystem(name='clove', parameters='{"type": "granular", "particle_density": 1050.0}'), ParticleSystem(name='coconut', parameters='{"type": "macro_physical_particle", "particle_density": 1000.0}'), ParticleSystem(name='granola', parameters='{"type": "macro_physical_particle", "particle_density": 467.0}'), ParticleSystem(name='kidney_bean', parameters='{"type": "macro_physical_particle", "particle_density": 748.0}'), ParticleSystem(name='orzo', parameters='{"type": "macro_physical_particle", "particle_density": 710.0}')]

# %%
# Count by group
import collections
ctr = collections.Counter([("cooked__" in ps.name, "diced__" in ps.name) for ps in missing_particle])
print("Uncooked Diced:", ctr[(False, True)])
print("Cooked Diced:", ctr[(True, True)])
print("Uncooked Non-Diced:", ctr[(False, False)])
print("Cooked Non-Diced:", ctr[(True, False)])
# Out:
# Uncooked Diced: 23
# Cooked Diced: 21
# Uncooked Non-Diced: 5
# Cooked Non-Diced: 8

# %%
# How many non-liquid particle systems are there anyway?
print("Total non-liquid particle systems:", sum([1 for s in Synset.all_objects() if s.is_substance and not s.is_liquid]))
# Out:
# Total non-liquid particle systems: 670

# %%
# And how many diced?
print("Total diced particle systems:", sum([1 for s in Synset.all_objects() if s.is_substance and "diced__" in s.name]))
print("Diced particle systems w/ particles:", sum([1 for s in Synset.all_objects() if s.is_substance and "diced__" in s.name and s.state == SynsetState.MATCHED]))
# Out:
# Total diced particle systems: 405
# Diced particle systems w/ particles: 361

# %%
# Get a list of all cookable substances
for s in Synset.all_objects():
  if s.is_substance and "cookable" in s.property_names:
    print(s)
# Out:
# Synset(name='allspice.n.03')
# Synset(name='almond.n.02')
# Synset(name='barbecue_sauce.n.01')
# Synset(name='beaten_egg.n.01')
# Synset(name='beef_broth.n.01')
# Synset(name='beef_stew.n.01')
# Synset(name='beer.n.01')
# Synset(name='black_bean.n.01')
# Synset(name='black_pepper.n.02')
# Synset(name='blueberry.n.02')
# Synset(name='blueberry_compote.n.01')
# Synset(name='blueberry_mousse.n.01')
# Synset(name='breadcrumb.n.01')
# Synset(name='brown_rice.n.01')
# Synset(name='brown_sugar.n.01')
# Synset(name='brownie_batter.n.01')
# Synset(name='cafe_au_lait.n.01')
# Synset(name='cake_mix.n.01')
# Synset(name='cashew.n.02')
# Synset(name='catsup.n.01')
# Synset(name='cayenne.n.02')
# Synset(name='cheese_pastry_filling.n.01')
# Synset(name='cheese_sauce.n.01')
# Synset(name='cherry_filling.n.01')
# Synset(name='chia_seed.n.01')
# Synset(name='chicken_broth.n.01')
# Synset(name='chicken_curry.n.01')
# Synset(name='chicken_soup.n.01')
# Synset(name='chickpea.n.03')
# Synset(name='chocolate_sauce.n.01')
# Synset(name='cinnamon.n.03')
# Synset(name='cinnamon_sugar.n.01')
# Synset(name='clove.n.04')
# Synset(name='coca_cola.n.01')
# Synset(name='cocoa.n.01')
# Synset(name='cocoa_powder.n.01')
# Synset(name='coconut.n.01')
# Synset(name='coconut_oil.n.01')
# Synset(name='coffee_bean.n.01')
# Synset(name='coffee_grounds.n.01')
# Synset(name='cooking_oil.n.01')
# Synset(name='coriander.n.02')
# Synset(name='cornstarch.n.01')
# Synset(name='cranberry.n.02')
# Synset(name='cream_cheese.n.01')
# Synset(name='crouton.n.01')
# Synset(name='cumin.n.02')
# Synset(name='curry_powder.n.01')
# Synset(name='diced__apple.n.01')
# Synset(name='diced__apricot.n.01')
# Synset(name='diced__arepa.n.01')
# Synset(name='diced__artichoke.n.01')
# Synset(name='diced__arugula.n.01')
# Synset(name='diced__asparagus.n.01')
# Synset(name='diced__auricularia.n.01')
# Synset(name='diced__avocado.n.01')
# Synset(name='diced__bacon.n.01')
# Synset(name='diced__bagel.n.01')
# Synset(name='diced__bagel_dough.n.01')
# Synset(name='diced__baguet.n.01')
# Synset(name='diced__banana.n.01')
# Synset(name='diced__banana_bread.n.01')
# Synset(name='diced__bay_leaf.n.01')
# Synset(name='diced__bean_curd.n.01')
# Synset(name='diced__beefsteak_tomato.n.01')
# Synset(name='diced__beet.n.01')
# Synset(name='diced__bell_pepper.n.01')
# Synset(name='diced__biscuit_dough.n.01')
# Synset(name='diced__blackberry.n.01')
# Synset(name='diced__bok_choy.n.01')
# Synset(name='diced__bratwurst.n.01')
# Synset(name='diced__brisket.n.01')
# Synset(name='diced__broccoli.n.01')
# Synset(name='diced__broccoli_rabe.n.01')
# Synset(name='diced__broccolini.n.01')
# Synset(name='diced__brownie.n.01')
# Synset(name='diced__brussels_sprouts.n.01')
# Synset(name='diced__burrito.n.01')
# Synset(name='diced__butter_cookie.n.01')
# Synset(name='diced__buttermilk_pancake.n.01')
# Synset(name='diced__butternut_squash.n.01')
# Synset(name='diced__cantaloup.n.01')
# Synset(name='diced__carne_asada.n.01')
# Synset(name='diced__carrot.n.01')
# Synset(name='diced__cauliflower.n.01')
# Synset(name='diced__celery.n.01')
# Synset(name='diced__chanterelle.n.01')
# Synset(name='diced__chard.n.01')
# Synset(name='diced__cheese_tart.n.01')
# Synset(name='diced__cheesecake.n.01')
# Synset(name='diced__cherry.n.01')
# Synset(name='diced__cherry_tomato.n.01')
# Synset(name='diced__chestnut.n.01')
# Synset(name='diced__chicken.n.01')
# Synset(name='diced__chicken_breast.n.01')
# Synset(name='diced__chicken_leg.n.01')
# Synset(name='diced__chicken_tender.n.01')
# Synset(name='diced__chicken_wing.n.01')
# Synset(name='diced__chili.n.01')
# Synset(name='diced__chives.n.01')
# Synset(name='diced__chocolate_biscuit.n.01')
# Synset(name='diced__chocolate_cake.n.01')
# Synset(name='diced__chocolate_chip_cookie.n.01')
# Synset(name='diced__chocolate_cookie_dough.n.01')
# Synset(name='diced__chorizo.n.01')
# Synset(name='diced__cinnamon_roll.n.01')
# Synset(name='diced__clove.n.01')
# Synset(name='diced__club_sandwich.n.01')
# Synset(name='diced__coconut.n.01')
# Synset(name='diced__cold_cuts.n.01')
# Synset(name='diced__cookie_dough.n.01')
# Synset(name='diced__crab.n.01')
# Synset(name='diced__crayfish.n.01')
# Synset(name='diced__crescent_roll.n.01')
# Synset(name='diced__cucumber.n.01')
# Synset(name='diced__danish.n.01')
# Synset(name='diced__date.n.01')
# Synset(name='diced__doughnut.n.01')
# Synset(name='diced__dried_apricot.n.01')
# Synset(name='diced__duck.n.01')
# Synset(name='diced__durian.n.01')
# Synset(name='diced__edible_cookie_dough.n.01')
# Synset(name='diced__eggplant.n.01')
# Synset(name='diced__enchilada.n.01')
# Synset(name='diced__fennel.n.01')
# Synset(name='diced__fillet.n.01')
# Synset(name='diced__frank.n.01')
# Synset(name='diced__frankfurter_bun.n.01')
# Synset(name='diced__french_fries.n.01')
# Synset(name='diced__french_toast.n.01')
# Synset(name='diced__fruitcake.n.01')
# Synset(name='diced__garlic_bread.n.01')
# Synset(name='diced__gelatin.n.01')
# Synset(name='diced__ginger.n.01')
# Synset(name='diced__gingerbread.n.01')
# Synset(name='diced__gooseberry.n.01')
# Synset(name='diced__gourd.n.01')
# Synset(name='diced__granola_bar.n.01')
# Synset(name='diced__grapefruit.n.01')
# Synset(name='diced__green_bean.n.01')
# Synset(name='diced__green_onion.n.01')
# Synset(name='diced__ham_hock.n.01')
# Synset(name='diced__hamburger.n.01')
# Synset(name='diced__hamburger_bun.n.01')
# Synset(name='diced__hard-boiled_egg.n.01')
# Synset(name='diced__hazelnut.n.01')
# Synset(name='diced__head_cabbage.n.01')
# Synset(name='diced__hip.n.01')
# Synset(name='diced__hotdog.n.01')
# Synset(name='diced__huitre.n.01')
# Synset(name='diced__kabob.n.01')
# Synset(name='diced__kale.n.01')
# Synset(name='diced__kielbasa.n.01')
# Synset(name='diced__kiwi.n.01')
# Synset(name='diced__lamb.n.01')
# Synset(name='diced__leek.n.01')
# Synset(name='diced__lemon.n.01')
# Synset(name='diced__lemon_peel.n.01')
# Synset(name='diced__lettuce.n.01')
# Synset(name='diced__lime.n.01')
# Synset(name='diced__lobster.n.01')
# Synset(name='diced__macaroon.n.01')
# Synset(name='diced__mango.n.01')
# Synset(name='diced__marshmallow.n.01')
# Synset(name='diced__meat_loaf.n.01')
# Synset(name='diced__meatball.n.01')
# Synset(name='diced__melon.n.01')
# Synset(name='diced__muffin.n.01')
# Synset(name='diced__mushroom.n.01')
# Synset(name='diced__mustard.n.01')
# Synset(name='diced__nectarine.n.01')
# Synset(name='diced__olive.n.01')
# Synset(name='diced__omelet.n.01')
# Synset(name='diced__onion.n.01')
# Synset(name='diced__orange.n.01')
# Synset(name='diced__papaya.n.01')
# Synset(name='diced__parsley.n.01')
# Synset(name='diced__parsnip.n.01')
# Synset(name='diced__pastry.n.01')
# Synset(name='diced__peach.n.01')
# Synset(name='diced__pear.n.01')
# Synset(name='diced__peppermint.n.01')
# Synset(name='diced__pepperoni.n.01')
# Synset(name='diced__pieplant.n.01')
# Synset(name='diced__pineapple.n.01')
# Synset(name='diced__pita.n.01')
# Synset(name='diced__pizza.n.01')
# Synset(name='diced__pizza_dough.n.01')
# Synset(name='diced__plum.n.01')
# Synset(name='diced__pomegranate.n.01')
# Synset(name='diced__pomelo.n.01')
# Synset(name='diced__pork.n.01')
# Synset(name='diced__porkchop.n.01')
# Synset(name='diced__potato.n.01')
# Synset(name='diced__prawn.n.01')
# Synset(name='diced__prosciutto.n.01')
# Synset(name='diced__pumpkin.n.01')
# Synset(name='diced__quail.n.01')
# Synset(name='diced__quiche.n.01')
# Synset(name='diced__radish.n.01')
# Synset(name='diced__ramen.n.01')
# Synset(name='diced__rib.n.01')
# Synset(name='diced__roast_beef.n.01')
# Synset(name='diced__roll_dough.n.01')
# Synset(name='diced__rutabaga.n.01')
# Synset(name='diced__salmon.n.01')
# Synset(name='diced__scone.n.01')
# Synset(name='diced__shiitake.n.01')
# Synset(name='diced__snapper.n.01')
# Synset(name='diced__sour_bread.n.01')
# Synset(name='diced__spice_cookie.n.01')
# Synset(name='diced__spice_cookie_dough.n.01')
# Synset(name='diced__spinach.n.01')
# Synset(name='diced__squid.n.01')
# Synset(name='diced__steak.n.01')
# Synset(name='diced__strawberry.n.01')
# Synset(name='diced__sugar_cookie.n.01')
# Synset(name='diced__sugar_cookie_dough.n.01')
# Synset(name='diced__sushi.n.01')
# Synset(name='diced__sweet_corn.n.01')
# Synset(name='diced__taco.n.01')
# Synset(name='diced__tenderloin.n.01')
# Synset(name='diced__toast.n.01')
# Synset(name='diced__tofu.n.01')
# Synset(name='diced__tomato.n.01')
# Synset(name='diced__tortilla.n.01')
# Synset(name='diced__tortilla_chip.n.01')
# Synset(name='diced__trout.n.01')
# Synset(name='diced__tuna.n.01')
# Synset(name='diced__turkey.n.01')
# Synset(name='diced__turkey_leg.n.01')
# Synset(name='diced__vanilla.n.01')
# Synset(name='diced__veal.n.01')
# Synset(name='diced__venison.n.01')
# Synset(name='diced__vidalia_onion.n.01')
# Synset(name='diced__virginia_ham.n.01')
# Synset(name='diced__waffle.n.01')
# Synset(name='diced__walnut.n.01')
# Synset(name='diced__watermelon.n.01')
# Synset(name='diced__white_turnip.n.01')
# Synset(name='diced__whole_garlic.n.01')
# Synset(name='diced__yam.n.01')
# Synset(name='diced__zucchini.n.01')
# Synset(name='dog_food.n.01')
# Synset(name='drip_coffee.n.01')
# Synset(name='eggnog.n.01')
# Synset(name='espresso.n.01')
# Synset(name='flour.n.01')
# Synset(name='fritter_batter.n.01')
# Synset(name='frosting.n.01')
# Synset(name='ginger.n.02')
# Synset(name='granola.n.01')
# Synset(name='granulated_salt.n.01')
# Synset(name='gravy.n.01')
# Synset(name='green_tea.n.01')
# Synset(name='green_tea_latte.n.01')
# Synset(name='ground_beef.n.01')
# Synset(name='ground_coffee.n.01')
# Synset(name='heavy_cream.n.01')
# Synset(name='honey.n.01')
# Synset(name='hot_sauce.n.01')
# Synset(name='hummus.n.01')
# Synset(name='iced_cappuccino.n.01')
# Synset(name='iced_chocolate.n.01')
# Synset(name='instant_coffee.n.01')
# Synset(name='jam.n.01')
# Synset(name='jelly.n.02')
# Synset(name='jelly_bean.n.01')
# Synset(name='jerk_seasoning.n.01')
# Synset(name='jimmies.n.01')
# Synset(name='kidney_bean.n.02')
# Synset(name='lemon-pepper_seasoning.n.01')
# Synset(name='lemon_juice.n.01')
# Synset(name='lemonade.n.01')
# Synset(name='lime_juice.n.01')
# Synset(name='limeade.n.01')
# Synset(name='maple_syrup.n.01')
# Synset(name='marinade.n.01')
# Synset(name='marinara.n.01')
# Synset(name='marjoram.n.02')
# Synset(name='mashed_potato.n.02')
# Synset(name='meringue.n.01')
# Synset(name='milkshake.n.01')
# Synset(name='muffin_batter.n.01')
# Synset(name='mustard.n.02')
# Synset(name='mustard_seed.n.01')
# Synset(name='noodle.n.01')
# Synset(name='nutmeg.n.02')
# Synset(name='oat.n.02')
# Synset(name='olive_oil.n.01')
# Synset(name='onion_powder.n.01')
# Synset(name='onion_ring_batter.n.01')
# Synset(name='orange_juice.n.01')
# Synset(name='orzo.n.01')
# Synset(name='pancake_batter.n.01')
# Synset(name='paprika.n.02')
# Synset(name='pea.n.01')
# Synset(name='peanut.n.04')
# Synset(name='peanut_butter.n.01')
# Synset(name='pecan.n.03')
# Synset(name='penne.n.01')
# Synset(name='pesto.n.01')
# Synset(name='pine_nut.n.01')
# Synset(name='pistachio.n.02')
# Synset(name='popcorn.n.02')
# Synset(name='pumpkin_pie_spice.n.01')
# Synset(name='pumpkin_seed.n.01')
# Synset(name='quinoa.n.01')
# Synset(name='raisin.n.01')
# Synset(name='ravioli.n.01')
# Synset(name='red_meat_sauce.n.01')
# Synset(name='red_wine.n.01')
# Synset(name='refried_beans.n.01')
# Synset(name='risotto.n.01')
# Synset(name='saffron.n.02')
# Synset(name='sage.n.02')
# Synset(name='salsa.n.01')
# Synset(name='salt.n.02')
# Synset(name='scrambled_eggs.n.01')
# Synset(name='sesame_oil.n.01')
# Synset(name='sesame_seed.n.01')
# Synset(name='shortening.n.01')
# Synset(name='soy.n.04')
# Synset(name='soy_sauce.n.01')
# Synset(name='sugar_syrup.n.01')
# Synset(name='sunflower_seed.n.01')
# Synset(name='thyme.n.02')
# Synset(name='tomato_paste.n.01')
# Synset(name='tomato_rice.n.01')
# Synset(name='tomato_sauce.n.01')
# Synset(name='vanilla.n.02')
# Synset(name='vinegar.n.01')
# Synset(name='waffle_batter.n.01')
# Synset(name='water.n.06')
# Synset(name='whipped_cream.n.01')
# Synset(name='white_rice.n.01')
# Synset(name='white_wine.n.01')
# Synset(name='whole_milk.n.01')
# Synset(name='wine_sauce.n.01')
# Synset(name='yogurt.n.01')

# %%
# For all existing particle systems, get the average max extent of their particles
import numpy as np
systems_and_sizes = []
for ps in ParticleSystem.all_objects():
  if not any("macro" in pn for pn in ps.synset.property_names):
    continue
  if len(ps.particles) > 0:
    avg = np.mean([np.max(p.bounding_box_size) for p in ps.particles])
    systems_and_sizes.append((ps, avg))

# Sort by size
systems_and_sizes.sort(key=lambda x: x[1])
for ps, size in systems_and_sizes:
  print(ps, size)
# Out:
# cooked__green_tea 0.003
# grated_cheese 0.003
# green_tea 0.003
# cooked__diced__artichoke 0.005
# cooked__diced__arugula 0.005
# cooked__diced__asparagus 0.005
# cooked__diced__auricularia 0.005
# cooked__diced__bacon 0.005
# cooked__diced__bay_leaf 0.005
# cooked__diced__broccoli_rabe 0.005
# cooked__diced__brussels_sprouts 0.005
# cooked__diced__butter_cookie 0.005
# cooked__diced__buttermilk_pancake 0.005
# cooked__diced__chanterelle 0.005
# cooked__diced__chard 0.005
# cooked__diced__cherry 0.005
# cooked__diced__cherry_tomato 0.005
# cooked__diced__chestnut 0.005
# cooked__diced__chives 0.005
# cooked__diced__chocolate_biscuit 0.005
# cooked__diced__chocolate_chip_cookie 0.005
# cooked__diced__cold_cuts 0.005
# cooked__diced__date 0.005
# cooked__diced__dried_apricot 0.005
# cooked__diced__gelatin 0.005
# cooked__diced__ginger 0.005
# cooked__diced__gingerbread 0.005
# cooked__diced__green_bean 0.005
# cooked__diced__hard_boiled_egg 0.005
# cooked__diced__hazelnut 0.005
# cooked__diced__kale 0.005
# cooked__diced__lemon_peel 0.005
# cooked__diced__lime 0.005
# cooked__diced__macaroon 0.005
# cooked__diced__marshmallow 0.005
# cooked__diced__meatball 0.005
# cooked__diced__muffin 0.005
# cooked__diced__mushroom 0.005
# cooked__diced__mustard 0.005
# cooked__diced__olive 0.005
# cooked__diced__onion 0.005
# cooked__diced__orange 0.005
# cooked__diced__parsley 0.005
# cooked__diced__peppermint 0.005
# cooked__diced__pepperoni 0.005
# diced__frankfurter_bun 0.02
# diced__fruitcake 0.02
# diced__lamb 0.02
# diced__nectarine 0.02
# diced__omelet 0.02
# diced__peach 0.02
# diced__pizza_dough 0.02
# diced__pumpkin 0.02
# diced__quail 0.02
# diced__rib 0.02
# diced__snapper 0.02
# diced__spice_cookie_dough 0.02
# diced__tofu 0.02
# diced__white_turnip 0.02
# conchiglie 0.021413055419921875
# cooked__diced__arepa 0.0225
# cooked__diced__bagel_dough 0.0225
# cooked__diced__brownie 0.0225
# cooked__diced__cheesecake 0.0225
# cooked__diced__edible_cookie_dough 0.0225
# cooked__diced__garlic_bread 0.0225
# cooked__diced__gourd 0.0225
# cooked__diced__pizza 0.0225
# cooked__diced__pork 0.0225
# cooked__diced__quiche 0.0225
# cooked__diced__roll_dough 0.0225
# cooked__diced__tenderloin 0.0225
# cooked__diced__tuna 0.0225
# cooked__diced__veal 0.0225
# diced__arepa 0.0225
# diced__bagel_dough 0.0225
# diced__brownie 0.0225
# diced__cheesecake 0.0225
# diced__edible_cookie_dough 0.0225
# diced__garlic_bread 0.0225
# diced__gourd 0.0225
# diced__pizza 0.0225
# diced__pork 0.0225
# diced__quiche 0.0225
# diced__roll_dough 0.0225
# diced__tenderloin 0.0225
# diced__tuna 0.0225
# diced__veal 0.0225
# dried_cranberry 0.02274925009409587
# cooked__diced__cinnamon_roll 0.025
# cooked__diced__durian 0.025
# cooked__diced__kabob 0.025
# cooked__diced__pomelo 0.025
# cooked__diced__roast_beef 0.025
# cooked__diced__scone 0.025
# cooked__diced__steak 0.025
# cooked__diced__waffle 0.025
# diced__cinnamon_roll 0.025
# diced__durian 0.025
# diced__kabob 0.025
# diced__pomelo 0.025
# diced__roast_beef 0.025
# diced__scone 0.025
# diced__steak 0.025
# diced__waffle 0.025
# peanut 0.025699848143259683
# cashew 0.02629058265686035
# cooked__cashew 0.02629058265686035
# pistachio 0.02633625590801239
# crouton 0.028301711082458495
# cooked__peanut 0.029319030024788594
# cooked__diced__chicken_leg 0.03
# diced__chicken_leg 0.03
# cooked__penne 0.03130810546875
# penne 0.03130810546875
# cooked__pistachio 0.03224498494466146
# cooked__pecan 0.03299737548828125
# pecan 0.03299737548828125
# hair 0.056036298751831054
# wood_chip 0.07162424392700198
# rosemary 0.10125155067443847
# hay 0.10141212463378907
# cooked__scrambled_eggs 0.11597911834716797
# scrambled_eggs 0.11597911834716797

# %%
# Diced-not-cooked particle system record for Wensi's pass
import json
diced_not_cooked = []
for ps in missing_particle_not_cooked:
  if "diced__" in ps.name and "cooked__" not in ps.name:
    # Get the definition of the derivative parent
    parents = [da for da in ps.synset.derivative_ancestors if not da.is_derivative and "sliced__" not in da.name]
    definition = None
    if len(parents) > 0:
        assert len(parents) == 1, f"Expected 1 parent for {ps.name}, got {parents}"
        parent = parents[0]
        definition = parent.definition
    diced_not_cooked.append((ps.name, definition))
with open("diced_particle_systems.json", "w") as f:
  json.dump(diced_not_cooked, f, indent=4)
