# %%
import json
import pathlib

d = json.loads(pathlib.Path("/scr/ig_pipeline/artifacts/pipeline/validate_scenes.json").read_text())

# %%
import re
import collections

results = {}
issue_object_ids = collections.defaultdict(set)

issue_re = re.compile(r"^(.*) (position|orientation)")

for scene_name, result in d["scenes"].items():
  if result["success"]:
    results[scene_name] = "success"
  elif result["issues"]:
    results[scene_name] = "issues"
    for issue in result["issues"]:
      obj_name = re.match(issue_re, issue).group(1)
      obj_id = obj_name.split("-", 1)[0].rsplit("_", 2)[1]
      assert len(obj_id) == 6, obj_id
      issue_object_ids[obj_id].add(scene_name)
  else:
    results[scene_name] = "failure"

# %%
collections.Counter(results.values())
# Out:
# Counter({'issues': 44, 'success': 9, 'failure': 4})

# %%
from bddl.knowledge_base import *

# %%
# How many problematic objects are there?
len(issue_object_ids)
# Out:
# 183

# %%
objs_by_id = {obj.name.split("-")[-1]: obj for obj in Object.all_objects()}
issue_objects = {objs_by_id[k]: v for k, v in issue_object_ids.items()}

# %%
issue_objects
# Out:
# {Object(name='bottom_cabinet-bamfsz', original_name='bottom_cabinet-bamfsz', provider='objects/legacy_batch-00', ready=True, planned=True): {'Benevolence_2_int',
#   'Ihlen_1_int',
#   'Merom_1_int',
#   'Rs_garden',
#   'Rs_int',
#   'Wainscott_1_int',
#   'office_large',
#   'office_vendor_machine'},
#  Object(name='bottom_cabinet-jhymlr', original_name='bottom_cabinet-jhymlr', provider='objects/legacy_batch-00', ready=True, planned=True): {'Merom_1_int',
#   'Rs_garden',
#   'Rs_int',
#   'Wainscott_1_int',
#   'office_large'},
#  Object(name='coffee_table-qlmqyy', original_name='coffee_table-qlmqyy', provider='objects/legacy_batch-04', ready=True, planned=True): {'Wainscott_1_int'},
#  Object(name='table_lamp-xbfgjc', original_name='table_lamp-xbfgjc', provider='objects/legacy_batch-02', ready=True, planned=True): {'Ihlen_1_int',
#   'Merom_1_int',
#   'Rs_garden',
#   'Rs_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int',
#   'Wainscott_1_int'},
#  Object(name='door-ktydvs', original_name='door-ktydvs', provider='objects/legacy_batch-05', ready=True, planned=True): {'Benevolence_1_int',
#   'Ihlen_0_int',
#   'Ihlen_1_int',
#   'Rs_garden',
#   'Rs_int',
#   'Wainscott_0_int',
#   'Wainscott_1_int',
#   'restaurant_brunch'},
#  Object(name='door-ohagsq', original_name='door-ohagsq', provider='objects/legacy_batch-05', ready=True, planned=True): {'Beechwood_0_garden',
#   'Beechwood_0_int',
#   'Benevolence_0_int',
#   'Benevolence_1_int',
#   'Benevolence_2_int',
#   'Merom_0_int',
#   'Merom_1_int',
#   'Pomaria_0_int',
#   'Pomaria_1_int',
#   'Pomaria_2_int',
#   'Wainscott_0_int',
#   'Wainscott_1_int'},
#  Object(name='toilet-vtqdev', original_name='toilet-vtqdev', provider='objects/legacy_batch-04', ready=True, planned=True): {'Benevolence_0_int',
#   'Rs_garden',
#   'Rs_int'},
#  Object(name='bottom_cabinet-dajebq', original_name='bottom_cabinet-dajebq', provider='objects/legacy_batch-00', ready=True, planned=True): {'Merom_1_int',
#   'Rs_garden',
#   'Rs_int'},
#  Object(name='loudspeaker-bmpdyv', original_name='loudspeaker-bmpdyv', provider='objects/legacy_batch-09', ready=True, planned=True): {'Rs_garden',
#   'Rs_int'},
#  Object(name='pot_plant-jatssq', original_name='pot_plant-jatssq', provider='objects/legacy_batch-03', ready=True, planned=True): {'Rs_garden',
#   'Rs_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='pot_plant-udqjui', original_name='pot_plant-udqjui', provider='objects/legacy_batch-03', ready=True, planned=True): {'Merom_1_int',
#   'Rs_garden',
#   'Rs_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='shelf-owvfik', original_name='shelf-owvfik', provider='objects/legacy_batch-05', ready=True, planned=True): {'Rs_garden'},
#  Object(name='standing_tv-udotid', original_name='standing_tv-udotid', provider='objects/legacy_batch-06', ready=True, planned=True): {'Merom_0_int',
#   'Pomaria_0_garden',
#   'Pomaria_0_int',
#   'Pomaria_2_int',
#   'Rs_garden',
#   'Rs_int'},
#  Object(name='pedestal_table-nyprvh', original_name='pedestal_table-nyprvh', provider='scenes/Rs_garden', ready=True, planned=True): {'Rs_garden'},
#  Object(name='pot_plant-cecdwu', original_name='pot_plant-cecdwu', provider='scenes/Rs_garden', ready=True, planned=True): {'Rs_garden'},
#  Object(name='pot_plant-irffta', original_name='pot_plant-irffta', provider='scenes/Rs_garden', ready=True, planned=True): {'Rs_garden'},
#  Object(name='trash_can-cdzyew', original_name='trash_can-cdzyew', provider='scenes/public_restroom_white', ready=True, planned=True): {'hall_conference_large',
#   'hall_train_station',
#   'public_restroom_white',
#   'restaurant_asian'},
#  Object(name='toilet-mminnd', original_name='toilet-mminnd', provider='scenes/public_restroom_white', ready=True, planned=True): {'hall_conference_large',
#   'hall_train_station',
#   'public_restroom_white',
#   'restaurant_asian'},
#  Object(name='bottom_cabinet-immwzb', original_name='bottom_cabinet-immwzb', provider='objects/legacy_batch-00', ready=True, planned=True): {'Merom_0_int',
#   'office_cubicles_right',
#   'office_large'},
#  Object(name='bottom_cabinet-ojceew', original_name='bottom_cabinet-ojceew', provider='objects/legacy_batch-00', ready=True, planned=True): {'office_large'},
#  Object(name='bottom_cabinet-rvunhj', original_name='bottom_cabinet-rvunhj', provider='objects/legacy_batch-00', ready=True, planned=True): {'office_cubicles_right',
#   'office_large'},
#  Object(name='bottom_cabinet-zuwvdo', original_name='bottom_cabinet-zuwvdo', provider='objects/legacy_batch-00', ready=True, planned=True): {'office_large'},
#  Object(name='fridge-juwaoh', original_name='fridge-juwaoh', provider='objects/legacy_batch-06', ready=True, planned=True): {'office_large'},
#  Object(name='trash_can-glzckq', original_name='trash_can-glzckq', provider='objects/legacy_batch-04', ready=True, planned=True): {'office_large'},
#  Object(name='armchair-ccpgpe', original_name='armchair-ccpgpe', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='armchair-pfntgd', original_name='armchair-pfntgd', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='armchair-qerjol', original_name='armchair-qerjol', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='armchair-wkmkvd', original_name='armchair-wkmkvd', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='bottom_cabinet-todoa3', original_name='bottom_cabinet-todoa3', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='conference_table-qzmjrj', original_name='conference_table-qzmjrj', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='desk-puapey', original_name='desk-puapey', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='desk-qpuflh', original_name='desk-qpuflh', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='desk-wtlxfr', original_name='desk-wtlxfr', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='pedestal_table-aympln', original_name='pedestal_table-aympln', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='pedestal_table-dmghrm', original_name='pedestal_table-dmghrm', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='pedestal_table-ssnzie', original_name='pedestal_table-ssnzie', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='swivel_chair-srucpc', original_name='swivel_chair-srucpc', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='swivel_chair-wksozf', original_name='swivel_chair-wksozf', provider='scenes/office_large', ready=True, planned=True): {'office_large'},
#  Object(name='table_lamp-uzrovn', original_name='table_lamp-uzrovn', provider='scenes/hotel_suite_large', ready=True, planned=True): {'hotel_suite_large'},
#  Object(name='bottom_cabinet-jrhgeu', original_name='bottom_cabinet-jrhgeu', provider='objects/legacy_batch-00', ready=True, planned=True): {'Benevolence_2_int',
#   'Ihlen_0_int',
#   'Ihlen_1_int',
#   'Merom_1_int',
#   'Wainscott_0_int'},
#  Object(name='flower-mylblj', original_name='flower-mylblj', provider='scenes/Pomaria_0_garden', ready=True, planned=True): {'Pomaria_0_garden'},
#  Object(name='bed-siuxgz', original_name='bed-siuxgz', provider='scenes/house_double_floor_upper', ready=True, planned=True): {'house_double_floor_upper'},
#  Object(name='coffee_table-osroux', original_name='coffee_table-osroux', provider='scenes/house_double_floor_upper', ready=True, planned=True): {'house_double_floor_upper'},
#  Object(name='ottoman-qsnawv', original_name='ottoman-qsnawv', provider='scenes/house_double_floor_upper', ready=True, planned=True): {'house_double_floor_upper'},
#  Object(name='table_lamp-htmtsr', original_name='table_lamp-htmtsr', provider='scenes/house_double_floor_upper', ready=True, planned=True): {'house_double_floor_upper'},
#  Object(name='toilet-udiezm', original_name='toilet-udiezm', provider='scenes/house_double_floor_upper', ready=True, planned=True): {'grocery_store_asian',
#   'hall_glass_ceiling',
#   'house_double_floor_upper',
#   'office_cubicles_right',
#   'office_vendor_machine',
#   'public_restroom_brown',
#   'restaurant_urban'},
#  Object(name='display_case-khxpgc', original_name='trophy_case-khxpgc', provider='scenes/school_gym', ready=True, planned=True): {'school_biology',
#   'school_chemistry',
#   'school_computer_lab_and_infirmary',
#   'school_geography',
#   'school_gym'},
#  Object(name='gym_mat-ocxiiu', original_name='gym_mat-ocxiiu', provider='scenes/school_gym', ready=True, planned=True): {'school_gym'},
#  Object(name='pommel_horse-safhsw', original_name='pommel_horse-safhsw', provider='scenes/school_gym', ready=True, planned=True): {'school_gym'},
#  Object(name='display_fridge-oddyhd', original_name='display_fridge-oddyhd', provider='scenes/grocery_store_convenience', ready=True, planned=True): {'grocery_store_convenience'},
#  Object(name='display_fridge-wlxyjn', original_name='display_fridge-wlxyjn', provider='scenes/grocery_store_convenience', ready=True, planned=True): {'grocery_store_convenience'},
#  Object(name='cash_register-ykfcaz', original_name='cash_register-ykfcaz', provider='scenes/grocery_store_convenience', ready=True, planned=True): {'grocery_store_convenience'},
#  Object(name='microwave-ihxrvr', original_name='microwave-ihxrvr', provider='scenes/grocery_store_convenience', ready=True, planned=True): {'grocery_store_convenience'},
#  Object(name='recycling_bin-duugbb', original_name='trash_can-duugbb', provider='scenes/grocery_store_convenience', ready=True, planned=True): {'grocery_store_convenience'},
#  Object(name='bottom_cabinet-nyfebf', original_name='bottom_cabinet-nyfebf', provider='objects/legacy_batch-00', ready=True, planned=True): {'Merom_0_int'},
#  Object(name='cedar_chest-fwstpx', original_name='cedar_chest-fwstpx', provider='objects/legacy_batch-08', ready=True, planned=True): {'Beechwood_0_garden',
#   'Beechwood_0_int',
#   'Benevolence_1_int',
#   'Ihlen_1_int',
#   'Merom_0_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='trash_can-wklill', original_name='trash_can-wklill', provider='objects/legacy_batch-04', ready=True, planned=True): {'Merom_0_int'},
#  Object(name='monitor-rbqanz', original_name='monitor-rbqanz', provider='objects/legacy_batch-09', ready=True, planned=True): {'Pomaria_0_int'},
#  Object(name='pot_plant-ttijye', original_name='pot_plant-ttijye', provider='scenes/public_restroom_brown', ready=True, planned=True): {'grocery_store_asian',
#   'hall_glass_ceiling',
#   'office_cubicles_right',
#   'office_vendor_machine',
#   'public_restroom_brown',
#   'restaurant_urban'},
#  Object(name='armchair-hicyww', original_name='armchair-hicyww', provider='scenes/restaurant_brunch', ready=True, planned=True): {'restaurant_brunch'},
#  Object(name='armchair-jdtdpa', original_name='armchair-jdtdpa', provider='scenes/restaurant_brunch', ready=True, planned=True): {'restaurant_brunch'},
#  Object(name='armchair-rtbsof', original_name='armchair-rtbsof', provider='scenes/restaurant_brunch', ready=True, planned=True): {'restaurant_brunch'},
#  Object(name='armchair-ukuwuu', original_name='armchair-ukuwuu', provider='scenes/restaurant_brunch', ready=True, planned=True): {'restaurant_brunch'},
#  Object(name='breakfast_table-hmzwxn', original_name='breakfast_table-hmzwxn', provider='scenes/restaurant_brunch', ready=True, planned=True): {'restaurant_brunch'},
#  Object(name='bottom_cabinet-ccjinv', original_name='bottom_cabinet-ccjinv', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='shelf-eniafz', original_name='shelf-eniafz', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='bottom_cabinet-eluyvx', original_name='bottom_cabinet-eluyvx', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='serving_cart-ouddxy', original_name='cart-ouddxy', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='desk-ccxuey', original_name='desk-ccxuey', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='straight_chair-askrhs', original_name='straight_chair-askrhs', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='water_cooler-essxzr', original_name='water_cooler-essxzr', provider='scenes/school_computer_lab_and_infirmary', ready=True, planned=True): {'school_computer_lab_and_infirmary'},
#  Object(name='straight_chair-dzrlfn', original_name='straight_chair-dzrlfn', provider='scenes/restaurant_cafeteria', ready=True, planned=True): {'restaurant_cafeteria'},
#  Object(name='straight_chair-qkyfxr', original_name='straight_chair-qkyfxr', provider='scenes/restaurant_cafeteria', ready=True, planned=True): {'restaurant_cafeteria'},
#  Object(name='conference_table-hdomxc', original_name='conference_table-hdomxc', provider='scenes/office_vendor_machine', ready=True, planned=True): {'office_vendor_machine'},
#  Object(name='shelf-xsfeyi', original_name='shelf-xsfeyi', provider='scenes/office_vendor_machine', ready=True, planned=True): {'office_vendor_machine'},
#  Object(name='shelf-zdsmhe', original_name='shelf-zdsmhe', provider='scenes/office_vendor_machine', ready=True, planned=True): {'office_vendor_machine'},
#  Object(name='swivel_chair-xvpywp', original_name='swivel_chair-xvpywp', provider='scenes/office_vendor_machine', ready=True, planned=True): {'office_vendor_machine'},
#  Object(name='coffee_table-fqluyq', original_name='coffee_table-fqluyq', provider='objects/legacy_batch-04', ready=True, planned=True): {'Rs_int'},
#  Object(name='laptop-nvulcs', original_name='laptop-nvulcs', provider='objects/legacy_batch-11', ready=True, planned=True): {'Rs_int'},
#  Object(name='oven-ffitak', original_name='oven-ffitak', provider='scenes/house_single_floor', ready=True, planned=True): {'house_double_floor_lower',
#   'house_single_floor'},
#  Object(name='coffee_table-koagbh', original_name='coffee_table-koagbh', provider='scenes/house_double_floor_lower', ready=True, planned=True): {'house_double_floor_lower'},
#  Object(name='grill-sxfjac', original_name='grill-sxfjac', provider='scenes/house_double_floor_lower', ready=True, planned=True): {'house_double_floor_lower'},
#  Object(name='ottoman-wxodip', original_name='ottoman-wxodip', provider='scenes/house_double_floor_lower', ready=True, planned=True): {'house_double_floor_lower'},
#  Object(name='sofa-frlxgz', original_name='sofa-frlxgz', provider='scenes/house_double_floor_lower', ready=True, planned=True): {'house_double_floor_lower'},
#  Object(name='washer-ziomqg', original_name='washer-ziomqg', provider='scenes/house_double_floor_lower', ready=True, planned=True): {'house_double_floor_lower'},
#  Object(name='coffee_table-gcollb', original_name='coffee_table-gcollb', provider='objects/legacy_batch-04', ready=True, planned=True): {'Ihlen_1_int',
#   'Pomaria_1_int'},
#  Object(name='coffee_table-gpkbiw', original_name='coffee_table-gpkbiw', provider='objects/legacy_batch-04', ready=True, planned=True): {'Pomaria_1_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='conference_table-fpkmyw', original_name='conference_table-fpkmyw', provider='scenes/office_cubicles_left', ready=True, planned=True): {'office_cubicles_right'},
#  Object(name='swivel_chair-ryznxk', original_name='swivel_chair-ryznxk', provider='scenes/office_cubicles_left', ready=True, planned=True): {'office_cubicles_right'},
#  Object(name='swivel_chair-ucawqa', original_name='swivel_chair-ucawqa', provider='scenes/office_cubicles_left', ready=True, planned=True): {'office_cubicles_right'},
#  Object(name='top_cabinet-oztrra', original_name='top_cabinet-oztrra', provider='objects/legacy_batch-04', ready=True, planned=True): {'office_cubicles_right'},
#  Object(name='door-pwoerr', original_name='door-pwoerr', provider='scenes/office_cubicles_right', ready=True, planned=True): {'office_cubicles_right'},
#  Object(name='bottom_cabinet-qacthv', original_name='bottom_cabinet-qacthv', provider='objects/legacy_batch-00', ready=True, planned=True): {'Beechwood_0_garden',
#   'Beechwood_0_int'},
#  Object(name='straight_chair-vkgbbl', original_name='straight_chair-vkgbbl', provider='objects/legacy_batch-01', ready=True, planned=True): {'Beechwood_0_int'},
#  Object(name='console_table-emeeke', original_name='console_table-emeeke', provider='objects/legacy_batch-07', ready=True, planned=True): {'Benevolence_1_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='armchair-tcxiue', original_name='armchair-tcxiue', provider='objects/legacy_batch-02', ready=True, planned=True): {'Merom_1_int'},
#  Object(name='bed-zrumze', original_name='bed-zrumze', provider='objects/legacy_batch-03', ready=True, planned=True): {'Merom_1_int'},
#  Object(name='bottom_cabinet-slgzfc', original_name='bottom_cabinet-slgzfc', provider='objects/legacy_batch-00', ready=True, planned=True): {'Benevolence_2_int',
#   'Merom_1_int'},
#  Object(name='floor_lamp-vdxlda', original_name='floor_lamp-vdxlda', provider='objects/legacy_batch-06', ready=True, planned=True): {'Beechwood_0_garden',
#   'Merom_1_int'},
#  Object(name='armchair-bslhmj', original_name='armchair-bslhmj', provider='objects/legacy_batch-02', ready=True, planned=True): {'Ihlen_1_int',
#   'Wainscott_0_int'},
#  Object(name='armchair-xpcheg', original_name='armchair-xpcheg', provider='objects/legacy_batch-02', ready=True, planned=True): {'Wainscott_0_int'},
#  Object(name='breakfast_table-skczfi', original_name='breakfast_table-skczfi', provider='objects/legacy_batch-02', ready=True, planned=True): {'Beechwood_0_garden',
#   'Ihlen_1_int',
#   'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='straight_chair-amgwaw', original_name='straight_chair-amgwaw', provider='objects/legacy_batch-01', ready=True, planned=True): {'Wainscott_0_int'},
#  Object(name='swivel_chair-qtqitn', original_name='swivel_chair-qtqitn', provider='objects/legacy_batch-01', ready=True, planned=True): {'Wainscott_0_garden',
#   'Wainscott_0_int'},
#  Object(name='armchair-vzfhpv', original_name='armchair-vzfhpv', provider='scenes/restaurant_asian', ready=True, planned=True): {'restaurant_asian'},
#  Object(name='breakfast_table-iaritq', original_name='breakfast_table-iaritq', provider='scenes/restaurant_asian', ready=True, planned=True): {'restaurant_asian'},
#  Object(name='breakfast_table-yaanqr', original_name='breakfast_table-yaanqr', provider='scenes/restaurant_asian', ready=True, planned=True): {'restaurant_asian'},
#  Object(name='bottom_cabinet-pkdnbu', original_name='bottom_cabinet-pkdnbu', provider='objects/legacy_batch-00', ready=True, planned=True): {'commercial_kitchen_pans',
#   'restaurant_asian',
#   'restaurant_diner'},
#  Object(name='bottom_cabinet-ttmejh', original_name='bottom_cabinet-ttmejh', provider='objects/legacy_batch-00', ready=True, planned=True): {'commercial_kitchen_pans',
#   'restaurant_asian',
#   'restaurant_diner'},
#  Object(name='commercial_kitchen_table-nisnrl', original_name='commercial_kitchen_table-nisnrl', provider='scenes/commercial_kitchen_pans', ready=True, planned=True): {'commercial_kitchen_pans',
#   'restaurant_asian'},
#  Object(name='commercial_kitchen_table-vxvtec', original_name='commercial_kitchen_table-vxvtec', provider='scenes/commercial_kitchen_pans', ready=True, planned=True): {'commercial_kitchen_pans',
#   'restaurant_asian',
#   'restaurant_diner'},
#  Object(name='shelf-jpdtvg', original_name='shelf-jpdtvg', provider='scenes/commercial_kitchen_pans', ready=True, planned=True): {'commercial_kitchen_pans',
#   'restaurant_asian',
#   'restaurant_diner'},
#  Object(name='coffee_maker-pyttso', original_name='coffee_maker-pyttso', provider='objects/legacy_batch-10', ready=True, planned=True): {'Wainscott_0_garden'},
#  Object(name='armchair-ouqlrc', original_name='armchair-ouqlrc', provider='scenes/Wainscott_0_garden', ready=True, planned=True): {'Wainscott_0_garden'},
#  Object(name='garden_umbrella-bkfuvq', original_name='garden_umbrella-bkfuvq', provider='scenes/Wainscott_0_garden', ready=True, planned=True): {'Wainscott_0_garden'},
#  Object(name='pedestal_table-ifmhpn', original_name='pedestal_table-ifmhpn', provider='scenes/Wainscott_0_garden', ready=True, planned=True): {'Wainscott_0_garden'},
#  Object(name='pot_plant-eixiaq', original_name='pot_plant-eixiaq', provider='scenes/Wainscott_0_garden', ready=True, planned=True): {'Wainscott_0_garden'},
#  Object(name='sofa-ggaqxz', original_name='sofa-ggaqxz', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='sofa-hzzthj', original_name='sofa-hzzthj', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='sofa-uonbcs', original_name='sofa-uonbcs', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='sofa-yiniqe', original_name='sofa-yiniqe', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='armchair-irzlby', original_name='armchair-irzlby', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='breakfast_table-wdbwhc', original_name='breakfast_table-wdbwhc', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='pedestal_table-swgvxs', original_name='pedestal_table-swgvxs', provider='scenes/restaurant_urban', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='commercial_kitchen_table-bwlfnu', original_name='console_table-bwlfnu', provider='scenes/commercial_kitchen_fire_extinguisher', ready=True, planned=True): {'restaurant_urban'},
#  Object(name='straight_chair-enuago', original_name='straight_chair-enuago', provider='objects/legacy_batch-01', ready=True, planned=True): {'Ihlen_1_int'},
#  Object(name='toilet-sjjweo', original_name='toilet-sjjweo', provider='objects/legacy_batch-04', ready=True, planned=True): {'Ihlen_1_int'},
#  Object(name='armchair-qhcrgb', original_name='armchair-qhcrgb', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='breakfast_table-rhjoby', original_name='breakfast_table-rhjoby', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='coffee_table-rlsebe', original_name='coffee_table-rlsebe', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='floor_lamp-disyzd', original_name='floor_lamp-disyzd', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='water_glass-ggpnlr', original_name='glass-ggpnlr', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-bcirge', original_name='pot_plant-bcirge', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-bjwskl', original_name='pot_plant-bjwskl', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-lligdl', original_name='pot_plant-lligdl', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-nwfojy', original_name='pot_plant-nwfojy', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-rkqvba', original_name='pot_plant-rkqvba', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-xcybvc', original_name='pot_plant-xcybvc', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='pot_plant-yfqgfd', original_name='pot_plant-yfqgfd', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='sofa-hiphpn', original_name='sofa-hiphpn', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='taboret-ivtoxu', original_name='stool-ivtoxu', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='straight_chair-jgoolz', original_name='straight_chair-jgoolz', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='straight_chair-rljebp', original_name='straight_chair-rljebp', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='table_lamp-btdcou', original_name='table_lamp-btdcou', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='table_lamp-qgdwbh', original_name='table_lamp-qgdwbh', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='door-engzvq', original_name='door-engzvq', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='door-fnvpyu', original_name='door-fnvpyu', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='door-xqdonc', original_name='sliding_door-xqdonc', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='window-dbqbzg', original_name='window-dbqbzg', provider='scenes/house_single_floor', ready=True, planned=True): {'house_single_floor'},
#  Object(name='armchair-nibzys', original_name='armchair-nibzys', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='coffee_table-hbgcej', original_name='coffee_table-hbgcej', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='coffee_table-lpwbgm', original_name='coffee_table-lpwbgm', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='coffee_table-mjyitq', original_name='coffee_table-mjyitq', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='coffee_table-qplrhv', original_name='coffee_table-qplrhv', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='coffee_table-rkdwxe', original_name='coffee_table-rkdwxe', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='coffee_table-wwgaym', original_name='coffee_table-wwgaym', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='pot_plant-ibvdwh', original_name='pot_plant-ibvdwh', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='pot_plant-liqyem', original_name='pot_plant-liqyem', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='sofa-ahgkci', original_name='sofa-ahgkci', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='sofa-tlsxpc', original_name='sofa-tlsxpc', provider='scenes/Beechwood_0_garden', ready=True, planned=True): {'Beechwood_0_garden'},
#  Object(name='toilet-chuack', original_name='toilet-chuack', provider='objects/legacy_batch-04', ready=True, planned=True): {'Benevolence_2_int'},
#  Object(name='bottom_cabinet-olgoza', original_name='bottom_cabinet-olgoza', provider='objects/legacy_batch-00', ready=True, planned=True): {'restaurant_diner'},
#  Object(name='popcorn_machine-ignowl', original_name='popcorn_machine-ignowl', provider='scenes/restaurant_diner', ready=True, planned=True): {'restaurant_diner'},
#  Object(name='straight_chair-nntxvr', original_name='straight_chair-nntxvr', provider='scenes/restaurant_diner', ready=True, planned=True): {'restaurant_diner'},
#  Object(name='bottom_cabinet-kctcuj', original_name='bottom_cabinet-kctcuj', provider='scenes/school_biology', ready=True, planned=True): {'school_biology'},
#  Object(name='bottom_cabinet-qbdweu', original_name='bottom_cabinet-qbdweu', provider='scenes/school_biology', ready=True, planned=True): {'school_biology'},
#  Object(name='desk-ctaxkd', original_name='desk-ctaxkd', provider='scenes/school_biology', ready=True, planned=True): {'school_biology'},
#  Object(name='taboret-wjrpwg', original_name='stool-wjrpwg', provider='scenes/school_biology', ready=True, planned=True): {'school_biology'},
#  Object(name='swivel_chair-iyruig', original_name='swivel_chair-iyruig', provider='scenes/school_biology', ready=True, planned=True): {'school_biology'},
#  Object(name='breakfast_table-dcdtsr', original_name='breakfast_table-dcdtsr', provider='scenes/hall_conference_large', ready=True, planned=True): {'hall_conference_large'},
#  Object(name='straight_chair-hxuygm', original_name='straight_chair-hxuygm', provider='scenes/hall_conference_large', ready=True, planned=True): {'hall_conference_large'},
#  Object(name='bottom_cabinet-rmmvcd', original_name='bottom_cabinet-rmmvcd', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='lab_exhaust_hood-sdlkyk', original_name='lab_exhaust_hood-sdlkyk', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='shelf-gsksby', original_name='shelf-gsksby', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='desk-slgrxc', original_name='desk-slgrxc', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='desk-tmluxa', original_name='desk-tmluxa', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='straight_chair-fmdswa', original_name='straight_chair-fmdswa', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='swivel_chair-wcitvd', original_name='swivel_chair-wcitvd', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='lab_table-ishrsy', original_name='lab_table-ishrsy', provider='scenes/school_chemistry', ready=True, planned=True): {'school_chemistry'},
#  Object(name='door-ceddpg', original_name='door-ceddpg', provider='objects/legacy_batch-05', ready=True, planned=True): {'hotel_gym_spa'},
#  Object(name='door-nfrbch', original_name='door-nfrbch', provider='objects/legacy_batch-05', ready=True, planned=True): {'hotel_gym_spa'},
#  Object(name='free_weight_rack-fatvwt', original_name='free_weight_rack-fatvwt', provider='scenes/hotel_gym_spa', ready=True, planned=True): {'hotel_gym_spa'},
#  Object(name='bench_press_machine-pxlgue', original_name='bench_press_machine-pxlgue', provider='scenes/hotel_gym_spa', ready=True, planned=True): {'hotel_gym_spa'}}
