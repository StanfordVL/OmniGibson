# %%
import json, pathlib

# %%
by_target = {}
for p in pathlib.Path(r"D:\ig_pipeline").rglob("cad/*/*/artifacts/check_collisions.json"):
    with p.open() as f:
        target = "/".join(p.parts[-4:-2])
        by_target[target] = json.load(f)

# %%
by_target
# Out:
# {'scenes/Beechwood_0_garden': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Beechwood_0_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Beechwood_1_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Benevolence_0_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Benevolence_1_int': {'success': True,
#   'collisions': [],
#   'error': None},
#  'scenes/Benevolence_2_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/commercial_kitchen_fire_extinguisher': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 352, in main\n    scene = prepare_scene()\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 227, in prepare_scene\n    obj, base_link_frames[model_id]\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 51, in get_collision_meshes_relative_to_base\n    assert len(elems) <= 32, f"{obj.name} should not have more than 32 elements."\nAssertionError: C-electric_mixer-ceaeqf-0-base_link-Mcollision should not have more than 32 elements.\n'},
#  'scenes/commercial_kitchen_pans': {'success': False,
#   'collisions': [[['mkcndz', '0'], ['vikfyd', '0'], 19.007824891191376]],
#   'error': None},
#  'scenes/gates_bedroom': {'success': False,
#   'collisions': [[['fieiyo', '0'], ['zlyqcq', '0'], 46.15897489529061],
#    [['fsfsas', '0'], ['nvoqyl', '0'], 42.07577297727249]],
#   'error': None},
#  'scenes/grocery_store_asian': {'success': False,
#   'collisions': [[['akinbg', '0'], ['rqextk', '1'], 1462.4599571789104],
#    [['ekvdjq', '0'], ['odcaop', '0'], 63.08269313952454]],
#   'error': None},
#  'scenes/grocery_store_cafe': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/grocery_store_convenience': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/grocery_store_half_stocked': {'success': False,
#   'collisions': [[['jzvfvo', '0'], ['msovkn', '0'], 18.5775292152822]],
#   'error': None},
#  'scenes/hall_arch_wood': {'success': True, 'collisions': [], 'error': None},
#  'scenes/hall_conference_large': {'success': False,
#   'collisions': [[['dcdtsr', '150'], ['hxuygm', '419'], 22.49769492065286],
#    [['dcdtsr', '152'], ['hxuygm', '425'], 197.24054021401642],
#    [['dcdtsr', '149'], ['hxuygm', '422'], 176.1596040061961],
#    [['dcdtsr', '115'], ['hxuygm', '343'], 85.22381661716783],
#    [['dcdtsr', '119'], ['hxuygm', '361'], 276.9147616689952],
#    [['dcdtsr', '114'], ['hxuygm', '340'], 29.46820500344694],
#    [['dcdtsr', '116'], ['hxuygm', '364'], 72.40777883536947],
#    [['dcdtsr', '117'], ['hxuygm', '367'], 222.68621554256745],
#    [['dcdtsr', '66'], ['hxuygm', '405'], 27.040666511426195],
#    [['dcdtsr', '65'], ['hxuygm', '200'], 49.3954635762816],
#    [['hxuygm', '220'], ['hxuygm', '221'], 294.32802589123656],
#    [['opknyj', '0'], ['pdpkuw', '1'], 10.217196240967496],
#    [['dcdtsr', '58'], ['hxuygm', '176'], 70.17852049952558]],
#   'error': None},
#  'scenes/hall_glass_ceiling': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/hall_train_station': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/hotel_gym_spa': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/hotel_suite_large': {'success': False,
#   'collisions': [[['uzrovn', '1'], ['xftoqy', '0'], 18.759521484375],
#    [['maeowc', '1'], ['xftoqy', '0'], 58.95269892241157],
#    [['maeowc', '0'], ['xftoqy', '0'], 58.948324046351985],
#    [['maeowc', '2'], ['xftoqy', '0'], 58.95269892241163],
#    [['uzrovn', '0'], ['xftoqy', '0'], 21.260009765625],
#    [['kudtlk', '0'], ['uptpdr', '0'], 2137.54745331984]],
#   'error': None},
#  'scenes/hotel_suite_small': {'success': False,
#   'collisions': [[['frkbgd', '0'], ['lllojr', '0'], 18.6638386672671]],
#   'error': None},
#  'scenes/house_double_floor_lower': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/house_double_floor_upper': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/house_single_floor': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Ihlen_0_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Ihlen_1_int': {'success': True, 'collisions': [], 'error': None},
#  'scenes/Merom_0_garden': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Merom_0_int': {'success': True, 'collisions': [], 'error': None},
#  'scenes/Merom_1_int': {'success': True, 'collisions': [], 'error': None},
#  'scenes/office_bike': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/office_cubicles_left': {'success': False,
#   'collisions': [[['glpnus', '0'], ['xqxiyb', '0'], 10.543614338996122],
#    [['kraeyl', '0'], ['xqxiyb', '0'], 10.543695113278545]],
#   'error': None},
#  'scenes/office_cubicles_right': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 356, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/office_large': {'success': False,
#   'collisions': [[['roqtxf', '0'], ['stnoqf', '0'], 19.30050352044691],
#    [['nkjevu', '0'], ['stvajh', '0'], 23.775686008480605]],
#   'error': None},
#  'scenes/office_vendor_machine': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Pomaria_0_garden': {'success': False,
#   'collisions': [[['lgkqiw', '0'], ['poafwh', '0'], 35.54850518325088],
#    [['mfocvp', '0'], ['wsbuol', '0'], 31.44541984198395],
#    [['mfocvp', '1'], ['rrizax', '0'], 34.906584031261445],
#    [['chjeoy', '0'], ['rdvxkm', '0'], 20.21179431880762],
#    [['bpmwqx', '0'], ['yorgot', '0'], 55.21061718284733],
#    [['bpmwqx', '0'], ['ofgpit', '0'], 55.60470223757183],
#    [['cyanxu', '0'], ['ytelxk', '0'], 12.64666748046875]],
#   'error': None},
#  'scenes/Pomaria_0_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Pomaria_1_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Pomaria_2_int': {'success': True, 'collisions': [], 'error': None},
#  'scenes/public_restroom_blue': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/public_restroom_brown': {'success': True,
#   'collisions': [],
#   'error': None},
#  'scenes/public_restroom_futuristic': {'success': True,
#   'collisions': [],
#   'error': None},
#  'scenes/public_restroom_marble': {'success': True,
#   'collisions': [],
#   'error': None},
#  'scenes/public_restroom_white': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/restaurant_asian': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/restaurant_brunch': {'success': False,
#   'collisions': [[['hmzwxn', '0'], ['hmzwxn', '1'], 33.92944388979868],
#    [['hmzwxn', '0'], ['ukuwuu', '3'], 76.39798709599103],
#    [['hmzwxn', '1'], ['ukuwuu', '3'], 239.8445183366639],
#    [['cfqmqw', '0'], ['hdibix', '0'], 51.07885824507321],
#    [['hmzwxn', '1'], ['ukuwuu', '7'], 165.03203377566706],
#    [['hmzwxn', '6'], ['hmzwxn', '7'], 33.39355484556728],
#    [['hmzwxn', '7'], ['ukuwuu', '0'], 240.41793646257145],
#    [['hmzwxn', '7'], ['jdtdpa', '0'], 47.733226562367804],
#    [['hmzwxn', '6'], ['ukuwuu', '0'], 74.3713203643704],
#    [['hmzwxn', '4'], ['hmzwxn', '5'], 25.645066868532012],
#    [['hmzwxn', '4'], ['ukuwuu', '4'], 165.0320665464733]],
#   'error': None},
#  'scenes/restaurant_cafeteria': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/restaurant_diner': {'success': False,
#   'collisions': [[['cxcxqq', '0'], ['nlfgwe', '1'], 11.648868489060703],
#    [['nntxvr', '1'], ['xtujiy', '0'], 107.34944942953007],
#    [['cxcxqq', '0'], ['nlfgwe', '0'], 10.600833415985107],
#    [['nntxvr', '0'], ['xtujiy', '0'], 87.92575678401045],
#    [['xxftww', '0'], ['ysrhuw', '4'], 26.659013241729298],
#    [['xrchql', '0'], ['xxftww', '0'], 10.2841796875],
#    [['cxcxqq', '0'], ['nlfgwe', '2'], 11.648746013641357],
#    [['ccyiwn', '0'], ['cxcxqq', '0'], 18.62509924064875],
#    [['cxcxqq', '0'], ['jkisfk', '0'], 18.62509925693871]],
#   'error': None},
#  'scenes/restaurant_hotel': {'success': False,
#   'collisions': [[['scfdua', '0'], ['xsosmv', '0'], 328.92093240502714],
#    [['gzaggw', '0'], ['wtwwvl', '0'], 11.601761365838684],
#    [['mdglvs', '0'], ['wtwwvl', '0'], 21.25895648371352],
#    [['iqnove', '1'], ['wnrior', '8'], 651.5767457293131],
#    [['iqnove', '0'], ['wnrior', '9'], 651.5769647269293],
#    [['brrqkq', '1'], ['esfrjm', '12'], 345.70348469094654],
#    [['brrqkq', '1'], ['esfrjm', '11'], 331.46832479579973],
#    [['eivonw', '0'], ['jdilum', '3'], 12.98321533203125],
#    [['brrqkq', '1'], ['esfrjm', '8'], 345.70290400262957],
#    [['brrqkq', '1'], ['esfrjm', '7'], 331.46894762663646],
#    [['eivonw', '0'], ['qjiray', '0'], 17.88299560546875],
#    [['eivonw', '0'], ['jdilum', '1'], 12.98321533203125],
#    [['esfrjm', '20'], ['rfdlor', '0'], 81.58147401595963],
#    [['eivonw', '0'], ['jdilum', '0'], 12.98321533203125],
#    [['eivonw', '0'], ['jdilum', '2'], 12.98321533203125],
#    [['eivonw', '0'], ['wnrior', '2'], 19.345007571882377],
#    [['eivonw', '0'], ['wnrior', '0'], 19.344691399268527],
#    [['eivonw', '0'], ['wnrior', '1'], 19.34476647705111],
#    [['eivonw', '0'], ['wnrior', '3'], 19.345007571882377],
#    [['eivonw', '0'], ['wnrior', '7'], 19.345007571882377],
#    [['eivonw', '0'], ['wnrior', '6'], 19.345007571882434],
#    [['eivonw', '0'], ['wnrior', '5'], 19.344691399268584],
#    [['eivonw', '0'], ['wnrior', '4'], 19.344691399268584]],
#   'error': None},
#  'scenes/restaurant_urban': {'success': False,
#   'collisions': [[['mismdx', '0'], ['wdbwhc', '9'], 22.45575023373459],
#    [['irzlby', '12'], ['wdbwhc', '1'], 12.29913330078125],
#    [['irzlby', '31'], ['swgvxs', '2'], 13.997700433090927],
#    [['irzlby', '32'], ['swgvxs', '2'], 33.82720694208035],
#    [['nvnauj', '0'], ['wdbwhc', '3'], 50.37501917750433],
#    [['hhltqq', '0'], ['lymciz', '0'], 11.0614013671875],
#    [['hrrrbw', '0'], ['tgcuwh', '0'], 470.9084258843212],
#    [['dqvlff', '7'], ['hhltqq', '0'], 15.25482646612872],
#    [['tgcuwh', '0'], ['xemcsb', '0'], 390.0615360999294],
#    [['hhltqq', '0'], ['lymciz', '2'], 10.6781005859375],
#    [['hhltqq', '0'], ['lymciz', '3'], 10.6781005859375],
#    [['hhltqq', '0'], ['lymciz', '4'], 10.6781005859375],
#    [['hhltqq', '0'], ['lymciz', '1'], 10.0267333984375]],
#   'error': None},
#  'scenes/Rs_garden': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Rs_int': {'success': True, 'collisions': [], 'error': None},
#  'scenes/school_biology': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 356, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/school_chemistry': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/school_computer_lab_and_infirmary': {'success': False,
#   'collisions': [[['ckjxoo', '1'], ['zysogn', '0'], 10.247299194335938],
#    [['ckjxoo', '0'], ['ckjxoo', '1'], 152.05659552678745],
#    [['ckjxoo', '0'], ['iwdnuy', '0'], 45.514648254630316],
#    [['eniafz', '0'], ['xdyqvv', '0'], 24.947050022310577],
#    [['eluyvx', '0'], ['ouddxy', '0'], 15.169863211973166],
#    [['ccjinv', '2'], ['xiepks', '0'], 10.201186297937966],
#    [['xdyqvv', '0'], ['zypzqh', '1'], 40.92986991464534],
#    [['vedzwu', '0'], ['zypzqh', '1'], 21.615659889910148],
#    [['qloiuu', '0'], ['zypzqh', '1'], 38.38969342512064]],
#   'error': None},
#  'scenes/school_geography': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/school_gym': {'success': False,
#   'collisions': [[['ocxiiu', '10'], ['ocxiiu', '39'], 564.7447846932398],
#    [['ocxiiu', '33'], ['wnfyin', '1'], 65.73789268035978],
#    [['ocxiiu', '28'], ['wnfyin', '0'], 49.43936455749122],
#    [['ocxiiu', '39'], ['wnfyin', '0'], 65.7383621379795],
#    [['ocxiiu', '4'], ['ocxiiu', '40'], 251.98677602240065],
#    [['ocxiiu', '20'], ['wnfyin', '1'], 49.4349714795012],
#    [['ocxiiu', '14'], ['ocxiiu', '2'], 38.4860466285304],
#    [['ocxiiu', '19'], ['ocxiiu', '8'], 35.123474223778885],
#    [['ocxiiu', '0'], ['ocxiiu', '25'], 35.125060843844096],
#    [['ocxiiu', '19'], ['ocxiiu', '7'], 28.049169701331834],
#    [['ocxiiu', '14'], ['ocxiiu', '25'], 28.049169701331834],
#    [['ocxiiu', '1'], ['ocxiiu', '13'], 28.049169701331834],
#    [['ocxiiu', '13'], ['ocxiiu', '37'], 35.12347422362643],
#    [['ocxiiu', '18'], ['ocxiiu', '31'], 28.04559641960077],
#    [['ocxiiu', '2'], ['ocxiiu', '32'], 28.04559641977687],
#    [['ocxiiu', '1'], ['ocxiiu', '31'], 38.48604662867547],
#    [['ocxiiu', '24'], ['ocxiiu', '36'], 28.04559641960077],
#    [['ocxiiu', '36'], ['ocxiiu', '7'], 38.48604662867547],
#    [['ocxiiu', '23'], ['ocxiiu', '35'], 28.027533369260937],
#    [['ocxiiu', '38'], ['ocxiiu', '9'], 28.02753336908478],
#    [['ocxiiu', '12'], ['ocxiiu', '6'], 46.181332675307715],
#    [['ocxiiu', '26'], ['ocxiiu', '27'], 46.177317176963754],
#    [['gvzlnj', '0'], ['uatmde', '1'], 12.160035345048527],
#    [['gvzlnj', '0'], ['uatmde', '0'], 12.160035345048527]],
#   'error': None},
#  'scenes/Wainscott_0_garden': {'success': False,
#   'collisions': [[['bkfuvq', '1'], ['ifmhpn', '0'], 687.0548735968177],
#    [['gkfwyg', '0'], ['ouqlrc', '4'], 198.2735206224068],
#    [['gkfwyg', '0'], ['ouqlrc', '5'], 196.5969144441549],
#    [['gkfwyg', '0'], ['ifmhpn', '0'], 180.9296149950036],
#    [['gkfwyg', '0'], ['ouqlrc', '3'], 196.93222924871796],
#    [['bkfuvq', '1'], ['gkfwyg', '0'], 102.89468739929498],
#    [['deuron', '0'], ['gkfwyg', '0'], 111.57879298689488],
#    [['gkfwyg', '0'], ['jkhlnp', '0'], 107.17858026646095],
#    [['deuron', '1'], ['gkfwyg', '0'], 111.24593831587944],
#    [['fxtqtn', '0'], ['ymomhw', '0'], 34.71155283715742],
#    [['fxtqtn', '1'], ['ymomhw', '1'], 34.712459303681044],
#    [['gkfwyg', '0'], ['ouqlrc', '6'], 198.44148253762825],
#    [['dxypbs', '0'], ['gkfwyg', '0'], 206.81834518147355],
#    [['gkfwyg', '0'], ['ouqlrc', '2'], 197.2877819663579],
#    [['bkfuvq', '0'], ['ifmhpn', '1'], 687.0604614182946],
#    [['gkfwyg', '0'], ['ouqlrc', '7'], 197.2680476278933],
#    [['gkfwyg', '0'], ['ifmhpn', '1'], 180.90912600743022],
#    [['gkfwyg', '0'], ['ouqlrc', '1'], 197.282635608758],
#    [['bkfuvq', '0'], ['gkfwyg', '0'], 102.87498423136279],
#    [['gkfwyg', '0'], ['ouqlrc', '0'], 197.26109296347295],
#    [['eixiaq', '2'], ['gkfwyg', '0'], 202.81746214936697]],
#   'error': None},
#  'scenes/Wainscott_0_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'},
#  'scenes/Wainscott_1_int': {'success': False,
#   'collisions': [],
#   'error': 'Traceback (most recent call last):\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 354, in main\n    collisions = check_collisions(scene, use_clutter=use_clutter)\n  File "D:\\ig_pipeline\\b1k_pipeline\\max\\check_collisions.py", line 275, in check_collisions\n    cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)\nTypeError: scene_to_collision() got an unexpected keyword argument \'use_clutter\'\n'}}

# %%
# Find out the errors
for target, data in by_target.items():
    err = data["error"]
    if not err:
        continue
    print(target, err)
# Out:
# scenes/Beechwood_0_garden Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Beechwood_0_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Beechwood_1_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Benevolence_0_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Benevolence_2_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/commercial_kitchen_fire_extinguisher Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 352, in main
#     scene = prepare_scene()
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 227, in prepare_scene
#     obj, base_link_frames[model_id]
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 51, in get_collision_meshes_relative_to_base
#     assert len(elems) <= 32, f"{obj.name} should not have more than 32 elements."
# AssertionError: C-electric_mixer-ceaeqf-0-base_link-Mcollision should not have more than 32 elements.
#
# scenes/grocery_store_cafe Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/grocery_store_convenience Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/hall_glass_ceiling Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/hall_train_station Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/hotel_gym_spa Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/house_double_floor_lower Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/house_double_floor_upper Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/house_single_floor Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Ihlen_0_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Merom_0_garden Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/office_bike Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/office_cubicles_right Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 356, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/office_vendor_machine Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Pomaria_0_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Pomaria_1_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/public_restroom_blue Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/public_restroom_white Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/restaurant_asian Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/restaurant_cafeteria Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Rs_garden Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/school_biology Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 356, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/school_chemistry Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/school_geography Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Wainscott_0_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'
#
# scenes/Wainscott_1_int Traceback (most recent call last):
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 354, in main
#     collisions = check_collisions(scene, use_clutter=use_clutter)
#   File "D:\ig_pipeline\b1k_pipeline\max\check_collisions.py", line 275, in check_collisions
#     cm, _ = trimesh.collision.scene_to_collision(scene, use_clutter=use_clutter)
# TypeError: scene_to_collision() got an unexpected keyword argument 'use_clutter'

# %%
# Check the number of collisions per file and total
collisions = {t: len(data["collisions"]) for t, data in by_target.items()}
print(*sorted(collisions.items(), key=lambda x: x[1], reverse=True), sep="\n")
print("Total", sum(collisions.values()))
# Out:
# ('scenes/Beechwood_0_garden', 26)
# ('scenes/house_double_floor_upper', 24)
# ('scenes/restaurant_hotel', 23)
# ('scenes/Rs_garden', 23)
# ('scenes/restaurant_asian', 22)
# ('scenes/office_cubicles_right', 21)
# ('scenes/Wainscott_0_garden', 21)
# ('scenes/house_double_floor_lower', 16)
# ('scenes/office_vendor_machine', 16)
# ('scenes/hall_conference_large', 13)
# ('scenes/house_single_floor', 13)
# ('scenes/commercial_kitchen_fire_extinguisher', 12)
# ('scenes/hotel_gym_spa', 12)
# ('scenes/restaurant_cafeteria', 12)
# ('scenes/restaurant_brunch', 11)
# ('scenes/restaurant_urban', 11)
# ('scenes/school_computer_lab_and_infirmary', 10)
# ('scenes/grocery_store_convenience', 9)
# ('scenes/restaurant_diner', 9)
# ('scenes/Pomaria_0_garden', 7)
# ('scenes/hotel_suite_large', 5)
# ('scenes/public_restroom_white', 5)
# ('scenes/office_bike', 4)
# ('scenes/public_restroom_blue', 4)
# ('scenes/school_biology', 4)
# ('scenes/commercial_kitchen_pans', 3)
# ('scenes/Merom_0_garden', 3)
# ('scenes/school_geography', 3)
# ('scenes/office_large', 2)
# ('scenes/gates_bedroom', 1)
# ('scenes/grocery_store_cafe', 1)
# ('scenes/grocery_store_half_stocked', 1)
# ('scenes/hotel_suite_small', 1)
# ('scenes/school_gym', 1)
# ('scenes/Beechwood_0_int', 0)
# ('scenes/Beechwood_1_int', 0)
# ('scenes/Benevolence_0_int', 0)
# ('scenes/Benevolence_1_int', 0)
# ('scenes/Benevolence_2_int', 0)
# ('scenes/grocery_store_asian', 0)
# ('scenes/hall_arch_wood', 0)
# ('scenes/hall_glass_ceiling', 0)
# ('scenes/hall_train_station', 0)
# ('scenes/Ihlen_0_int', 0)
# ('scenes/Ihlen_1_int', 0)
# ('scenes/Merom_0_int', 0)
# ('scenes/Merom_1_int', 0)
# ('scenes/office_cubicles_left', 0)
# ('scenes/Pomaria_0_int', 0)
# ('scenes/Pomaria_1_int', 0)
# ('scenes/Pomaria_2_int', 0)
# ('scenes/public_restroom_brown', 0)
# ('scenes/public_restroom_futuristic', 0)
# ('scenes/public_restroom_marble', 0)
# ('scenes/Rs_int', 0)
# ('scenes/school_chemistry', 0)
# ('scenes/Wainscott_0_int', 0)
# ('scenes/Wainscott_1_int', 0)
# Total 349
