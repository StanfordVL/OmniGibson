"legacy_folder-piezyg",
"legacy_folder-poqpux",
"legacy_folderal-ttldpx",
"legacy_folding_chair-dqhazh",
"legacy_folding_chair-dxergu",
"legacy_folding_chair-vngcqu",
"legacy_foot_rule-ckywbx",
"legacy_foot_rule-rutqab",
"legacy_foot_rule-swlgkg",
"legacy_foot_rule-ujizkx",
"legacy_foot_rule-vmnaih",
"legacy_fridge-dszchb",
"legacy_fridge-hivvdf",
"legacy_fridge-hzgqdn",
"legacy_fridge-jtqazu",
"legacy_fridge-juwaoh",
"legacy_fridge-xyejdx",
"legacy_frying_pan-sfbdjn",
"legacy_gaming_table-ipdvzo",
"legacy_ginger-wqcasl",
"legacy_gingerbread-hxkcxs",
"legacy_glass-nfoydb",
"legacy_glass-slscza",
"legacy_glove-crbvcg",
"legacy_glove-hsaxtc",
"legacy_glove-rlzvry",
"legacy_gooseberry-cltzwx",
"legacy_grandfather_clock-icznug",
"legacy_grandfather_clock-oskfvo",
"legacy_grandfather_clock-veyqcp",
"legacy_grape-snjrhg",
"legacy_grape-uprbwp",
"legacy_grape-venbog",
"legacy_grater-jlkowf",
"legacy_green_onion-wzqhsg",
"legacy_green_onion_chopped-akrkjr",
"legacy_griddle-ryvqep",
"legacy_grill-ddlqye",
"legacy_guacamole-ajnjvv",
"legacy_guitar-cybisc",
"legacy_guitar-gysapt",
"legacy_guitar-hpqjrq",
"legacy_guitar-wjohag",
"legacy_gym_shoe-arigtn",
"legacy_gym_shoe-hwrvmy",
"legacy_gym_shoe-kmcbym",
"legacy_gym_shoe-lqzooz",
"legacy_gym_shoe-mjyyda",
"legacy_gym_shoe-pblxfp",
"legacy_gym_shoe-picdro",
"legacy_gym_shoe-qxecbh",
"legacy_gym_shoe-uuvwev",
"legacy_gym_shoe-wfmrpw",
"legacy_hairbrush-bdylnb",
"legacy_hamburger-fyswch",
"legacy_hammer-bbzlel",
"legacy_hand_towel-jaubic",
"legacy_hanger-ffecvd",
"legacy_hard_drive-ijibkm",
"legacy_hard_drive-ubjbsm",
"legacy_hardback-nubbfj",
"legacy_hat-avvknr",
"legacy_hat-ldxyyc",
"legacy_hat-wkrzep",
"legacy_hat-zymxgw",
"legacy_head_cabbage-tqohvs",
"legacy_headset-oytuam",
"legacy_heater-arfdpk",
"legacy_heater-dwmloz",
"legacy_heater-wntwxx",
"legacy_highchair-eteuuf",
"legacy_highchair-pahqnp",
"legacy_highlighter-tcsmqv",
"legacy_hinge-qroify",
"legacy_honing_steel-ugerym",
"legacy_hook-mdnfjr",
"legacy_hose-gavrvw",
"legacy_ice_cube-iiimgo",
"legacy_ink_cartridge-ltblou",
"legacy_ink_cartridge-oepuip",
"legacy_ink_cartridge-oinelo",
"legacy_iron-fzbvce",
"legacy_jam-vxjbjf",
"legacy_jar-fyfahz",
"legacy_jar-gtnmis",
"legacy_jar-irqkdw",
"legacy_jar-jbhdeu",
"legacy_jar-lnxzuy",
"legacy_jar-nzcbda",
"legacy_pineapple-jizmyh",
"legacy_pineapple-wfaybl",
"legacy_pineapple-zympwt",
"legacy_pistachio-bhirar",
"legacy_plate-iawoof",
"legacy_platter-csanbr",
"legacy_platter-ekjpdj",
"legacy_platter-hnlivs",
"legacy_platter-iadlti",
"legacy_platter-kiiamx",
"legacy_plum-dsybez",
"legacy_plum-rhaemq",
"legacy_plywood-fkmkqa",
"legacy_pocketknife-ngtgdn",
"legacy_pomegranate-tbwsgm",
"legacy_pomegranate-tldskr",
"legacy_pomegranate-vqybii",
"legacy_pomelo-ezckjt",
"legacy_pomelo-qecwzm",
"legacy_pool-xixlzr",
"legacy_pool_table-atjfhn",
"legacy_pop-bqretx",
"legacy_pop-chwjfu",
"legacy_pop-dlqmit",
"legacy_pop-drqbiy",
"legacy_pop-exapzb",
"legacy_pop-ghxeqz",
"legacy_pop-haoywb",
"legacy_pop-hjrwqb",
"legacy_pop-iloapr",
"legacy_pop-jnoksl",
"legacy_pop-kviogj",
"legacy_pop-mdznsn",
"legacy_pop-mhzttm",
"legacy_pop-mrrozu",
"legacy_pop-msmlud",
"legacy_pop-nepfjl",
"legacy_pop-nyupqh",
"legacy_pop-oeipjl",
"legacy_pop-oghrnk",
"legacy_pop-pfjzkn",
"legacy_pop-pvabxf",
"legacy_pop-pyrics",
"legacy_pop-rhclfg",
"legacy_pop-ribekf",
"legacy_pop-sevoto",
"legacy_pop-ubazru",
"legacy_pop-uwmchl",
"legacy_pop-uzbpnw",
"legacy_pop-vfjhav",
"legacy_pop-vszbvb",
"legacy_pop-wmqhul",
"legacy_pop-wrgmdt",
"legacy_pop-xlyult",
"legacy_pop-xoldze",
"legacy_pop-zxambx",
"legacy_pop_case-dufbnv",
"legacy_pop_case-gwgaqb",
"legacy_pop_case-noiyxv",
"legacy_pop_case-oarbks",
"legacy_pop_case-pldtgy",
"legacy_pop_case-qcfxec",
"legacy_pop_case-qwtbon",
"legacy_pop_case-rzhvvk",
"legacy_pop_case-seiatm",
"legacy_pop_case-sqiatv",
"legacy_pop_case-unmexe",
"legacy_pop_case-zfyatg",
"legacy_pop_case-zxguap",
"legacy_pork-ihekpm",
"legacy_pot_plant-azfbnd",
"legacy_pot_plant-ftbsdt",
"legacy_pot_plant-imhfnc",
"legacy_pot_plant-jatssq",
"legacy_pot_plant-jaunqh",
"legacy_pot_plant-kjnypo",
"legacy_pot_plant-kxmvco",
"legacy_pot_plant-nscddw",
"legacy_pot_plant-qbnaph",
"legacy_pot_plant-qcpges",
"legacy_pot_plant-qenqqv",
"legacy_pot_plant-quaxmw",
"legacy_pot_plant-udqjui",
"legacy_pot_plant-uvbpsf",
"legacy_pot_plant-vcwwrd",
"legacy_pot_plant-vyswzs",
"legacy_pot_plant-xlylfy",
"legacy_pot_plant-yvuagy",
"legacy_potato-bpwohr",
"legacy_potato-ljfitc",
"legacy_potato-lqjear",
"legacy_potato-ngjeog",
"legacy_powder_bottle-vfabau",
"legacy_pretzel-rmutwn",
"legacy_video_game-apjpos",
"legacy_video_game-ceaxsd",
"legacy_video_game-ckugyi",
"legacy_video_game-coiafo",
"legacy_video_game-lfdpse",
"legacy_video_game-muwcnf",
"legacy_video_game-ppnzqm",
"legacy_video_game-pujfzk",
"legacy_video_game-qsyyql",
"legacy_video_game-quzjuo",
"legacy_video_game-rzaxlj",
"legacy_video_game-veodkq",
"legacy_video_game-yyvkel",
"legacy_vinegar-snzyfk",
"legacy_walker-cmfdmv",
"legacy_walker-dgewyj",
"legacy_walker-glrsok",
"legacy_walker-ndexvs",
"legacy_walker-scbatq",
"legacy_walker-txpihh",
"legacy_walker-xnpimz",
"legacy_walker-ykjauh",
"legacy_wall_clock-przkmo",
"legacy_wall_clock-xevvel",
"legacy_wall_mounted_tv-gffrzl",
"legacy_wall_mounted_tv-ggfznh",
"legacy_wall_mounted_tv-ylvjhb",
"legacy_wall_socket-eaxxbm",
"legacy_walnut-nzqier",
"legacy_walnut-rmwtdh",
"legacy_washer-dobgmu",
"legacy_washer-jgyzhv",
"legacy_washer-mrgspe",
"legacy_washer-omeuop",
"legacy_washer-xusefg",
"legacy_washer-zgzvcv",
"legacy_watch-ghobzn",
"legacy_water-emquat",
"legacy_watermelon-slucoe",
"legacy_watermelon-zgmaqe",
"legacy_whiteboard-bqqmtc",
"legacy_window-bhwwja",
"legacy_window-bxydsr",
"legacy_window-fufios",
"legacy_window-ithrgo",
"legacy_window-iwcqsz",
"legacy_window-jzxtbv",
"legacy_window-mjssrd",
"legacy_window-qdkcdn",
"legacy_window-subxdn",
"legacy_window-tflzbx",
"legacy_window-tuztdv",
"legacy_window-ulnafj",
"legacy_wine_bottle-fzuiwy",
"legacy_wine_bottle-hnkiog",
"legacy_wine_bottle-vecadn",
"legacy_wrapped_gift-wpmksn",
"legacy_wreath-rkrxno",
"legacy_yogurt-kihdsj",
"legacy_zucchini-dybtwb",
"legacy_zucchini-ifvmal",
"legacy_zucchini-udvfaz",
"lemon_juice_bottle-fa",
"pastry-hz",
"roasting_pan-kd",
"shoe_box-gw",
"smoothie-ee",
"strawberries-eh",
]

# %%
import glob, json, pathlib, os
from tqdm.notebook import tqdm
# sanitychecks = list(glob.glob(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects\*\artifacts\export_meshes.json"))
o_jsons = {}
for target in tqdm(obj_targets):
    x = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "artifacts/object_list.json"
    if not x.exists():
        o_jsons[target] = {"success": False, "error": "missing json"}
        continue
    with open(x, "r") as f:
        name = str(pathlib.Path(x))  # .parts[-3]
        o_jsons[target] = json.load(f)

# %%
failed_o = {x for x, j in o_jsons.items() if not j["success"] or not j["provided_objects"]}
print("dvc add", " ".join(f'cad/objects/{x}/processed.max' for x in failed_o))
print("dvc add", " ".join(f'cad/objects/{x}/textures' for x in failed_o))
# print("\n".join(f'rm -Recurse cad/objects/{x}' for x in failed_o))

# %%
len(failed_o)

# %%
import glob, json, pathlib, os
from tqdm.notebook import tqdm
# sanitychecks = list(glob.glob(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects\*\artifacts\export_meshes.json"))
s_jsons = {}
for target in tqdm(obj_targets):
    x = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "artifacts/sanitycheck.json"
    if not x.exists():
        s_jsons[target] = {"success": False, "error": "missing json"}
        continue
    with open(x, "r") as f:
        name = str(pathlib.Path(x))  # .parts[-3]
        s_jsons[target] = json.load(f)

# %%
failed_s = {x for x, j in s_jsons.items() if not j["success"]}
print("dvc repro", " ".join(f'sanitycheck@objects/{x}' for x in failed_s))

# %%
import glob, json, pathlib, os
from tqdm.notebook import tqdm
# sanitychecks = list(glob.glob(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects\*\artifacts\export_meshes.json"))
m_jsons = {}
for target in tqdm(obj_targets):
    x = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "artifacts/export_meshes.json"
    if not x.exists():
        m_jsons[target] = {"success": False, "error": "missing json"}
        continue
    x2 = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "artifacts/export_meshes.success"
    if not x2.exists():
        m_jsons[target] = {"success": False, "error": "missing succ"}
        continue
    with open(x, "r") as f:
        name = str(pathlib.Path(x))  # .parts[-3]
        m_jsons[target] = json.load(f)

# %%
failed_m = {x for x, j in m_jsons.items() if not j["success"]}
print("dvc repro", " ".join(f'export_meshes@objects/{x}' for x in failed_m))

# %%
for x in failed_m:
    print(x, m_jsons[x])

# %%
import glob, json, pathlib, os
from tqdm.notebook import tqdm
# sanitychecks = list(glob.glob(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects\*\artifacts\export_meshes.json"))
jsons = {}
for target in tqdm(obj_targets):
    x = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "artifacts/export_objs.json"
    if not x.exists():
        jsons[target] = {"success": False, "error": "missing"}
        continue
    #x2 = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "artifacts/export_objs.success"
    #if not x2.exists():
    #    jsons[target] = {"success": False, "error": "missing succ"}
    #    continue
    with open(x, "r") as f:
        name = str(pathlib.Path(x))  # .parts[-3]
        jsons[target] = json.load(f)

# %%
import time
total = len(jsons)
failed = {name for name, x in jsons.items() if not x["success"]}
total, len(failed)

# %%
from tqdm import tqdm
import pathlib
t_failed = []
for target in tqdm(obj_targets):
    x = pathlib.Path(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects") / target / "textures"
    if not x.exists():
        print("No ", x)
        continue
    if len(list(x.glob('*'))) == 0:
        t_failed.append(target)
        continue
        
print(len(t_failed))
print(t_failed)
# Out:
#   0%|                                                                                         | 0/1227 [00:00<?, ?it/s]
# No  D:\BEHAVIOR-1K\asset_pipeline\cad\objects\ice_cubes\textures
# 100%|█████████████████████████████████████████████████████████████████████████████| 1227/1227 [00:02<00:00, 472.13it/s]
# 0
# []

# %%
print("dvc add", " ".join(f'cad/objects/{x}/processed.max' for x in t_failed))
print("dvc add", " ".join(f'cad/objects/{x}/textures' for x in t_failed))
# print("\n".join(f'rm -Recurse cad/objects/{x}' for x in t_failed))
# Out:
# dvc add cad/objects/legacy_basil-bebpnf/processed.max cad/objects/legacy_basket-xhdtjn/processed.max cad/objects/legacy_bench-pcymmc/processed.max cad/objects/legacy_bench-zfpjkj/processed.max cad/objects/legacy_bowl-adciys/processed.max cad/objects/legacy_briefcase-rxvbea/processed.max cad/objects/legacy_broccoli-wsxavx/processed.max cad/objects/legacy_christmas_tree_decorated-wakmhn/processed.max cad/objects/legacy_coconut-nnankv/processed.max cad/objects/legacy_coconut-qwriih/processed.max cad/objects/legacy_coconut-txtabm/processed.max cad/objects/legacy_container_cranberry-fbcpsl/processed.max cad/objects/legacy_desk-cjhriz/processed.max cad/objects/legacy_kiwi-khupqq/processed.max cad/objects/legacy_kiwi-ukwism/processed.max cad/objects/legacy_lid-kuibhu/processed.max cad/objects/legacy_notebook-svisnb/processed.max cad/objects/legacy_rocking_chair-wkduul/processed.max cad/objects/legacy_roller-nbwihe/processed.max cad/objects/legacy_shelf-njwsoa/processed.max cad/objects/legac
# ...

# %%
for fail in failed:
    print(fail, jsons[fail], "\n")

# %%
# Unprotect failures
print("dvc unprotect", " ".join("cad/objects/" + x + "/textures" for x in sorted(failed_s | failed_m | failed)))

# %%
failed_list = sorted([pathlib.Path(x).name for x in glob.glob("D:/BEHAVIOR-1K/asset_pipeline/cad/objects/legacy*")])
groups_of = 100
for i in range(len(failed_list) // groups_of + 1):
    # print("dvc repro -s -f", " ".join("export_objs@objects/" + x for x in failed_list[i*groups_of:(i+1)*groups_of]))
    print("dvc add", " ".join("cad/objects/" + x + "/processed.max" for x in failed_list[i*groups_of:(i+1)*groups_of]))
print("echo done")

# %%
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_armchair_xpcheg\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_bed_smmmaf\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_bed_zrumze\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_bottom_cabinet_rvpunw\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_coffee_table_fqluyq\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_coffee_table_qlmqyy\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_oven_fexqbj\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_sofa_qnnwfx\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_sofa_uixwiv\processed.max
D:\BEHAVIOR-1K\asset_pipeline\cad\objects\legacy_sofa_xhxdqf\processed.max
