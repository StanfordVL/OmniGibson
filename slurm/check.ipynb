# %%
import pathlib, json
import pandas as pd
from tqdm.notebook import tqdm

# %%
hssd_output_root = pathlib.Path("/fsx-siro/cgokmen/behavior-data2/hssd")
hssd_root = pathlib.Path("/fsx-siro/cgokmen/habitat-data/scene_datasets/hssd-hab")
hssd_models_root = pathlib.Path("/fsx-siro/cgokmen/hssd-models")
hssd_metadata = pd.read_csv(hssd_root / "metadata/hssd_obj_semantics_condensed.csv")
hssd_models = sorted([fn for fn in hssd_models_root.rglob("*.glb") if "filteredSupportSurface" not in fn.name and "collider" not in fn.name])

hssd_mapping = {}
hssd_missing_count = 0
for obj_path in tqdm(hssd_models):
    if obj_path.parts[-2] == "openings":
        category = "openings"
    elif obj_path.parts[-2] == "stages":
        category = "stages"
    else:
        # Check if it exists in the dataframe
        rows = hssd_metadata[hssd_metadata["Object Hash"] == obj_path.stem]
        if not rows.empty:
            category = rows.iloc[0][
                "Semantic Category:\nCONDENSED\n\nThis is an effort to condense the semantic categories by a couple hundred"
            ]
        else:
            print(f"Warning: {obj_path.stem} not found in metadata, defaulting to 'object'")
            category = "object"

    # Sanitize both category and model names to contain only letters (and underscores for category)
    category = "".join(c if c.isalnum() or c == "_" else "_" for c in category.lower())
    model = "hssd" + "".join(c if c.isalnum() else "" for c in obj_path.stem)

    model_root = hssd_output_root / "objects" / category / model
    success_file = model_root / "import.success"
    if not success_file.exists():
        print(f"Missing success file for {obj_path}: {success_file}")
        hssd_missing_count += 1
    
    assert obj_path.stem not in hssd_mapping, f"Filename overlap! {obj_path}"
    hssd_mapping[obj_path.stem] = (category, model)

(hssd_output_root / "object_name_mapping.json").write_text(json.dumps(hssd_mapping, indent=4))
print(hssd_missing_count, "missing hssd mappings")
# Out:
#   0%|          | 0/14267 [00:00<?, ?it/s]
# Missing success file for /fsx-siro/cgokmen/hssd-models/objects/6/620aac904b075417a57a155ba2b43268ea5a3464.glb: /fsx-siro/cgokmen/behavior-data2/hssd/objects/lamp/hssd620aac904b075417a57a155ba2b43268ea5a3464/import.success
# Missing success file for /fsx-siro/cgokmen/hssd-models/objects/9/917b764eeecca7c6224ed9dc3cf5ed13034b42f7.glb: /fsx-siro/cgokmen/behavior-data2/hssd/objects/table/hssd917b764eeecca7c6224ed9dc3cf5ed13034b42f7/import.success
# Missing success file for /fsx-siro/cgokmen/hssd-models/objects/c/c4aca10e8652ed3704c50608a556afd9ff0a912a.glb: /fsx-siro/cgokmen/behavior-data2/hssd/objects/hanger/hssdc4aca10e8652ed3704c50608a556afd9ff0a912a/import.success
# Missing success file for /fsx-siro/cgokmen/hssd-models/objects/f/f8c471802c4fd0622b2367a4f2ae7c58652aece7.glb: /fsx-siro/cgokmen/behavior-data2/hssd/objects/globe/hssdf8c471802c4fd0622b2367a4f2ae7c58652aece7/import.success
# Missing success file for /fsx-siro/cgokmen/hssd-models/objects/openings/218-171.glb: /fsx-siro/cgokmen/behavior-data2/hssd/objects/openings/hssd218171/import.success
# Missing success file for /fsx-siro/cgokmen/hssd-models/objects/openings/3760-53.glb: /fsx-siro/cgokmen/behavior-data2/hssd/objects/openings/hssd376053/import.success
# 6 missing hssd mappings

# %%
spoc_output_root = pathlib.Path("/fsx-siro/cgokmen/behavior-data2/spoc")
spoc_root = pathlib.Path("/fsx-siro/cgokmen/procthor/assets/2023_07_28")
spoc_annots = json.loads((spoc_root / "annotations.json").read_text())
spoc_models = sorted(spoc_root.glob("assets/*/*.glb"))

spoc_mapping = {}
spoc_missing_count = 0
for obj_path in tqdm(spoc_models):
    if obj_path.stem not in spoc_annots:
        print(f"Skipping {obj_path.stem} as it has no annotations")
        continue
    this_annots = spoc_annots[obj_path.stem]

    # Sanitize both category and model names to contain only letters (and underscores for category)
    category = "".join(c if c.isalnum() or c == "_" else "_" for c in this_annots["category"].lower())
    model = "spoc" + "".join(c if c.isalnum() else "" for c in obj_path.stem.lower())

    model_root = spoc_output_root / "objects" / category / model
    success_file = model_root / "import.success"

    if not success_file.exists():
        print(f"Missing success file for {obj_path}: {success_file}")
        spoc_missing_count += 1

    assert obj_path.stem not in spoc_mapping, f"Filename overlap! {obj_path}"
    spoc_mapping[obj_path.stem] = (category, model)

(spoc_output_root / "object_name_mapping.json").write_text(json.dumps(spoc_mapping, indent=4))
print(spoc_missing_count, "missing spoc mappings")
# Out:
#   0%|          | 0/38476 [00:00<?, ?it/s]
# Missing success file for /fsx-siro/cgokmen/procthor/assets/2023_07_28/assets/75b9ea70272249dcbe812999297fd27f/75b9ea70272249dcbe812999297fd27f.glb: /fsx-siro/cgokmen/behavior-data2/spoc/objects/crate/spoc75b9ea70272249dcbe812999297fd27f/import.success
# 1 missing spoc mappings

# %%
ai2_output_root = pathlib.Path("/fsx-siro/cgokmen/behavior-data2/ai2thor")
ai2_hab_root = pathlib.Path("/fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab")
ai2_uc_root = pathlib.Path("/fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed")
ai2_categories = pd.read_csv("/fsx-siro/cgokmen/procthor/ai2thor/ai2thor_categories.csv")
model2cat = dict(zip(ai2_categories["Model Name"], ai2_categories["Category"]))

ai2_main_models = set(ai2_uc_root.glob("assets/objects/*.glb"))
print(len(ai2_main_models), "main models")
ai2_stage_models = set(ai2_hab_root.glob("assets/stages/**/*.glb"))
print(len(ai2_stage_models), "stage models")
ai2_models = sorted(ai2_main_models | ai2_stage_models)
print(len(ai2_models), "models")

ai2_mapping = {}
ai2_missing_count = 0
for obj_path in tqdm(ai2_models):
    if obj_path in ai2_stage_models:
        # For stages, the file hierarchy is a bit different.
        stages_dir = ai2_hab_root / "assets" / "stages"
        assert stages_dir in obj_path.parents, f"Stage GLB {obj_path} is not in stages directory"
        # Get the index of stages_dir in the parents list
        idx = obj_path.parents.index(stages_dir)
        # The type is the next parent directory
        stage_type_dir = obj_path.parents[idx - 1]
        # If the filename doesn't already start with the type, rename it
        category = "stages"
        model = obj_path.stem
        if not model.startswith(stage_type_dir.name):
            model = f"{stage_type_dir.name}-{model}"
    else:
        model = obj_path.stem
        category = model2cat[model]

    # Sanitize both category and model names to contain only letters (and underscores for category)
    category = "".join(c if c.isalnum() or c == "_" else "_" for c in category.lower())
    model = "ai2thor" + "".join(c if c.isalnum() else "" for c in obj_path.stem)

    model_root = ai2_output_root / "objects" / category / model
    success_file = model_root / "import.success"
    if not success_file.exists():
        print(f"Missing success file for {obj_path}: {success_file}")
        ai2_missing_count += 1

    relpath = obj_path.relative_to(ai2_hab_root) if obj_path in ai2_stage_models else obj_path.relative_to(ai2_uc_root)
    assert obj_path.stem not in ai2_mapping, f"Filename overlap! {obj_path}"
    ai2_mapping[obj_path.stem] = (category, model)

(ai2_output_root / "object_name_mapping.json").write_text(json.dumps(ai2_mapping, indent=4))
print(ai2_missing_count, "missing ai2 mappings")
# Out:
# 5320 main models
# 12235 stage models
# 17555 models
#   0%|          | 0/17555 [00:00<?, ?it/s]
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/1/ProcTHOR-Test-114.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTest114/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/2/ProcTHOR-Train-219.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain219/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/2/ProcTHOR-Train-448.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain448/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/2/ProcTHOR-Train-528.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain528/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/2/ProcTHOR-Train-533.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain533/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/2/ProcTHOR-Train-622.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain622/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/2/ProcTHOR-Train-707.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain707/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/3/ProcTHOR-Train-1085.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain1085/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/3/ProcTHOR-Train-1787.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain1787/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/4/ProcTHOR-Train-2224.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain2224/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/4/ProcTHOR-Train-2401.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain2401/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/4/ProcTHOR-Train-2808.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain2808/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/4/ProcTHOR-Train-2924.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain2924/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/6/ProcTHOR-Train-4399.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain4399/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/6/ProcTHOR-Train-4488.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain4488/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/6/ProcTHOR-Train-4936.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain4936/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/7/ProcTHOR-Train-5166.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain5166/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/7/ProcTHOR-Train-5178.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain5178/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/7/ProcTHOR-Train-5608.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain5608/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/8/ProcTHOR-Train-6162.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain6162/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/8/ProcTHOR-Train-6232.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain6232/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/8/ProcTHOR-Train-6346.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain6346/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/8/ProcTHOR-Train-6366.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain6366/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/8/ProcTHOR-Train-6372.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain6372/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/8/ProcTHOR-Train-6572.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain6572/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/9/ProcTHOR-Train-7603.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain7603/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/9/ProcTHOR-Train-7654.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain7654/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/9/ProcTHOR-Train-7666.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain7666/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/b/ProcTHOR-Train-9274.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain9274/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/b/ProcTHOR-Train-9281.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain9281/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/b/ProcTHOR-Train-9478.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain9478/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/b/ProcTHOR-Train-9933.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain9933/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/b/ProcTHOR-Train-9938.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORTrain9938/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/c/ProcTHOR-Val-121.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORVal121/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/c/ProcTHOR-Val-191.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORVal191/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/c/ProcTHOR-Val-648.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORVal648/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/c/ProcTHOR-Val-670.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORVal670/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/ProcTHOR/c/ProcTHOR-Val-801.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorProcTHORVal801/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/iTHOR/FloorPlan204_physics.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorFloorPlan204physics/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thor-hab/assets/stages/iTHOR/FloorPlan522_physics.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/stages/ai2thorFloorPlan522physics/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/Coffee_Table_315_1.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/coffee_table/ai2thorCoffeeTable3151/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/Desk_301_1.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/desk/ai2thorDesk3011/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/Dresser_210_2_1.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/dresser/ai2thorDresser21021/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan10_physics-Cabinet_47fc321b.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects
glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/shower_door/ai2thorFloorPlan428physicsShowerDoor876cda39/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan429_physics-Window_9211f74b.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan429physicsWindow9211f74b/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-CounterTop_d2ae5fa0.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/countertop/ai2thorFloorPlan430physicsCounterTopd2ae5fa0/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-ShowerDoor_ba1f59f4.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/shower_door/ai2thorFloorPlan430physicsShowerDoorba1f59f4/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-ShowerGlass_50a177ce.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/shower_glass/ai2thorFloorPlan430physicsShowerGlass50a177ce/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-Window_67928466.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan430physicsWindow67928466/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-Window_8a389dbc.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan430physicsWindow8a389dbc/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-Window_a61de043.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan430physicsWindowa61de043/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan430_physics-Window_b4845eb7.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan430physicsWindowb4845eb7/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan4_physics-Window_8da09bf1.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan4physicsWindow8da09bf1/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan4_physics-Window_d350e675.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan4physicsWindowd350e675/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan501_physics-Missing_Prefab_with_guid:_40f570e3076810342bb5161a183a0a9f.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/object/ai2thorFloorPlan501physicsMissingPrefabwithguid40f570e3076810342bb5161a183a0a9f/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan501_physics-OpenableDoor1.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/door/ai2thorFloorPlan501physicsOpenableDoor1/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan505_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan505physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan505_physics-closet_bar_01.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan505physicsclosetbar01/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan507_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan507physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan507_physics-closet_bar_01.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan507physicsclosetbar01/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan512_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan512physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan512_physics-closet_bar_01.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan512physicsclosetbar01/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan513_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan513physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan518_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan518physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan519_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan519physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan521_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan521physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan521_physics-closet_bar_01.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan521physicsclosetbar01/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan523_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan523physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan527_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan527physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan529_physics-closet_bar.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan529physicsclosetbar/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan529_physics-closet_bar_01.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan529physicsclosetbar01/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan529_physics-closet_bar_02.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/closet_bar/ai2thorFloorPlan529physicsclosetbar02/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan7_physics-Window_0b4820f6.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan7physicsWindow0b4820f6/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan8_physics-Window_f74feaf0.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan8physicsWindowf74feaf0/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/FloorPlan9_physics-Window_5b0957c7.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/window/ai2thorFloorPlan9physicsWindow5b0957c7/import.success
# Missing success file for /fsx-siro/cgokmen/procthor/ai2thor/ai2thorhab-uncompressed/assets/objects/RoboTHOR_hemnes_day_bed.glb: /fsx-siro/cgokmen/behavior-data2/ai2thor/objects/bed/ai2thorRoboTHORhemnesdaybed/import.success
# 230 missing ai2 mappings
